# %% [markdown]
# # Final Project - Reinforcements Learning
# Hello dear students,<br> this is the template notebook. Please click on the "File" tab and then on "Save a copy into drive".
#
# ---
# <br>
#
# ### Name and ID:
# Student 1: Avraham Raviv, 204355390
# <br>
# Student 2: Yevgeni Berkovitch, 317079234
# <br><br>
# <img src="https://play-lh.googleusercontent.com/e_oKlKPISbgdzut1H9opevS7-LTB8-8lsmpCdMkhlnqFenZhpjxbLmx7l158-xQQCIY">
#
# ### https://github.com/mpSchrader/gym-sokoban

# %% [markdown]
# # Installs

# %%
# %%capture
# !sudo apt-get update
# !sudo apt-get install -y xvfb ffmpeg freeglut3-dev
# !pip install 'imageio==2.4.0'
# !pip install gym
# !pip install pygame
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet
# !pip install gym
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install gym_sokoban

# !imageio_download_bin ffmpeg

# %% [markdown]
# # Imports

# %%
import random
import time

import numpy as np
import matplotlib.pyplot as plt

import base64
import imageio
from pyvirtualdisplay import Display
from IPython.display import HTML

import gym
from gym import error, spaces, utils
from soko_pap import *

from collections import deque
from queue import PriorityQueue

from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten

# %%
# %matplotlib inline

# %%
imageio.plugins.ffmpeg.download()

# %%
from gym import logger as gymlogger
gymlogger.set_level(40) # error only

# %% [markdown]
# # Display utils
# The cell below contains the video display configuration. No need to make changes here.

# %%
def embed_mp4(filename):
    """Embeds an mp4 file in the notebook."""
    video = open(filename,'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())

    return HTML(tag)

# %% [markdown]
# # Utils

# %%
def get_distances(room_state):
    for i in range(room_state.shape[0]):
        for j in range(room_state.shape[1]):
            if room_state[i][j] == 2:
                target = (i, j)

    distances = np.zeros(shape=room_state.shape)
    visited_cells = set()
    cell_queue = deque()

    visited_cells.add(target)
    cell_queue.appendleft(target)

    while len(cell_queue) != 0:
        cell = cell_queue.pop()
        distance = distances[cell[0]][cell[1]]
        for x,y in ((1,0), (-1,-0), (0,1), (0,-1)):
            next_cell_x, next_cell_y = cell[0]+x, cell[1]+y
            if room_state[next_cell_x][next_cell_y] != 0 and not (next_cell_x, next_cell_y) in visited_cells:
                distances[next_cell_x][next_cell_y] = distance + 1
                visited_cells.add((next_cell_x, next_cell_y))
                cell_queue.appendleft((next_cell_x, next_cell_y))
                
    return distances   

def calc_distances(room_state, distances):
    box = None
    mover = None
    for i in range(room_state.shape[0]):
        for j in range(room_state.shape[1]):            
            if room_state[i][j] == 4:
                box = (i,j)
            
            if room_state[i][j] == 5:
                mover = (i,j)
    
    return mover, box, distances[box[0]][box[1]]   

def box2target_change_reward(room_state, next_room_state, distances):
    if np.array_equal(room_state, next_room_state):
        return -0.5
    
    mover, box, t2b = calc_distances(room_state, distances)
    n_mover, n_box, n_t2b = calc_distances(next_room_state, distances)
    
    change_reward = 0.0
    if n_t2b < t2b:
        change_reward += 1.0
    elif n_t2b > t2b:
        change_reward -= 1.0
        
    m2b = np.sqrt((mover[0]-box[0])**2 + (mover[1]-box[1])**2)
    n_m2b = np.sqrt((n_mover[0]-n_box[0])**2 + (n_mover[1]-n_box[1])**2)
    
    if n_m2b < m2b and m2b >= 2:
        change_reward += 0.25
    elif n_m2b > m2b and n_m2b >= 2:
        change_reward -= 0.25
        
    return change_reward

# %% [markdown]
# # Solution

# %%
class SOK_Agent:
    def __init__(self):
        # Construct DQN models
        self.state_size = (5, 5, 1) 
        self.action_size = 8
        self.model = self._build_model()
        self.target_model = self._build_model()
        self.target_model.set_weights(self.model.get_weights())
        self.batch_size = 8
        
        # Replay buffers
        self.replay_buffer = deque(maxlen=1500)
        self.prioritized_replay_buffer = deque(maxlen=500)
        self.prioritized_replay_batch = 20        
        
        # Hyperparameters
        self.gamma = 0.9
        self.epsilon = 1.0   
        self.epsilon_min = 0.05
        self.epsilon_decay = 0.99995
        self.replay_rate = 10
        self.update_beta = 0.99

        self.verbosity = 100 
        
        self.action_rotation_map = {
            0: 2,
            1: 3,
            2: 1,
            3: 0,
            4: 6,
            5: 7,
            6: 5,
            7: 4
        }

    def _build_model(self):
        model = Sequential()
        model.add(Conv2D(64, (3, 3), input_shape=self.state_size))
        model.add(Flatten())
        model.add(Dense(512, activation='relu'))
        model.add(Dense(64, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer="adam") 
        return model

    def remember(self, state, action, reward, next_state, done):
        self.replay_buffer.append([state, action, reward, next_state, done])    
        
    def copy_to_prioritized_buffer(self, n):
        for i in range(n):
            self.prioritized_replay_buffer.append(self.replay_buffer[-1-i])  

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        
        act_values = self.model.predict(state, verbose=0)
        return np.argmax(act_values[0]) 

    def replay(self):        
        minibatch = random.sample(self.replay_buffer, self.batch_size//2) 
        minibatch.extend(random.sample(self.prioritized_replay_buffer, self.batch_size//2))
        
        states = np.zeros((self.batch_size*4, self.state_size[0], self.state_size[1]))
        actions = np.zeros(self.batch_size*4, dtype=int)
        rewards = np.zeros(self.batch_size*4)
        next_states = np.zeros((self.batch_size*4, self.state_size[0], self.state_size[1]))
        statuses = np.zeros(self.batch_size*4)
        targets = np.zeros((self.batch_size*4, self.action_size)) 
        
        for i, (state, action, reward, next_state, done) in enumerate(minibatch): 
            for rot in range(4):  
                ind = i*4+rot
                if rot != 0:
                    state = np.rot90(state, axes=(1,2))
                    next_state = np.rot90(next_state, axes=(1,2))
                    action = self.action_rotation_map.get(action)

                states[ind] = state.copy()
                actions[ind] = action
                rewards[ind] = reward
                next_states[ind] = next_state.copy()
                statuses[ind] = 1 if done else 0        

        targets = self.model.predict(states) 
        max_actions = np.argmax(self.model.predict(next_states), axis=1)
        next_rewards = self.target_model.predict(next_states)
        
        ind = 0
        for action, reward, next_reward, max_action, done in zip(actions, rewards, next_rewards, max_actions, statuses):  
            if not done:
                reward += self.gamma * next_reward[max_action]
            targets[ind][action] = reward
            ind += 1
        
        self.model.fit(states, targets, epochs=1, verbose=0)
                
    def update_epsilon(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon = self.epsilon * self.epsilon_decay
        
    def update_target_model(self):
        model_w = self.model.get_weights()
        target_model_w = self.target_model.get_weights()
        updated_target_model_w = []
        for i in range(len(model_w)):
            updated_target_model_w.append(self.update_beta*target_model_w[i] + (1-self.update_beta)*model_w[i])
        self.target_model.set_weights(updated_target_model_w)    
            
    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

# %%
def process_frame(frame):
    f = frame[16:96, 16:96, 0]   
    f = f.reshape(5, 16, 5, 16).max(axis=(1, 3))
    #f = f.flatten()
    f = f / 255
    return np.expand_dims(f, axis=0)

# %% [markdown]
# ## Training

# %%
max_episodes = 25000
max_steps = 100

def init_sok(r):
    random.seed(r%100)
    sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
    sok.set_maxsteps(max_steps)
    return sok

# %%
agent = SOK_Agent()

continuous_successes_goal = 100
continuous_successes = 0

total_steps = 0
solved_puzzles = []
steps_per_episode = []

puzzle_run = 0
for e in range(max_episodes):
    if continuous_successes >= continuous_successes_goal:
        print("Agent training finished!")
        break
    
    print("Episode: %d" % (e))
    
    sok = init_sok(e)
    state = process_frame(sok.get_image('rgb_array'))
    random.seed(e)
    
    room_state = sok.room_state.copy() 
    distances = get_distances(room_state)
    
    for step in range(sok.max_steps):
        total_steps += 1
        current_epsilon = agent.epsilon
        if current_epsilon < 0.1 and step >= 20:
            agent.epsilon = 0.9 
        action = agent.act(state)
        agent.epsilon = current_epsilon
        
        if action < 4:
            next_state, reward, done, _ = sok.step(action+1) 
        else:
            next_state, reward, done, _ = sok.step(action+5)         
        
        next_state = process_frame(next_state)        
        next_room_state = sok.room_state
        
        if not done:
            reward += box2target_change_reward(room_state, next_room_state, distances)
        
        agent.remember(state, action, reward, next_state, done)
        
        state = next_state.copy() 
        room_state = next_room_state.copy()
                
        if e >= 100:
            if (total_steps+1) % agent.replay_rate == 0:
                agent.replay() 
                agent.update_target_model()
                agent.update_epsilon()
        
        if done:            
            if 3 in sok.room_state:
                puzzle_run += 1
                continuous_successes += 1
                print("SOLVED! Steps: %d {%d}" % (step+1, puzzle_run)) 
                agent.copy_to_prioritized_buffer(min(agent.prioritized_replay_batch, step+1))
            else:
                continuous_successes = 0
                
            if (e+1) % 100 == 0:
                solved_puzzles.append(puzzle_run)
                print("*"*50)
                print("%s" % solved_puzzles[-10:])
                print("*"*50)
                puzzle_run = 0
                
            steps_per_episode.append(step+1)
            agent.save("saved_models\episode%d.h5" % (e))
            
            break
# Out:
# Episode: 0
# Episode: 1
# Episode: 2
# Episode: 3
# SOLVED! Steps: 54 {1}
# Episode: 4
# SOLVED! Steps: 1 {2}
# Episode: 5
# SOLVED! Steps: 28 {3}
# Episode: 6
# Episode: 7
# SOLVED! Steps: 25 {4}
# Episode: 8
# Episode: 9
# SOLVED! Steps: 74 {5}
# Episode: 10
# Episode: 11
# SOLVED! Steps: 27 {6}
# Episode: 12
# Episode: 13
# Episode: 14
# Episode: 15
# SOLVED! Steps: 54 {7}
# Episode: 16
# Episode: 17
# Episode: 18
# Episode: 19
# Episode: 20
# Episode: 21
# Episode: 22
# Episode: 23
# Episode: 24
# Episode: 25
# Episode: 26
# Episode: 27
# Episode: 28
# Episode: 29
# SOLVED! Steps: 12 {8}
# Episode: 30
# SOLVED! Steps: 59 {9}
# Episode: 31
# Episode: 32
# Episode: 33
# Episode: 34
# Episode: 35
# Episode: 36
# Episode: 37
# SOLVED! Steps: 11 {10}
# Episode: 38
# Episode: 39
# SOLVED! Steps: 12 {11}
# Episode: 40
# Episode: 41
# Episode: 42
# Episode: 43
# Episode: 44
# Episode: 45
# Episode: 46
# SOLVED! Steps: 43 {12}
# Episode: 47
# Episode: 48
# Episode: 49
# Episode: 50
# Episode: 51
# Episode: 52
# SOLVED! Steps: 2 {13}
# Episode: 53
# SOLVED! Steps: 6 {14}
# Episode: 54
# SOLVED! Steps: 22 {15}
# Episode: 55
# SOLVED! Steps: 2 {16}
# Episode: 56
# SOLVED! Steps: 15 {17}
# Episode: 57
# SOLVED! Steps: 59 {18}
# Episode: 58
# SOLVED! Steps: 70 {19}
# Episode: 59
# SOLVED! Steps: 28 {20}
# Episode: 60
# Episode: 61
# Episode: 62
# Episode: 63
# Episode: 64
# SOLVED! Steps: 43 {21}
# Episode: 65
# Episode: 66
# Episode: 67
# Episode: 68
# Episode: 69
# Episode: 70
# Episode: 71
# Episode: 72
# SOLVED! Steps: 6 {22}
# Episode: 73
# SOLVED! Steps: 95 {23}
# Episode: 74
# Episode: 75
# Episode: 76
# SOLVED! Steps: 55 {24}
# Episode: 77
# Episode: 78
# Episode: 79
# Episode: 80
# SOLVED! Steps: 58 {25}
# Episode: 81
# Episode: 82
# Episode: 83
# Episode: 84
# SOLVED! Steps: 4 {26}
# Episode: 85
# Episode: 86
# Episode: 87
# Episode: 88
# SOLVED! Steps: 48 {27}
# Episode: 89
# Episode: 90
# Episode: 91
# Episode: 92
# Episode: 93
# SOLVED! Steps: 54 {28}
# Episode: 94
# Episode: 95
# Episode: 96
# Episode: 97
# SOLVED! Steps: 6 {29}
# Episode: 98
# SOLVED! Steps: 22 {30}
# Episode: 99
# **************************************************
# [30]
# **************************************************
# Episode: 100
# Episode: 101
# Episode: 102
# Episode: 103
# SOLVED! Steps: 32 {1}
# Episode: 104
# Episode: 105
# Episode: 106
# Episode: 107
# Episode: 108
# Episode: 109
# Episode: 110
# Episode: 111
# SOLVED! Steps: 3 {2}
# Episode: 112
# Episode: 113
# Episode: 114
# Episode: 115
# SOLVED! Steps: 10 {3}
# Episode: 116
# SOLVED! Steps: 2 {4}
# Episode: 117
# SOLVED! Steps: 1 {5}
# Episode: 118
# Episode: 119
# Episode: 120
# Episode: 121
# Episode: 122
# SOLVED! Steps: 3 {6}
# Episode: 123
# Episode: 124
# Episode: 125
# Episode: 126
# Episode: 127
# Episode: 128
# Episode: 129
# SOLVED! Steps: 23 {7}
# Episode: 130
# Episode: 131
# Episode: 132
# Episode: 133
# Episode: 134
# Episode: 135
# SOLVED! Steps: 98 {8}
# Episode: 136
# SOLVED! Steps: 6 {9}
# Episode: 137
# SOLVED! Steps: 19 {10}
# Episode: 138
# Episode: 139
# SOLVED! Steps: 1 {11}
# Episode: 140
# Episode: 141
# Episode: 142
# Episode: 143
# SOLVED! Steps: 17 {12}
# Episode: 144
# Episode: 145
# Episode: 146
# SOLVED! Steps: 77 {13}
# Episode: 147
# Episode: 148
# Episode: 149
# Episode: 150
# Episode: 151
# Episode: 152
# Episode: 153
# SOLVED! Steps: 16 {14}
# Episode: 154
# Episode: 155
# Episode: 156
# Episode: 157
# SOLVED! Steps: 70 {15}
# Episode: 158
# Episode: 159
# Episode: 160
# Episode: 161
# Episode: 162
# Episode: 163
# SOLVED! Steps: 2 {16}
# Episode: 164
# SOLVED! Steps: 20 {17}
# Episode: 165
# Episode: 166
# Episode: 167
# Episode: 168
# Episode: 169
# Episode: 170
# SOLVED! Steps: 46 {18}
# Episode: 171
# SOLVED! Steps: 68 {19}
# Episode: 172
# Episode: 173
# Episode: 174
# SOLVED! Steps: 23 {20}
# Episode: 175
# Episode: 176
# SOLVED! Steps: 1 {21}
# Episode: 177
# Episode: 178
# Episode: 179
# Episode: 180
# SOLVED! Steps: 89 {22}
# Episode: 181
# Episode: 182
# Episode: 183
# SOLVED! Steps: 17 {23}
# Episode: 184
# SOLVED! Steps: 45 {24}
# Episode: 185
# Episode: 186
# Episode: 187
# SOLVED! Steps: 4 {25}
# Episode: 188
# SOLVED! Steps: 66 {26}
# Episode: 189
# Episode: 190
# SOLVED! Steps: 37 {27}
# Episode: 191
# Episode: 192
# Episode: 193
# Episode: 194
# Episode: 195
# Episode: 196
# SOLVED! Steps: 88 {28}
# Episode: 197
# Episode: 198
# SOLVED! Steps: 10 {29}
# Episode: 199
# **************************************************
# [30, 29]
# **************************************************
# Episode: 200
# Episode: 201
# SOLVED! Steps: 81 {1}
# Episode: 202
# Episode: 203
# SOLVED! Steps: 1 {2}
# Episode: 204
# SOLVED! Steps: 3 {3}
# Episode: 205
# Episode: 206
# Episode: 207
# Episode: 208
# SOLVED! Steps: 6 {4}
# Episode: 209
# Episode: 210
# Episode: 211
# SOLVED! Steps: 17 {5}
# Episode: 212
# SOLVED! Steps: 60 {6}
# Episode: 213
# Episode: 214
# SOLVED! Steps: 55 {7}
# Episode: 215
# SOLVED! Steps: 33 {8}
# Episode: 216
# Episode: 217
# SOLVED! Steps: 35 {9}
# Episode: 218
# Episode: 219
# Episode: 220
# SOLVED! Steps: 39 {10}
# Episode: 221
# Episode: 222
# SOLVED! Steps: 1 {11}
# Episode: 223
# Episode: 224
# Episode: 225
# Episode: 226
# Episode: 227
# Episode: 228
# SOLVED! Steps: 79 {12}
# Episode: 229
# SOLVED! Steps: 2 {13}
# Episode: 230
# Episode: 231
# Episode: 232
# Episode: 233
# Episode: 234
# Episode: 235
# SOLVED! Steps: 56 {14}
# Episode: 236
# SOLVED! Steps: 61 {15}
# Episode: 237
# Episode: 238
# Episode: 239
# SOLVED! Steps: 3 {16}
# Episode: 240
# SOLVED! Steps: 74 {17}
# Episode: 241
# Episode: 242
# Episode: 243
# SOLVED! Steps: 17 {18}
# Episode: 244
# Episode: 245
# Episode: 246
# SOLVED! Steps: 43 {19}
# Episode: 247
# Episode: 248
# Episode: 249
# Episode: 250
# Episode: 251
# Episode: 252
# SOLVED! Steps: 1 {20}
# Episode: 253
# SOLVED! Steps: 7 {21}
# Episode: 254
# Episode: 255
# SOLVED! Steps: 43 {22}
# Episode: 256
# SOLVED! Steps: 4 {23}
# Episode: 257
# SOLVED! Steps: 13 {24}
# Episode: 258
# Episode: 259
# Episode: 260
# Episode: 261
# SOLVED! Steps: 43 {25}
# Episode: 262
# Episode: 263
# SOLVED! Steps: 91 {26}
# Episode: 264
# SOLVED! Steps: 27 {27}
# Episode: 265
# Episode: 266
# Episode: 267
# Episode: 268
# Episode: 269
# Episode: 270
# SOLVED! Steps: 46 {28}
# Episode: 271
# SOLVED! Steps: 55 {29}
# Episode: 272
# SOLVED! Steps: 12 {30}
# Episode: 273
# Episode: 274
# SOLVED! Steps: 55 {31}
# Episode: 275
# Episode: 276
# SOLVED! Steps: 14 {32}
# Episode: 277
# Episode: 278
# Episode: 279
# Episode: 280
# SOLVED! Steps: 85 {33}
# Episode: 281
# Episode: 282
# SOLVED! Steps: 44 {34}
# Episode: 283
# SOLVED! Steps: 2 {35}
# Episode: 284
# Episode: 285
# Episode: 286
# Episode: 287
# SOLVED! Steps: 1 {36}
# Episode: 288
# SOLVED! Steps: 74 {37}
# Episode: 289
# Episode: 290
# SOLVED! Steps: 4 {38}
# Episode: 291
# Episode: 292
# Episode: 293
# Episode: 294
# Episode: 295
# Episode: 296
# Episode: 297
# Episode: 298
# SOLVED! Steps: 2 {39}
# Episode: 299
# SOLVED! Steps: 55 {40}
# **************************************************
# [30, 29, 40]
# **************************************************
# Episode: 300
# Episode: 301
# Episode: 302
# Episode: 303
# SOLVED! Steps: 8 {1}
# Episode: 304
# SOLVED! Steps: 2 {2}
# Episode: 305
# Episode: 306
# Episode: 307
# SOLVED! Steps: 12 {3}
# Episode: 308
# Episode: 309
# Episode: 310
# Episode: 311
# SOLVED! Steps: 17 {4}
# Episode: 312
# Episode: 313
# Episode: 314
# Episode: 315
# SOLVED! Steps: 96 {5}
# Episode: 316
# SOLVED! Steps: 1 {6}
# Episode: 317
# SOLVED! Steps: 36 {7}
# Episode: 318
# Episode: 319
# Episode: 320
# Episode: 321
# Episode: 322
# Episode: 323
# Episode: 324
# Episode: 325
# Episode: 326
# Episode: 327
# SOLVED! Steps: 13 {8}
# Episode: 328
# SOLVED! Steps: 91 {9}
# Episode: 329
# SOLVED! Steps: 4 {10}
# Episode: 330
# Episode: 331
# Episode: 332
# Episode: 333
# Episode: 334
# Episode: 335
# Episode: 336
# SOLVED! Steps: 48 {11}
# Episode: 337
# SOLVED! Steps: 66 {12}
# Episode: 338
# SOLVED! Steps: 75 {13}
# Episode: 339
# SOLVED! Steps: 9 {14}
# Episode: 340
# SOLVED! Steps: 20 {15}
# Episode: 341
# SOLVED! Steps: 93 {16}
# Episode: 342
# Episode: 343
# SOLVED! Steps: 26 {17}
# Episode: 344
# Episode: 345
# Episode: 346
# SOLVED! Steps: 38 {18}
# Episode: 347
# Episode: 348
# Episode: 349
# Episode: 350
# Episode: 351
# Episode: 352
# Episode: 353
# SOLVED! Steps: 10 {19}
# Episode: 354
# Episode: 355
# SOLVED! Steps: 4 {20}
# Episode: 356
# Episode: 357
# SOLVED! Steps: 33 {21}
# Episode: 358
# Episode: 359
# SOLVED! Steps: 92 {22}
# Episode: 360
# Episode: 361
# Episode: 362
# Episode: 363
# SOLVED! Steps: 1 {23}
# Episode: 364
# SOLVED! Steps: 27 {24}
# Episode: 365
# Episode: 366
# Episode: 367
# Episode: 368
# Episode: 369
# Episode: 370
# SOLVED! Steps: 43 {25}
# Episode: 371
# SOLVED! Steps: 7 {26}
# Episode: 372
# Episode: 373
# Episode: 374
# SOLVED! Steps: 70 {27}
# Episode: 375
# Episode: 376
# SOLVED! Steps: 9 {28}
# Episode: 377
# Episode: 378
# Episode: 379
# Episode: 380
# SOLVED! Steps: 96 {29}
# Episode: 381
# Episode: 382
# SOLVED! Steps: 66 {30}
# Episode: 383
# SOLVED! Steps: 2 {31}
# Episode: 384
# SOLVED! Steps: 71 {32}
# Episode: 385
# Episode: 386
# Episode: 387
# Episode: 388
# Episode: 389
# Episode: 390
# SOLVED! Steps: 13 {33}
# Episode: 391
# SOLVED! Steps: 83 {34}
# Episode: 392
# Episode: 393
# SOLVED! Steps: 8 {35}
# Episode: 394
# Episode: 395
# Episode: 396
# SOLVED! Steps: 24 {36}
# Episode: 397
# Episode: 398
# SOLVED! Steps: 17 {37}
# Episode: 399
# **************************************************
# [30, 29, 40, 37]
# **************************************************
# Episode: 400
# SOLVED! Steps: 38 {1}
# Episode: 401
# SOLVED! Steps: 26 {2}
# Episode: 402
# Episode: 403
# SOLVED! Steps: 17 {3}
# Episode: 404
# SOLVED! Steps: 38 {4}
# Episode: 405
# Episode: 406
# Episode: 407
# SOLVED! Steps: 38 {5}
# Episode: 408
# SOLVED! Steps: 14 {6}
# Episode: 409
# SOLVED! Steps: 82 {7}
# Episode: 410
# SOLVED! Steps: 35 {8}
# Episode: 411
# SOLVED! Steps: 4 {9}
# Episode: 412
# SOLVED! Steps: 7 {10}
# Episode: 413
# Episode: 414
# SOLVED! Steps: 15 {11}
# Episode: 415
# SOLVED! Steps: 2 {12}
# Episode: 416
# SOLVED! Steps: 2 {13}
# Episode: 417
# SOLVED! Steps: 53 {14}
# Episode: 418
# Episode: 419
# Episode: 420
# SOLVED! Steps: 1 {15}
# Episode: 421
# Episode: 422
# Episode: 423
# Episode: 424
# Episode: 425
# Episode: 426
# Episode: 427
# Episode: 428
# SOLVED! Steps: 13 {16}
# Episode: 429
# SOLVED! Steps: 17 {17}
# Episode: 430
# Episode: 431
# SOLVED! Steps: 51 {18}
# Episode: 432
# Episode: 433
# SOLVED! Steps: 92 {19}
# Episode: 434
# SOLVED! Steps: 83 {20}
# Episode: 435
# Episode: 436
# SOLVED! Steps: 11 {21}
# Episode: 437
# Episode: 438
# Episode: 439
# SOLVED! Steps: 6 {22}
# Episode: 440
# Episode: 441
# Episode: 442
# Episode: 443
# SOLVED! Steps: 15 {23}
# Episode: 444
# Episode: 445
# SOLVED! Steps: 65 {24}
# Episode: 446
# SOLVED! Steps: 22 {25}
# Episode: 447
# Episode: 448
# Episode: 449
# Episode: 450
# Episode: 451
# SOLVED! Steps: 1 {26}
# Episode: 452
# SOLVED! Steps: 6 {27}
# Episode: 453
# SOLVED! Steps: 5 {28}
# Episode: 454
# Episode: 455
# SOLVED! Steps: 41 {29}
# Episode: 456
# Episode: 457
# Episode: 458
# Episode: 459
# Episode: 460
# Episode: 461
# Episode: 462
# Episode: 463
# Episode: 464
# SOLVED! Steps: 7 {30}
# Episode: 465
# Episode: 466
# SOLVED! Steps: 17 {31}
# Episode: 467
# Episode: 468
# Episode: 469
# Episode: 470
# SOLVED! Steps: 43 {32}
# Episode: 471
# Episode: 472
# SOLVED! Steps: 34 {33}
# Episode: 473
# SOLVED! Steps: 4 {34}
# Episode: 474
# Episode: 475
# Episode: 476
# SOLVED! Steps: 19 {35}
# Episode: 477
# Episode: 478
# Episode: 479
# Episode: 480
# SOLVED! Steps: 37 {36}
# Episode: 481
# Episode: 482
# Episode: 483
# SOLVED! Steps: 25 {37}
# Episode: 484
# SOLVED! Steps: 7 {38}
# Episode: 485
# Episode: 486
# Episode: 487
# Episode: 488
# Episode: 489
# SOLVED! Steps: 7 {39}
# Episode: 490
# SOLVED! Steps: 7 {40}
# Episode: 491
# Episode: 492
# Episode: 493
# Episode: 494
# Episode: 495
# Episode: 496
# Episode: 497
# Episode: 498
# SOLVED! Steps: 12 {41}
# Episode: 499
# **************************************************
# [30, 29, 40, 37, 41]
# **************************************************
# Episode: 500
# Episode: 501
# SOLVED! Steps: 88 {1}
# Episode: 502
# Episode: 503
# SOLVED! Steps: 17 {2}
# Episode: 504
# Episode: 505
# SOLVED! Steps: 51 {3}
# Episode: 506
# Episode: 507
# Episode: 508
# SOLVED! Steps: 17 {4}
# Episode: 509
# Episode: 510
# Episode: 511
# SOLVED! Steps: 19 {5}
# Episode: 512
# SOLVED! Steps: 7 {6}
# Episode: 513
# SOLVED! Steps: 75 {7}
# Episode: 514
# Episode: 515
# SOLVED! Steps: 1 {8}
# Episode: 516
# SOLVED! Steps: 6 {9}
# Episode: 517
# SOLVED! Steps: 2 {10}
# Episode: 518
# Episode: 519
# Episode: 520
# SOLVED! Steps: 1 {11}
# Episode: 521
# SOLVED! Steps: 18 {12}
# Episode: 522
# SOLVED! Steps: 1 {13}
# Episode: 523
# Episode: 524
# Episode: 525
# Episode: 526
# Episode: 527
# Episode: 528
# Episode: 529
# SOLVED! Steps: 2 {14}
# Episode: 530
# Episode: 531
# Episode: 532
# Episode: 533
# Episode: 534
# Episode: 535
# SOLVED! Steps: 33 {15}
# Episode: 536
# Episode: 537
# SOLVED! Steps: 2 {16}
# Episode: 538
# Episode: 539
# SOLVED! Steps: 26 {17}
# Episode: 540
# Episode: 541
# Episode: 542
# SOLVED! Steps: 80 {18}
# Episode: 543
# SOLVED! Steps: 25 {19}
# Episode: 544
# Episode: 545
# Episode: 546
# SOLVED! Steps: 38 {20}
# Episode: 547
# Episode: 548
# Episode: 549
# Episode: 550
# Episode: 551
# SOLVED! Steps: 11 {21}
# Episode: 552
# SOLVED! Steps: 1 {22}
# Episode: 553
# SOLVED! Steps: 2 {23}
# Episode: 554
# Episode: 555
# SOLVED! Steps: 1 {24}
# Episode: 556
# SOLVED! Steps: 10 {25}
# Episode: 557
# Episode: 558
# Episode: 559
# SOLVED! Steps: 23 {26}
# Episode: 560
# Episode: 561
# Episode: 562
# Episode: 563
# SOLVED! Steps: 1 {27}
# Episode: 564
# SOLVED! Steps: 70 {28}
# Episode: 565
# Episode: 566
# Episode: 567
# Episode: 568
# Episode: 569
# SOLVED! Steps: 46 {29}
# Episode: 570
# SOLVED! Steps: 3 {30}
# Episode: 571
# SOLVED! Steps: 6 {31}
# Episode: 572
# SOLVED! Steps: 2 {32}
# Episode: 573
# Episode: 574
# Episode: 575
# Episode: 576
# SOLVED! Steps: 2 {33}
# Episode: 577
# Episode: 578
# Episode: 579
# Episode: 580
# SOLVED! Steps: 7 {34}
# Episode: 581
# Episode: 582
# Episode: 583
# SOLVED! Steps: 6 {35}
# Episode: 584
# SOLVED! Steps: 7 {36}
# Episode: 585
# Episode: 586
# Episode: 587
# SOLVED! Steps: 5 {37}
# Episode: 588
# SOLVED! Steps: 19 {38}
# Episode: 589
# Episode: 590
# SOLVED! Steps: 1 {39}
# Episode: 591
# Episode: 592
# Episode: 593
# SOLVED! Steps: 7 {40}
# Episode: 594
# Episode: 595
# Episode: 596
# SOLVED! Steps: 8 {41}
# Episode: 597
# Episode: 598
# SOLVED! Steps: 1 {42}
# Episode: 599
# SOLVED! Steps: 19 {43}
# **************************************************
# [30, 29, 40, 37, 41, 43]
# **************************************************
# Episode: 600
# Episode: 601
# Episode: 602
# Episode: 603
# SOLVED! Steps: 1 {1}
# Episode: 604
# SOLVED! Steps: 1 {2}
# Episode: 605
# Episode: 606
# SOLVED! Steps: 12 {3}
# Episode: 607
# SOLVED! Steps: 7 {4}
# Episode: 608
# SOLVED! Steps: 2 {5}
# Episode: 609
# Episode: 610
# Episode: 611
# SOLVED! Steps: 2 {6}
# Episode: 612
# SOLVED! Steps: 7 {7}
# Episode: 613
# Episode: 614
# Episode: 615
# SOLVED! Steps: 1 {8}
# Episode: 616
# SOLVED! Steps: 1 {9}
# Episode: 617
# SOLVED! Steps: 6 {10}
# Episode: 618
# Episode: 619
# Episode: 620
# SOLVED! Steps: 1 {11}
# Episode: 621
# Episode: 622
# SOLVED! Steps: 1 {12}
# Episode: 623
# Episode: 624
# Episode: 625
# SOLVED! Steps: 45 {13}
# Episode: 626
# Episode: 627
# Episode: 628
# Episode: 629
# SOLVED! Steps: 1 {14}
# Episode: 630
# SOLVED! Steps: 58 {15}
# Episode: 631
# Episode: 632
# Episode: 633
# Episode: 634
# Episode: 635
# Episode: 636
# SOLVED! Steps: 8 {16}
# Episode: 637
# SOLVED! Steps: 1 {17}
# Episode: 638
# Episode: 639
# SOLVED! Steps: 4 {18}
# Episode: 640
# SOLVED! Steps: 3 {19}
# Episode: 641
# SOLVED! Steps: 62 {20}
# Episode: 642
# Episode: 643
# SOLVED! Steps: 2 {21}
# Episode: 644
# SOLVED! Steps: 92 {22}
# Episode: 645
# Episode: 646
# SOLVED! Steps: 2 {23}
# Episode: 647
# Episode: 648
# Episode: 649
# Episode: 650
# Episode: 651
# SOLVED! Steps: 1 {24}
# Episode: 652
# SOLVED! Steps: 6 {25}
# Episode: 653
# SOLVED! Steps: 34 {26}
# Episode: 654
# Episode: 655
# SOLVED! Steps: 1 {27}
# Episode: 656
# SOLVED! Steps: 51 {28}
# Episode: 657
# Episode: 658
# SOLVED! Steps: 8 {29}
# Episode: 659
# SOLVED! Steps: 32 {30}
# Episode: 660
# Episode: 661
# Episode: 662
# Episode: 663
# SOLVED! Steps: 21 {31}
# Episode: 664
# Episode: 665
# Episode: 666
# SOLVED! Steps: 38 {32}
# Episode: 667
# Episode: 668
# Episode: 669
# Episode: 670
# SOLVED! Steps: 3 {33}
# Episode: 671
# SOLVED! Steps: 24 {34}
# Episode: 672
# SOLVED! Steps: 2 {35}
# Episode: 673
# SOLVED! Steps: 6 {36}
# Episode: 674
# Episode: 675
# SOLVED! Steps: 3 {37}
# Episode: 676
# SOLVED! Steps: 1 {38}
# Episode: 677
# Episode: 678
# Episode: 679
# Episode: 680
# SOLVED! Steps: 7 {39}
# Episode: 681
# Episode: 682
# Episode: 683
# SOLVED! Steps: 2 {40}
# Episode: 684
# SOLVED! Steps: 18 {41}
# Episode: 685
# Episode: 686
# Episode: 687
# SOLVED! Steps: 1 {42}
# Episode: 688
# Episode: 689
# Episode: 690
# SOLVED! Steps: 1 {43}
# Episode: 691
# Episode: 692
# SOLVED! Steps: 55 {44}
# Episode: 693
# SOLVED! Steps: 19 {45}
# Episode: 694
# SOLVED! Steps: 60 {46}
# Episode: 695
# Episode: 696
# SOLVED! Steps: 70 {47}
# Episode: 697
# Episode: 698
# SOLVED! Steps: 1 {48}
# Episode: 699
# SOLVED! Steps: 3 {49}
# **************************************************
# [30, 29, 40, 37, 41, 43, 49]
# **************************************************
# Episode: 700
# SOLVED! Steps: 3 {1}
# Episode: 701
# SOLVED! Steps: 19 {2}
# Episode: 702
# Episode: 703
# SOLVED! Steps: 1 {3}
# Episode: 704
# SOLVED! Steps: 1 {4}
# Episode: 705
# Episode: 706
# Episode: 707
# Episode: 708
# SOLVED! Steps: 2 {5}
# Episode: 709
# Episode: 710
# Episode: 711
# SOLVED! Steps: 2 {6}
# Episode: 712
# SOLVED! Steps: 7 {7}
# Episode: 713
# Episode: 714
# Episode: 715
# SOLVED! Steps: 1 {8}
# Episode: 716
# SOLVED! Steps: 16 {9}
# Episode: 717
# SOLVED! Steps: 4 {10}
# Episode: 718
# Episode: 719
# Episode: 720
# Episode: 721
# Episode: 722
# SOLVED! Steps: 1 {11}
# Episode: 723
# Episode: 724
# Episode: 725
# Episode: 726
# Episode: 727
# Episode: 728
# Episode: 729
# SOLVED! Steps: 11 {12}
# Episode: 730
# Episode: 731
# Episode: 732
# Episode: 733
# Episode: 734
# Episode: 735
# Episode: 736
# SOLVED! Steps: 12 {13}
# Episode: 737
# SOLVED! Steps: 1 {14}
# Episode: 738
# Episode: 739
# SOLVED! Steps: 6 {15}
# Episode: 740
# SOLVED! Steps: 3 {16}
# Episode: 741
# Episode: 742
# Episode: 743
# SOLVED! Steps: 2 {17}
# Episode: 744
# Episode: 745
# SOLVED! Steps: 51 {18}
# Episode: 746
# SOLVED! Steps: 2 {19}
# Episode: 747
# Episode: 748
# Episode: 749
# Episode: 750
# Episode: 751
# Episode: 752
# SOLVED! Steps: 1 {20}
# Episode: 753
# SOLVED! Steps: 1 {21}
# Episode: 754
# Episode: 755
# SOLVED! Steps: 1 {22}
# Episode: 756
# Episode: 757
# SOLVED! Steps: 99 {23}
# Episode: 758
# Episode: 759
# SOLVED! Steps: 75 {24}
# Episode: 760
# Episode: 761
# Episode: 762
# Episode: 763
# SOLVED! Steps: 1 {25}
# Episode: 764
# Episode: 765
# Episode: 766
# Episode: 767
# SOLVED! Steps: 76 {26}
# Episode: 768
# Episode: 769
# Episode: 770
# SOLVED! Steps: 3 {27}
# Episode: 771
# SOLVED! Steps: 7 {28}
# Episode: 772
# SOLVED! Steps: 2 {29}
# Episode: 773
# SOLVED! Steps: 51 {30}
# Episode: 774
# SOLVED! Steps: 3 {31}
# Episode: 775
# SOLVED! Steps: 3 {32}
# Episode: 776
# SOLVED! Steps: 1 {33}
# Episode: 777
# Episode: 778
# Episode: 779
# Episode: 780
# SOLVED! Steps: 62 {34}
# Episode: 781
# Episode: 782
# Episode: 783
# SOLVED! Steps: 6 {35}
# Episode: 784
# SOLVED! Steps: 12 {36}
# Episode: 785
# Episode: 786
# Episode: 787
# SOLVED! Steps: 1 {37}
# Episode: 788
# Episode: 789
# SOLVED! Steps: 88 {38}
# Episode: 790
# SOLVED! Steps: 1 {39}
# Episode: 791
# Episode: 792
# SOLVED! Steps: 3 {40}
# Episode: 793
# SOLVED! Steps: 7 {41}
# Episode: 794
# Episode: 795
# Episode: 796
# Episode: 797
# Episode: 798
# SOLVED! Steps: 1 {42}
# Episode: 799
# SOLVED! Steps: 3 {43}
# **************************************************
# [30, 29, 40, 37, 41, 43, 49, 43]
# **************************************************
# Episode: 800
# Episode: 801
# Episode: 802
# Episode: 803
# SOLVED! Steps: 1 {1}
# Episode: 804
# Episode: 805
# Episode: 806
# SOLVED! Steps: 49 {2}
# Episode: 807
# Episode: 808
# SOLVED! Steps: 2 {3}
# Episode: 809
# Episode: 810
# Episode: 811
# SOLVED! Steps: 2 {4}
# Episode: 812
# SOLVED! Steps: 6 {5}
# Episode: 813
# Episode: 814
# Episode: 815
# SOLVED! Steps: 1 {6}
# Episode: 816
# SOLVED! Steps: 60 {7}
# Episode: 817
# SOLVED! Steps: 1 {8}
# Episode: 818
# Episode: 819
# SOLVED! Steps: 78 {9}
# Episode: 820
# SOLVED! Steps: 1 {10}
# Episode: 821
# SOLVED! Steps: 23 {11}
# Episode: 822
# SOLVED! Steps: 1 {12}
# Episode: 823
# Episode: 824
# Episode: 825
# Episode: 826
# Episode: 827
# Episode: 828
# Episode: 829
# SOLVED! Steps: 1 {13}
# Episode: 830
# Episode: 831
# Episode: 832
# Episode: 833
# Episode: 834
# Episode: 835
# Episode: 836
# SOLVED! Steps: 9 {14}
# Episode: 837
# SOLVED! Steps: 1 {15}
# Episode: 838
# SOLVED! Steps: 80 {16}
# Episode: 839
# SOLVED! Steps: 3 {17}
# Episode: 840
# SOLVED! Steps: 3 {18}
# Episode: 841
# SOLVED! Steps: 65 {19}
# Episode: 842
# Episode: 843
# SOLVED! Steps: 2 {20}
# Episode: 844
# SOLVED! Steps: 17 {21}
# Episode: 845
# Episode: 846
# SOLVED! Steps: 2 {22}
# Episode: 847
# Episode: 848
# Episode: 849
# Episode: 850
# Episode: 851
# SOLVED! Steps: 42 {23}
# Episode: 852
# SOLVED! Steps: 1 {24}
# Episode: 853
# SOLVED! Steps: 1 {25}
# Episode: 854
# Episode: 855
# SOLVED! Steps: 1 {26}
# Episode: 856
# SOLVED! Steps: 4 {27}
# Episode: 857
# Episode: 858
# Episode: 859
# SOLVED! Steps: 19 {28}
# Episode: 860
# Episode: 861
# Episode: 862
# Episode: 863
# SOLVED! Steps: 1 {29}
# Episode: 864
# SOLVED! Steps: 68 {30}
# Episode: 865
# Episode: 866
# Episode: 867
# Episode: 868
# Episode: 869
# SOLVED! Steps: 89 {31}
# Episode: 870
# SOLVED! Steps: 3 {32}
# Episode: 871
# SOLVED! Steps: 7 {33}
# Episode: 872
# SOLVED! Steps: 2 {34}
# Episode: 873
# SOLVED! Steps: 65 {35}
# Episode: 874
# SOLVED! Steps: 3 {36}
# Episode: 875
# SOLVED! Steps: 3 {37}
# Episode: 876
# SOLVED! Steps: 1 {38}
# Episode: 877
# Episode: 878
# Episode: 879
# Episode: 880
# SOLVED! Steps: 7 {39}
# Episode: 881
# Episode: 882
# Episode: 883
# Episode: 884
# SOLVED! Steps: 5 {40}
# Episode: 885
# Episode: 886
# Episode: 887
# SOLVED! Steps: 1 {41}
# Episode: 888
# Episode: 889
# Episode: 890
# SOLVED! Steps: 1 {42}
# Episode: 891
# Episode: 892
# SOLVED! Steps: 3 {43}
# Episode: 893
# Episode: 894
# Episode: 895
# Episode: 896
# SOLVED! Steps: 47 {44}
# Episode: 897
# Episode: 898
# SOLVED! Steps: 1 {45}
# Episode: 899
# SOLVED! Steps: 3 {46}
# **************************************************
# [30, 29, 40, 37, 41, 43, 49, 43, 46]
# **************************************************
# Episode: 900
# Episode: 901
# SOLVED! Steps: 9 {1}
# Episode: 902
# Episode: 903
# SOLVED! Steps: 1 {2}
# Episode: 904
# SOLVED! Steps: 1 {3}
# Episode: 905
# Episode: 906
# Episode: 907
# SOLVED! Steps: 97 {4}
# Episode: 908
# SOLVED! Steps: 2 {5}
# Episode: 909
# Episode: 910
# Episode: 911
# SOLVED! Steps: 2 {6}
# Episode: 912
# Episode: 913
# Episode: 914
# Episode: 915
# SOLVED! Steps: 1 {7}
# Episode: 916
# SOLVED! Steps: 6 {8}
# Episode: 917
# SOLVED! Steps: 1 {9}
# Episode: 918
# Episode: 919
# Episode: 920
# SOLVED! Steps: 1 {10}
# Episode: 921
# SOLVED! Steps: 69 {11}
# Episode: 922
# SOLVED! Steps: 1 {12}
# Episode: 923
# Episode: 924
# Episode: 925
# Episode: 926
# Episode: 927
# Episode: 928
# Episode: 929
# SOLVED! Steps: 1 {13}
# Episode: 930
# SOLVED! Steps: 12 {14}
# Episode: 931
# Episode: 932
# Episode: 933
# Episode: 934
# SOLVED! Steps: 89 {15}
# Episode: 935
# SOLVED! Steps: 2 {16}
# Episode: 936
# SOLVED! Steps: 7 {17}
# Episode: 937
# SOLVED! Steps: 1 {18}
# Episode: 938
# Episode: 939
# Episode: 940
# Episode: 941
# SOLVED! Steps: 12 {19}
# Episode: 942
# Episode: 943
# SOLVED! Steps: 2 {20}
# Episode: 944
# Episode: 945
# Episode: 946
# SOLVED! Steps: 2 {21}
# Episode: 947
# Episode: 948
# Episode: 949
# Episode: 950
# Episode: 951
# SOLVED! Steps: 11 {22}
# Episode: 952
# SOLVED! Steps: 2 {23}
# Episode: 953
# SOLVED! Steps: 1 {24}
# Episode: 954
# SOLVED! Steps: 60 {25}
# Episode: 955
# SOLVED! Steps: 1 {26}
# Episode: 956
# SOLVED! Steps: 2 {27}
# Episode: 957
# Episode: 958
# SOLVED! Steps: 37 {28}
# Episode: 959
# Episode: 960
# Episode: 961
# Episode: 962
# Episode: 963
# SOLVED! Steps: 1 {29}
# Episode: 964
# SOLVED! Steps: 7 {30}
# Episode: 965
# Episode: 966
# Episode: 967
# Episode: 968
# Episode: 969
# Episode: 970
# SOLVED! Steps: 3 {31}
# Episode: 971
# Episode: 972
# SOLVED! Steps: 69 {32}
# Episode: 973
# SOLVED! Steps: 6 {33}
# Episode: 974
# SOLVED! Steps: 3 {34}
# Episode: 975
# SOLVED! Steps: 3 {35}
# Episode: 976
# SOLVED! Steps: 20 {36}
# Episode: 977
# Episode: 978
# Episode: 979
# Episode: 980
# SOLVED! Steps: 98 {37}
# Episode: 981
# Episode: 982
# Episode: 983
# SOLVED! Steps: 6 {38}
# Episode: 984
# SOLVED! Steps: 7 {39}
# Episode: 985
# Episode: 986
# SOLVED! Steps: 90 {40}
# Episode: 987
# SOLVED! Steps: 1 {41}
# Episode: 988
# SOLVED! Steps: 82 {42}
# Episode: 989
# Episode: 990
# SOLVED! Steps: 1 {43}
# Episode: 991
# Episode: 992
# SOLVED! Steps: 3 {44}
# Episode: 993
# SOLVED! Steps: 12 {45}
# Episode: 994
# Episode: 995
# Episode: 996
# SOLVED! Steps: 8 {46}
# Episode: 997
# Episode: 998
# SOLVED! Steps: 1 {47}
# Episode: 999
# SOLVED! Steps: 3 {48}
# **************************************************
# [30, 29, 40, 37, 41, 43, 49, 43, 46, 48]
# **************************************************
# Episode: 1000
# SOLVED! Steps: 3 {1}
# Episode: 1001
# SOLVED! Steps: 18 {2}
# Episode: 1002
# Episode: 1003
# SOLVED! Steps: 1 {3}
# Episode: 1004
# SOLVED! Steps: 1 {4}
# Episode: 1005
# Episode: 1006
# Episode: 1007
# SOLVED! Steps: 17 {5}
# Episode: 1008
# SOLVED! Steps: 2 {6}
# Episode: 1009
# Episode: 1010
# Episode: 1011
# SOLVED! Steps: 2 {7}
# Episode: 1012
# SOLVED! Steps: 7 {8}
# Episode: 1013
# Episode: 1014
# Episode: 1015
# SOLVED! Steps: 1 {9}
# Episode: 1016
# SOLVED! Steps: 51 {10}
# Episode: 1017
# SOLVED! Steps: 18 {11}
# Episode: 1018
# Episode: 1019
# SOLVED! Steps: 89 {12}
# Episode: 1020
# SOLVED! Steps: 1 {13}
# Episode: 1021
# SOLVED! Steps: 9 {14}
# Episode: 1022
# SOLVED! Steps: 1 {15}
# Episode: 1023
# SOLVED! Steps: 97 {16}
# Episode: 1024
# Episode: 1025
# Episode: 1026
# Episode: 1027
# Episode: 1028
# Episode: 1029
# SOLVED! Steps: 1 {17}
# Episode: 1030
# SOLVED! Steps: 9 {18}
# Episode: 1031
# Episode: 1032
# Episode: 1033
# Episode: 1034
# Episode: 1035
# SOLVED! Steps: 2 {19}
# Episode: 1036
# Episode: 1037
# SOLVED! Steps: 1 {20}
# Episode: 1038
# Episode: 1039
# Episode: 1040
# SOLVED! Steps: 3 {21}
# Episode: 1041
# SOLVED! Steps: 10 {22}
# Episode: 1042
# Episode: 1043
# SOLVED! Steps: 2 {23}
# Episode: 1044
# Episode: 1045
# Episode: 1046
# SOLVED! Steps: 10 {24}
# Episode: 1047
# Episode: 1048
# Episode: 1049
# Episode: 1050
# Episode: 1051
# SOLVED! Steps: 1 {25}
# Episode: 1052
# SOLVED! Steps: 58 {26}
# Episode: 1053
# SOLVED! Steps: 1 {27}
# Episode: 1054
# Episode: 1055
# SOLVED! Steps: 1 {28}
# Episode: 1056
# Episode: 1057
# SOLVED! Steps: 44 {29}
# Episode: 1058
# SOLVED! Steps: 99 {30}
# Episode: 1059
# SOLVED! Steps: 53 {31}
# Episode: 1060
# Episode: 1061
# Episode: 1062
# Episode: 1063
# SOLVED! Steps: 1 {32}
# Episode: 1064
# SOLVED! Steps: 8 {33}
# Episode: 1065
# Episode: 1066
# Episode: 1067
# Episode: 1068
# Episode: 1069
# Episode: 1070
# SOLVED! Steps: 3 {34}
# Episode: 1071
# Episode: 1072
# SOLVED! Steps: 2 {35}
# Episode: 1073
# SOLVED! Steps: 6 {36}
# Episode: 1074
# SOLVED! Steps: 3 {37}
# Episode: 1075
# SOLVED! Steps: 3 {38}
# Episode: 1076
# SOLVED! Steps: 1 {39}
# Episode: 1077
# Episode: 1078
# Episode: 1079
# Episode: 1080
# SOLVED! Steps: 7 {40}
# Episode: 1081
# Episode: 1082
# Episode: 1083
# Episode: 1084
# SOLVED! Steps: 6 {41}
# Episode: 1085
# Episode: 1086
# Episode: 1087
# SOLVED! Steps: 1 {42}
# Episode: 1088
# SOLVED! Steps: 16 {43}
# Episode: 1089
# Episode: 1090
# SOLVED! Steps: 1 {44}
# Episode: 1091
# Episode: 1092
# SOLVED! Steps: 3 {45}
# Episode: 1093
# Episode: 1094
# Episode: 1095
# Episode: 1096
# SOLVED! Steps: 8 {46}
# Episode: 1097
# Episode: 1098
# SOLVED! Steps: 1 {47}
# Episode: 1099
# SOLVED! Steps: 3 {48}
# **************************************************
# [29, 40, 37, 41, 43, 49, 43, 46, 48, 48]
# **************************************************
# Episode: 1100
# SOLVED! Steps: 3 {1}
# Episode: 1101
# SOLVED! Steps: 9 {2}
# Episode: 1102
# Episode: 1103
# SOLVED! Steps: 1 {3}
# Episode: 1104
# SOLVED! Steps: 1 {4}
# Episode: 1105
# Episode: 1106
# Episode: 1107
# SOLVED! Steps: 9 {5}
# Episode: 1108
# SOLVED! Steps: 2 {6}
# Episode: 1109
# Episode: 1110
# Episode: 1111
# SOLVED! Steps: 2 {7}
# Episode: 1112
# Episode: 1113
# Episode: 1114
# Episode: 1115
# SOLVED! Steps: 1 {8}
# Episode: 1116
# SOLVED! Steps: 4 {9}
# Episode: 1117
# SOLVED! Steps: 40 {10}
# Episode: 1118
# Episode: 1119
# Episode: 1120
# SOLVED! Steps: 1 {11}
# Episode: 1121
# SOLVED! Steps: 8 {12}
# Episode: 1122
# SOLVED! Steps: 1 {13}
# Episode: 1123
# Episode: 1124
# Episode: 1125
# SOLVED! Steps: 59 {14}
# Episode: 1126
# Episode: 1127
# Episode: 1128
# Episode: 1129
# SOLVED! Steps: 1 {15}
# Episode: 1130
# SOLVED! Steps: 8 {16}
# Episode: 1131
# Episode: 1132
# Episode: 1133
# Episode: 1134
# Episode: 1135
# Episode: 1136
# SOLVED! Steps: 11 {17}
# Episode: 1137
# SOLVED! Steps: 1 {18}
# Episode: 1138
# Episode: 1139
# Episode: 1140
# SOLVED! Steps: 3 {19}
# Episode: 1141
# Episode: 1142
# Episode: 1143
# SOLVED! Steps: 2 {20}
# Episode: 1144
# Episode: 1145
# Episode: 1146
# SOLVED! Steps: 2 {21}
# Episode: 1147
# Episode: 1148
# Episode: 1149
# Episode: 1150
# Episode: 1151
# Episode: 1152
# Episode: 1153
# SOLVED! Steps: 1 {22}
# Episode: 1154
# SOLVED! Steps: 86 {23}
# Episode: 1155
# SOLVED! Steps: 1 {24}
# Episode: 1156
# Episode: 1157
# SOLVED! Steps: 7 {25}
# Episode: 1158
# SOLVED! Steps: 17 {26}
# Episode: 1159
# Episode: 1160
# Episode: 1161
# SOLVED! Steps: 3 {27}
# Episode: 1162
# Episode: 1163
# SOLVED! Steps: 62 {28}
# Episode: 1164
# Episode: 1165
# Episode: 1166
# Episode: 1167
# Episode: 1168
# Episode: 1169
# Episode: 1170
# SOLVED! Steps: 3 {29}
# Episode: 1171
# SOLVED! Steps: 9 {30}
# Episode: 1172
# Episode: 1173
# SOLVED! Steps: 7 {31}
# Episode: 1174
# SOLVED! Steps: 3 {32}
# Episode: 1175
# SOLVED! Steps: 3 {33}
# Episode: 1176
# SOLVED! Steps: 1 {34}
# Episode: 1177
# Episode: 1178
# Episode: 1179
# Episode: 1180
# SOLVED! Steps: 7 {35}
# Episode: 1181
# SOLVED! Steps: 96 {36}
# Episode: 1182
# Episode: 1183
# SOLVED! Steps: 6 {37}
# Episode: 1184
# SOLVED! Steps: 40 {38}
# Episode: 1185
# SOLVED! Steps: 38 {39}
# Episode: 1186
# Episode: 1187
# SOLVED! Steps: 1 {40}
# Episode: 1188
# SOLVED! Steps: 72 {41}
# Episode: 1189
# SOLVED! Steps: 41 {42}
# Episode: 1190
# SOLVED! Steps: 11 {43}
# Episode: 1191
# SOLVED! Steps: 3 {44}
# Episode: 1192
# SOLVED! Steps: 3 {45}
# Episode: 1193
# SOLVED! Steps: 58 {46}
# Episode: 1194
# SOLVED! Steps: 34 {47}
# Episode: 1195
# Episode: 1196
# SOLVED! Steps: 7 {48}
# Episode: 1197
# SOLVED! Steps: 42 {49}
# Episode: 1198
# SOLVED! Steps: 1 {50}
# Episode: 1199
# SOLVED! Steps: 3 {51}
# **************************************************
# [40, 37, 41, 43, 49, 43, 46, 48, 48, 51]
# **************************************************
# Episode: 1200
# Episode: 1201
# SOLVED! Steps: 9 {1}
# Episode: 1202
# Episode: 1203
# SOLVED! Steps: 1 {2}
# Episode: 1204
# SOLVED! Steps: 1 {3}
# Episode: 1205
# SOLVED! Steps: 30 {4}
# Episode: 1206
# Episode: 1207
# SOLVED! Steps: 7 {5}
# Episode: 1208
# SOLVED! Steps: 2 {6}
# Episode: 1209
# Episode: 1210
# SOLVED! Steps: 3 {7}
# Episode: 1211
# SOLVED! Steps: 2 {8}
# Episode: 1212
# Episode: 1213
# Episode: 1214
# Episode: 1215
# SOLVED! Steps: 1 {9}
# Episode: 1216
# SOLVED! Steps: 2 {10}
# Episode: 1217
# Episode: 1218
# SOLVED! Steps: 43 {11}
# Episode: 1219
# Episode: 1220
# Episode: 1221
# SOLVED! Steps: 47 {12}
# Episode: 1222
# SOLVED! Steps: 1 {13}
# Episode: 1223
# Episode: 1224
# Episode: 1225
# SOLVED! Steps: 9 {14}
# Episode: 1226
# Episode: 1227
# Episode: 1228
# Episode: 1229
# SOLVED! Steps: 45 {15}
# Episode: 1230
# SOLVED! Steps: 7 {16}
# Episode: 1231
# Episode: 1232
# Episode: 1233
# Episode: 1234
# Episode: 1235
# SOLVED! Steps: 2 {17}
# Episode: 1236
# SOLVED! Steps: 12 {18}
# Episode: 1237
# SOLVED! Steps: 1 {19}
# Episode: 1238
# Episode: 1239
# SOLVED! Steps: 54 {20}
# Episode: 1240
# SOLVED! Steps: 3 {21}
# Episode: 1241
# SOLVED! Steps: 95 {22}
# Episode: 1242
# Episode: 1243
# SOLVED! Steps: 2 {23}
# Episode: 1244
# Episode: 1245
# Episode: 1246
# SOLVED! Steps: 2 {24}
# Episode: 1247
# Episode: 1248
# Episode: 1249
# Episode: 1250
# Episode: 1251
# SOLVED! Steps: 1 {25}
# Episode: 1252
# Episode: 1253
# SOLVED! Steps: 7 {26}
# Episode: 1254
# SOLVED! Steps: 54 {27}
# Episode: 1255
# SOLVED! Steps: 1 {28}
# Episode: 1256
# SOLVED! Steps: 6 {29}
# Episode: 1257
# Episode: 1258
# Episode: 1259
# SOLVED! Steps: 82 {30}
# Episode: 1260
# Episode: 1261
# SOLVED! Steps: 3 {31}
# Episode: 1262
# SOLVED! Steps: 78 {32}
# Episode: 1263
# SOLVED! Steps: 1 {33}
# Episode: 1264
# Episode: 1265
# Episode: 1266
# Episode: 1267
# Episode: 1268
# Episode: 1269
# Episode: 1270
# SOLVED! Steps: 3 {34}
# Episode: 1271
# SOLVED! Steps: 7 {35}
# Episode: 1272
# Episode: 1273
# SOLVED! Steps: 51 {36}
# Episode: 1274
# SOLVED! Steps: 3 {37}
# Episode: 1275
# SOLVED! Steps: 3 {38}
# Episode: 1276
# SOLVED! Steps: 39 {39}
# Episode: 1277
# Episode: 1278
# Episode: 1279
# Episode: 1280
# SOLVED! Steps: 69 {40}
# Episode: 1281
# Episode: 1282
# SOLVED! Steps: 88 {41}
# Episode: 1283
# SOLVED! Steps: 6 {42}
# Episode: 1284
# SOLVED! Steps: 6 {43}
# Episode: 1285
# Episode: 1286
# Episode: 1287
# SOLVED! Steps: 1 {44}
# Episode: 1288
# SOLVED! Steps: 30 {45}
# Episode: 1289
# Episode: 1290
# SOLVED! Steps: 1 {46}
# Episode: 1291
# SOLVED! Steps: 3 {47}
# Episode: 1292
# SOLVED! Steps: 3 {48}
# Episode: 1293
# SOLVED! Steps: 7 {49}
# Episode: 1294
# Episode: 1295
# Episode: 1296
# SOLVED! Steps: 32 {50}
# Episode: 1297
# Episode: 1298
# SOLVED! Steps: 1 {51}
# Episode: 1299
# SOLVED! Steps: 3 {52}
# **************************************************
# [37, 41, 43, 49, 43, 46, 48, 48, 51, 52]
# **************************************************
# Episode: 1300
# Episode: 1301
# SOLVED! Steps: 38 {1}
# Episode: 1302
# Episode: 1303
# SOLVED! Steps: 1 {2}
# Episode: 1304
# SOLVED! Steps: 1 {3}
# Episode: 1305
# Episode: 1306
# Episode: 1307
# SOLVED! Steps: 9 {4}
# Episode: 1308
# SOLVED! Steps: 2 {5}
# Episode: 1309
# Episode: 1310
# SOLVED! Steps: 3 {6}
# Episode: 1311
# SOLVED! Steps: 2 {7}
# Episode: 1312
# Episode: 1313
# Episode: 1314
# SOLVED! Steps: 33 {8}
# Episode: 1315
# SOLVED! Steps: 1 {9}
# Episode: 1316
# SOLVED! Steps: 7 {10}
# Episode: 1317
# SOLVED! Steps: 28 {11}
# Episode: 1318
# Episode: 1319
# Episode: 1320
# Episode: 1321
# Episode: 1322
# SOLVED! Steps: 1 {12}
# Episode: 1323
# SOLVED! Steps: 16 {13}
# Episode: 1324
# Episode: 1325
# SOLVED! Steps: 8 {14}
# Episode: 1326
# Episode: 1327
# Episode: 1328
# SOLVED! Steps: 7 {15}
# Episode: 1329
# SOLVED! Steps: 1 {16}
# Episode: 1330
# Episode: 1331
# Episode: 1332
# Episode: 1333
# Episode: 1334
# Episode: 1335
# SOLVED! Steps: 2 {17}
# Episode: 1336
# SOLVED! Steps: 69 {18}
# Episode: 1337
# SOLVED! Steps: 1 {19}
# Episode: 1338
# Episode: 1339
# SOLVED! Steps: 48 {20}
# Episode: 1340
# SOLVED! Steps: 3 {21}
# Episode: 1341
# Episode: 1342
# Episode: 1343
# SOLVED! Steps: 2 {22}
# Episode: 1344
# Episode: 1345
# Episode: 1346
# SOLVED! Steps: 2 {23}
# Episode: 1347
# Episode: 1348
# Episode: 1349
# Episode: 1350
# Episode: 1351
# Episode: 1352
# Episode: 1353
# SOLVED! Steps: 1 {24}
# Episode: 1354
# Episode: 1355
# SOLVED! Steps: 1 {25}
# Episode: 1356
# Episode: 1357
# SOLVED! Steps: 65 {26}
# Episode: 1358
# SOLVED! Steps: 7 {27}
# Episode: 1359
# Episode: 1360
# Episode: 1361
# SOLVED! Steps: 3 {28}
# Episode: 1362
# Episode: 1363
# SOLVED! Steps: 1 {29}
# Episode: 1364
# SOLVED! Steps: 38 {30}
# Episode: 1365
# Episode: 1366
# Episode: 1367
# Episode: 1368
# Episode: 1369
# Episode: 1370
# SOLVED! Steps: 3 {31}
# Episode: 1371
# SOLVED! Steps: 7 {32}
# Episode: 1372
# SOLVED! Steps: 50 {33}
# Episode: 1373
# SOLVED! Steps: 38 {34}
# Episode: 1374
# SOLVED! Steps: 38 {35}
# Episode: 1375
# SOLVED! Steps: 3 {36}
# Episode: 1376
# SOLVED! Steps: 1 {37}
# Episode: 1377
# Episode: 1378
# Episode: 1379
# SOLVED! Steps: 23 {38}
# Episode: 1380
# SOLVED! Steps: 73 {39}
# Episode: 1381
# Episode: 1382
# Episode: 1383
# SOLVED! Steps: 6 {40}
# Episode: 1384
# SOLVED! Steps: 52 {41}
# Episode: 1385
# Episode: 1386
# Episode: 1387
# SOLVED! Steps: 1 {42}
# Episode: 1388
# SOLVED! Steps: 7 {43}
# Episode: 1389
# Episode: 1390
# SOLVED! Steps: 1 {44}
# Episode: 1391
# SOLVED! Steps: 3 {45}
# Episode: 1392
# SOLVED! Steps: 3 {46}
# Episode: 1393
# SOLVED! Steps: 7 {47}
# Episode: 1394
# Episode: 1395
# Episode: 1396
# SOLVED! Steps: 13 {48}
# Episode: 1397
# Episode: 1398
# SOLVED! Steps: 1 {49}
# Episode: 1399
# SOLVED! Steps: 3 {50}
# **************************************************
# [41, 43, 49, 43, 46, 48, 48, 51, 52, 50]
# **************************************************
# Episode: 1400
# Episode: 1401
# SOLVED! Steps: 18 {1}
# Episode: 1402
# Episode: 1403
# SOLVED! Steps: 1 {2}
# Episode: 1404
# SOLVED! Steps: 1 {3}
# Episode: 1405
# Episode: 1406
# SOLVED! Steps: 87 {4}
# Episode: 1407
# SOLVED! Steps: 68 {5}
# Episode: 1408
# SOLVED! Steps: 2 {6}
# Episode: 1409
# Episode: 1410
# SOLVED! Steps: 3 {7}
# Episode: 1411
# SOLVED! Steps: 2 {8}
# Episode: 1412
# SOLVED! Steps: 63 {9}
# Episode: 1413
# Episode: 1414
# Episode: 1415
# SOLVED! Steps: 1 {10}
# Episode: 1416
# SOLVED! Steps: 12 {11}
# Episode: 1417
# SOLVED! Steps: 1 {12}
# Episode: 1418
# Episode: 1419
# Episode: 1420
# SOLVED! Steps: 1 {13}
# Episode: 1421
# SOLVED! Steps: 7 {14}
# Episode: 1422
# SOLVED! Steps: 1 {15}
# Episode: 1423
# SOLVED! Steps: 37 {16}
# Episode: 1424
# Episode: 1425
# SOLVED! Steps: 7 {17}
# Episode: 1426
# Episode: 1427
# Episode: 1428
# SOLVED! Steps: 10 {18}
# Episode: 1429
# SOLVED! Steps: 1 {19}
# Episode: 1430
# SOLVED! Steps: 7 {20}
# Episode: 1431
# Episode: 1432
# Episode: 1433
# Episode: 1434
# Episode: 1435
# SOLVED! Steps: 2 {21}
# Episode: 1436
# SOLVED! Steps: 7 {22}
# Episode: 1437
# SOLVED! Steps: 1 {23}
# Episode: 1438
# Episode: 1439
# Episode: 1440
# Episode: 1441
# SOLVED! Steps: 46 {24}
# Episode: 1442
# Episode: 1443
# SOLVED! Steps: 2 {25}
# Episode: 1444
# Episode: 1445
# Episode: 1446
# SOLVED! Steps: 2 {26}
# Episode: 1447
# Episode: 1448
# Episode: 1449
# Episode: 1450
# Episode: 1451
# SOLVED! Steps: 16 {27}
# Episode: 1452
# Episode: 1453
# SOLVED! Steps: 1 {28}
# Episode: 1454
# Episode: 1455
# SOLVED! Steps: 1 {29}
# Episode: 1456
# SOLVED! Steps: 2 {30}
# Episode: 1457
# SOLVED! Steps: 7 {31}
# Episode: 1458
# SOLVED! Steps: 11 {32}
# Episode: 1459
# SOLVED! Steps: 33 {33}
# Episode: 1460
# Episode: 1461
# SOLVED! Steps: 3 {34}
# Episode: 1462
# SOLVED! Steps: 72 {35}
# Episode: 1463
# SOLVED! Steps: 1 {36}
# Episode: 1464
# SOLVED! Steps: 8 {37}
# Episode: 1465
# Episode: 1466
# Episode: 1467
# Episode: 1468
# Episode: 1469
# Episode: 1470
# SOLVED! Steps: 3 {38}
# Episode: 1471
# SOLVED! Steps: 6 {39}
# Episode: 1472
# SOLVED! Steps: 2 {40}
# Episode: 1473
# SOLVED! Steps: 5 {41}
# Episode: 1474
# SOLVED! Steps: 3 {42}
# Episode: 1475
# SOLVED! Steps: 3 {43}
# Episode: 1476
# SOLVED! Steps: 1 {44}
# Episode: 1477
# Episode: 1478
# Episode: 1479
# Episode: 1480
# Episode: 1481
# Episode: 1482
# Episode: 1483
# SOLVED! Steps: 1 {45}
# Episode: 1484
# SOLVED! Steps: 38 {46}
# Episode: 1485
# Episode: 1486
# Episode: 1487
# SOLVED! Steps: 1 {47}
# Episode: 1488
# SOLVED! Steps: 7 {48}
# Episode: 1489
# Episode: 1490
# SOLVED! Steps: 1 {49}
# Episode: 1491
# SOLVED! Steps: 3 {50}
# Episode: 1492
# SOLVED! Steps: 3 {51}
# Episode: 1493
# SOLVED! Steps: 7 {52}
# Episode: 1494
# Episode: 1495
# Episode: 1496
# SOLVED! Steps: 9 {53}
# Episode: 1497
# SOLVED! Steps: 61 {54}
# Episode: 1498
# SOLVED! Steps: 1 {55}
# Episode: 1499
# SOLVED! Steps: 3 {56}
# **************************************************
# [43, 49, 43, 46, 48, 48, 51, 52, 50, 56]
# **************************************************
# Episode: 1500
# SOLVED! Steps: 3 {1}
# Episode: 1501
# SOLVED! Steps: 6 {2}
# Episode: 1502
# Episode: 1503
# SOLVED! Steps: 1 {3}
# Episode: 1504
# SOLVED! Steps: 1 {4}
# Episode: 1505
# Episode: 1506
# Episode: 1507
# SOLVED! Steps: 6 {5}
# Episode: 1508
# SOLVED! Steps: 2 {6}
# Episode: 1509
# Episode: 1510
# SOLVED! Steps: 3 {7}
# Episode: 1511
# SOLVED! Steps: 2 {8}
# Episode: 1512
# Episode: 1513
# Episode: 1514
# SOLVED! Steps: 37 {9}
# Episode: 1515
# SOLVED! Steps: 1 {10}
# Episode: 1516
# SOLVED! Steps: 15 {11}
# Episode: 1517
# SOLVED! Steps: 1 {12}
# Episode: 1518
# Episode: 1519
# Episode: 1520
# SOLVED! Steps: 1 {13}
# Episode: 1521
# SOLVED! Steps: 7 {14}
# Episode: 1522
# SOLVED! Steps: 1 {15}
# Episode: 1523
# SOLVED! Steps: 25 {16}
# Episode: 1524
# Episode: 1525
# Episode: 1526
# Episode: 1527
# Episode: 1528
# SOLVED! Steps: 57 {17}
# Episode: 1529
# SOLVED! Steps: 1 {18}
# Episode: 1530
# Episode: 1531
# Episode: 1532
# Episode: 1533
# Episode: 1534
# Episode: 1535
# Episode: 1536
# SOLVED! Steps: 7 {19}
# Episode: 1537
# SOLVED! Steps: 1 {20}
# Episode: 1538
# Episode: 1539
# SOLVED! Steps: 1 {21}
# Episode: 1540
# SOLVED! Steps: 3 {22}
# Episode: 1541
# SOLVED! Steps: 21 {23}
# Episode: 1542
# Episode: 1543
# SOLVED! Steps: 2 {24}
# Episode: 1544
# SOLVED! Steps: 37 {25}
# Episode: 1545
# Episode: 1546
# SOLVED! Steps: 2 {26}
# Episode: 1547
# Episode: 1548
# Episode: 1549
# Episode: 1550
# Episode: 1551
# SOLVED! Steps: 4 {27}
# Episode: 1552
# Episode: 1553
# SOLVED! Steps: 1 {28}
# Episode: 1554
# Episode: 1555
# SOLVED! Steps: 1 {29}
# Episode: 1556
# SOLVED! Steps: 4 {30}
# Episode: 1557
# Episode: 1558
# SOLVED! Steps: 9 {31}
# Episode: 1559
# Episode: 1560
# Episode: 1561
# SOLVED! Steps: 3 {32}
# Episode: 1562
# SOLVED! Steps: 98 {33}
# Episode: 1563
# SOLVED! Steps: 11 {34}
# Episode: 1564
# SOLVED! Steps: 83 {35}
# Episode: 1565
# Episode: 1566
# SOLVED! Steps: 69 {36}
# Episode: 1567
# Episode: 1568
# Episode: 1569
# Episode: 1570
# SOLVED! Steps: 3 {37}
# Episode: 1571
# SOLVED! Steps: 6 {38}
# Episode: 1572
# SOLVED! Steps: 2 {39}
# Episode: 1573
# SOLVED! Steps: 4 {40}
# Episode: 1574
# SOLVED! Steps: 3 {41}
# Episode: 1575
# SOLVED! Steps: 3 {42}
# Episode: 1576
# SOLVED! Steps: 1 {43}
# Episode: 1577
# Episode: 1578
# Episode: 1579
# Episode: 1580
# SOLVED! Steps: 4 {44}
# Episode: 1581
# Episode: 1582
# Episode: 1583
# Episode: 1584
# SOLVED! Steps: 55 {45}
# Episode: 1585
# Episode: 1586
# Episode: 1587
# SOLVED! Steps: 6 {46}
# Episode: 1588
# SOLVED! Steps: 16 {47}
# Episode: 1589
# Episode: 1590
# SOLVED! Steps: 1 {48}
# Episode: 1591
# Episode: 1592
# Episode: 1593
# SOLVED! Steps: 38 {49}
# Episode: 1594
# Episode: 1595
# Episode: 1596
# SOLVED! Steps: 7 {50}
# Episode: 1597
# SOLVED! Steps: 7 {51}
# Episode: 1598
# SOLVED! Steps: 1 {52}
# Episode: 1599
# SOLVED! Steps: 3 {53}
# **************************************************
# [49, 43, 46, 48, 48, 51, 52, 50, 56, 53]
# **************************************************
# Episode: 1600
# SOLVED! Steps: 3 {1}
# Episode: 1601
# SOLVED! Steps: 82 {2}
# Episode: 1602
# Episode: 1603
# SOLVED! Steps: 1 {3}
# Episode: 1604
# SOLVED! Steps: 1 {4}
# Episode: 1605
# Episode: 1606
# Episode: 1607
# SOLVED! Steps: 9 {5}
# Episode: 1608
# SOLVED! Steps: 2 {6}
# Episode: 1609
# Episode: 1610
# SOLVED! Steps: 3 {7}
# Episode: 1611
# SOLVED! Steps: 2 {8}
# Episode: 1612
# Episode: 1613
# Episode: 1614
# Episode: 1615
# SOLVED! Steps: 1 {9}
# Episode: 1616
# SOLVED! Steps: 4 {10}
# Episode: 1617
# SOLVED! Steps: 1 {11}
# Episode: 1618
# Episode: 1619
# Episode: 1620
# SOLVED! Steps: 1 {12}
# Episode: 1621
# Episode: 1622
# SOLVED! Steps: 1 {13}
# Episode: 1623
# Episode: 1624
# Episode: 1625
# Episode: 1626
# SOLVED! Steps: 52 {14}
# Episode: 1627
# Episode: 1628
# SOLVED! Steps: 30 {15}
# Episode: 1629
# SOLVED! Steps: 1 {16}
# Episode: 1630
# Episode: 1631
# Episode: 1632
# Episode: 1633
# Episode: 1634
# Episode: 1635
# SOLVED! Steps: 2 {17}
# Episode: 1636
# Episode: 1637
# SOLVED! Steps: 1 {18}
# Episode: 1638
# Episode: 1639
# SOLVED! Steps: 2 {19}
# Episode: 1640
# SOLVED! Steps: 3 {20}
# Episode: 1641
# Episode: 1642
# Episode: 1643
# SOLVED! Steps: 2 {21}
# Episode: 1644
# Episode: 1645
# Episode: 1646
# SOLVED! Steps: 31 {22}
# Episode: 1647
# Episode: 1648
# Episode: 1649
# Episode: 1650
# Episode: 1651
# SOLVED! Steps: 1 {23}
# Episode: 1652
# Episode: 1653
# SOLVED! Steps: 1 {24}
# Episode: 1654
# SOLVED! Steps: 97 {25}
# Episode: 1655
# SOLVED! Steps: 1 {26}
# Episode: 1656
# SOLVED! Steps: 4 {27}
# Episode: 1657
# SOLVED! Steps: 7 {28}
# Episode: 1658
# Episode: 1659
# SOLVED! Steps: 32 {29}
# Episode: 1660
# Episode: 1661
# SOLVED! Steps: 3 {30}
# Episode: 1662
# Episode: 1663
# SOLVED! Steps: 1 {31}
# Episode: 1664
# SOLVED! Steps: 7 {32}
# Episode: 1665
# Episode: 1666
# Episode: 1667
# Episode: 1668
# Episode: 1669
# Episode: 1670
# SOLVED! Steps: 3 {33}
# Episode: 1671
# SOLVED! Steps: 89 {34}
# Episode: 1672
# SOLVED! Steps: 2 {35}
# Episode: 1673
# SOLVED! Steps: 6 {36}
# Episode: 1674
# SOLVED! Steps: 3 {37}
# Episode: 1675
# SOLVED! Steps: 3 {38}
# Episode: 1676
# SOLVED! Steps: 1 {39}
# Episode: 1677
# Episode: 1678
# Episode: 1679
# SOLVED! Steps: 82 {40}
# Episode: 1680
# Episode: 1681
# Episode: 1682
# SOLVED! Steps: 29 {41}
# Episode: 1683
# SOLVED! Steps: 3 {42}
# Episode: 1684
# SOLVED! Steps: 12 {43}
# Episode: 1685
# Episode: 1686
# Episode: 1687
# SOLVED! Steps: 1 {44}
# Episode: 1688
# SOLVED! Steps: 7 {45}
# Episode: 1689
# Episode: 1690
# Episode: 1691
# SOLVED! Steps: 3 {46}
# Episode: 1692
# SOLVED! Steps: 13 {47}
# Episode: 1693
# SOLVED! Steps: 18 {48}
# Episode: 1694
# Episode: 1695
# Episode: 1696
# SOLVED! Steps: 6 {49}
# Episode: 1697
# Episode: 1698
# SOLVED! Steps: 1 {50}
# Episode: 1699
# SOLVED! Steps: 3 {51}
# **************************************************
# [43, 46, 48, 48, 51, 52, 50, 56, 53, 51]
# **************************************************
# Episode: 1700
# SOLVED! Steps: 3 {1}
# Episode: 1701
# SOLVED! Steps: 24 {2}
# Episode: 1702
# Episode: 1703
# Episode: 1704
# SOLVED! Steps: 1 {3}
# Episode: 1705
# Episode: 1706
# Episode: 1707
# SOLVED! Steps: 7 {4}
# Episode: 1708
# SOLVED! Steps: 2 {5}
# Episode: 1709
# SOLVED! Steps: 46 {6}
# Episode: 1710
# SOLVED! Steps: 3 {7}
# Episode: 1711
# SOLVED! Steps: 2 {8}
# Episode: 1712
# SOLVED! Steps: 65 {9}
# Episode: 1713
# Episode: 1714
# Episode: 1715
# SOLVED! Steps: 1 {10}
# Episode: 1716
# SOLVED! Steps: 1 {11}
# Episode: 1717
# SOLVED! Steps: 1 {12}
# Episode: 1718
# SOLVED! Steps: 28 {13}
# Episode: 1719
# Episode: 1720
# SOLVED! Steps: 1 {14}
# Episode: 1721
# Episode: 1722
# SOLVED! Steps: 1 {15}
# Episode: 1723
# SOLVED! Steps: 97 {16}
# Episode: 1724
# Episode: 1725
# Episode: 1726
# Episode: 1727
# Episode: 1728
# SOLVED! Steps: 36 {17}
# Episode: 1729
# Episode: 1730
# Episode: 1731
# Episode: 1732
# Episode: 1733
# Episode: 1734
# Episode: 1735
# SOLVED! Steps: 2 {18}
# Episode: 1736
# SOLVED! Steps: 4 {19}
# Episode: 1737
# SOLVED! Steps: 1 {20}
# Episode: 1738
# Episode: 1739
# SOLVED! Steps: 45 {21}
# Episode: 1740
# SOLVED! Steps: 3 {22}
# Episode: 1741
# Episode: 1742
# Episode: 1743
# SOLVED! Steps: 2 {23}
# Episode: 1744
# Episode: 1745
# Episode: 1746
# SOLVED! Steps: 2 {24}
# Episode: 1747
# Episode: 1748
# Episode: 1749
# Episode: 1750
# Episode: 1751
# SOLVED! Steps: 1 {25}
# Episode: 1752
# SOLVED! Steps: 1 {26}
# Episode: 1753
# SOLVED! Steps: 1 {27}
# Episode: 1754
# Episode: 1755
# SOLVED! Steps: 1 {28}
# Episode: 1756
# SOLVED! Steps: 1 {29}
# Episode: 1757
# SOLVED! Steps: 7 {30}
# Episode: 1758
# SOLVED! Steps: 6 {31}
# Episode: 1759
# Episode: 1760
# Episode: 1761
# SOLVED! Steps: 3 {32}
# Episode: 1762
# Episode: 1763
# SOLVED! Steps: 1 {33}
# Episode: 1764
# SOLVED! Steps: 3 {34}
# Episode: 1765
# Episode: 1766
# Episode: 1767
# Episode: 1768
# Episode: 1769
# Episode: 1770
# SOLVED! Steps: 3 {35}
# Episode: 1771
# SOLVED! Steps: 6 {36}
# Episode: 1772
# SOLVED! Steps: 2 {37}
# Episode: 1773
# SOLVED! Steps: 4 {38}
# Episode: 1774
# SOLVED! Steps: 3 {39}
# Episode: 1775
# SOLVED! Steps: 3 {40}
# Episode: 1776
# SOLVED! Steps: 1 {41}
# Episode: 1777
# Episode: 1778
# Episode: 1779
# Episode: 1780
# SOLVED! Steps: 6 {42}
# Episode: 1781
# SOLVED! Steps: 34 {43}
# Episode: 1782
# Episode: 1783
# SOLVED! Steps: 1 {44}
# Episode: 1784
# SOLVED! Steps: 2 {45}
# Episode: 1785
# Episode: 1786
# Episode: 1787
# SOLVED! Steps: 1 {46}
# Episode: 1788
# SOLVED! Steps: 5 {47}
# Episode: 1789
# Episode: 1790
# SOLVED! Steps: 1 {48}
# Episode: 1791
# SOLVED! Steps: 3 {49}
# Episode: 1792
# SOLVED! Steps: 3 {50}
# Episode: 1793
# SOLVED! Steps: 4 {51}
# Episode: 1794
# Episode: 1795
# Episode: 1796
# Episode: 1797
# SOLVED! Steps: 5 {52}
# Episode: 1798
# SOLVED! Steps: 1 {53}
# Episode: 1799
# SOLVED! Steps: 3 {54}
# **************************************************
# [46, 48, 48, 51, 52, 50, 56, 53, 51, 54]
# **************************************************
# Episode: 1800
# SOLVED! Steps: 3 {1}
# Episode: 1801
# SOLVED! Steps: 6 {2}
# Episode: 1802
# Episode: 1803
# SOLVED! Steps: 1 {3}
# Episode: 1804
# SOLVED! Steps: 1 {4}
# Episode: 1805
# Episode: 1806
# Episode: 1807
# SOLVED! Steps: 16 {5}
# Episode: 1808
# SOLVED! Steps: 2 {6}
# Episode: 1809
# Episode: 1810
# SOLVED! Steps: 3 {7}
# Episode: 1811
# SOLVED! Steps: 2 {8}
# Episode: 1812
# Episode: 1813
# Episode: 1814
# Episode: 1815
# SOLVED! Steps: 1 {9}
# Episode: 1816
# SOLVED! Steps: 1 {10}
# Episode: 1817
# SOLVED! Steps: 1 {11}
# Episode: 1818
# Episode: 1819
# Episode: 1820
# SOLVED! Steps: 1 {12}
# Episode: 1821
# Episode: 1822
# SOLVED! Steps: 1 {13}
# Episode: 1823
# SOLVED! Steps: 67 {14}
# Episode: 1824
# Episode: 1825
# Episode: 1826
# Episode: 1827
# Episode: 1828
# SOLVED! Steps: 16 {15}
# Episode: 1829
# SOLVED! Steps: 1 {16}
# Episode: 1830
# Episode: 1831
# Episode: 1832
# Episode: 1833
# Episode: 1834
# Episode: 1835
# Episode: 1836
# Episode: 1837
# SOLVED! Steps: 1 {17}
# Episode: 1838
# Episode: 1839
# SOLVED! Steps: 1 {18}
# Episode: 1840
# SOLVED! Steps: 3 {19}
# Episode: 1841
# Episode: 1842
# Episode: 1843
# SOLVED! Steps: 2 {20}
# Episode: 1844
# Episode: 1845
# Episode: 1846
# SOLVED! Steps: 2 {21}
# Episode: 1847
# Episode: 1848
# Episode: 1849
# Episode: 1850
# Episode: 1851
# SOLVED! Steps: 1 {22}
# Episode: 1852
# SOLVED! Steps: 1 {23}
# Episode: 1853
# SOLVED! Steps: 8 {24}
# Episode: 1854
# Episode: 1855
# SOLVED! Steps: 1 {25}
# Episode: 1856
# SOLVED! Steps: 1 {26}
# Episode: 1857
# Episode: 1858
# Episode: 1859
# Episode: 1860
# Episode: 1861
# SOLVED! Steps: 3 {27}
# Episode: 1862
# SOLVED! Steps: 43 {28}
# Episode: 1863
# SOLVED! Steps: 1 {29}
# Episode: 1864
# SOLVED! Steps: 5 {30}
# Episode: 1865
# Episode: 1866
# Episode: 1867
# Episode: 1868
# Episode: 1869
# Episode: 1870
# SOLVED! Steps: 3 {31}
# Episode: 1871
# SOLVED! Steps: 6 {32}
# Episode: 1872
# SOLVED! Steps: 2 {33}
# Episode: 1873
# SOLVED! Steps: 2 {34}
# Episode: 1874
# SOLVED! Steps: 3 {35}
# Episode: 1875
# SOLVED! Steps: 3 {36}
# Episode: 1876
# SOLVED! Steps: 1 {37}
# Episode: 1877
# Episode: 1878
# SOLVED! Steps: 70 {38}
# Episode: 1879
# Episode: 1880
# SOLVED! Steps: 2 {39}
# Episode: 1881
# Episode: 1882
# SOLVED! Steps: 88 {40}
# Episode: 1883
# Episode: 1884
# SOLVED! Steps: 16 {41}
# Episode: 1885
# Episode: 1886
# Episode: 1887
# SOLVED! Steps: 1 {42}
# Episode: 1888
# SOLVED! Steps: 4 {43}
# Episode: 1889
# SOLVED! Steps: 19 {44}
# Episode: 1890
# SOLVED! Steps: 1 {45}
# Episode: 1891
# SOLVED! Steps: 3 {46}
# Episode: 1892
# SOLVED! Steps: 3 {47}
# Episode: 1893
# SOLVED! Steps: 17 {48}
# Episode: 1894
# Episode: 1895
# Episode: 1896
# Episode: 1897
# Episode: 1898
# SOLVED! Steps: 1 {49}
# Episode: 1899
# SOLVED! Steps: 3 {50}
# **************************************************
# [48, 48, 51, 52, 50, 56, 53, 51, 54, 50]
# **************************************************
# Episode: 1900
# SOLVED! Steps: 3 {1}
# Episode: 1901
# SOLVED! Steps: 12 {2}
# Episode: 1902
# Episode: 1903
# SOLVED! Steps: 1 {3}
# Episode: 1904
# SOLVED! Steps: 1 {4}
# Episode: 1905
# Episode: 1906
# SOLVED! Steps: 82 {5}
# Episode: 1907
# SOLVED! Steps: 6 {6}
# Episode: 1908
# SOLVED! Steps: 2 {7}
# Episode: 1909
# Episode: 1910
# SOLVED! Steps: 3 {8}
# Episode: 1911
# SOLVED! Steps: 2 {9}
# Episode: 1912
# SOLVED! Steps: 2 {10}
# Episode: 1913
# Episode: 1914
# Episode: 1915
# SOLVED! Steps: 1 {11}
# Episode: 1916
# SOLVED! Steps: 1 {12}
# Episode: 1917
# SOLVED! Steps: 26 {13}
# Episode: 1918
# Episode: 1919
# Episode: 1920
# SOLVED! Steps: 1 {14}
# Episode: 1921
# SOLVED! Steps: 4 {15}
# Episode: 1922
# SOLVED! Steps: 1 {16}
# ...
# SOLVED! Steps: 3 {54}
# Episode: 4593
# SOLVED! Steps: 3 {55}
# Episode: 4594
# SOLVED! Steps: 3 {56}
# Episode: 4595
# Episode: 4596
# SOLVED! Steps: 3 {57}
# Episode: 4597
# SOLVED! Steps: 3 {58}
# Episode: 4598
# SOLVED! Steps: 1 {59}
# Episode: 4599
# SOLVED! Steps: 3 {60}
# **************************************************
# [56, 59, 58, 59, 57, 58, 59, 59, 59, 60]
# **************************************************
# Episode: 4600
# SOLVED! Steps: 3 {1}
# Episode: 4601
# SOLVED! Steps: 3 {2}
# Episode: 4602
# Episode: 4603
# SOLVED! Steps: 7 {3}
# Episode: 4604
# SOLVED! Steps: 1 {4}
# Episode: 4605
# Episode: 4606
# Episode: 4607
# SOLVED! Steps: 3 {5}
# Episode: 4608
# SOLVED! Steps: 2 {6}
# Episode: 4609
# Episode: 4610
# SOLVED! Steps: 3 {7}
# Episode: 4611
# SOLVED! Steps: 2 {8}
# Episode: 4612
# SOLVED! Steps: 2 {9}
# Episode: 4613
# Episode: 4614
# SOLVED! Steps: 93 {10}
# Episode: 4615
# SOLVED! Steps: 1 {11}
# Episode: 4616
# SOLVED! Steps: 1 {12}
# Episode: 4617
# SOLVED! Steps: 1 {13}
# Episode: 4618
# Episode: 4619
# Episode: 4620
# SOLVED! Steps: 1 {14}
# Episode: 4621
# SOLVED! Steps: 3 {15}
# Episode: 4622
# SOLVED! Steps: 1 {16}
# Episode: 4623
# Episode: 4624
# Episode: 4625
# SOLVED! Steps: 3 {17}
# Episode: 4626
# Episode: 4627
# Episode: 4628
# Episode: 4629
# SOLVED! Steps: 1 {18}
# Episode: 4630
# SOLVED! Steps: 3 {19}
# Episode: 4631
# Episode: 4632
# Episode: 4633
# Episode: 4634
# Episode: 4635
# SOLVED! Steps: 2 {20}
# Episode: 4636
# SOLVED! Steps: 3 {21}
# Episode: 4637
# SOLVED! Steps: 1 {22}
# Episode: 4638
# Episode: 4639
# SOLVED! Steps: 1 {23}
# Episode: 4640
# SOLVED! Steps: 3 {24}
# Episode: 4641
# Episode: 4642
# Episode: 4643
# SOLVED! Steps: 2 {25}
# Episode: 4644
# Episode: 4645
# SOLVED! Steps: 61 {26}
# Episode: 4646
# SOLVED! Steps: 7 {27}
# Episode: 4647
# Episode: 4648
# Episode: 4649
# Episode: 4650
# Episode: 4651
# SOLVED! Steps: 1 {28}
# Episode: 4652
# SOLVED! Steps: 1 {29}
# Episode: 4653
# SOLVED! Steps: 1 {30}
# Episode: 4654
# Episode: 4655
# SOLVED! Steps: 1 {31}
# Episode: 4656
# SOLVED! Steps: 1 {32}
# Episode: 4657
# SOLVED! Steps: 3 {33}
# Episode: 4658
# SOLVED! Steps: 3 {34}
# Episode: 4659
# Episode: 4660
# Episode: 4661
# SOLVED! Steps: 3 {35}
# Episode: 4662
# Episode: 4663
# SOLVED! Steps: 1 {36}
# Episode: 4664
# SOLVED! Steps: 3 {37}
# Episode: 4665
# Episode: 4666
# Episode: 4667
# Episode: 4668
# Episode: 4669
# Episode: 4670
# SOLVED! Steps: 3 {38}
# Episode: 4671
# SOLVED! Steps: 2 {39}
# Episode: 4672
# SOLVED! Steps: 2 {40}
# Episode: 4673
# SOLVED! Steps: 2 {41}
# Episode: 4674
# SOLVED! Steps: 9 {42}
# Episode: 4675
# SOLVED! Steps: 3 {43}
# Episode: 4676
# SOLVED! Steps: 1 {44}
# Episode: 4677
# Episode: 4678
# Episode: 4679
# Episode: 4680
# SOLVED! Steps: 2 {45}
# Episode: 4681
# Episode: 4682
# Episode: 4683
# SOLVED! Steps: 1 {46}
# Episode: 4684
# SOLVED! Steps: 67 {47}
# Episode: 4685
# Episode: 4686
# Episode: 4687
# SOLVED! Steps: 1 {48}
# Episode: 4688
# SOLVED! Steps: 3 {49}
# Episode: 4689
# SOLVED! Steps: 3 {50}
# Episode: 4690
# SOLVED! Steps: 1 {51}
# Episode: 4691
# SOLVED! Steps: 3 {52}
# Episode: 4692
# SOLVED! Steps: 3 {53}
# Episode: 4693
# SOLVED! Steps: 3 {54}
# Episode: 4694
# SOLVED! Steps: 3 {55}
# Episode: 4695
# Episode: 4696
# SOLVED! Steps: 3 {56}
# Episode: 4697
# SOLVED! Steps: 3 {57}
# Episode: 4698
# SOLVED! Steps: 1 {58}
# Episode: 4699
# SOLVED! Steps: 3 {59}
# **************************************************
# [59, 58, 59, 57, 58, 59, 59, 59, 60, 59]
# **************************************************
# Episode: 4700
# SOLVED! Steps: 3 {1}
# Episode: 4701
# SOLVED! Steps: 3 {2}
# Episode: 4702
# Episode: 4703
# SOLVED! Steps: 1 {3}
# Episode: 4704
# SOLVED! Steps: 1 {4}
# Episode: 4705
# Episode: 4706
# Episode: 4707
# SOLVED! Steps: 31 {5}
# Episode: 4708
# SOLVED! Steps: 2 {6}
# Episode: 4709
# Episode: 4710
# SOLVED! Steps: 3 {7}
# Episode: 4711
# SOLVED! Steps: 2 {8}
# Episode: 4712
# SOLVED! Steps: 2 {9}
# Episode: 4713
# Episode: 4714
# Episode: 4715
# SOLVED! Steps: 1 {10}
# Episode: 4716
# SOLVED! Steps: 1 {11}
# Episode: 4717
# SOLVED! Steps: 1 {12}
# Episode: 4718
# Episode: 4719
# Episode: 4720
# SOLVED! Steps: 1 {13}
# Episode: 4721
# SOLVED! Steps: 3 {14}
# Episode: 4722
# SOLVED! Steps: 1 {15}
# Episode: 4723
# Episode: 4724
# Episode: 4725
# SOLVED! Steps: 3 {16}
# Episode: 4726
# Episode: 4727
# Episode: 4728
# Episode: 4729
# SOLVED! Steps: 1 {17}
# Episode: 4730
# SOLVED! Steps: 3 {18}
# Episode: 4731
# SOLVED! Steps: 86 {19}
# Episode: 4732
# Episode: 4733
# SOLVED! Steps: 92 {20}
# Episode: 4734
# Episode: 4735
# SOLVED! Steps: 2 {21}
# Episode: 4736
# SOLVED! Steps: 3 {22}
# Episode: 4737
# SOLVED! Steps: 1 {23}
# Episode: 4738
# Episode: 4739
# SOLVED! Steps: 1 {24}
# Episode: 4740
# SOLVED! Steps: 3 {25}
# Episode: 4741
# SOLVED! Steps: 88 {26}
# Episode: 4742
# Episode: 4743
# SOLVED! Steps: 2 {27}
# Episode: 4744
# Episode: 4745
# SOLVED! Steps: 61 {28}
# Episode: 4746
# SOLVED! Steps: 2 {29}
# Episode: 4747
# Episode: 4748
# Episode: 4749
# Episode: 4750
# Episode: 4751
# SOLVED! Steps: 1 {30}
# Episode: 4752
# SOLVED! Steps: 1 {31}
# Episode: 4753
# SOLVED! Steps: 1 {32}
# Episode: 4754
# Episode: 4755
# SOLVED! Steps: 1 {33}
# Episode: 4756
# SOLVED! Steps: 1 {34}
# Episode: 4757
# SOLVED! Steps: 3 {35}
# Episode: 4758
# SOLVED! Steps: 3 {36}
# Episode: 4759
# Episode: 4760
# Episode: 4761
# SOLVED! Steps: 3 {37}
# Episode: 4762
# Episode: 4763
# SOLVED! Steps: 1 {38}
# Episode: 4764
# SOLVED! Steps: 3 {39}
# Episode: 4765
# Episode: 4766
# Episode: 4767
# Episode: 4768
# Episode: 4769
# Episode: 4770
# SOLVED! Steps: 3 {40}
# Episode: 4771
# SOLVED! Steps: 2 {41}
# Episode: 4772
# SOLVED! Steps: 2 {42}
# Episode: 4773
# SOLVED! Steps: 2 {43}
# Episode: 4774
# SOLVED! Steps: 3 {44}
# Episode: 4775
# SOLVED! Steps: 3 {45}
# Episode: 4776
# SOLVED! Steps: 1 {46}
# Episode: 4777
# Episode: 4778
# Episode: 4779
# SOLVED! Steps: 49 {47}
# Episode: 4780
# SOLVED! Steps: 2 {48}
# Episode: 4781
# Episode: 4782
# Episode: 4783
# SOLVED! Steps: 1 {49}
# Episode: 4784
# SOLVED! Steps: 2 {50}
# Episode: 4785
# Episode: 4786
# Episode: 4787
# SOLVED! Steps: 1 {51}
# Episode: 4788
# SOLVED! Steps: 3 {52}
# Episode: 4789
# SOLVED! Steps: 3 {53}
# Episode: 4790
# SOLVED! Steps: 1 {54}
# Episode: 4791
# SOLVED! Steps: 3 {55}
# Episode: 4792
# SOLVED! Steps: 3 {56}
# Episode: 4793
# SOLVED! Steps: 3 {57}
# Episode: 4794
# SOLVED! Steps: 3 {58}
# Episode: 4795
# Episode: 4796
# SOLVED! Steps: 3 {59}
# Episode: 4797
# SOLVED! Steps: 3 {60}
# Episode: 4798
# SOLVED! Steps: 1 {61}
# Episode: 4799
# SOLVED! Steps: 3 {62}
# **************************************************
# [58, 59, 57, 58, 59, 59, 59, 60, 59, 62]
# **************************************************
# Episode: 4800
# SOLVED! Steps: 3 {1}
# Episode: 4801
# SOLVED! Steps: 3 {2}
# Episode: 4802
# Episode: 4803
# SOLVED! Steps: 1 {3}
# Episode: 4804
# SOLVED! Steps: 1 {4}
# Episode: 4805
# SOLVED! Steps: 71 {5}
# Episode: 4806
# Episode: 4807
# SOLVED! Steps: 3 {6}
# Episode: 4808
# SOLVED! Steps: 2 {7}
# Episode: 4809
# Episode: 4810
# SOLVED! Steps: 3 {8}
# Episode: 4811
# SOLVED! Steps: 2 {9}
# Episode: 4812
# SOLVED! Steps: 2 {10}
# Episode: 4813
# Episode: 4814
# Episode: 4815
# SOLVED! Steps: 1 {11}
# Episode: 4816
# SOLVED! Steps: 1 {12}
# Episode: 4817
# SOLVED! Steps: 1 {13}
# Episode: 4818
# SOLVED! Steps: 97 {14}
# Episode: 4819
# Episode: 4820
# SOLVED! Steps: 1 {15}
# Episode: 4821
# SOLVED! Steps: 3 {16}
# Episode: 4822
# SOLVED! Steps: 1 {17}
# Episode: 4823
# SOLVED! Steps: 79 {18}
# Episode: 4824
# Episode: 4825
# SOLVED! Steps: 3 {19}
# Episode: 4826
# Episode: 4827
# Episode: 4828
# Episode: 4829
# SOLVED! Steps: 1 {20}
# Episode: 4830
# SOLVED! Steps: 3 {21}
# Episode: 4831
# Episode: 4832
# Episode: 4833
# SOLVED! Steps: 92 {22}
# Episode: 4834
# Episode: 4835
# SOLVED! Steps: 2 {23}
# Episode: 4836
# SOLVED! Steps: 3 {24}
# Episode: 4837
# Episode: 4838
# Episode: 4839
# SOLVED! Steps: 1 {25}
# Episode: 4840
# SOLVED! Steps: 3 {26}
# Episode: 4841
# Episode: 4842
# Episode: 4843
# SOLVED! Steps: 2 {27}
# Episode: 4844
# Episode: 4845
# Episode: 4846
# Episode: 4847
# Episode: 4848
# Episode: 4849
# Episode: 4850
# Episode: 4851
# SOLVED! Steps: 1 {28}
# Episode: 4852
# SOLVED! Steps: 1 {29}
# Episode: 4853
# SOLVED! Steps: 1 {30}
# Episode: 4854
# Episode: 4855
# SOLVED! Steps: 1 {31}
# Episode: 4856
# SOLVED! Steps: 1 {32}
# Episode: 4857
# SOLVED! Steps: 3 {33}
# Episode: 4858
# SOLVED! Steps: 3 {34}
# Episode: 4859
# SOLVED! Steps: 34 {35}
# Episode: 4860
# Episode: 4861
# SOLVED! Steps: 3 {36}
# Episode: 4862
# Episode: 4863
# SOLVED! Steps: 1 {37}
# Episode: 4864
# SOLVED! Steps: 3 {38}
# Episode: 4865
# Episode: 4866
# Episode: 4867
# Episode: 4868
# Episode: 4869
# Episode: 4870
# SOLVED! Steps: 3 {39}
# Episode: 4871
# SOLVED! Steps: 2 {40}
# Episode: 4872
# SOLVED! Steps: 2 {41}
# Episode: 4873
# SOLVED! Steps: 2 {42}
# Episode: 4874
# SOLVED! Steps: 3 {43}
# Episode: 4875
# SOLVED! Steps: 3 {44}
# Episode: 4876
# SOLVED! Steps: 1 {45}
# Episode: 4877
# Episode: 4878
# Episode: 4879
# Episode: 4880
# SOLVED! Steps: 2 {46}
# Episode: 4881
# Episode: 4882
# Episode: 4883
# SOLVED! Steps: 1 {47}
# Episode: 4884
# SOLVED! Steps: 2 {48}
# Episode: 4885
# Episode: 4886
# Episode: 4887
# SOLVED! Steps: 1 {49}
# Episode: 4888
# SOLVED! Steps: 3 {50}
# Episode: 4889
# SOLVED! Steps: 3 {51}
# Episode: 4890
# SOLVED! Steps: 1 {52}
# Episode: 4891
# SOLVED! Steps: 3 {53}
# Episode: 4892
# SOLVED! Steps: 3 {54}
# Episode: 4893
# SOLVED! Steps: 3 {55}
# Episode: 4894
# SOLVED! Steps: 3 {56}
# Episode: 4895
# Episode: 4896
# SOLVED! Steps: 3 {57}
# Episode: 4897
# SOLVED! Steps: 3 {58}
# Episode: 4898
# SOLVED! Steps: 1 {59}
# Episode: 4899
# SOLVED! Steps: 3 {60}
# **************************************************
# [59, 57, 58, 59, 59, 59, 60, 59, 62, 60]
# **************************************************
# Episode: 4900
# SOLVED! Steps: 3 {1}
# Episode: 4901
# SOLVED! Steps: 3 {2}
# Episode: 4902
# Episode: 4903
# SOLVED! Steps: 1 {3}
# Episode: 4904
# SOLVED! Steps: 1 {4}
# Episode: 4905
# Episode: 4906
# Episode: 4907
# SOLVED! Steps: 3 {5}
# Episode: 4908
# SOLVED! Steps: 2 {6}
# Episode: 4909
# SOLVED! Steps: 76 {7}
# Episode: 4910
# SOLVED! Steps: 3 {8}
# Episode: 4911
# SOLVED! Steps: 2 {9}
# Episode: 4912
# Episode: 4913
# Episode: 4914
# SOLVED! Steps: 17 {10}
# Episode: 4915
# SOLVED! Steps: 1 {11}
# Episode: 4916
# SOLVED! Steps: 1 {12}
# Episode: 4917
# SOLVED! Steps: 1 {13}
# Episode: 4918
# Episode: 4919
# Episode: 4920
# SOLVED! Steps: 1 {14}
# Episode: 4921
# SOLVED! Steps: 3 {15}
# Episode: 4922
# SOLVED! Steps: 1 {16}
# Episode: 4923
# Episode: 4924
# Episode: 4925
# SOLVED! Steps: 3 {17}
# Episode: 4926
# Episode: 4927
# Episode: 4928
# Episode: 4929
# SOLVED! Steps: 1 {18}
# Episode: 4930
# SOLVED! Steps: 3 {19}
# Episode: 4931
# Episode: 4932
# Episode: 4933
# SOLVED! Steps: 34 {20}
# Episode: 4934
# Episode: 4935
# SOLVED! Steps: 2 {21}
# Episode: 4936
# SOLVED! Steps: 3 {22}
# Episode: 4937
# SOLVED! Steps: 1 {23}
# Episode: 4938
# Episode: 4939
# SOLVED! Steps: 1 {24}
# Episode: 4940
# SOLVED! Steps: 3 {25}
# Episode: 4941
# Episode: 4942
# Episode: 4943
# SOLVED! Steps: 2 {26}
# Episode: 4944
# Episode: 4945
# Episode: 4946
# SOLVED! Steps: 2 {27}
# Episode: 4947
# Episode: 4948
# Episode: 4949
# Episode: 4950
# Episode: 4951
# SOLVED! Steps: 1 {28}
# Episode: 4952
# Episode: 4953
# SOLVED! Steps: 1 {29}
# Episode: 4954
# Episode: 4955
# SOLVED! Steps: 1 {30}
# Episode: 4956
# SOLVED! Steps: 1 {31}
# Episode: 4957
# SOLVED! Steps: 3 {32}
# Episode: 4958
# SOLVED! Steps: 3 {33}
# Episode: 4959
# Episode: 4960
# Episode: 4961
# SOLVED! Steps: 3 {34}
# Episode: 4962
# Episode: 4963
# SOLVED! Steps: 1 {35}
# Episode: 4964
# SOLVED! Steps: 3 {36}
# Episode: 4965
# Episode: 4966
# SOLVED! Steps: 91 {37}
# Episode: 4967
# Episode: 4968
# Episode: 4969
# Episode: 4970
# SOLVED! Steps: 3 {38}
# Episode: 4971
# SOLVED! Steps: 2 {39}
# Episode: 4972
# SOLVED! Steps: 2 {40}
# Episode: 4973
# SOLVED! Steps: 2 {41}
# Episode: 4974
# SOLVED! Steps: 3 {42}
# Episode: 4975
# Episode: 4976
# SOLVED! Steps: 1 {43}
# Episode: 4977
# Episode: 4978
# Episode: 4979
# Episode: 4980
# SOLVED! Steps: 2 {44}
# Episode: 4981
# Episode: 4982
# Episode: 4983
# SOLVED! Steps: 1 {45}
# Episode: 4984
# SOLVED! Steps: 61 {46}
# Episode: 4985
# Episode: 4986
# Episode: 4987
# SOLVED! Steps: 1 {47}
# Episode: 4988
# SOLVED! Steps: 3 {48}
# Episode: 4989
# SOLVED! Steps: 3 {49}
# Episode: 4990
# SOLVED! Steps: 1 {50}
# Episode: 4991
# SOLVED! Steps: 3 {51}
# Episode: 4992
# SOLVED! Steps: 3 {52}
# Episode: 4993
# SOLVED! Steps: 3 {53}
# Episode: 4994
# SOLVED! Steps: 3 {54}
# Episode: 4995
# Episode: 4996
# SOLVED! Steps: 3 {55}
# Episode: 4997
# SOLVED! Steps: 3 {56}
# Episode: 4998
# SOLVED! Steps: 1 {57}
# Episode: 4999
# SOLVED! Steps: 3 {58}
# **************************************************
# [57, 58, 59, 59, 59, 60, 59, 62, 60, 58]
# **************************************************
# Episode: 5000
# SOLVED! Steps: 3 {1}
# Episode: 5001
# SOLVED! Steps: 3 {2}
# Episode: 5002
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-986fd837840c> in <module>
#      28         if current_epsilon < 0.1 and step >= 20:
#      29             agent.epsilon = 0.9
# ---> 30         action = agent.act(state)
#      31         agent.epsilon = current_epsilon
#      32
#
# <ipython-input-13-67b7600bfa50> in act(self, state)
#      57             return random.randrange(self.action_size)
#      58
# ---> 59         act_values = self.model.predict(state, verbose=0)
#      60         return np.argmax(act_values[0])
#      61
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1756               stacklevel=2)
#    1757
# -> 1758       data_handler = data_adapter.get_data_handler(
#    1759           x=x,
#    1760           batch_size=batch_size,
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1401   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1402     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1403   return DataHandler(*args, **kwargs)
#    1404
#    1405
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1151
#    1152     adapter_cls = select_data_adapter(x, y)
# -> 1153     self._adapter = adapter_cls(
#    1154         x,
#    1155         y,
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     325     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     326
# --> 327     dataset = self.slice_inputs(indices_dataset, inputs)
#     328
#     329     if shuffle == "batch":
#
# ~\anaconda3\lib\site-packages\keras\engine\data_adapter.py in slice_inputs(self, indices_dataset, inputs)
#     357       return tf.nest.map_structure(lambda d: tf.gather(d, i, axis=0), data)
#     358
# --> 359     dataset = dataset.map(
#     360         grab_batch, num_parallel_calls=tf.data.AUTOTUNE)
#     361
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in map(self, map_func, num_parallel_calls, deterministic, name)
#    2004       return MapDataset(self, map_func, preserve_cardinality=True, name=name)
#    2005     else:
# -> 2006       return ParallelMapDataset(
#    2007           self,
#    2008           map_func,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func, num_parallel_calls, deterministic, use_inter_op_parallelism, preserve_cardinality, use_legacy_function, name)
#    5519     if name or compat.forward_compatible(2021, 9, 30):
#    5520       kwargs["metadata"] = self._metadata.SerializeToString()
# -> 5521     variant_tensor = gen_dataset_ops.parallel_map_dataset_v2(
#    5522         input_dataset._variant_tensor,  # pylint: disable=protected-access
#    5523         self._map_func.function.captured_inputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in parallel_map_dataset_v2(input_dataset, other_arguments, num_parallel_calls, f, output_types, output_shapes, use_inter_op_parallelism, deterministic, preserve_cardinality, metadata, name)
#    5715   if tld.is_eager:
#    5716     try:
# -> 5717       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    5718         _ctx, "ParallelMapDatasetV2", name, input_dataset, other_arguments,
#    5719         num_parallel_calls, "f", f, "output_types", output_types,
#
# KeyboardInterrupt:

# %% [markdown]
# ## Test Generalization

# %% [markdown]
# #### Learned Policy

# %%
agent.epsilon = 0.0
num_solved = 0

for t in range(100):    
    random.seed(t+100)
    sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
    sok.set_maxsteps(100)
    
    steps = 0
        
    state = sok.get_image('rgb_array')
    done = False
    while not done:
        steps += 1
        action = agent.act(process_frame(state))

        if action < 4:
            action += 1
        else:
            action += 5

        state, reward, done, info = sok.step(action)
        
    solved = False
    if 3 in sok.room_state:
        solved = True
        num_solved += 1
    
    print("Puzzle # %d: %d (%s) [%d/%d]" % ((t+1), steps, "YES" if solved else "NOT", num_solved, (t+1)))
# Out:
# Puzzle # 1: 100 (NOT) [0/1]
# Puzzle # 2: 2 (YES) [1/2]
# Puzzle # 3: 2 (YES) [2/3]
# Puzzle # 4: 100 (NOT) [2/4]
# Puzzle # 5: 100 (NOT) [2/5]
# Puzzle # 6: 3 (YES) [3/6]
# Puzzle # 7: 3 (YES) [4/7]
# Puzzle # 8: 2 (YES) [5/8]
# Puzzle # 9: 100 (NOT) [5/9]
# Puzzle # 10: 100 (NOT) [5/10]
# Puzzle # 11: 2 (YES) [6/11]
# Puzzle # 12: 100 (NOT) [6/12]
# Puzzle # 13: 100 (NOT) [6/13]
# Puzzle # 14: 3 (YES) [7/14]
# Puzzle # 15: 100 (NOT) [7/15]
# Puzzle # 16: 100 (NOT) [7/16]
# Puzzle # 17: 100 (NOT) [7/17]
# Puzzle # 18: 100 (NOT) [7/18]
# Puzzle # 19: 2 (YES) [8/19]
# Puzzle # 20: 100 (NOT) [8/20]
# Puzzle # 21: 100 (NOT) [8/21]
# Puzzle # 22: 100 (NOT) [8/22]
# Puzzle # 23: 100 (NOT) [8/23]
# Puzzle # 24: 100 (NOT) [8/24]
# Puzzle # 25: 100 (NOT) [8/25]
# Puzzle # 26: 100 (NOT) [8/26]
# Puzzle # 27: 100 (NOT) [8/27]
# Puzzle # 28: 100 (NOT) [8/28]
# Puzzle # 29: 100 (NOT) [8/29]
# Puzzle # 30: 1 (YES) [9/30]
# Puzzle # 31: 100 (NOT) [9/31]
# Puzzle # 32: 100 (NOT) [9/32]
# Puzzle # 33: 3 (YES) [10/33]
# Puzzle # 34: 100 (NOT) [10/34]
# Puzzle # 35: 100 (NOT) [10/35]
# Puzzle # 36: 100 (NOT) [10/36]
# Puzzle # 37: 100 (NOT) [10/37]
# Puzzle # 38: 3 (YES) [11/38]
# Puzzle # 39: 100 (NOT) [11/39]
# Puzzle # 40: 2 (YES) [12/40]
# Puzzle # 41: 100 (NOT) [12/41]
# Puzzle # 42: 3 (YES) [13/42]
# Puzzle # 43: 100 (NOT) [13/43]
# Puzzle # 44: 100 (NOT) [13/44]
# Puzzle # 45: 100 (NOT) [13/45]
# Puzzle # 46: 100 (NOT) [13/46]
# Puzzle # 47: 100 (NOT) [13/47]
# Puzzle # 48: 100 (NOT) [13/48]
# Puzzle # 49: 1 (YES) [14/49]
# Puzzle # 50: 100 (NOT) [14/50]
# Puzzle # 51: 100 (NOT) [14/51]
# Puzzle # 52: 3 (YES) [15/52]
# Puzzle # 53: 100 (NOT) [15/53]
# Puzzle # 54: 3 (YES) [16/54]
# Puzzle # 55: 2 (YES) [17/55]
# Puzzle # 56: 100 (NOT) [17/56]
# Puzzle # 57: 100 (NOT) [17/57]
# Puzzle # 58: 100 (NOT) [17/58]
# Puzzle # 59: 100 (NOT) [17/59]
# Puzzle # 60: 100 (NOT) [17/60]
# Puzzle # 61: 100 (NOT) [17/61]
# Puzzle # 62: 1 (YES) [18/62]
# Puzzle # 63: 100 (NOT) [18/63]
# Puzzle # 64: 100 (NOT) [18/64]
# Puzzle # 65: 100 (NOT) [18/65]
# Puzzle # 66: 100 (NOT) [18/66]
# Puzzle # 67: 100 (NOT) [18/67]
# Puzzle # 68: 100 (NOT) [18/68]
# Puzzle # 69: 3 (YES) [19/69]
# Puzzle # 70: 100 (NOT) [19/70]
# Puzzle # 71: 100 (NOT) [19/71]
# Puzzle # 72: 100 (NOT) [19/72]
# Puzzle # 73: 100 (NOT) [19/73]
# Puzzle # 74: 100 (NOT) [19/74]
# Puzzle # 75: 100 (NOT) [19/75]
# Puzzle # 76: 100 (NOT) [19/76]
# Puzzle # 77: 100 (NOT) [19/77]
# Puzzle # 78: 100 (NOT) [19/78]
# Puzzle # 79: 100 (NOT) [19/79]
# Puzzle # 80: 100 (NOT) [19/80]
# Puzzle # 81: 100 (NOT) [19/81]
# Puzzle # 82: 100 (NOT) [19/82]
# Puzzle # 83: 100 (NOT) [19/83]
# Puzzle # 84: 3 (YES) [20/84]
# Puzzle # 85: 100 (NOT) [20/85]
# Puzzle # 86: 1 (YES) [21/86]
# Puzzle # 87: 100 (NOT) [21/87]
# Puzzle # 88: 100 (NOT) [21/88]
# Puzzle # 89: 100 (NOT) [21/89]
# Puzzle # 90: 100 (NOT) [21/90]
# Puzzle # 91: 1 (YES) [22/91]
# Puzzle # 92: 1 (YES) [23/92]
# Puzzle # 93: 100 (NOT) [23/93]
# Puzzle # 94: 1 (YES) [24/94]
# Puzzle # 95: 100 (NOT) [24/95]
# Puzzle # 96: 1 (YES) [25/96]
# Puzzle # 97: 100 (NOT) [25/97]
# Puzzle # 98: 100 (NOT) [25/98]
# Puzzle # 99: 100 (NOT) [25/99]
# Puzzle # 100: 100 (NOT) [25/100]

# %% [markdown]
# #### Random Policy

# %%
agent.epsilon = 1.0
num_solved = 0

for t in range(100):    
    random.seed(t+100)
    sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
    sok.set_maxsteps(100)
    
    steps = 0
        
    state = sok.get_image('rgb_array')
    done = False
    while not done:
        steps += 1
        action = agent.act(process_frame(state))

        if action < 4:
            action += 1
        else:
            action += 5

        state, reward, done, info = sok.step(action)
        
    solved = False
    if 3 in sok.room_state:
        solved = True
        num_solved += 1
    
    print("Puzzle # %d: %d (%s) [%d/%d]" % ((t+1), steps, "YES" if solved else "NOT", num_solved, (t+1)))
# Out:
# Puzzle # 1: 100 (NOT) [0/1]
# Puzzle # 2: 100 (NOT) [0/2]
# Puzzle # 3: 100 (NOT) [0/3]
# Puzzle # 4: 100 (NOT) [0/4]
# Puzzle # 5: 100 (NOT) [0/5]
# Puzzle # 6: 100 (NOT) [0/6]
# Puzzle # 7: 100 (NOT) [0/7]
# Puzzle # 8: 46 (YES) [1/8]
# Puzzle # 9: 26 (YES) [2/9]
# Puzzle # 10: 100 (NOT) [2/10]
# Puzzle # 11: 9 (YES) [3/11]
# Puzzle # 12: 100 (NOT) [3/12]
# Puzzle # 13: 100 (NOT) [3/13]
# Puzzle # 14: 100 (NOT) [3/14]
# Puzzle # 15: 1 (YES) [4/15]
# Puzzle # 16: 100 (NOT) [4/16]
# Puzzle # 17: 100 (NOT) [4/17]
# Puzzle # 18: 100 (NOT) [4/18]
# Puzzle # 19: 89 (YES) [5/19]
# Puzzle # 20: 10 (YES) [6/20]
# Puzzle # 21: 100 (NOT) [6/21]
# Puzzle # 22: 4 (YES) [7/22]
# Puzzle # 23: 100 (NOT) [7/23]
# Puzzle # 24: 100 (NOT) [7/24]
# Puzzle # 25: 100 (NOT) [7/25]
# Puzzle # 26: 100 (NOT) [7/26]
# Puzzle # 27: 100 (NOT) [7/27]
# Puzzle # 28: 100 (NOT) [7/28]
# Puzzle # 29: 100 (NOT) [7/29]
# Puzzle # 30: 11 (YES) [8/30]
# Puzzle # 31: 100 (NOT) [8/31]
# Puzzle # 32: 100 (NOT) [8/32]
# Puzzle # 33: 100 (NOT) [8/33]
# Puzzle # 34: 100 (NOT) [8/34]
# Puzzle # 35: 70 (YES) [9/35]
# Puzzle # 36: 100 (NOT) [9/36]
# Puzzle # 37: 100 (NOT) [9/37]
# Puzzle # 38: 100 (NOT) [9/38]
# Puzzle # 39: 100 (NOT) [9/39]
# Puzzle # 40: 12 (YES) [10/40]
# Puzzle # 41: 100 (NOT) [10/41]
# Puzzle # 42: 100 (NOT) [10/42]
# Puzzle # 43: 100 (NOT) [10/43]
# Puzzle # 44: 100 (NOT) [10/44]
# Puzzle # 45: 100 (NOT) [10/45]
# Puzzle # 46: 100 (NOT) [10/46]
# Puzzle # 47: 100 (NOT) [10/47]
# Puzzle # 48: 19 (YES) [11/48]
# Puzzle # 49: 42 (YES) [12/49]
# Puzzle # 50: 100 (NOT) [12/50]
# Puzzle # 51: 85 (YES) [13/51]
# Puzzle # 52: 100 (NOT) [13/52]
# Puzzle # 53: 100 (NOT) [13/53]
# Puzzle # 54: 100 (NOT) [13/54]
# Puzzle # 55: 3 (YES) [14/55]
# Puzzle # 56: 100 (NOT) [14/56]
# Puzzle # 57: 5 (YES) [15/57]
# Puzzle # 58: 6 (YES) [16/58]
# Puzzle # 59: 38 (YES) [17/59]
# Puzzle # 60: 23 (YES) [18/60]
# Puzzle # 61: 100 (NOT) [18/61]
# Puzzle # 62: 1 (YES) [19/62]
# Puzzle # 63: 100 (NOT) [19/63]
# Puzzle # 64: 100 (NOT) [19/64]
# Puzzle # 65: 43 (YES) [20/65]
# Puzzle # 66: 7 (YES) [21/66]
# Puzzle # 67: 100 (NOT) [21/67]
# Puzzle # 68: 100 (NOT) [21/68]
# Puzzle # 69: 100 (NOT) [21/69]
# Puzzle # 70: 100 (NOT) [21/70]
# Puzzle # 71: 11 (YES) [22/71]
# Puzzle # 72: 1 (YES) [23/72]
# Puzzle # 73: 5 (YES) [24/73]
# Puzzle # 74: 100 (NOT) [24/74]
# Puzzle # 75: 100 (NOT) [24/75]
# Puzzle # 76: 100 (NOT) [24/76]
# Puzzle # 77: 100 (NOT) [24/77]
# Puzzle # 78: 100 (NOT) [24/78]
# Puzzle # 79: 100 (NOT) [24/79]
# Puzzle # 80: 100 (NOT) [24/80]
# Puzzle # 81: 100 (NOT) [24/81]
# Puzzle # 82: 100 (NOT) [24/82]
# Puzzle # 83: 17 (YES) [25/83]
# Puzzle # 84: 100 (NOT) [25/84]
# Puzzle # 85: 42 (YES) [26/85]
# Puzzle # 86: 71 (YES) [27/86]
# Puzzle # 87: 100 (NOT) [27/87]
# Puzzle # 88: 100 (NOT) [27/88]
# Puzzle # 89: 40 (YES) [28/89]
# Puzzle # 90: 100 (NOT) [28/90]
# Puzzle # 91: 2 (YES) [29/91]
# Puzzle # 92: 74 (YES) [30/92]
# Puzzle # 93: 100 (NOT) [30/93]
# Puzzle # 94: 1 (YES) [31/94]
# Puzzle # 95: 12 (YES) [32/95]
# Puzzle # 96: 13 (YES) [33/96]
# Puzzle # 97: 100 (NOT) [33/97]
# Puzzle # 98: 100 (NOT) [33/98]
# Puzzle # 99: 100 (NOT) [33/99]
# Puzzle # 100: 100 (NOT) [33/100]
