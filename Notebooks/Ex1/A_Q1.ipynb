# %% [markdown]
# # Final Project - Reinforcements Learning
# Hello dear students,<br> this is the template notebook. Please click on the "File" tab and then on "Save a copy into drive".
#
# ---
# <br>
#
# ### Name and ID:
# Student 1: Avraham Raviv, 204355390
# <br>
# Student 2: Yevgeni Berkovitch, 317079234
# <br><br>
# <img src="https://play-lh.googleusercontent.com/e_oKlKPISbgdzut1H9opevS7-LTB8-8lsmpCdMkhlnqFenZhpjxbLmx7l158-xQQCIY">
#
# ### https://github.com/mpSchrader/gym-sokoban

# %% [markdown]
# # Installs

# %%
# %%capture
# !sudo apt-get update
# !sudo apt-get install -y xvfb ffmpeg freeglut3-dev
# !pip install 'imageio==2.4.0'
# !pip install gym
# !pip install pygame
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet
# !pip install gym
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install gym_sokoban

# !imageio_download_bin ffmpeg

# %% [markdown]
# # Imports

# %%
import random
import time

import numpy as np
import matplotlib.pyplot as plt

import base64
import imageio
from pyvirtualdisplay import Display
from IPython.display import HTML

import gym
from gym import error, spaces, utils
from soko_pap import *

from collections import deque
from queue import PriorityQueue

from keras.models import Sequential
from keras.layers import Dense

# %%
# %matplotlib inline

# %%
imageio.plugins.ffmpeg.download()

# %%
from gym import logger as gymlogger
gymlogger.set_level(40) # error only

# %% [markdown]
# # Display utils
# The cell below contains the video display configuration. No need to make changes here.

# %%
def embed_mp4(filename):
    """Embeds an mp4 file in the notebook."""
    video = open(filename,'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())

    return HTML(tag)

# %% [markdown]
# # Solution

# %%
class SOK_Agent:
    def __init__(self):
        # Construct DQN models
        self.state_size = (25,) 
        self.action_size = 8
        self.model = self._build_model()
        self.target_model = self._build_model()
        self.target_model.set_weights(self.model.get_weights())
        self.batch_size = 8
        
        # Replay buffers
        self.replay_buffer = deque(maxlen=1500)
        self.prioritized_replay_buffer = deque(maxlen=500)
        self.prioritized_replay_batch = 50        
        
        # Hyperparameters
        self.gamma = 0.9
        self.epsilon = 1.0   
        self.epsilon_min = 0.3
        self.epsilon_decay = 0.995
        self.epsilon_update_rate = 10
        self.replay_rate = 10
        self.update_beta = 0.99

        self.verbosity = 100 

    def _build_model(self):
        model = Sequential()
        model.add(Dense(25, input_shape=self.state_size, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='huber', optimizer="adam")        
        return model

    def remember(self, state, action, reward, next_state, done):
        self.replay_buffer.append([state, action, reward, next_state, done])    
        
    def copy_to_prioritized_buffer(self, n):
        for i in range(n):
            self.prioritized_replay_buffer.append(self.replay_buffer[-1-i])  

    def act(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        
        act_values = self.model.predict(state, verbose=0)
        return np.argmax(act_values[0]) 

    def replay(self):        
        minibatch = random.sample(self.replay_buffer, self.batch_size//2) 
        minibatch.extend(random.sample(self.prioritized_replay_buffer, self.batch_size//2))
        
        states = np.zeros((self.batch_size, self.state_size[0]))
        targets = np.zeros((self.batch_size, self.action_size))
        for i, (state, action, reward, next_state, done) in enumerate(minibatch): 
            states[i] = state
            targets[i] = self.model.predict(state, verbose=0)
            if done:
                targets[i][action] = reward
            else:
                max_action = np.argmax(self.model.predict(next_state)[0])
                targets[i][action] = reward + self.gamma*self.target_model.predict(next_state)[0][max_action]
                
        self.model.fit(states, targets, epochs=10, verbose=0) 
        
    def update_epsilon(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon = self.epsilon * self.epsilon_decay
        
    def update_target_model(self):
        model_w = self.model.get_weights()
        target_model_w = self.target_model.get_weights()
        updated_target_model_w = []
        for i in range(len(model_w)):
            updated_target_model_w.append(self.update_beta*target_model_w[i] + (1-self.update_beta)*model_w[i])
        self.target_model.set_weights(updated_target_model_w)    
            
    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

# %%
def process_frame(frame):
    f = frame[16:96, 16:96, 0]   
    f = f.reshape(5, 16, 5, 16).max(axis=(1, 3))
    f = f.flatten()
    f = f / 255
    return np.expand_dims(f, axis=0)

# %% [markdown]
# ## Training

# %%
max_episodes = 10000
max_steps = 500

def init_sok():
    random.seed(2)
    sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
    sok.set_maxsteps(max_steps)
    return sok

# %%
agent = SOK_Agent()
successes_before_train = 5
successful_episodes = 0
continuous_successes_goal = 10
continuous_successes = 0

steps_per_episode = []

for e in range(max_episodes):
    if continuous_successes >= continuous_successes_goal:
        print("Agent training finished!")
        break
    
    print("Episode: %d" % (e+1))
    
    sok = init_sok()
    state = process_frame(sok.get_image('rgb_array'))
    random.seed(e)
    
    for step in range(sok.max_steps):
        action = agent.act(state)
        if action < 4:
            next_state, reward, done, _ = sok.step(action+1) 
        else:
            next_state, reward, done, _ = sok.step(action+5)         
        next_state = process_frame(next_state)
        
        if reward > 0:
            reward = 1.0
        
        agent.remember(state, action, reward, next_state, done)
        
        state = next_state  
        
        if successful_episodes >= successes_before_train:
            if (step+1) % agent.replay_rate == 0:
                agent.replay() 
                agent.update_target_model()
                agent.update_epsilon()
            if (step+1) % agent.verbosity == 0: 
                print("Episode %d Steps %d Epsilon %.4f" % (e+1, step+1, agent.epsilon)) 
        
        if done:            
            if 3 in sok.room_state:
                successful_episodes += 1
                continuous_successes += 1
                print("SOLVED! Episode %d Steps: %d Epsilon %.4f" % (e+1, step+1, agent.epsilon)) 
                agent.copy_to_prioritized_buffer(min(agent.prioritized_replay_batch, step+1))
            else:
                continuous_successes = 0
                
            steps_per_episode.append(step+1)
            agent.save("exp1_episode%d.h5" % (e+1))
            
            break
# Out:
# Episode: 1
# Episode: 2
# Episode: 3
# Episode: 4
# Episode: 5
# Episode: 6
# Episode: 7
# Episode: 8
# Episode: 9
# Episode: 10
# Episode: 11
# Episode: 12
# Episode: 13
# Episode: 14
# Episode: 15
# Episode: 16
# Episode: 17
# Episode: 18
# Episode: 19
# Episode: 20
# Episode: 21
# Episode: 22
# Episode: 23
# SOLVED! Episode 23 Steps: 438 Epsilon 1.0000
# Episode: 24
# Episode: 25
# Episode: 26
# Episode: 27
# Episode: 28
# Episode: 29
# SOLVED! Episode 29 Steps: 488 Epsilon 1.0000
# Episode: 30
# Episode: 31
# Episode: 32
# Episode: 33
# Episode: 34
# Episode: 35
# Episode: 36
# Episode: 37
# Episode: 38
# Episode: 39
# Episode: 40
# Episode: 41
# Episode: 42
# Episode: 43
# Episode: 44
# Episode: 45
# Episode: 46
# Episode: 47
# Episode: 48
# Episode: 49
# Episode: 50
# Episode: 51
# Episode: 52
# Episode: 53
# Episode: 54
# Episode: 55
# Episode: 56
# Episode: 57
# SOLVED! Episode 57 Steps: 466 Epsilon 1.0000
# Episode: 58
# Episode: 59
# SOLVED! Episode 59 Steps: 454 Epsilon 1.0000
# Episode: 60
# Episode: 61
# Episode: 62
# Episode: 63
# SOLVED! Episode 63 Steps: 226 Epsilon 1.0000
# Episode: 64
# Episode 64 Steps 100 Epsilon 0.9511
# Episode 64 Steps 200 Epsilon 0.9046
# Episode 64 Steps 300 Epsilon 0.8604
# Episode 64 Steps 400 Epsilon 0.8183
# Episode 64 Steps 500 Epsilon 0.7783
# Episode: 65
# Episode 65 Steps 100 Epsilon 0.7403
# Episode 65 Steps 200 Epsilon 0.7041
# Episode 65 Steps 300 Epsilon 0.6696
# Episode 65 Steps 400 Epsilon 0.6369
# Episode 65 Steps 500 Epsilon 0.6058
# Episode: 66
# Episode 66 Steps 100 Epsilon 0.5762
# Episode 66 Steps 200 Epsilon 0.5480
# Episode 66 Steps 300 Epsilon 0.5212
# Episode 66 Steps 400 Epsilon 0.4957
# Episode 66 Steps 500 Epsilon 0.4715
# Episode: 67
# Episode 67 Steps 100 Epsilon 0.4484
# Episode 67 Steps 200 Epsilon 0.4265
# Episode 67 Steps 300 Epsilon 0.4057
# Episode 67 Steps 400 Epsilon 0.3858
# Episode 67 Steps 500 Epsilon 0.3670
# Episode: 68
# Episode 68 Steps 100 Epsilon 0.3490
# Episode 68 Steps 200 Epsilon 0.3320
# Episode 68 Steps 300 Epsilon 0.3157
# Episode 68 Steps 400 Epsilon 0.3003
# Episode 68 Steps 500 Epsilon 0.2988
# Episode: 69
# Episode 69 Steps 100 Epsilon 0.2988
# Episode 69 Steps 200 Epsilon 0.2988
# Episode 69 Steps 300 Epsilon 0.2988
# Episode 69 Steps 400 Epsilon 0.2988
# Episode 69 Steps 500 Epsilon 0.2988
# Episode: 70
# Episode 70 Steps 100 Epsilon 0.2988
# Episode 70 Steps 200 Epsilon 0.2988
# Episode 70 Steps 300 Epsilon 0.2988
# Episode 70 Steps 400 Epsilon 0.2988
# Episode 70 Steps 500 Epsilon 0.2988
# Episode: 71
# Episode 71 Steps 100 Epsilon 0.2988
# Episode 71 Steps 200 Epsilon 0.2988
# Episode 71 Steps 300 Epsilon 0.2988
# Episode 71 Steps 400 Epsilon 0.2988
# Episode 71 Steps 500 Epsilon 0.2988
# Episode: 72
# Episode 72 Steps 100 Epsilon 0.2988
# Episode 72 Steps 200 Epsilon 0.2988
# Episode 72 Steps 300 Epsilon 0.2988
# Episode 72 Steps 400 Epsilon 0.2988
# Episode 72 Steps 500 Epsilon 0.2988
# Episode: 73
# Episode 73 Steps 100 Epsilon 0.2988
# Episode 73 Steps 200 Epsilon 0.2988
# Episode 73 Steps 300 Epsilon 0.2988
# Episode 73 Steps 400 Epsilon 0.2988
# Episode 73 Steps 500 Epsilon 0.2988
# Episode: 74
# Episode 74 Steps 100 Epsilon 0.2988
# Episode 74 Steps 200 Epsilon 0.2988
# Episode 74 Steps 300 Epsilon 0.2988
# Episode 74 Steps 400 Epsilon 0.2988
# Episode 74 Steps 500 Epsilon 0.2988
# Episode: 75
# Episode 75 Steps 100 Epsilon 0.2988
# Episode 75 Steps 200 Epsilon 0.2988
# Episode 75 Steps 300 Epsilon 0.2988
# Episode 75 Steps 400 Epsilon 0.2988
# Episode 75 Steps 500 Epsilon 0.2988
# Episode: 76
# Episode 76 Steps 100 Epsilon 0.2988
# Episode 76 Steps 200 Epsilon 0.2988
# Episode 76 Steps 300 Epsilon 0.2988
# Episode 76 Steps 400 Epsilon 0.2988
# Episode 76 Steps 500 Epsilon 0.2988
# Episode: 77
# Episode 77 Steps 100 Epsilon 0.2988
# Episode 77 Steps 200 Epsilon 0.2988
# Episode 77 Steps 300 Epsilon 0.2988
# Episode 77 Steps 400 Epsilon 0.2988
# Episode 77 Steps 500 Epsilon 0.2988
# Episode: 78
# Episode 78 Steps 100 Epsilon 0.2988
# Episode 78 Steps 200 Epsilon 0.2988
# Episode 78 Steps 300 Epsilon 0.2988
# Episode 78 Steps 400 Epsilon 0.2988
# Episode 78 Steps 500 Epsilon 0.2988
# Episode: 79
# Episode 79 Steps 100 Epsilon 0.2988
# Episode 79 Steps 200 Epsilon 0.2988
# Episode 79 Steps 300 Epsilon 0.2988
# Episode 79 Steps 400 Epsilon 0.2988
# Episode 79 Steps 500 Epsilon 0.2988
# Episode: 80
# Episode 80 Steps 100 Epsilon 0.2988
# Episode 80 Steps 200 Epsilon 0.2988
# Episode 80 Steps 300 Epsilon 0.2988
# Episode 80 Steps 400 Epsilon 0.2988
# Episode 80 Steps 500 Epsilon 0.2988
# Episode: 81
# Episode 81 Steps 100 Epsilon 0.2988
# Episode 81 Steps 200 Epsilon 0.2988
# Episode 81 Steps 300 Epsilon 0.2988
# Episode 81 Steps 400 Epsilon 0.2988
# Episode 81 Steps 500 Epsilon 0.2988
# Episode: 82
# Episode 82 Steps 100 Epsilon 0.2988
# Episode 82 Steps 200 Epsilon 0.2988
# Episode 82 Steps 300 Epsilon 0.2988
# Episode 82 Steps 400 Epsilon 0.2988
# Episode 82 Steps 500 Epsilon 0.2988
# Episode: 83
# Episode 83 Steps 100 Epsilon 0.2988
# Episode 83 Steps 200 Epsilon 0.2988
# Episode 83 Steps 300 Epsilon 0.2988
# Episode 83 Steps 400 Epsilon 0.2988
# Episode 83 Steps 500 Epsilon 0.2988
# Episode: 84
# Episode 84 Steps 100 Epsilon 0.2988
# Episode 84 Steps 200 Epsilon 0.2988
# Episode 84 Steps 300 Epsilon 0.2988
# Episode 84 Steps 400 Epsilon 0.2988
# Episode 84 Steps 500 Epsilon 0.2988
# Episode: 85
# Episode 85 Steps 100 Epsilon 0.2988
# Episode 85 Steps 200 Epsilon 0.2988
# Episode 85 Steps 300 Epsilon 0.2988
# Episode 85 Steps 400 Epsilon 0.2988
# Episode 85 Steps 500 Epsilon 0.2988
# Episode: 86
# Episode 86 Steps 100 Epsilon 0.2988
# Episode 86 Steps 200 Epsilon 0.2988
# Episode 86 Steps 300 Epsilon 0.2988
# Episode 86 Steps 400 Epsilon 0.2988
# Episode 86 Steps 500 Epsilon 0.2988
# Episode: 87
# Episode 87 Steps 100 Epsilon 0.2988
# Episode 87 Steps 200 Epsilon 0.2988
# Episode 87 Steps 300 Epsilon 0.2988
# Episode 87 Steps 400 Epsilon 0.2988
# Episode 87 Steps 500 Epsilon 0.2988
# Episode: 88
# Episode 88 Steps 100 Epsilon 0.2988
# Episode 88 Steps 200 Epsilon 0.2988
# Episode 88 Steps 300 Epsilon 0.2988
# Episode 88 Steps 400 Epsilon 0.2988
# Episode 88 Steps 500 Epsilon 0.2988
# Episode: 89
# Episode 89 Steps 100 Epsilon 0.2988
# Episode 89 Steps 200 Epsilon 0.2988
# Episode 89 Steps 300 Epsilon 0.2988
# Episode 89 Steps 400 Epsilon 0.2988
# Episode 89 Steps 500 Epsilon 0.2988
# Episode: 90
# Episode 90 Steps 100 Epsilon 0.2988
# Episode 90 Steps 200 Epsilon 0.2988
# Episode 90 Steps 300 Epsilon 0.2988
# Episode 90 Steps 400 Epsilon 0.2988
# Episode 90 Steps 500 Epsilon 0.2988
# Episode: 91
# Episode 91 Steps 100 Epsilon 0.2988
# Episode 91 Steps 200 Epsilon 0.2988
# Episode 91 Steps 300 Epsilon 0.2988
# Episode 91 Steps 400 Epsilon 0.2988
# Episode 91 Steps 500 Epsilon 0.2988
# Episode: 92
# Episode 92 Steps 100 Epsilon 0.2988
# Episode 92 Steps 200 Epsilon 0.2988
# Episode 92 Steps 300 Epsilon 0.2988
# Episode 92 Steps 400 Epsilon 0.2988
# Episode 92 Steps 500 Epsilon 0.2988
# Episode: 93
# Episode 93 Steps 100 Epsilon 0.2988
# Episode 93 Steps 200 Epsilon 0.2988
# Episode 93 Steps 300 Epsilon 0.2988
# Episode 93 Steps 400 Epsilon 0.2988
# Episode 93 Steps 500 Epsilon 0.2988
# Episode: 94
# Episode 94 Steps 100 Epsilon 0.2988
# Episode 94 Steps 200 Epsilon 0.2988
# Episode 94 Steps 300 Epsilon 0.2988
# Episode 94 Steps 400 Epsilon 0.2988
# Episode 94 Steps 500 Epsilon 0.2988
# Episode: 95
# Episode 95 Steps 100 Epsilon 0.2988
# Episode 95 Steps 200 Epsilon 0.2988
# Episode 95 Steps 300 Epsilon 0.2988
# Episode 95 Steps 400 Epsilon 0.2988
# Episode 95 Steps 500 Epsilon 0.2988
# Episode: 96
# Episode 96 Steps 100 Epsilon 0.2988
# Episode 96 Steps 200 Epsilon 0.2988
# Episode 96 Steps 300 Epsilon 0.2988
# Episode 96 Steps 400 Epsilon 0.2988
# Episode 96 Steps 500 Epsilon 0.2988
# Episode: 97
# Episode 97 Steps 100 Epsilon 0.2988
# Episode 97 Steps 200 Epsilon 0.2988
# Episode 97 Steps 300 Epsilon 0.2988
# Episode 97 Steps 400 Epsilon 0.2988
# Episode 97 Steps 500 Epsilon 0.2988
# Episode: 98
# Episode 98 Steps 100 Epsilon 0.2988
# Episode 98 Steps 200 Epsilon 0.2988
# Episode 98 Steps 300 Epsilon 0.2988
# Episode 98 Steps 400 Epsilon 0.2988
# Episode 98 Steps 500 Epsilon 0.2988
# Episode: 99
# Episode 99 Steps 100 Epsilon 0.2988
# Episode 99 Steps 200 Epsilon 0.2988
# Episode 99 Steps 300 Epsilon 0.2988
# Episode 99 Steps 400 Epsilon 0.2988
# Episode 99 Steps 500 Epsilon 0.2988
# Episode: 100
# Episode 100 Steps 100 Epsilon 0.2988
# Episode 100 Steps 200 Epsilon 0.2988
# Episode 100 Steps 300 Epsilon 0.2988
# Episode 100 Steps 400 Epsilon 0.2988
# Episode 100 Steps 500 Epsilon 0.2988
# Episode: 101
# Episode 101 Steps 100 Epsilon 0.2988
# Episode 101 Steps 200 Epsilon 0.2988
# Episode 101 Steps 300 Epsilon 0.2988
# Episode 101 Steps 400 Epsilon 0.2988
# Episode 101 Steps 500 Epsilon 0.2988
# Episode: 102
# Episode 102 Steps 100 Epsilon 0.2988
# Episode 102 Steps 200 Epsilon 0.2988
# Episode 102 Steps 300 Epsilon 0.2988
# Episode 102 Steps 400 Epsilon 0.2988
# Episode 102 Steps 500 Epsilon 0.2988
# Episode: 103
# Episode 103 Steps 100 Epsilon 0.2988
# Episode 103 Steps 200 Epsilon 0.2988
# Episode 103 Steps 300 Epsilon 0.2988
# Episode 103 Steps 400 Epsilon 0.2988
# Episode 103 Steps 500 Epsilon 0.2988
# Episode: 104
# Episode 104 Steps 100 Epsilon 0.2988
# Episode 104 Steps 200 Epsilon 0.2988
# Episode 104 Steps 300 Epsilon 0.2988
# Episode 104 Steps 400 Epsilon 0.2988
# Episode 104 Steps 500 Epsilon 0.2988
# Episode: 105
# Episode 105 Steps 100 Epsilon 0.2988
# Episode 105 Steps 200 Epsilon 0.2988
# Episode 105 Steps 300 Epsilon 0.2988
# Episode 105 Steps 400 Epsilon 0.2988
# Episode 105 Steps 500 Epsilon 0.2988
# Episode: 106
# SOLVED! Episode 106 Steps: 72 Epsilon 0.2988
# Episode: 107
# Episode 107 Steps 100 Epsilon 0.2988
# Episode 107 Steps 200 Epsilon 0.2988
# Episode 107 Steps 300 Epsilon 0.2988
# Episode 107 Steps 400 Epsilon 0.2988
# Episode 107 Steps 500 Epsilon 0.2988
# Episode: 108
# Episode 108 Steps 100 Epsilon 0.2988
# Episode 108 Steps 200 Epsilon 0.2988
# Episode 108 Steps 300 Epsilon 0.2988
# Episode 108 Steps 400 Epsilon 0.2988
# Episode 108 Steps 500 Epsilon 0.2988
# Episode: 109
# Episode 109 Steps 100 Epsilon 0.2988
# Episode 109 Steps 200 Epsilon 0.2988
# Episode 109 Steps 300 Epsilon 0.2988
# Episode 109 Steps 400 Epsilon 0.2988
# Episode 109 Steps 500 Epsilon 0.2988
# Episode: 110
# Episode 110 Steps 100 Epsilon 0.2988
# Episode 110 Steps 200 Epsilon 0.2988
# Episode 110 Steps 300 Epsilon 0.2988
# Episode 110 Steps 400 Epsilon 0.2988
# Episode 110 Steps 500 Epsilon 0.2988
# Episode: 111
# Episode 111 Steps 100 Epsilon 0.2988
# Episode 111 Steps 200 Epsilon 0.2988
# Episode 111 Steps 300 Epsilon 0.2988
# Episode 111 Steps 400 Epsilon 0.2988
# Episode 111 Steps 500 Epsilon 0.2988
# Episode: 112
# SOLVED! Episode 112 Steps: 44 Epsilon 0.2988
# Episode: 113
# Episode 113 Steps 100 Epsilon 0.2988
# Episode 113 Steps 200 Epsilon 0.2988
# Episode 113 Steps 300 Epsilon 0.2988
# Episode 113 Steps 400 Epsilon 0.2988
# Episode 113 Steps 500 Epsilon 0.2988
# Episode: 114
# Episode 114 Steps 100 Epsilon 0.2988
# Episode 114 Steps 200 Epsilon 0.2988
# SOLVED! Episode 114 Steps: 219 Epsilon 0.2988
# Episode: 115
# Episode 115 Steps 100 Epsilon 0.2988
# Episode 115 Steps 200 Epsilon 0.2988
# Episode 115 Steps 300 Epsilon 0.2988
# Episode 115 Steps 400 Epsilon 0.2988
# Episode 115 Steps 500 Epsilon 0.2988
# Episode: 116
# Episode 116 Steps 100 Epsilon 0.2988
# Episode 116 Steps 200 Epsilon 0.2988
# Episode 116 Steps 300 Epsilon 0.2988
# Episode 116 Steps 400 Epsilon 0.2988
# Episode 116 Steps 500 Epsilon 0.2988
# Episode: 117
# Episode 117 Steps 100 Epsilon 0.2988
# Episode 117 Steps 200 Epsilon 0.2988
# Episode 117 Steps 300 Epsilon 0.2988
# Episode 117 Steps 400 Epsilon 0.2988
# Episode 117 Steps 500 Epsilon 0.2988
# Episode: 118
# Episode 118 Steps 100 Epsilon 0.2988
# Episode 118 Steps 200 Epsilon 0.2988
# Episode 118 Steps 300 Epsilon 0.2988
# Episode 118 Steps 400 Epsilon 0.2988
# Episode 118 Steps 500 Epsilon 0.2988
# Episode: 119
# Episode 119 Steps 100 Epsilon 0.2988
# Episode 119 Steps 200 Epsilon 0.2988
# Episode 119 Steps 300 Epsilon 0.2988
# Episode 119 Steps 400 Epsilon 0.2988
# Episode 119 Steps 500 Epsilon 0.2988
# Episode: 120
# Episode 120 Steps 100 Epsilon 0.2988
# Episode 120 Steps 200 Epsilon 0.2988
# Episode 120 Steps 300 Epsilon 0.2988
# Episode 120 Steps 400 Epsilon 0.2988
# Episode 120 Steps 500 Epsilon 0.2988
# Episode: 121
# Episode 121 Steps 100 Epsilon 0.2988
# Episode 121 Steps 200 Epsilon 0.2988
# Episode 121 Steps 300 Epsilon 0.2988
# Episode 121 Steps 400 Epsilon 0.2988
# Episode 121 Steps 500 Epsilon 0.2988
# Episode: 122
# Episode 122 Steps 100 Epsilon 0.2988
# Episode 122 Steps 200 Epsilon 0.2988
# SOLVED! Episode 122 Steps: 221 Epsilon 0.2988
# Episode: 123
# Episode 123 Steps 100 Epsilon 0.2988
# SOLVED! Episode 123 Steps: 114 Epsilon 0.2988
# Episode: 124
# Episode 124 Steps 100 Epsilon 0.2988
# Episode 124 Steps 200 Epsilon 0.2988
# Episode 124 Steps 300 Epsilon 0.2988
# Episode 124 Steps 400 Epsilon 0.2988
# Episode 124 Steps 500 Epsilon 0.2988
# Episode: 125
# Episode 125 Steps 100 Epsilon 0.2988
# SOLVED! Episode 125 Steps: 118 Epsilon 0.2988
# Episode: 126
# SOLVED! Episode 126 Steps: 72 Epsilon 0.2988
# Episode: 127
# Episode 127 Steps 100 Epsilon 0.2988
# Episode 127 Steps 200 Epsilon 0.2988
# Episode 127 Steps 300 Epsilon 0.2988
# Episode 127 Steps 400 Epsilon 0.2988
# Episode 127 Steps 500 Epsilon 0.2988
# Episode: 128
# SOLVED! Episode 128 Steps: 22 Epsilon 0.2988
# Episode: 129
# Episode 129 Steps 100 Epsilon 0.2988
# Episode 129 Steps 200 Epsilon 0.2988
# Episode 129 Steps 300 Epsilon 0.2988
# Episode 129 Steps 400 Epsilon 0.2988
# Episode 129 Steps 500 Epsilon 0.2988
# Episode: 130
# Episode 130 Steps 100 Epsilon 0.2988
# Episode 130 Steps 200 Epsilon 0.2988
# Episode 130 Steps 300 Epsilon 0.2988
# Episode 130 Steps 400 Epsilon 0.2988
# Episode 130 Steps 500 Epsilon 0.2988
# Episode: 131
# Episode 131 Steps 100 Epsilon 0.2988
# Episode 131 Steps 200 Epsilon 0.2988
# Episode 131 Steps 300 Epsilon 0.2988
# Episode 131 Steps 400 Epsilon 0.2988
# Episode 131 Steps 500 Epsilon 0.2988
# Episode: 132
# Episode 132 Steps 100 Epsilon 0.2988
# Episode 132 Steps 200 Epsilon 0.2988
# Episode 132 Steps 300 Epsilon 0.2988
# Episode 132 Steps 400 Epsilon 0.2988
# Episode 132 Steps 500 Epsilon 0.2988
# Episode: 133
# Episode 133 Steps 100 Epsilon 0.2988
# Episode 133 Steps 200 Epsilon 0.2988
# Episode 133 Steps 300 Epsilon 0.2988
# Episode 133 Steps 400 Epsilon 0.2988
# Episode 133 Steps 500 Epsilon 0.2988
# Episode: 134
# Episode 134 Steps 100 Epsilon 0.2988
# Episode 134 Steps 200 Epsilon 0.2988
# Episode 134 Steps 300 Epsilon 0.2988
# Episode 134 Steps 400 Epsilon 0.2988
# Episode 134 Steps 500 Epsilon 0.2988
# Episode: 135
# Episode 135 Steps 100 Epsilon 0.2988
# Episode 135 Steps 200 Epsilon 0.2988
# Episode 135 Steps 300 Epsilon 0.2988
# Episode 135 Steps 400 Epsilon 0.2988
# Episode 135 Steps 500 Epsilon 0.2988
# Episode: 136
# Episode 136 Steps 100 Epsilon 0.2988
# Episode 136 Steps 200 Epsilon 0.2988
# Episode 136 Steps 300 Epsilon 0.2988
# Episode 136 Steps 400 Epsilon 0.2988
# Episode 136 Steps 500 Epsilon 0.2988
# Episode: 137
# SOLVED! Episode 137 Steps: 88 Epsilon 0.2988
# Episode: 138
# SOLVED! Episode 138 Steps: 67 Epsilon 0.2988
# Episode: 139
# Episode 139 Steps 100 Epsilon 0.2988
# Episode 139 Steps 200 Epsilon 0.2988
# Episode 139 Steps 300 Epsilon 0.2988
# Episode 139 Steps 400 Epsilon 0.2988
# Episode 139 Steps 500 Epsilon 0.2988
# Episode: 140
# Episode 140 Steps 100 Epsilon 0.2988
# Episode 140 Steps 200 Epsilon 0.2988
# Episode 140 Steps 300 Epsilon 0.2988
# Episode 140 Steps 400 Epsilon 0.2988
# Episode 140 Steps 500 Epsilon 0.2988
# Episode: 141
# Episode 141 Steps 100 Epsilon 0.2988
# Episode 141 Steps 200 Epsilon 0.2988
# Episode 141 Steps 300 Epsilon 0.2988
# Episode 141 Steps 400 Epsilon 0.2988
# Episode 141 Steps 500 Epsilon 0.2988
# Episode: 142
# Episode 142 Steps 100 Epsilon 0.2988
# Episode 142 Steps 200 Epsilon 0.2988
# Episode 142 Steps 300 Epsilon 0.2988
# Episode 142 Steps 400 Epsilon 0.2988
# Episode 142 Steps 500 Epsilon 0.2988
# Episode: 143
# Episode 143 Steps 100 Epsilon 0.2988
# Episode 143 Steps 200 Epsilon 0.2988
# Episode 143 Steps 300 Epsilon 0.2988
# Episode 143 Steps 400 Epsilon 0.2988
# Episode 143 Steps 500 Epsilon 0.2988
# Episode: 144
# Episode 144 Steps 100 Epsilon 0.2988
# Episode 144 Steps 200 Epsilon 0.2988
# Episode 144 Steps 300 Epsilon 0.2988
# Episode 144 Steps 400 Epsilon 0.2988
# Episode 144 Steps 500 Epsilon 0.2988
# Episode: 145
# Episode 145 Steps 100 Epsilon 0.2988
# Episode 145 Steps 200 Epsilon 0.2988
# Episode 145 Steps 300 Epsilon 0.2988
# Episode 145 Steps 400 Epsilon 0.2988
# Episode 145 Steps 500 Epsilon 0.2988
# Episode: 146
# Episode 146 Steps 100 Epsilon 0.2988
# Episode 146 Steps 200 Epsilon 0.2988
# Episode 146 Steps 300 Epsilon 0.2988
# Episode 146 Steps 400 Epsilon 0.2988
# Episode 146 Steps 500 Epsilon 0.2988
# Episode: 147
# Episode 147 Steps 100 Epsilon 0.2988
# Episode 147 Steps 200 Epsilon 0.2988
# Episode 147 Steps 300 Epsilon 0.2988
# Episode 147 Steps 400 Epsilon 0.2988
# Episode 147 Steps 500 Epsilon 0.2988
# Episode: 148
# Episode 148 Steps 100 Epsilon 0.2988
# Episode 148 Steps 200 Epsilon 0.2988
# Episode 148 Steps 300 Epsilon 0.2988
# Episode 148 Steps 400 Epsilon 0.2988
# Episode 148 Steps 500 Epsilon 0.2988
# Episode: 149
# Episode 149 Steps 100 Epsilon 0.2988
# Episode 149 Steps 200 Epsilon 0.2988
# Episode 149 Steps 300 Epsilon 0.2988
# Episode 149 Steps 400 Epsilon 0.2988
# Episode 149 Steps 500 Epsilon 0.2988
# Episode: 150
# Episode 150 Steps 100 Epsilon 0.2988
# Episode 150 Steps 200 Epsilon 0.2988
# SOLVED! Episode 150 Steps: 250 Epsilon 0.2988
# Episode: 151
# Episode 151 Steps 100 Epsilon 0.2988
# Episode 151 Steps 200 Epsilon 0.2988
# SOLVED! Episode 151 Steps: 246 Epsilon 0.2988
# Episode: 152
# Episode 152 Steps 100 Epsilon 0.2988
# Episode 152 Steps 200 Epsilon 0.2988
# Episode 152 Steps 300 Epsilon 0.2988
# Episode 152 Steps 400 Epsilon 0.2988
# Episode 152 Steps 500 Epsilon 0.2988
# Episode: 153
# Episode 153 Steps 100 Epsilon 0.2988
# Episode 153 Steps 200 Epsilon 0.2988
# Episode 153 Steps 300 Epsilon 0.2988
# Episode 153 Steps 400 Epsilon 0.2988
# Episode 153 Steps 500 Epsilon 0.2988
# Episode: 154
# Episode 154 Steps 100 Epsilon 0.2988
# Episode 154 Steps 200 Epsilon 0.2988
# Episode 154 Steps 300 Epsilon 0.2988
# Episode 154 Steps 400 Epsilon 0.2988
# Episode 154 Steps 500 Epsilon 0.2988
# Episode: 155
# Episode 155 Steps 100 Epsilon 0.2988
# Episode 155 Steps 200 Epsilon 0.2988
# Episode 155 Steps 300 Epsilon 0.2988
# Episode 155 Steps 400 Epsilon 0.2988
# Episode 155 Steps 500 Epsilon 0.2988
# Episode: 156
# Episode 156 Steps 100 Epsilon 0.2988
# Episode 156 Steps 200 Epsilon 0.2988
# Episode 156 Steps 300 Epsilon 0.2988
# Episode 156 Steps 400 Epsilon 0.2988
# Episode 156 Steps 500 Epsilon 0.2988
# Episode: 157
# Episode 157 Steps 100 Epsilon 0.2988
# Episode 157 Steps 200 Epsilon 0.2988
# Episode 157 Steps 300 Epsilon 0.2988
# Episode 157 Steps 400 Epsilon 0.2988
# Episode 157 Steps 500 Epsilon 0.2988
# Episode: 158
# Episode 158 Steps 100 Epsilon 0.2988
# SOLVED! Episode 158 Steps: 134 Epsilon 0.2988
# Episode: 159
# Episode 159 Steps 100 Epsilon 0.2988
# Episode 159 Steps 200 Epsilon 0.2988
# Episode 159 Steps 300 Epsilon 0.2988
# Episode 159 Steps 400 Epsilon 0.2988
# Episode 159 Steps 500 Epsilon 0.2988
# Episode: 160
# Episode 160 Steps 100 Epsilon 0.2988
# Episode 160 Steps 200 Epsilon 0.2988
# Episode 160 Steps 300 Epsilon 0.2988
# Episode 160 Steps 400 Epsilon 0.2988
# Episode 160 Steps 500 Epsilon 0.2988
# Episode: 161
# Episode 161 Steps 100 Epsilon 0.2988
# Episode 161 Steps 200 Epsilon 0.2988
# Episode 161 Steps 300 Epsilon 0.2988
# Episode 161 Steps 400 Epsilon 0.2988
# Episode 161 Steps 500 Epsilon 0.2988
# Episode: 162
# Episode 162 Steps 100 Epsilon 0.2988
# Episode 162 Steps 200 Epsilon 0.2988
# Episode 162 Steps 300 Epsilon 0.2988
# Episode 162 Steps 400 Epsilon 0.2988
# Episode 162 Steps 500 Epsilon 0.2988
# Episode: 163
# Episode 163 Steps 100 Epsilon 0.2988
# Episode 163 Steps 200 Epsilon 0.2988
# SOLVED! Episode 163 Steps: 273 Epsilon 0.2988
# Episode: 164
# SOLVED! Episode 164 Steps: 21 Epsilon 0.2988
# Episode: 165
# Episode 165 Steps 100 Epsilon 0.2988
# Episode 165 Steps 200 Epsilon 0.2988
# Episode 165 Steps 300 Epsilon 0.2988
# Episode 165 Steps 400 Epsilon 0.2988
# Episode 165 Steps 500 Epsilon 0.2988
# Episode: 166
# Episode 166 Steps 100 Epsilon 0.2988
# Episode 166 Steps 200 Epsilon 0.2988
# SOLVED! Episode 166 Steps: 210 Epsilon 0.2988
# Episode: 167
# SOLVED! Episode 167 Steps: 21 Epsilon 0.2988
# Episode: 168
# Episode 168 Steps 100 Epsilon 0.2988
# Episode 168 Steps 200 Epsilon 0.2988
# Episode 168 Steps 300 Epsilon 0.2988
# Episode 168 Steps 400 Epsilon 0.2988
# Episode 168 Steps 500 Epsilon 0.2988
# Episode: 169
# SOLVED! Episode 169 Steps: 22 Epsilon 0.2988
# Episode: 170
# SOLVED! Episode 170 Steps: 21 Epsilon 0.2988
# Episode: 171
# Episode 171 Steps 100 Epsilon 0.2988
# Episode 171 Steps 200 Epsilon 0.2988
# Episode 171 Steps 300 Epsilon 0.2988
# Episode 171 Steps 400 Epsilon 0.2988
# Episode 171 Steps 500 Epsilon 0.2988
# Episode: 172
# Episode 172 Steps 100 Epsilon 0.2988
# Episode 172 Steps 200 Epsilon 0.2988
# Episode 172 Steps 300 Epsilon 0.2988
# Episode 172 Steps 400 Epsilon 0.2988
# Episode 172 Steps 500 Epsilon 0.2988
# Episode: 173
# Episode 173 Steps 100 Epsilon 0.2988
# Episode 173 Steps 200 Epsilon 0.2988
# Episode 173 Steps 300 Epsilon 0.2988
# Episode 173 Steps 400 Epsilon 0.2988
# Episode 173 Steps 500 Epsilon 0.2988
# Episode: 174
# Episode 174 Steps 100 Epsilon 0.2988
# Episode 174 Steps 200 Epsilon 0.2988
# Episode 174 Steps 300 Epsilon 0.2988
# Episode 174 Steps 400 Epsilon 0.2988
# Episode 174 Steps 500 Epsilon 0.2988
# Episode: 175
# Episode 175 Steps 100 Epsilon 0.2988
# Episode 175 Steps 200 Epsilon 0.2988
# Episode 175 Steps 300 Epsilon 0.2988
# Episode 175 Steps 400 Epsilon 0.2988
# Episode 175 Steps 500 Epsilon 0.2988
# Episode: 176
# Episode 176 Steps 100 Epsilon 0.2988
# Episode 176 Steps 200 Epsilon 0.2988
# Episode 176 Steps 300 Epsilon 0.2988
# Episode 176 Steps 400 Epsilon 0.2988
# Episode 176 Steps 500 Epsilon 0.2988
# Episode: 177
# Episode 177 Steps 100 Epsilon 0.2988
# Episode 177 Steps 200 Epsilon 0.2988
# Episode 177 Steps 300 Epsilon 0.2988
# Episode 177 Steps 400 Epsilon 0.2988
# Episode 177 Steps 500 Epsilon 0.2988
# Episode: 178
# Episode 178 Steps 100 Epsilon 0.2988
# Episode 178 Steps 200 Epsilon 0.2988
# Episode 178 Steps 300 Epsilon 0.2988
# Episode 178 Steps 400 Epsilon 0.2988
# Episode 178 Steps 500 Epsilon 0.2988
# Episode: 179
# Episode 179 Steps 100 Epsilon 0.2988
# Episode 179 Steps 200 Epsilon 0.2988
# Episode 179 Steps 300 Epsilon 0.2988
# Episode 179 Steps 400 Epsilon 0.2988
# Episode 179 Steps 500 Epsilon 0.2988
# Episode: 180
# Episode 180 Steps 100 Epsilon 0.2988
# Episode 180 Steps 200 Epsilon 0.2988
# Episode 180 Steps 300 Epsilon 0.2988
# Episode 180 Steps 400 Epsilon 0.2988
# Episode 180 Steps 500 Epsilon 0.2988
# Episode: 181
# Episode 181 Steps 100 Epsilon 0.2988
# Episode 181 Steps 200 Epsilon 0.2988
# Episode 181 Steps 300 Epsilon 0.2988
# Episode 181 Steps 400 Epsilon 0.2988
# Episode 181 Steps 500 Epsilon 0.2988
# Episode: 182
# Episode 182 Steps 100 Epsilon 0.2988
# Episode 182 Steps 200 Epsilon 0.2988
# Episode 182 Steps 300 Epsilon 0.2988
# Episode 182 Steps 400 Epsilon 0.2988
# Episode 182 Steps 500 Epsilon 0.2988
# Episode: 183
# Episode 183 Steps 100 Epsilon 0.2988
# Episode 183 Steps 200 Epsilon 0.2988
# Episode 183 Steps 300 Epsilon 0.2988
# Episode 183 Steps 400 Epsilon 0.2988
# Episode 183 Steps 500 Epsilon 0.2988
# Episode: 184
# Episode 184 Steps 100 Epsilon 0.2988
# Episode 184 Steps 200 Epsilon 0.2988
# Episode 184 Steps 300 Epsilon 0.2988
# Episode 184 Steps 400 Epsilon 0.2988
# Episode 184 Steps 500 Epsilon 0.2988
# Episode: 185
# Episode 185 Steps 100 Epsilon 0.2988
# Episode 185 Steps 200 Epsilon 0.2988
# Episode 185 Steps 300 Epsilon 0.2988
# Episode 185 Steps 400 Epsilon 0.2988
# Episode 185 Steps 500 Epsilon 0.2988
# Episode: 186
# Episode 186 Steps 100 Epsilon 0.2988
# Episode 186 Steps 200 Epsilon 0.2988
# Episode 186 Steps 300 Epsilon 0.2988
# Episode 186 Steps 400 Epsilon 0.2988
# Episode 186 Steps 500 Epsilon 0.2988
# Episode: 187
# Episode 187 Steps 100 Epsilon 0.2988
# SOLVED! Episode 187 Steps: 138 Epsilon 0.2988
# Episode: 188
# Episode 188 Steps 100 Epsilon 0.2988
# Episode 188 Steps 200 Epsilon 0.2988
# Episode 188 Steps 300 Epsilon 0.2988
# Episode 188 Steps 400 Epsilon 0.2988
# Episode 188 Steps 500 Epsilon 0.2988
# Episode: 189
# Episode 189 Steps 100 Epsilon 0.2988
# Episode 189 Steps 200 Epsilon 0.2988
# Episode 189 Steps 300 Epsilon 0.2988
# Episode 189 Steps 400 Epsilon 0.2988
# Episode 189 Steps 500 Epsilon 0.2988
# Episode: 190
# Episode 190 Steps 100 Epsilon 0.2988
# Episode 190 Steps 200 Epsilon 0.2988
# Episode 190 Steps 300 Epsilon 0.2988
# Episode 190 Steps 400 Epsilon 0.2988
# Episode 190 Steps 500 Epsilon 0.2988
# Episode: 191
# Episode 191 Steps 100 Epsilon 0.2988
# Episode 191 Steps 200 Epsilon 0.2988
# Episode 191 Steps 300 Epsilon 0.2988
# Episode 191 Steps 400 Epsilon 0.2988
# Episode 191 Steps 500 Epsilon 0.2988
# Episode: 192
# Episode 192 Steps 100 Epsilon 0.2988
# Episode 192 Steps 200 Epsilon 0.2988
# SOLVED! Episode 192 Steps: 242 Epsilon 0.2988
# Episode: 193
# Episode 193 Steps 100 Epsilon 0.2988
# Episode 193 Steps 200 Epsilon 0.2988
# Episode 193 Steps 300 Epsilon 0.2988
# Episode 193 Steps 400 Epsilon 0.2988
# Episode 193 Steps 500 Epsilon 0.2988
# Episode: 194
# SOLVED! Episode 194 Steps: 21 Epsilon 0.2988
# Episode: 195
# SOLVED! Episode 195 Steps: 52 Epsilon 0.2988
# Episode: 196
# Episode 196 Steps 100 Epsilon 0.2988
# Episode 196 Steps 200 Epsilon 0.2988
# Episode 196 Steps 300 Epsilon 0.2988
# Episode 196 Steps 400 Epsilon 0.2988
# Episode 196 Steps 500 Epsilon 0.2988
# Episode: 197
# Episode 197 Steps 100 Epsilon 0.2988
# Episode 197 Steps 200 Epsilon 0.2988
# Episode 197 Steps 300 Epsilon 0.2988
# Episode 197 Steps 400 Epsilon 0.2988
# Episode 197 Steps 500 Epsilon 0.2988
# Episode: 198
# Episode 198 Steps 100 Epsilon 0.2988
# Episode 198 Steps 200 Epsilon 0.2988
# Episode 198 Steps 300 Epsilon 0.2988
# Episode 198 Steps 400 Epsilon 0.2988
# Episode 198 Steps 500 Epsilon 0.2988
# Episode: 199
# Episode 199 Steps 100 Epsilon 0.2988
# SOLVED! Episode 199 Steps: 138 Epsilon 0.2988
# Episode: 200
# Episode 200 Steps 100 Epsilon 0.2988
# Episode 200 Steps 200 Epsilon 0.2988
# Episode 200 Steps 300 Epsilon 0.2988
# Episode 200 Steps 400 Epsilon 0.2988
# Episode 200 Steps 500 Epsilon 0.2988
# Episode: 201
# Episode 201 Steps 100 Epsilon 0.2988
# Episode 201 Steps 200 Epsilon 0.2988
# Episode 201 Steps 300 Epsilon 0.2988
# Episode 201 Steps 400 Epsilon 0.2988
# Episode 201 Steps 500 Epsilon 0.2988
# Episode: 202
# Episode 202 Steps 100 Epsilon 0.2988
# Episode 202 Steps 200 Epsilon 0.2988
# Episode 202 Steps 300 Epsilon 0.2988
# Episode 202 Steps 400 Epsilon 0.2988
# Episode 202 Steps 500 Epsilon 0.2988
# Episode: 203
# Episode 203 Steps 100 Epsilon 0.2988
# Episode 203 Steps 200 Epsilon 0.2988
# Episode 203 Steps 300 Epsilon 0.2988
# Episode 203 Steps 400 Epsilon 0.2988
# Episode 203 Steps 500 Epsilon 0.2988
# Episode: 204
# Episode 204 Steps 100 Epsilon 0.2988
# Episode 204 Steps 200 Epsilon 0.2988
# Episode 204 Steps 300 Epsilon 0.2988
# Episode 204 Steps 400 Epsilon 0.2988
# Episode 204 Steps 500 Epsilon 0.2988
# Episode: 205
# Episode 205 Steps 100 Epsilon 0.2988
# Episode 205 Steps 200 Epsilon 0.2988
# Episode 205 Steps 300 Epsilon 0.2988
# Episode 205 Steps 400 Epsilon 0.2988
# Episode 205 Steps 500 Epsilon 0.2988
# Episode: 206
# Episode 206 Steps 100 Epsilon 0.2988
# Episode 206 Steps 200 Epsilon 0.2988
# Episode 206 Steps 300 Epsilon 0.2988
# Episode 206 Steps 400 Epsilon 0.2988
# Episode 206 Steps 500 Epsilon 0.2988
# Episode: 207
# Episode 207 Steps 100 Epsilon 0.2988
# Episode 207 Steps 200 Epsilon 0.2988
# Episode 207 Steps 300 Epsilon 0.2988
# Episode 207 Steps 400 Epsilon 0.2988
# Episode 207 Steps 500 Epsilon 0.2988
# Episode: 208
# Episode 208 Steps 100 Epsilon 0.2988
# Episode 208 Steps 200 Epsilon 0.2988
# Episode 208 Steps 300 Epsilon 0.2988
# Episode 208 Steps 400 Epsilon 0.2988
# Episode 208 Steps 500 Epsilon 0.2988
# Episode: 209
# Episode 209 Steps 100 Epsilon 0.2988
# Episode 209 Steps 200 Epsilon 0.2988
# Episode 209 Steps 300 Epsilon 0.2988
# Episode 209 Steps 400 Epsilon 0.2988
# Episode 209 Steps 500 Epsilon 0.2988
# Episode: 210
# Episode 210 Steps 100 Epsilon 0.2988
# Episode 210 Steps 200 Epsilon 0.2988
# Episode 210 Steps 300 Epsilon 0.2988
# Episode 210 Steps 400 Epsilon 0.2988
# Episode 210 Steps 500 Epsilon 0.2988
# Episode: 211
# Episode 211 Steps 100 Epsilon 0.2988
# Episode 211 Steps 200 Epsilon 0.2988
# Episode 211 Steps 300 Epsilon 0.2988
# Episode 211 Steps 400 Epsilon 0.2988
# Episode 211 Steps 500 Epsilon 0.2988
# Episode: 212
# Episode 212 Steps 100 Epsilon 0.2988
# Episode 212 Steps 200 Epsilon 0.2988
# Episode 212 Steps 300 Epsilon 0.2988
# Episode 212 Steps 400 Epsilon 0.2988
# Episode 212 Steps 500 Epsilon 0.2988
# Episode: 213
# Episode 213 Steps 100 Epsilon 0.2988
# Episode 213 Steps 200 Epsilon 0.2988
# Episode 213 Steps 300 Epsilon 0.2988
# Episode 213 Steps 400 Epsilon 0.2988
# Episode 213 Steps 500 Epsilon 0.2988
# Episode: 214
# Episode 214 Steps 100 Epsilon 0.2988
# Episode 214 Steps 200 Epsilon 0.2988
# Episode 214 Steps 300 Epsilon 0.2988
# Episode 214 Steps 400 Epsilon 0.2988
# Episode 214 Steps 500 Epsilon 0.2988
# Episode: 215
# SOLVED! Episode 215 Steps: 60 Epsilon 0.2988
# Episode: 216
# Episode 216 Steps 100 Epsilon 0.2988
# Episode 216 Steps 200 Epsilon 0.2988
# Episode 216 Steps 300 Epsilon 0.2988
# Episode 216 Steps 400 Epsilon 0.2988
# SOLVED! Episode 216 Steps: 486 Epsilon 0.2988
# Episode: 217
# SOLVED! Episode 217 Steps: 23 Epsilon 0.2988
# Episode: 218
# Episode 218 Steps 100 Epsilon 0.2988
# Episode 218 Steps 200 Epsilon 0.2988
# Episode 218 Steps 300 Epsilon 0.2988
# Episode 218 Steps 400 Epsilon 0.2988
# Episode 218 Steps 500 Epsilon 0.2988
# Episode: 219
# SOLVED! Episode 219 Steps: 58 Epsilon 0.2988
# Episode: 220
# Episode 220 Steps 100 Epsilon 0.2988
# Episode 220 Steps 200 Epsilon 0.2988
# Episode 220 Steps 300 Epsilon 0.2988
# Episode 220 Steps 400 Epsilon 0.2988
# Episode 220 Steps 500 Epsilon 0.2988
# Episode: 221
# Episode 221 Steps 100 Epsilon 0.2988
# Episode 221 Steps 200 Epsilon 0.2988
# Episode 221 Steps 300 Epsilon 0.2988
# Episode 221 Steps 400 Epsilon 0.2988
# Episode 221 Steps 500 Epsilon 0.2988
# Episode: 222
# Episode 222 Steps 100 Epsilon 0.2988
# Episode 222 Steps 200 Epsilon 0.2988
# Episode 222 Steps 300 Epsilon 0.2988
# Episode 222 Steps 400 Epsilon 0.2988
# Episode 222 Steps 500 Epsilon 0.2988
# Episode: 223
# Episode 223 Steps 100 Epsilon 0.2988
# Episode 223 Steps 200 Epsilon 0.2988
# Episode 223 Steps 300 Epsilon 0.2988
# Episode 223 Steps 400 Epsilon 0.2988
# Episode 223 Steps 500 Epsilon 0.2988
# Episode: 224
# Episode 224 Steps 100 Epsilon 0.2988
# Episode 224 Steps 200 Epsilon 0.2988
# Episode 224 Steps 300 Epsilon 0.2988
# Episode 224 Steps 400 Epsilon 0.2988
# Episode 224 Steps 500 Epsilon 0.2988
# Episode: 225
# Episode 225 Steps 100 Epsilon 0.2988
# Episode 225 Steps 200 Epsilon 0.2988
# Episode 225 Steps 300 Epsilon 0.2988
# Episode 225 Steps 400 Epsilon 0.2988
# Episode 225 Steps 500 Epsilon 0.2988
# Episode: 226
# Episode 226 Steps 100 Epsilon 0.2988
# Episode 226 Steps 200 Epsilon 0.2988
# Episode 226 Steps 300 Epsilon 0.2988
# Episode 226 Steps 400 Epsilon 0.2988
# Episode 226 Steps 500 Epsilon 0.2988
# Episode: 227
# Episode 227 Steps 100 Epsilon 0.2988
# Episode 227 Steps 200 Epsilon 0.2988
# Episode 227 Steps 300 Epsilon 0.2988
# Episode 227 Steps 400 Epsilon 0.2988
# Episode 227 Steps 500 Epsilon 0.2988
# Episode: 228
# Episode 228 Steps 100 Epsilon 0.2988
# Episode 228 Steps 200 Epsilon 0.2988
# Episode 228 Steps 300 Epsilon 0.2988
# Episode 228 Steps 400 Epsilon 0.2988
# Episode 228 Steps 500 Epsilon 0.2988
# Episode: 229
# Episode 229 Steps 100 Epsilon 0.2988
# Episode 229 Steps 200 Epsilon 0.2988
# Episode 229 Steps 300 Epsilon 0.2988
# Episode 229 Steps 400 Epsilon 0.2988
# Episode 229 Steps 500 Epsilon 0.2988
# Episode: 230
# SOLVED! Episode 230 Steps: 71 Epsilon 0.2988
# Episode: 231
# Episode 231 Steps 100 Epsilon 0.2988
# Episode 231 Steps 200 Epsilon 0.2988
# Episode 231 Steps 300 Epsilon 0.2988
# Episode 231 Steps 400 Epsilon 0.2988
# Episode 231 Steps 500 Epsilon 0.2988
# Episode: 232
# SOLVED! Episode 232 Steps: 23 Epsilon 0.2988
# Episode: 233
# Episode 233 Steps 100 Epsilon 0.2988
# Episode 233 Steps 200 Epsilon 0.2988
# Episode 233 Steps 300 Epsilon 0.2988
# Episode 233 Steps 400 Epsilon 0.2988
# Episode 233 Steps 500 Epsilon 0.2988
# Episode: 234
# Episode 234 Steps 100 Epsilon 0.2988
# SOLVED! Episode 234 Steps: 109 Epsilon 0.2988
# Episode: 235
# Episode 235 Steps 100 Epsilon 0.2988
# Episode 235 Steps 200 Epsilon 0.2988
# Episode 235 Steps 300 Epsilon 0.2988
# SOLVED! Episode 235 Steps: 379 Epsilon 0.2988
# Episode: 236
# Episode 236 Steps 100 Epsilon 0.2988
# Episode 236 Steps 200 Epsilon 0.2988
# Episode 236 Steps 300 Epsilon 0.2988
# SOLVED! Episode 236 Steps: 319 Epsilon 0.2988
# Episode: 237
# SOLVED! Episode 237 Steps: 33 Epsilon 0.2988
# Episode: 238
# Episode 238 Steps 100 Epsilon 0.2988
# Episode 238 Steps 200 Epsilon 0.2988
# Episode 238 Steps 300 Epsilon 0.2988
# Episode 238 Steps 400 Epsilon 0.2988
# SOLVED! Episode 238 Steps: 421 Epsilon 0.2988
# Episode: 239
# Episode 239 Steps 100 Epsilon 0.2988
# Episode 239 Steps 200 Epsilon 0.2988
# Episode 239 Steps 300 Epsilon 0.2988
# Episode 239 Steps 400 Epsilon 0.2988
# Episode 239 Steps 500 Epsilon 0.2988
# Episode: 240
# Episode 240 Steps 100 Epsilon 0.2988
# Episode 240 Steps 200 Epsilon 0.2988
# SOLVED! Episode 240 Steps: 264 Epsilon 0.2988
# Episode: 241
# Episode 241 Steps 100 Epsilon 0.2988
# Episode 241 Steps 200 Epsilon 0.2988
# Episode 241 Steps 300 Epsilon 0.2988
# SOLVED! Episode 241 Steps: 340 Epsilon 0.2988
# Episode: 242
# Episode 242 Steps 100 Epsilon 0.2988
# Episode 242 Steps 200 Epsilon 0.2988
# Episode 242 Steps 300 Epsilon 0.2988
# Episode 242 Steps 400 Epsilon 0.2988
# Episode 242 Steps 500 Epsilon 0.2988
# Episode: 243
# Episode 243 Steps 100 Epsilon 0.2988
# SOLVED! Episode 243 Steps: 164 Epsilon 0.2988
# Episode: 244
# Episode 244 Steps 100 Epsilon 0.2988
# Episode 244 Steps 200 Epsilon 0.2988
# Episode 244 Steps 300 Epsilon 0.2988
# Episode 244 Steps 400 Epsilon 0.2988
# Episode 244 Steps 500 Epsilon 0.2988
# Episode: 245
# Episode 245 Steps 100 Epsilon 0.2988
# Episode 245 Steps 200 Epsilon 0.2988
# Episode 245 Steps 300 Epsilon 0.2988
# Episode 245 Steps 400 Epsilon 0.2988
# Episode 245 Steps 500 Epsilon 0.2988
# Episode: 246
# Episode 246 Steps 100 Epsilon 0.2988
# Episode 246 Steps 200 Epsilon 0.2988
# Episode 246 Steps 300 Epsilon 0.2988
# Episode 246 Steps 400 Epsilon 0.2988
# Episode 246 Steps 500 Epsilon 0.2988
# Episode: 247
# Episode 247 Steps 100 Epsilon 0.2988
# Episode 247 Steps 200 Epsilon 0.2988
# Episode 247 Steps 300 Epsilon 0.2988
# Episode 247 Steps 400 Epsilon 0.2988
# Episode 247 Steps 500 Epsilon 0.2988
# Episode: 248
# SOLVED! Episode 248 Steps: 72 Epsilon 0.2988
# Episode: 249
# Episode 249 Steps 100 Epsilon 0.2988
# Episode 249 Steps 200 Epsilon 0.2988
# Episode 249 Steps 300 Epsilon 0.2988
# Episode 249 Steps 400 Epsilon 0.2988
# Episode 249 Steps 500 Epsilon 0.2988
# Episode: 250
# Episode 250 Steps 100 Epsilon 0.2988
# Episode 250 Steps 200 Epsilon 0.2988
# Episode 250 Steps 300 Epsilon 0.2988
# Episode 250 Steps 400 Epsilon 0.2988
# Episode 250 Steps 500 Epsilon 0.2988
# Episode: 251
# Episode 251 Steps 100 Epsilon 0.2988
# Episode 251 Steps 200 Epsilon 0.2988
# Episode 251 Steps 300 Epsilon 0.2988
# Episode 251 Steps 400 Epsilon 0.2988
# Episode 251 Steps 500 Epsilon 0.2988
# Episode: 252
# Episode 252 Steps 100 Epsilon 0.2988
# Episode 252 Steps 200 Epsilon 0.2988
# Episode 252 Steps 300 Epsilon 0.2988
# Episode 252 Steps 400 Epsilon 0.2988
# Episode 252 Steps 500 Epsilon 0.2988
# Episode: 253
# Episode 253 Steps 100 Epsilon 0.2988
# Episode 253 Steps 200 Epsilon 0.2988
# Episode 253 Steps 300 Epsilon 0.2988
# Episode 253 Steps 400 Epsilon 0.2988
# Episode 253 Steps 500 Epsilon 0.2988
# Episode: 254
# Episode 254 Steps 100 Epsilon 0.2988
# Episode 254 Steps 200 Epsilon 0.2988
# Episode 254 Steps 300 Epsilon 0.2988
# Episode 254 Steps 400 Epsilon 0.2988
# Episode 254 Steps 500 Epsilon 0.2988
# Episode: 255
# Episode 255 Steps 100 Epsilon 0.2988
# Episode 255 Steps 200 Epsilon 0.2988
# Episode 255 Steps 300 Epsilon 0.2988
# Episode 255 Steps 400 Epsilon 0.2988
# Episode 255 Steps 500 Epsilon 0.2988
# Episode: 256
# Episode 256 Steps 100 Epsilon 0.2988
# Episode 256 Steps 200 Epsilon 0.2988
# Episode 256 Steps 300 Epsilon 0.2988
# Episode 256 Steps 400 Epsilon 0.2988
# Episode 256 Steps 500 Epsilon 0.2988
# Episode: 257
# Episode 257 Steps 100 Epsilon 0.2988
# Episode 257 Steps 200 Epsilon 0.2988
# Episode 257 Steps 300 Epsilon 0.2988
# Episode 257 Steps 400 Epsilon 0.2988
# Episode 257 Steps 500 Epsilon 0.2988
# Episode: 258
# Episode 258 Steps 100 Epsilon 0.2988
# Episode 258 Steps 200 Epsilon 0.2988
# Episode 258 Steps 300 Epsilon 0.2988
# Episode 258 Steps 400 Epsilon 0.2988
# Episode 258 Steps 500 Epsilon 0.2988
# Episode: 259
# Episode 259 Steps 100 Epsilon 0.2988
# Episode 259 Steps 200 Epsilon 0.2988
# Episode 259 Steps 300 Epsilon 0.2988
# Episode 259 Steps 400 Epsilon 0.2988
# Episode 259 Steps 500 Epsilon 0.2988
# Episode: 260
# Episode 260 Steps 100 Epsilon 0.2988
# Episode 260 Steps 200 Epsilon 0.2988
# Episode 260 Steps 300 Epsilon 0.2988
# Episode 260 Steps 400 Epsilon 0.2988
# Episode 260 Steps 500 Epsilon 0.2988
# Episode: 261
# Episode 261 Steps 100 Epsilon 0.2988
# Episode 261 Steps 200 Epsilon 0.2988
# Episode 261 Steps 300 Epsilon 0.2988
# Episode 261 Steps 400 Epsilon 0.2988
# Episode 261 Steps 500 Epsilon 0.2988
# Episode: 262
# Episode 262 Steps 100 Epsilon 0.2988
# Episode 262 Steps 200 Epsilon 0.2988
# Episode 262 Steps 300 Epsilon 0.2988
# Episode 262 Steps 400 Epsilon 0.2988
# Episode 262 Steps 500 Epsilon 0.2988
# Episode: 263
# SOLVED! Episode 263 Steps: 21 Epsilon 0.2988
# Episode: 264
# SOLVED! Episode 264 Steps: 22 Epsilon 0.2988
# Episode: 265
# Episode 265 Steps 100 Epsilon 0.2988
# Episode 265 Steps 200 Epsilon 0.2988
# Episode 265 Steps 300 Epsilon 0.2988
# Episode 265 Steps 400 Epsilon 0.2988
# Episode 265 Steps 500 Epsilon 0.2988
# Episode: 266
# Episode 266 Steps 100 Epsilon 0.2988
# Episode 266 Steps 200 Epsilon 0.2988
# Episode 266 Steps 300 Epsilon 0.2988
# Episode 266 Steps 400 Epsilon 0.2988
# SOLVED! Episode 266 Steps: 405 Epsilon 0.2988
# Episode: 267
# Episode 267 Steps 100 Epsilon 0.2988
# Episode 267 Steps 200 Epsilon 0.2988
# Episode 267 Steps 300 Epsilon 0.2988
# Episode 267 Steps 400 Epsilon 0.2988
# Episode 267 Steps 500 Epsilon 0.2988
# Episode: 268
# Episode 268 Steps 100 Epsilon 0.2988
# Episode 268 Steps 200 Epsilon 0.2988
# Episode 268 Steps 300 Epsilon 0.2988
# Episode 268 Steps 400 Epsilon 0.2988
# Episode 268 Steps 500 Epsilon 0.2988
# Episode: 269
# SOLVED! Episode 269 Steps: 22 Epsilon 0.2988
# Episode: 270
# Episode 270 Steps 100 Epsilon 0.2988
# Episode 270 Steps 200 Epsilon 0.2988
# SOLVED! Episode 270 Steps: 212 Epsilon 0.2988
# Episode: 271
# Episode 271 Steps 100 Epsilon 0.2988
# Episode 271 Steps 200 Epsilon 0.2988
# Episode 271 Steps 300 Epsilon 0.2988
# Episode 271 Steps 400 Epsilon 0.2988
# Episode 271 Steps 500 Epsilon 0.2988
# Episode: 272
# Episode 272 Steps 100 Epsilon 0.2988
# Episode 272 Steps 200 Epsilon 0.2988
# Episode 272 Steps 300 Epsilon 0.2988
# Episode 272 Steps 400 Epsilon 0.2988
# Episode 272 Steps 500 Epsilon 0.2988
# Episode: 273
# Episode 273 Steps 100 Epsilon 0.2988
# Episode 273 Steps 200 Epsilon 0.2988
# Episode 273 Steps 300 Epsilon 0.2988
# Episode 273 Steps 400 Epsilon 0.2988
# Episode 273 Steps 500 Epsilon 0.2988
# Episode: 274
# Episode 274 Steps 100 Epsilon 0.2988
# Episode 274 Steps 200 Epsilon 0.2988
# Episode 274 Steps 300 Epsilon 0.2988
# Episode 274 Steps 400 Epsilon 0.2988
# Episode 274 Steps 500 Epsilon 0.2988
# Episode: 275
# Episode 275 Steps 100 Epsilon 0.2988
# Episode 275 Steps 200 Epsilon 0.2988
# Episode 275 Steps 300 Epsilon 0.2988
# Episode 275 Steps 400 Epsilon 0.2988
# Episode 275 Steps 500 Epsilon 0.2988
# Episode: 276
# Episode 276 Steps 100 Epsilon 0.2988
# Episode 276 Steps 200 Epsilon 0.2988
# Episode 276 Steps 300 Epsilon 0.2988
# Episode 276 Steps 400 Epsilon 0.2988
# Episode 276 Steps 500 Epsilon 0.2988
# Episode: 277
# Episode 277 Steps 100 Epsilon 0.2988
# Episode 277 Steps 200 Epsilon 0.2988
# Episode 277 Steps 300 Epsilon 0.2988
# Episode 277 Steps 400 Epsilon 0.2988
# Episode 277 Steps 500 Epsilon 0.2988
# Episode: 278
# Episode 278 Steps 100 Epsilon 0.2988
# Episode 278 Steps 200 Epsilon 0.2988
# Episode 278 Steps 300 Epsilon 0.2988
# Episode 278 Steps 400 Epsilon 0.2988
# Episode 278 Steps 500 Epsilon 0.2988
# Episode: 279
# Episode 279 Steps 100 Epsilon 0.2988
# Episode 279 Steps 200 Epsilon 0.2988
# Episode 279 Steps 300 Epsilon 0.2988
# Episode 279 Steps 400 Epsilon 0.2988
# Episode 279 Steps 500 Epsilon 0.2988
# Episode: 280
# Episode 280 Steps 100 Epsilon 0.2988
# Episode 280 Steps 200 Epsilon 0.2988
# Episode 280 Steps 300 Epsilon 0.2988
# Episode 280 Steps 400 Epsilon 0.2988
# Episode 280 Steps 500 Epsilon 0.2988
# Episode: 281
# Episode 281 Steps 100 Epsilon 0.2988
# Episode 281 Steps 200 Epsilon 0.2988
# Episode 281 Steps 300 Epsilon 0.2988
# Episode 281 Steps 400 Epsilon 0.2988
# Episode 281 Steps 500 Epsilon 0.2988
# Episode: 282
# SOLVED! Episode 282 Steps: 22 Epsilon 0.2988
# Episode: 283
# Episode 283 Steps 100 Epsilon 0.2988
# Episode 283 Steps 200 Epsilon 0.2988
# Episode 283 Steps 300 Epsilon 0.2988
# Episode 283 Steps 400 Epsilon 0.2988
# Episode 283 Steps 500 Epsilon 0.2988
# Episode: 284
# Episode 284 Steps 100 Epsilon 0.2988
# Episode 284 Steps 200 Epsilon 0.2988
# Episode 284 Steps 300 Epsilon 0.2988
# Episode 284 Steps 400 Epsilon 0.2988
# Episode 284 Steps 500 Epsilon 0.2988
# Episode: 285
# Episode 285 Steps 100 Epsilon 0.2988
# Episode 285 Steps 200 Epsilon 0.2988
# Episode 285 Steps 300 Epsilon 0.2988
# Episode 285 Steps 400 Epsilon 0.2988
# Episode 285 Steps 500 Epsilon 0.2988
# Episode: 286
# Episode 286 Steps 100 Epsilon 0.2988
# Episode 286 Steps 200 Epsilon 0.2988
# Episode 286 Steps 300 Epsilon 0.2988
# Episode 286 Steps 400 Epsilon 0.2988
# Episode 286 Steps 500 Epsilon 0.2988
# Episode: 287
# Episode 287 Steps 100 Epsilon 0.2988
# Episode 287 Steps 200 Epsilon 0.2988
# Episode 287 Steps 300 Epsilon 0.2988
# Episode 287 Steps 400 Epsilon 0.2988
# Episode 287 Steps 500 Epsilon 0.2988
# Episode: 288
# Episode 288 Steps 100 Epsilon 0.2988
# Episode 288 Steps 200 Epsilon 0.2988
# Episode 288 Steps 300 Epsilon 0.2988
# Episode 288 Steps 400 Epsilon 0.2988
# Episode 288 Steps 500 Epsilon 0.2988
# Episode: 289
# Episode 289 Steps 100 Epsilon 0.2988
# Episode 289 Steps 200 Epsilon 0.2988
# Episode 289 Steps 300 Epsilon 0.2988
# Episode 289 Steps 400 Epsilon 0.2988
# Episode 289 Steps 500 Epsilon 0.2988
# Episode: 290
# Episode 290 Steps 100 Epsilon 0.2988
# Episode 290 Steps 200 Epsilon 0.2988
# Episode 290 Steps 300 Epsilon 0.2988
# Episode 290 Steps 400 Epsilon 0.2988
# Episode 290 Steps 500 Epsilon 0.2988
# Episode: 291
# SOLVED! Episode 291 Steps: 9 Epsilon 0.2988
# Episode: 292
# SOLVED! Episode 292 Steps: 9 Epsilon 0.2988
# Episode: 293
# SOLVED! Episode 293 Steps: 9 Epsilon 0.2988
# Episode: 294
# SOLVED! Episode 294 Steps: 9 Epsilon 0.2988
# Episode: 295
# SOLVED! Episode 295 Steps: 9 Epsilon 0.2988
# Episode: 296
# SOLVED! Episode 296 Steps: 9 Epsilon 0.2988
# Episode: 297
# SOLVED! Episode 297 Steps: 9 Epsilon 0.2988
# Episode: 298
# SOLVED! Episode 298 Steps: 9 Epsilon 0.2988
# Episode: 299
# SOLVED! Episode 299 Steps: 9 Epsilon 0.2988
# Episode: 300
# SOLVED! Episode 300 Steps: 9 Epsilon 0.2988
# Agent training finished!

# %% [markdown]
# ## Charts

# %%
textstr = '\n'.join((
    r'$\mu=%.2f$' % (mu, ),
    r'$\mathrm{median}=%.2f$' % (median, ),
    r'$\sigma=%.2f$' % (sigma, )))

ax.hist(x, 50)
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)

# place a text box in upper left in axes coords
ax.text(0.05, 0.95, textstr, transform=ax.transAxes, fontsize=14,
        verticalalignment='top', bbox=props)

# %%
fig, ax = plt.subplots(figsize=(16,8))
plt.plot(list(range(len(steps_per_episode))), steps_per_episode)
plt.title("Training for fixed Sokoban scenario (max_steps=500)", fontsize=20)
plt.xlabel("Steps", fontsize=16)
plt.ylabel("Episode", fontsize=16)
plt.axvline(63, color='k', linestyle='--', label='Start')
props = dict(boxstyle='round', facecolor='wheat', alpha=0.5)
ax.text(0.13, 0.8, "Exploration", transform=ax.transAxes, fontsize=14, verticalalignment='top', bbox=props)
ax.text(0.25, 0.8, "Training", transform=ax.transAxes, fontsize=14, verticalalignment='top', bbox=props)
plt.show()

# %% [markdown]
# ## Demo

# %%
sok = init_sok()
sok.epsilon = 0

start_time = time.time()
done = False
iter = 0
video_filename = 'imageio.mp4'

state = sok.get_image('rgb_array')

with imageio.get_writer(video_filename, fps=10) as video:
    while (iter < 10) or not done:
        time_passed = int(time.time() - start_time)
        if done or time_passed > 3:
            break
        iter +=1
        action = agent.act(process_frame(state))
        
        if action < 4:
            action += 1
        else:
            action += 5
        
        state, reward, done, info = sok.step(action)
        video.append_data(sok.render(mode='rgb_array'))
        
embed_mp4(video_filename)
# Out:
#     <video width="640" height="480" controls>
#     <source src="data:video/mp4;base64,..." type="video/mp4">
#     Your browser does not support the video tag.
#     </video>

# %%
import tensorflow as tf

oi = tf.keras.initializers.Orthogonal()
ortho_layer = tf.keras.layers.Dense(
    32, kernel_initializer=oi
)

# %%
opt_adam = optimizers.adam(clipnorm=1.)
opt_adam = optimizers.adam(clipvalue=0.5)
