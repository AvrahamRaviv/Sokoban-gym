# %% [markdown]
# # Final Project - Reinforcements Learning
# Hello dear students,<br> this is the template notebook. Please click on the "File" tab and then on "Save a copy into drive".
#
# ---
# <br>
#
# ### Name and ID:
# Student 1: Avraham Raviv, 204355390
# <br>
# Student 2: Yevgeni Berkovitch, 317079234
# <br><br>
# <img src="https://play-lh.googleusercontent.com/e_oKlKPISbgdzut1H9opevS7-LTB8-8lsmpCdMkhlnqFenZhpjxbLmx7l158-xQQCIY">
#
# ### https://github.com/mpSchrader/gym-sokoban

# %% [markdown]
# # Installs

# %%
# %%capture
# !sudo apt-get update
# !sudo apt-get install -y xvfb ffmpeg freeglut3-dev
# !pip install 'imageio==2.4.0'
# !pip install gym
# !pip install pygame
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet
# !pip install gym
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install gym_sokoban

# !imageio_download_bin ffmpeg

# %% [markdown]
# # Imports

# %%
import random
import time

import numpy as np
import scipy as scp
import matplotlib.pyplot as plt

import base64
import imageio
from pyvirtualdisplay import Display
from IPython.display import HTML

import gym
from gym import error, spaces, utils
from soko_pap import *

from collections import deque
from queue import PriorityQueue

from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten

from tqdm.notebook import tqdm
from collections import defaultdict

# %%
# %matplotlib inline

# %%
imageio.plugins.ffmpeg.download()

# %%
from gym import logger as gymlogger
gymlogger.set_level(40) # error only

# %% [markdown]
# # Display utils
# The cell below contains the video display configuration. No need to make changes here.

# %%
def embed_mp4(filename):
    """Embeds an mp4 file in the notebook."""
    video = open(filename,'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())

    return HTML(tag)

# %% [markdown]
# # Utils

# %%
def get_distances(room_state):
    for i in range(room_state.shape[0]):
        for j in range(room_state.shape[1]):
            if room_state[i][j] == 2:
                target = (i, j)

    distances = np.zeros(shape=room_state.shape)
    visited_cells = set()
    cell_queue = deque()

    visited_cells.add(target)
    cell_queue.appendleft(target)

    while len(cell_queue) != 0:
        cell = cell_queue.pop()
        distance = distances[cell[0]][cell[1]]
        for x,y in ((1,0), (-1,-0), (0,1), (0,-1)):
            next_cell_x, next_cell_y = cell[0]+x, cell[1]+y
            if room_state[next_cell_x][next_cell_y] != 0 and not (next_cell_x, next_cell_y) in visited_cells:
                distances[next_cell_x][next_cell_y] = distance + 1
                visited_cells.add((next_cell_x, next_cell_y))
                cell_queue.appendleft((next_cell_x, next_cell_y))
                
    return distances   

def calc_distances(room_state, distances):
    box = None
    mover = None
    for i in range(room_state.shape[0]):
        for j in range(room_state.shape[1]):            
            if room_state[i][j] == 4:
                box = (i,j)
            
            if room_state[i][j] == 5:
                mover = (i,j)
    
    return mover, box, distances[box[0]][box[1]]   

def box2target_change_reward(room_state, next_room_state, distances):
    if np.array_equal(room_state, next_room_state):
        return -1.0
    
    mover, box, t2b = calc_distances(room_state, distances)
    n_mover, n_box, n_t2b = calc_distances(next_room_state, distances)
    
    change_reward = 0.0
    if n_t2b < t2b:
        change_reward += 5.0
    elif n_t2b > t2b:
        change_reward -= 5.0
        
    m2b = np.sqrt((mover[0]-box[0])**2 + (mover[1]-box[1])**2)
    n_m2b = np.sqrt((n_mover[0]-n_box[0])**2 + (n_mover[1]-n_box[1])**2)
    
    if n_m2b < m2b and m2b >= 2:
        change_reward += 1.0
    elif n_m2b > m2b and n_m2b >= 2:
        change_reward -= 1.0
        
    return change_reward

# %% [markdown]
# # Solution

# %%
class SOK_Agent:
    def __init__(self):
        # Construct DQN models
        self.state_size = (112,112,1) 
        self.action_size = 8
        self.model = self._build_model()
        self.target_model = self._build_model()
        self.target_model.set_weights(self.model.get_weights())
        self.batch_size = 8
        
        # Replay buffers
        self.replay_buffer = deque(maxlen=5000)
        self.prioritized_replay_buffer = deque(maxlen=500)
        
        # Hyperparameters
        self.gamma = 0.9
        self.epsilon = 1.0   
        self.epsilon_min = 0.3
        self.epsilon_decay = 0.995
        self.replay_rate = 10
        self.update_beta = 0.999

        self.verbosity = 100 

    def _build_model(self):
        model = Sequential()
        model.add(Conv2D(64, (16,16), strides=(16,16), input_shape=self.state_size, activation='relu'))
        model.add(Conv2D(64, (3,3), activation='relu'))
        model.add(Flatten())
        model.add(Dense(512, activation='relu'))       
        model.add(Dense(64, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer="adam")        
        return model

    def remember(self, state, action, reward, next_state, done):
        self.replay_buffer.append([state, action, reward, next_state, done])    
        
    def copy_to_prioritized_buffer(self, n):
        for i in range(n):
            self.prioritized_replay_buffer.append(self.replay_buffer[-1-i])  

    def act(self, state, stochastic=False):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        
        act_values = self.model.predict(state, verbose=0)[0]
        
        if stochastic:
            act_probs = np.exp(act_values)/np.exp(act_values).sum()
            return np.random.choice(np.arange(self.action_size), size=1, p=act_probs)[0]
              
        return np.argmax(act_values) 

    def replay(self): 
        if len(self.replay_buffer) < self.batch_size:
            return
        
        if len(self.prioritized_replay_buffer) < self.batch_size//2:
            minibatch = random.sample(self.replay_buffer, self.batch_size) 
        else:    
            minibatch = random.sample(self.replay_buffer, self.batch_size//2) 
            minibatch.extend(random.sample(self.prioritized_replay_buffer, self.batch_size//2))
        
        states = np.zeros((self.batch_size, self.state_size[0], self.state_size[1]))
        actions = np.zeros(self.batch_size, dtype=int)
        rewards = np.zeros(self.batch_size)
        next_states = np.zeros((self.batch_size, self.state_size[0], self.state_size[1]))
        statuses = np.zeros(self.batch_size)
        targets = np.zeros((self.batch_size, self.action_size)) 
        
        for i, (state, action, reward, next_state, done) in enumerate(minibatch): 
            states[i] = state.copy()
            actions[i] = action
            rewards[i] = reward
            next_states[i] = next_state.copy()
            statuses[i] = 1 if done else 0    
        
        targets = self.model.predict(states) 
        max_actions = np.argmax(self.model.predict(next_states), axis=1)
        next_rewards = self.target_model.predict(next_states)
        
        ind = 0
        for action, reward, next_reward, max_action, done in zip(actions, rewards, next_rewards, max_actions, statuses):  
            if not done:
                reward += self.gamma * next_reward[max_action]
            targets[ind][action] = reward
            ind += 1
        
        self.model.fit(states, targets, epochs=10, verbose=0) 
        
        self.update_target_model()        
    
        if self.epsilon > self.epsilon_min:
            self.epsilon = self.epsilon * self.epsilon_decay
        
    def update_target_model(self):
        model_w = self.model.get_weights()
        target_model_w = self.target_model.get_weights()
        updated_target_model_w = []
        for i in range(len(model_w)):
            updated_target_model_w.append(self.update_beta*target_model_w[i] + (1-self.update_beta)*model_w[i])
        self.target_model.set_weights(updated_target_model_w)    
            
    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

# %%
def process_frame(frame):
    f = frame.mean(axis=2)
    f = f / 255
    return np.expand_dims(f, axis=0)

# %% [markdown]
# ## Training

# %% [markdown]
# #### Test Suite

# %%
def test_agent(stochastic=False):
    current_epsilon = agent.epsilon
    agent.epsilon = 0.0
    num_solved = 0
    solved_in_steps = defaultdict(int)

    for t in tqdm(range(100)):    
        random.seed(t)
        sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
        sok.set_maxsteps(20)
        steps = 0

        state = sok.get_image('rgb_array')
        done = False
        while not done:
            steps += 1
            action = agent.act(process_frame(state), stochastic)
            if action < 4:
                action += 1
            else:
                action += 5
            state, reward, done, info = sok.step(action)

        if 3 in sok.room_state:            
            num_solved += 1
            solved_in_steps[steps] += 1
    
    agent.epsilon = current_epsilon
    print("*" * 30)
    print("Stochastic" if stochastic else "Deterministic")
    print("*" * 30)
    print("Solved: %d" % num_solved)
    print("=" * 30)
    print(solved_in_steps)
    print("*" * 30)

# %%
max_episodes = 50000
max_steps = 20

def init_sok(r):
    random.seed(r+100)
    sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
    sok.set_maxsteps(max_steps)
    return sok

# %%
agent = SOK_Agent()

steps_per_episode = []

for e in range(max_episodes):
    if e % 100 == 0 and e > 0:
        test_agent(stochastic=False)
        
    print("Episode: %d" % (e))
    
    sok = init_sok(e)
    random.seed(e)
    
    state = process_frame(sok.get_image('rgb_array'))
    room_state = sok.room_state.copy() 
    distances = get_distances(room_state)
    
    for step in range(sok.max_steps):
        action = agent.act(state)
        if action < 4:
            next_state, reward, done, _ = sok.step(action+1) 
        else:
            next_state, reward, done, _ = sok.step(action+5)         
        
        next_state = process_frame(next_state)        
        next_room_state = sok.room_state
        
        if not done:
            reward += box2target_change_reward(room_state, next_room_state, distances)
        
        agent.remember(state, action, reward, next_state, done)
        
        state = next_state.copy() 
        room_state = next_room_state.copy()                
        
        if (step+1) % agent.replay_rate == 0:
            agent.replay()            
        
        if done:   
            steps_per_episode.append(step+1)
            
            if 3 in sok.room_state:                
                print("SOLVED! Episode %d Steps: %d Epsilon %.4f" % (e, step+1, agent.epsilon)) 
                agent.copy_to_prioritized_buffer(step+1)
            
            #agent.save("exp1_episode%d.h5" % (e))            
            break
# Out:
# Episode: 0
# Episode: 1
# Episode: 2
# Episode: 3
# Episode: 4
# Episode: 5
# Episode: 6
# Episode: 7
# SOLVED! Episode 7 Steps: 6 Epsilon 0.9322
# Episode: 8
# Episode: 9
# Episode: 10
# SOLVED! Episode 10 Steps: 13 Epsilon 0.9092
# Episode: 11
# Episode: 12
# Episode: 13
# SOLVED! Episode 13 Steps: 7 Epsilon 0.8911
# Episode: 14
# Episode: 15
# Episode: 16
# SOLVED! Episode 16 Steps: 19 Epsilon 0.8691
# Episode: 17
# Episode: 18
# Episode: 19
# Episode: 20
# Episode: 21
# Episode: 22
# SOLVED! Episode 22 Steps: 13 Epsilon 0.8224
# Episode: 23
# Episode: 24
# Episode: 25
# Episode: 26
# SOLVED! Episode 26 Steps: 4 Epsilon 0.7981
# Episode: 27
# Episode: 28
# Episode: 29
# SOLVED! Episode 29 Steps: 1 Epsilon 0.7822
# Episode: 30
# Episode: 31
# Episode: 32
# Episode: 33
# Episode: 34
# Episode: 35
# Episode: 36
# Episode: 37
# Episode: 38
# Episode: 39
# Episode: 40
# Episode: 41
# Episode: 42
# Episode: 43
# Episode: 44
# Episode: 45
# Episode: 46
# Episode: 47
# Episode: 48
# SOLVED! Episode 48 Steps: 1 Epsilon 0.6531
# Episode: 49
# Episode: 50
# Episode: 51
# Episode: 52
# Episode: 53
# Episode: 54
# Episode: 55
# Episode: 56
# SOLVED! Episode 56 Steps: 1 Epsilon 0.6088
# Episode: 57
# Episode: 58
# Episode: 59
# Episode: 60
# Episode: 61
# SOLVED! Episode 61 Steps: 1 Epsilon 0.5849
# Episode: 62
# Episode: 63
# Episode: 64
# Episode: 65
# SOLVED! Episode 65 Steps: 1 Epsilon 0.5676
# Episode: 66
# Episode: 67
# Episode: 68
# Episode: 69
# Episode: 70
# SOLVED! Episode 70 Steps: 1 Epsilon 0.5452
# Episode: 71
# Episode: 72
# Episode: 73
# Episode: 74
# Episode: 75
# Episode: 76
# SOLVED! Episode 76 Steps: 7 Epsilon 0.5186
# Episode: 77
# Episode: 78
# Episode: 79
# Episode: 80
# Episode: 81
# Episode: 82
# Episode: 83
# Episode: 84
# SOLVED! Episode 84 Steps: 1 Epsilon 0.4834
# Episode: 85
# SOLVED! Episode 85 Steps: 1 Epsilon 0.4834
# Episode: 86
# Episode: 87
# Episode: 88
# Episode: 89
# Episode: 90
# SOLVED! Episode 90 Steps: 1 Epsilon 0.4644
# Episode: 91
# Episode: 92
# Episode: 93
# Episode: 94
# SOLVED! Episode 94 Steps: 12 Epsilon 0.4484
# Episode: 95
# SOLVED! Episode 95 Steps: 1 Epsilon 0.4484
# Episode: 96
# Episode: 97
# Episode: 98
# Episode: 99
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 23
# ==============================
# defaultdict(<class 'int'>, {2: 4, 1: 15, 3: 4})
# ******************************
# Episode: 100
# Episode: 101
# Episode: 102
# Episode: 103
# SOLVED! Episode 103 Steps: 3 Epsilon 0.4180
# Episode: 104
# Episode: 105
# Episode: 106
# Episode: 107
# Episode: 108
# Episode: 109
# Episode: 110
# Episode: 111
# Episode: 112
# Episode: 113
# Episode: 114
# SOLVED! Episode 114 Steps: 1 Epsilon 0.3782
# Episode: 115
# Episode: 116
# Episode: 117
# Episode: 118
# SOLVED! Episode 118 Steps: 1 Epsilon 0.3670
# Episode: 119
# Episode: 120
# Episode: 121
# Episode: 122
# Episode: 123
# Episode: 124
# Episode: 125
# SOLVED! Episode 125 Steps: 2 Epsilon 0.3455
# Episode: 126
# Episode: 127
# Episode: 128
# Episode: 129
# SOLVED! Episode 129 Steps: 1 Epsilon 0.3353
# Episode: 130
# Episode: 131
# Episode: 132
# Episode: 133
# SOLVED! Episode 133 Steps: 13 Epsilon 0.3237
# Episode: 134
# Episode: 135
# Episode: 136
# Episode: 137
# Episode: 138
# Episode: 139
# Episode: 140
# Episode: 141
# SOLVED! Episode 141 Steps: 15 Epsilon 0.3003
# Episode: 142
# Episode: 143
# Episode: 144
# Episode: 145
# Episode: 146
# Episode: 147
# Episode: 148
# Episode: 149
# Episode: 150
# Episode: 151
# Episode: 152
# Episode: 153
# Episode: 154
# Episode: 155
# Episode: 156
# Episode: 157
# Episode: 158
# Episode: 159
# Episode: 160
# SOLVED! Episode 160 Steps: 19 Epsilon 0.2988
# Episode: 161
# SOLVED! Episode 161 Steps: 2 Epsilon 0.2988
# Episode: 162
# Episode: 163
# Episode: 164
# Episode: 165
# Episode: 166
# Episode: 167
# Episode: 168
# SOLVED! Episode 168 Steps: 18 Epsilon 0.2988
# Episode: 169
# Episode: 170
# Episode: 171
# Episode: 172
# Episode: 173
# Episode: 174
# Episode: 175
# Episode: 176
# Episode: 177
# Episode: 178
# SOLVED! Episode 178 Steps: 8 Epsilon 0.2988
# Episode: 179
# Episode: 180
# Episode: 181
# Episode: 182
# Episode: 183
# SOLVED! Episode 183 Steps: 6 Epsilon 0.2988
# Episode: 184
# Episode: 185
# Episode: 186
# Episode: 187
# Episode: 188
# SOLVED! Episode 188 Steps: 3 Epsilon 0.2988
# Episode: 189
# SOLVED! Episode 189 Steps: 2 Epsilon 0.2988
# Episode: 190
# Episode: 191
# SOLVED! Episode 191 Steps: 1 Epsilon 0.2988
# Episode: 192
# SOLVED! Episode 192 Steps: 3 Epsilon 0.2988
# Episode: 193
# Episode: 194
# Episode: 195
# Episode: 196
# Episode: 197
# Episode: 198
# Episode: 199
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 30
# ==============================
# defaultdict(<class 'int'>, {3: 9, 1: 16, 2: 5})
# ******************************
# Episode: 200
# SOLVED! Episode 200 Steps: 13 Epsilon 0.2988
# Episode: 201
# Episode: 202
# Episode: 203
# Episode: 204
# Episode: 205
# Episode: 206
# Episode: 207
# Episode: 208
# Episode: 209
# SOLVED! Episode 209 Steps: 2 Epsilon 0.2988
# Episode: 210
# Episode: 211
# Episode: 212
# SOLVED! Episode 212 Steps: 3 Epsilon 0.2988
# Episode: 213
# Episode: 214
# Episode: 215
# Episode: 216
# Episode: 217
# SOLVED! Episode 217 Steps: 3 Epsilon 0.2988
# Episode: 218
# SOLVED! Episode 218 Steps: 2 Epsilon 0.2988
# Episode: 219
# SOLVED! Episode 219 Steps: 2 Epsilon 0.2988
# Episode: 220
# SOLVED! Episode 220 Steps: 6 Epsilon 0.2988
# Episode: 221
# SOLVED! Episode 221 Steps: 1 Epsilon 0.2988
# Episode: 222
# Episode: 223
# Episode: 224
# Episode: 225
# SOLVED! Episode 225 Steps: 1 Epsilon 0.2988
# Episode: 226
# Episode: 227
# Episode: 228
# Episode: 229
# Episode: 230
# SOLVED! Episode 230 Steps: 1 Epsilon 0.2988
# Episode: 231
# Episode: 232
# Episode: 233
# SOLVED! Episode 233 Steps: 1 Epsilon 0.2988
# Episode: 234
# SOLVED! Episode 234 Steps: 3 Epsilon 0.2988
# Episode: 235
# Episode: 236
# Episode: 237
# SOLVED! Episode 237 Steps: 2 Epsilon 0.2988
# Episode: 238
# SOLVED! Episode 238 Steps: 1 Epsilon 0.2988
# Episode: 239
# SOLVED! Episode 239 Steps: 1 Epsilon 0.2988
# Episode: 240
# Episode: 241
# Episode: 242
# SOLVED! Episode 242 Steps: 3 Epsilon 0.2988
# Episode: 243
# Episode: 244
# SOLVED! Episode 244 Steps: 1 Epsilon 0.2988
# Episode: 245
# Episode: 246
# Episode: 247
# SOLVED! Episode 247 Steps: 1 Epsilon 0.2988
# Episode: 248
# Episode: 249
# SOLVED! Episode 249 Steps: 3 Epsilon 0.2988
# Episode: 250
# Episode: 251
# SOLVED! Episode 251 Steps: 3 Epsilon 0.2988
# Episode: 252
# Episode: 253
# Episode: 254
# Episode: 255
# Episode: 256
# SOLVED! Episode 256 Steps: 2 Epsilon 0.2988
# Episode: 257
# SOLVED! Episode 257 Steps: 3 Epsilon 0.2988
# Episode: 258
# Episode: 259
# SOLVED! Episode 259 Steps: 3 Epsilon 0.2988
# Episode: 260
# Episode: 261
# Episode: 262
# Episode: 263
# Episode: 264
# Episode: 265
# Episode: 266
# SOLVED! Episode 266 Steps: 3 Epsilon 0.2988
# Episode: 267
# Episode: 268
# SOLVED! Episode 268 Steps: 1 Epsilon 0.2988
# Episode: 269
# Episode: 270
# SOLVED! Episode 270 Steps: 2 Epsilon 0.2988
# Episode: 271
# Episode: 272
# SOLVED! Episode 272 Steps: 2 Epsilon 0.2988
# Episode: 273
# Episode: 274
# Episode: 275
# Episode: 276
# Episode: 277
# Episode: 278
# Episode: 279
# Episode: 280
# Episode: 281
# Episode: 282
# Episode: 283
# Episode: 284
# Episode: 285
# SOLVED! Episode 285 Steps: 3 Epsilon 0.2988
# Episode: 286
# Episode: 287
# Episode: 288
# Episode: 289
# Episode: 290
# Episode: 291
# Episode: 292
# SOLVED! Episode 292 Steps: 1 Epsilon 0.2988
# Episode: 293
# Episode: 294
# SOLVED! Episode 294 Steps: 1 Epsilon 0.2988
# Episode: 295
# Episode: 296
# Episode: 297
# Episode: 298
# Episode: 299
# SOLVED! Episode 299 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 41
# ==============================
# defaultdict(<class 'int'>, {3: 15, 1: 17, 2: 9})
# ******************************
# Episode: 300
# SOLVED! Episode 300 Steps: 1 Epsilon 0.2988
# Episode: 301
# Episode: 302
# Episode: 303
# Episode: 304
# Episode: 305
# SOLVED! Episode 305 Steps: 2 Epsilon 0.2988
# Episode: 306
# Episode: 307
# Episode: 308
# Episode: 309
# Episode: 310
# Episode: 311
# Episode: 312
# Episode: 313
# Episode: 314
# Episode: 315
# SOLVED! Episode 315 Steps: 3 Epsilon 0.2988
# Episode: 316
# Episode: 317
# Episode: 318
# SOLVED! Episode 318 Steps: 2 Epsilon 0.2988
# Episode: 319
# Episode: 320
# Episode: 321
# Episode: 322
# SOLVED! Episode 322 Steps: 13 Epsilon 0.2988
# Episode: 323
# Episode: 324
# SOLVED! Episode 324 Steps: 1 Epsilon 0.2988
# Episode: 325
# Episode: 326
# Episode: 327
# SOLVED! Episode 327 Steps: 2 Epsilon 0.2988
# Episode: 328
# Episode: 329
# Episode: 330
# Episode: 331
# Episode: 332
# Episode: 333
# Episode: 334
# SOLVED! Episode 334 Steps: 1 Epsilon 0.2988
# Episode: 335
# Episode: 336
# Episode: 337
# SOLVED! Episode 337 Steps: 2 Epsilon 0.2988
# Episode: 338
# Episode: 339
# Episode: 340
# Episode: 341
# SOLVED! Episode 341 Steps: 2 Epsilon 0.2988
# Episode: 342
# SOLVED! Episode 342 Steps: 2 Epsilon 0.2988
# Episode: 343
# SOLVED! Episode 343 Steps: 3 Epsilon 0.2988
# Episode: 344
# Episode: 345
# Episode: 346
# SOLVED! Episode 346 Steps: 3 Epsilon 0.2988
# Episode: 347
# Episode: 348
# SOLVED! Episode 348 Steps: 1 Epsilon 0.2988
# Episode: 349
# Episode: 350
# Episode: 351
# SOLVED! Episode 351 Steps: 3 Epsilon 0.2988
# Episode: 352
# Episode: 353
# Episode: 354
# Episode: 355
# Episode: 356
# Episode: 357
# Episode: 358
# Episode: 359
# Episode: 360
# Episode: 361
# Episode: 362
# Episode: 363
# Episode: 364
# Episode: 365
# Episode: 366
# SOLVED! Episode 366 Steps: 16 Epsilon 0.2988
# Episode: 367
# Episode: 368
# SOLVED! Episode 368 Steps: 14 Epsilon 0.2988
# Episode: 369
# Episode: 370
# SOLVED! Episode 370 Steps: 3 Epsilon 0.2988
# Episode: 371
# Episode: 372
# Episode: 373
# Episode: 374
# Episode: 375
# Episode: 376
# SOLVED! Episode 376 Steps: 3 Epsilon 0.2988
# Episode: 377
# Episode: 378
# Episode: 379
# SOLVED! Episode 379 Steps: 3 Epsilon 0.2988
# Episode: 380
# Episode: 381
# Episode: 382
# Episode: 383
# Episode: 384
# Episode: 385
# Episode: 386
# Episode: 387
# Episode: 388
# Episode: 389
# Episode: 390
# Episode: 391
# SOLVED! Episode 391 Steps: 3 Epsilon 0.2988
# Episode: 392
# Episode: 393
# Episode: 394
# SOLVED! Episode 394 Steps: 1 Epsilon 0.2988
# Episode: 395
# Episode: 396
# SOLVED! Episode 396 Steps: 3 Epsilon 0.2988
# Episode: 397
# Episode: 398
# Episode: 399
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 49
# ==============================
# defaultdict(<class 'int'>, {3: 21, 1: 20, 2: 8})
# ******************************
# Episode: 400
# SOLVED! Episode 400 Steps: 2 Epsilon 0.2988
# Episode: 401
# Episode: 402
# Episode: 403
# SOLVED! Episode 403 Steps: 3 Epsilon 0.2988
# Episode: 404
# SOLVED! Episode 404 Steps: 3 Epsilon 0.2988
# Episode: 405
# SOLVED! Episode 405 Steps: 1 Epsilon 0.2988
# Episode: 406
# SOLVED! Episode 406 Steps: 1 Epsilon 0.2988
# Episode: 407
# Episode: 408
# Episode: 409
# Episode: 410
# SOLVED! Episode 410 Steps: 2 Epsilon 0.2988
# Episode: 411
# Episode: 412
# Episode: 413
# SOLVED! Episode 413 Steps: 3 Epsilon 0.2988
# Episode: 414
# Episode: 415
# SOLVED! Episode 415 Steps: 13 Epsilon 0.2988
# Episode: 416
# SOLVED! Episode 416 Steps: 3 Epsilon 0.2988
# Episode: 417
# Episode: 418
# Episode: 419
# Episode: 420
# Episode: 421
# Episode: 422
# Episode: 423
# SOLVED! Episode 423 Steps: 1 Epsilon 0.2988
# Episode: 424
# Episode: 425
# Episode: 426
# Episode: 427
# SOLVED! Episode 427 Steps: 3 Epsilon 0.2988
# Episode: 428
# SOLVED! Episode 428 Steps: 2 Epsilon 0.2988
# Episode: 429
# Episode: 430
# Episode: 431
# Episode: 432
# Episode: 433
# Episode: 434
# Episode: 435
# SOLVED! Episode 435 Steps: 1 Epsilon 0.2988
# Episode: 436
# Episode: 437
# Episode: 438
# SOLVED! Episode 438 Steps: 1 Epsilon 0.2988
# Episode: 439
# SOLVED! Episode 439 Steps: 3 Epsilon 0.2988
# Episode: 440
# Episode: 441
# SOLVED! Episode 441 Steps: 2 Epsilon 0.2988
# Episode: 442
# SOLVED! Episode 442 Steps: 4 Epsilon 0.2988
# Episode: 443
# SOLVED! Episode 443 Steps: 2 Epsilon 0.2988
# Episode: 444
# Episode: 445
# Episode: 446
# Episode: 447
# Episode: 448
# SOLVED! Episode 448 Steps: 3 Epsilon 0.2988
# Episode: 449
# Episode: 450
# Episode: 451
# Episode: 452
# Episode: 453
# SOLVED! Episode 453 Steps: 3 Epsilon 0.2988
# Episode: 454
# Episode: 455
# SOLVED! Episode 455 Steps: 3 Epsilon 0.2988
# Episode: 456
# Episode: 457
# Episode: 458
# Episode: 459
# Episode: 460
# Episode: 461
# Episode: 462
# SOLVED! Episode 462 Steps: 2 Epsilon 0.2988
# Episode: 463
# Episode: 464
# Episode: 465
# SOLVED! Episode 465 Steps: 3 Epsilon 0.2988
# Episode: 466
# Episode: 467
# Episode: 468
# Episode: 469
# Episode: 470
# Episode: 471
# Episode: 472
# SOLVED! Episode 472 Steps: 2 Epsilon 0.2988
# Episode: 473
# Episode: 474
# Episode: 475
# Episode: 476
# SOLVED! Episode 476 Steps: 3 Epsilon 0.2988
# Episode: 477
# Episode: 478
# Episode: 479
# SOLVED! Episode 479 Steps: 3 Epsilon 0.2988
# Episode: 480
# Episode: 481
# Episode: 482
# Episode: 483
# Episode: 484
# Episode: 485
# Episode: 486
# Episode: 487
# Episode: 488
# SOLVED! Episode 488 Steps: 2 Epsilon 0.2988
# Episode: 489
# Episode: 490
# SOLVED! Episode 490 Steps: 1 Epsilon 0.2988
# Episode: 491
# Episode: 492
# Episode: 493
# SOLVED! Episode 493 Steps: 1 Epsilon 0.2988
# Episode: 494
# SOLVED! Episode 494 Steps: 3 Epsilon 0.2988
# Episode: 495
# SOLVED! Episode 495 Steps: 1 Epsilon 0.2988
# Episode: 496
# Episode: 497
# SOLVED! Episode 497 Steps: 2 Epsilon 0.2988
# Episode: 498
# SOLVED! Episode 498 Steps: 2 Epsilon 0.2988
# Episode: 499
# SOLVED! Episode 499 Steps: 2 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 53
# ==============================
# defaultdict(<class 'int'>, {3: 23, 1: 19, 2: 10, 5: 1})
# ******************************
# Episode: 500
# SOLVED! Episode 500 Steps: 2 Epsilon 0.2988
# Episode: 501
# Episode: 502
# Episode: 503
# SOLVED! Episode 503 Steps: 3 Epsilon 0.2988
# Episode: 504
# Episode: 505
# SOLVED! Episode 505 Steps: 3 Epsilon 0.2988
# Episode: 506
# Episode: 507
# Episode: 508
# Episode: 509
# SOLVED! Episode 509 Steps: 2 Epsilon 0.2988
# Episode: 510
# SOLVED! Episode 510 Steps: 1 Epsilon 0.2988
# Episode: 511
# SOLVED! Episode 511 Steps: 2 Epsilon 0.2988
# Episode: 512
# SOLVED! Episode 512 Steps: 1 Epsilon 0.2988
# Episode: 513
# Episode: 514
# Episode: 515
# Episode: 516
# Episode: 517
# SOLVED! Episode 517 Steps: 1 Epsilon 0.2988
# Episode: 518
# Episode: 519
# SOLVED! Episode 519 Steps: 2 Epsilon 0.2988
# Episode: 520
# SOLVED! Episode 520 Steps: 1 Epsilon 0.2988
# Episode: 521
# Episode: 522
# SOLVED! Episode 522 Steps: 3 Epsilon 0.2988
# Episode: 523
# SOLVED! Episode 523 Steps: 3 Epsilon 0.2988
# Episode: 524
# SOLVED! Episode 524 Steps: 3 Epsilon 0.2988
# Episode: 525
# Episode: 526
# Episode: 527
# Episode: 528
# SOLVED! Episode 528 Steps: 1 Epsilon 0.2988
# Episode: 529
# SOLVED! Episode 529 Steps: 3 Epsilon 0.2988
# Episode: 530
# SOLVED! Episode 530 Steps: 1 Epsilon 0.2988
# Episode: 531
# Episode: 532
# SOLVED! Episode 532 Steps: 2 Epsilon 0.2988
# Episode: 533
# Episode: 534
# Episode: 535
# Episode: 536
# SOLVED! Episode 536 Steps: 3 Epsilon 0.2988
# Episode: 537
# SOLVED! Episode 537 Steps: 2 Epsilon 0.2988
# Episode: 538
# Episode: 539
# SOLVED! Episode 539 Steps: 3 Epsilon 0.2988
# Episode: 540
# Episode: 541
# SOLVED! Episode 541 Steps: 3 Epsilon 0.2988
# Episode: 542
# SOLVED! Episode 542 Steps: 1 Epsilon 0.2988
# Episode: 543
# Episode: 544
# Episode: 545
# Episode: 546
# Episode: 547
# SOLVED! Episode 547 Steps: 2 Epsilon 0.2988
# Episode: 548
# SOLVED! Episode 548 Steps: 3 Epsilon 0.2988
# Episode: 549
# Episode: 550
# Episode: 551
# Episode: 552
# Episode: 553
# Episode: 554
# Episode: 555
# SOLVED! Episode 555 Steps: 1 Epsilon 0.2988
# Episode: 556
# Episode: 557
# Episode: 558
# SOLVED! Episode 558 Steps: 3 Epsilon 0.2988
# Episode: 559
# SOLVED! Episode 559 Steps: 7 Epsilon 0.2988
# Episode: 560
# SOLVED! Episode 560 Steps: 3 Epsilon 0.2988
# Episode: 561
# Episode: 562
# SOLVED! Episode 562 Steps: 2 Epsilon 0.2988
# Episode: 563
# SOLVED! Episode 563 Steps: 1 Epsilon 0.2988
# Episode: 564
# SOLVED! Episode 564 Steps: 3 Epsilon 0.2988
# Episode: 565
# Episode: 566
# Episode: 567
# Episode: 568
# SOLVED! Episode 568 Steps: 2 Epsilon 0.2988
# Episode: 569
# Episode: 570
# Episode: 571
# SOLVED! Episode 571 Steps: 2 Epsilon 0.2988
# Episode: 572
# Episode: 573
# Episode: 574
# Episode: 575
# Episode: 576
# SOLVED! Episode 576 Steps: 1 Epsilon 0.2988
# Episode: 577
# SOLVED! Episode 577 Steps: 3 Epsilon 0.2988
# Episode: 578
# Episode: 579
# SOLVED! Episode 579 Steps: 6 Epsilon 0.2988
# Episode: 580
# SOLVED! Episode 580 Steps: 3 Epsilon 0.2988
# Episode: 581
# Episode: 582
# Episode: 583
# Episode: 584
# Episode: 585
# Episode: 586
# SOLVED! Episode 586 Steps: 3 Epsilon 0.2988
# Episode: 587
# SOLVED! Episode 587 Steps: 3 Epsilon 0.2988
# Episode: 588
# Episode: 589
# Episode: 590
# Episode: 591
# SOLVED! Episode 591 Steps: 3 Epsilon 0.2988
# Episode: 592
# Episode: 593
# Episode: 594
# Episode: 595
# Episode: 596
# Episode: 597
# Episode: 598
# Episode: 599
# SOLVED! Episode 599 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 54
# ==============================
# defaultdict(<class 'int'>, {3: 24, 1: 19, 2: 11})
# ******************************
# Episode: 600
# SOLVED! Episode 600 Steps: 3 Epsilon 0.2988
# Episode: 601
# Episode: 602
# SOLVED! Episode 602 Steps: 1 Epsilon 0.2988
# Episode: 603
# Episode: 604
# Episode: 605
# Episode: 606
# SOLVED! Episode 606 Steps: 2 Epsilon 0.2988
# Episode: 607
# SOLVED! Episode 607 Steps: 1 Epsilon 0.2988
# Episode: 608
# SOLVED! Episode 608 Steps: 1 Epsilon 0.2988
# Episode: 609
# Episode: 610
# Episode: 611
# SOLVED! Episode 611 Steps: 15 Epsilon 0.2988
# Episode: 612
# Episode: 613
# SOLVED! Episode 613 Steps: 1 Epsilon 0.2988
# Episode: 614
# Episode: 615
# SOLVED! Episode 615 Steps: 2 Epsilon 0.2988
# Episode: 616
# SOLVED! Episode 616 Steps: 12 Epsilon 0.2988
# Episode: 617
# Episode: 618
# Episode: 619
# Episode: 620
# SOLVED! Episode 620 Steps: 3 Epsilon 0.2988
# Episode: 621
# Episode: 622
# Episode: 623
# SOLVED! Episode 623 Steps: 2 Epsilon 0.2988
# Episode: 624
# Episode: 625
# SOLVED! Episode 625 Steps: 2 Epsilon 0.2988
# Episode: 626
# SOLVED! Episode 626 Steps: 3 Epsilon 0.2988
# Episode: 627
# Episode: 628
# SOLVED! Episode 628 Steps: 3 Epsilon 0.2988
# Episode: 629
# Episode: 630
# Episode: 631
# Episode: 632
# SOLVED! Episode 632 Steps: 3 Epsilon 0.2988
# Episode: 633
# SOLVED! Episode 633 Steps: 1 Epsilon 0.2988
# Episode: 634
# Episode: 635
# SOLVED! Episode 635 Steps: 3 Epsilon 0.2988
# Episode: 636
# Episode: 637
# SOLVED! Episode 637 Steps: 1 Epsilon 0.2988
# Episode: 638
# Episode: 639
# Episode: 640
# SOLVED! Episode 640 Steps: 2 Epsilon 0.2988
# Episode: 641
# Episode: 642
# SOLVED! Episode 642 Steps: 2 Epsilon 0.2988
# Episode: 643
# Episode: 644
# Episode: 645
# SOLVED! Episode 645 Steps: 2 Epsilon 0.2988
# Episode: 646
# SOLVED! Episode 646 Steps: 1 Epsilon 0.2988
# Episode: 647
# Episode: 648
# SOLVED! Episode 648 Steps: 2 Epsilon 0.2988
# Episode: 649
# Episode: 650
# SOLVED! Episode 650 Steps: 3 Epsilon 0.2988
# Episode: 651
# Episode: 652
# SOLVED! Episode 652 Steps: 1 Epsilon 0.2988
# Episode: 653
# Episode: 654
# Episode: 655
# SOLVED! Episode 655 Steps: 3 Epsilon 0.2988
# Episode: 656
# SOLVED! Episode 656 Steps: 3 Epsilon 0.2988
# Episode: 657
# SOLVED! Episode 657 Steps: 3 Epsilon 0.2988
# Episode: 658
# SOLVED! Episode 658 Steps: 1 Epsilon 0.2988
# Episode: 659
# SOLVED! Episode 659 Steps: 2 Epsilon 0.2988
# Episode: 660
# Episode: 661
# Episode: 662
# Episode: 663
# Episode: 664
# SOLVED! Episode 664 Steps: 2 Epsilon 0.2988
# Episode: 665
# Episode: 666
# SOLVED! Episode 666 Steps: 2 Epsilon 0.2988
# Episode: 667
# Episode: 668
# Episode: 669
# SOLVED! Episode 669 Steps: 3 Epsilon 0.2988
# Episode: 670
# SOLVED! Episode 670 Steps: 2 Epsilon 0.2988
# Episode: 671
# SOLVED! Episode 671 Steps: 2 Epsilon 0.2988
# Episode: 672
# SOLVED! Episode 672 Steps: 3 Epsilon 0.2988
# Episode: 673
# Episode: 674
# SOLVED! Episode 674 Steps: 3 Epsilon 0.2988
# Episode: 675
# SOLVED! Episode 675 Steps: 2 Epsilon 0.2988
# Episode: 676
# SOLVED! Episode 676 Steps: 3 Epsilon 0.2988
# Episode: 677
# SOLVED! Episode 677 Steps: 2 Epsilon 0.2988
# Episode: 678
# Episode: 679
# SOLVED! Episode 679 Steps: 1 Epsilon 0.2988
# Episode: 680
# Episode: 681
# SOLVED! Episode 681 Steps: 20 Epsilon 0.2988
# Episode: 682
# Episode: 683
# Episode: 684
# Episode: 685
# Episode: 686
# Episode: 687
# Episode: 688
# Episode: 689
# Episode: 690
# Episode: 691
# Episode: 692
# Episode: 693
# Episode: 694
# Episode: 695
# Episode: 696
# Episode: 697
# SOLVED! Episode 697 Steps: 3 Epsilon 0.2988
# Episode: 698
# SOLVED! Episode 698 Steps: 1 Epsilon 0.2988
# Episode: 699
# SOLVED! Episode 699 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 57
# ==============================
# defaultdict(<class 'int'>, {3: 24, 1: 21, 2: 11, 5: 1})
# ******************************
# Episode: 700
# Episode: 701
# Episode: 702
# SOLVED! Episode 702 Steps: 1 Epsilon 0.2988
# Episode: 703
# Episode: 704
# Episode: 705
# SOLVED! Episode 705 Steps: 1 Epsilon 0.2988
# Episode: 706
# Episode: 707
# Episode: 708
# Episode: 709
# Episode: 710
# SOLVED! Episode 710 Steps: 1 Epsilon 0.2988
# Episode: 711
# SOLVED! Episode 711 Steps: 3 Epsilon 0.2988
# Episode: 712
# Episode: 713
# Episode: 714
# SOLVED! Episode 714 Steps: 4 Epsilon 0.2988
# Episode: 715
# Episode: 716
# Episode: 717
# Episode: 718
# SOLVED! Episode 718 Steps: 3 Epsilon 0.2988
# Episode: 719
# Episode: 720
# Episode: 721
# Episode: 722
# Episode: 723
# Episode: 724
# Episode: 725
# SOLVED! Episode 725 Steps: 3 Epsilon 0.2988
# Episode: 726
# Episode: 727
# Episode: 728
# SOLVED! Episode 728 Steps: 1 Epsilon 0.2988
# Episode: 729
# Episode: 730
# Episode: 731
# Episode: 732
# SOLVED! Episode 732 Steps: 3 Epsilon 0.2988
# Episode: 733
# SOLVED! Episode 733 Steps: 3 Epsilon 0.2988
# Episode: 734
# Episode: 735
# Episode: 736
# Episode: 737
# Episode: 738
# Episode: 739
# Episode: 740
# SOLVED! Episode 740 Steps: 2 Epsilon 0.2988
# Episode: 741
# Episode: 742
# SOLVED! Episode 742 Steps: 2 Epsilon 0.2988
# Episode: 743
# Episode: 744
# SOLVED! Episode 744 Steps: 1 Epsilon 0.2988
# Episode: 745
# Episode: 746
# Episode: 747
# Episode: 748
# Episode: 749
# SOLVED! Episode 749 Steps: 17 Epsilon 0.2988
# Episode: 750
# Episode: 751
# SOLVED! Episode 751 Steps: 1 Epsilon 0.2988
# Episode: 752
# Episode: 753
# Episode: 754
# SOLVED! Episode 754 Steps: 17 Epsilon 0.2988
# Episode: 755
# SOLVED! Episode 755 Steps: 1 Epsilon 0.2988
# Episode: 756
# SOLVED! Episode 756 Steps: 2 Epsilon 0.2988
# Episode: 757
# SOLVED! Episode 757 Steps: 1 Epsilon 0.2988
# Episode: 758
# SOLVED! Episode 758 Steps: 1 Epsilon 0.2988
# Episode: 759
# SOLVED! Episode 759 Steps: 2 Epsilon 0.2988
# Episode: 760
# Episode: 761
# SOLVED! Episode 761 Steps: 3 Epsilon 0.2988
# Episode: 762
# SOLVED! Episode 762 Steps: 3 Epsilon 0.2988
# Episode: 763
# Episode: 764
# SOLVED! Episode 764 Steps: 3 Epsilon 0.2988
# Episode: 765
# Episode: 766
# SOLVED! Episode 766 Steps: 3 Epsilon 0.2988
# Episode: 767
# SOLVED! Episode 767 Steps: 1 Epsilon 0.2988
# Episode: 768
# SOLVED! Episode 768 Steps: 3 Epsilon 0.2988
# Episode: 769
# SOLVED! Episode 769 Steps: 3 Epsilon 0.2988
# Episode: 770
# SOLVED! Episode 770 Steps: 1 Epsilon 0.2988
# Episode: 771
# Episode: 772
# SOLVED! Episode 772 Steps: 3 Epsilon 0.2988
# Episode: 773
# SOLVED! Episode 773 Steps: 3 Epsilon 0.2988
# Episode: 774
# Episode: 775
# SOLVED! Episode 775 Steps: 1 Epsilon 0.2988
# Episode: 776
# SOLVED! Episode 776 Steps: 9 Epsilon 0.2988
# Episode: 777
# Episode: 778
# SOLVED! Episode 778 Steps: 3 Epsilon 0.2988
# Episode: 779
# Episode: 780
# Episode: 781
# SOLVED! Episode 781 Steps: 1 Epsilon 0.2988
# Episode: 782
# SOLVED! Episode 782 Steps: 2 Epsilon 0.2988
# Episode: 783
# Episode: 784
# SOLVED! Episode 784 Steps: 2 Epsilon 0.2988
# Episode: 785
# Episode: 786
# Episode: 787
# Episode: 788
# Episode: 789
# Episode: 790
# SOLVED! Episode 790 Steps: 1 Epsilon 0.2988
# Episode: 791
# Episode: 792
# SOLVED! Episode 792 Steps: 16 Epsilon 0.2988
# Episode: 793
# Episode: 794
# SOLVED! Episode 794 Steps: 1 Epsilon 0.2988
# Episode: 795
# Episode: 796
# Episode: 797
# SOLVED! Episode 797 Steps: 3 Epsilon 0.2988
# Episode: 798
# SOLVED! Episode 798 Steps: 2 Epsilon 0.2988
# Episode: 799
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 56
# ==============================
# defaultdict(<class 'int'>, {3: 24, 1: 21, 2: 11})
# ******************************
# Episode: 800
# SOLVED! Episode 800 Steps: 2 Epsilon 0.2988
# Episode: 801
# Episode: 802
# Episode: 803
# Episode: 804
# Episode: 805
# SOLVED! Episode 805 Steps: 3 Epsilon 0.2988
# Episode: 806
# SOLVED! Episode 806 Steps: 3 Epsilon 0.2988
# Episode: 807
# Episode: 808
# Episode: 809
# Episode: 810
# SOLVED! Episode 810 Steps: 3 Epsilon 0.2988
# Episode: 811
# Episode: 812
# Episode: 813
# SOLVED! Episode 813 Steps: 1 Epsilon 0.2988
# Episode: 814
# Episode: 815
# Episode: 816
# Episode: 817
# Episode: 818
# Episode: 819
# Episode: 820
# Episode: 821
# SOLVED! Episode 821 Steps: 1 Epsilon 0.2988
# Episode: 822
# Episode: 823
# SOLVED! Episode 823 Steps: 2 Epsilon 0.2988
# Episode: 824
# Episode: 825
# Episode: 826
# SOLVED! Episode 826 Steps: 1 Epsilon 0.2988
# Episode: 827
# SOLVED! Episode 827 Steps: 3 Epsilon 0.2988
# Episode: 828
# SOLVED! Episode 828 Steps: 2 Epsilon 0.2988
# Episode: 829
# SOLVED! Episode 829 Steps: 11 Epsilon 0.2988
# Episode: 830
# Episode: 831
# Episode: 832
# SOLVED! Episode 832 Steps: 1 Epsilon 0.2988
# Episode: 833
# Episode: 834
# Episode: 835
# Episode: 836
# Episode: 837
# SOLVED! Episode 837 Steps: 2 Epsilon 0.2988
# Episode: 838
# Episode: 839
# Episode: 840
# SOLVED! Episode 840 Steps: 2 Epsilon 0.2988
# Episode: 841
# SOLVED! Episode 841 Steps: 1 Epsilon 0.2988
# Episode: 842
# Episode: 843
# Episode: 844
# SOLVED! Episode 844 Steps: 3 Epsilon 0.2988
# Episode: 845
# Episode: 846
# Episode: 847
# Episode: 848
# SOLVED! Episode 848 Steps: 3 Epsilon 0.2988
# Episode: 849
# Episode: 850
# SOLVED! Episode 850 Steps: 3 Epsilon 0.2988
# Episode: 851
# Episode: 852
# Episode: 853
# Episode: 854
# SOLVED! Episode 854 Steps: 3 Epsilon 0.2988
# Episode: 855
# Episode: 856
# Episode: 857
# Episode: 858
# SOLVED! Episode 858 Steps: 2 Epsilon 0.2988
# Episode: 859
# SOLVED! Episode 859 Steps: 1 Epsilon 0.2988
# Episode: 860
# Episode: 861
# SOLVED! Episode 861 Steps: 3 Epsilon 0.2988
# Episode: 862
# Episode: 863
# Episode: 864
# Episode: 865
# SOLVED! Episode 865 Steps: 1 Epsilon 0.2988
# Episode: 866
# Episode: 867
# Episode: 868
# SOLVED! Episode 868 Steps: 1 Epsilon 0.2988
# Episode: 869
# Episode: 870
# Episode: 871
# SOLVED! Episode 871 Steps: 2 Epsilon 0.2988
# Episode: 872
# Episode: 873
# SOLVED! Episode 873 Steps: 2 Epsilon 0.2988
# Episode: 874
# Episode: 875
# SOLVED! Episode 875 Steps: 1 Epsilon 0.2988
# Episode: 876
# Episode: 877
# Episode: 878
# Episode: 879
# Episode: 880
# SOLVED! Episode 880 Steps: 1 Epsilon 0.2988
# Episode: 881
# SOLVED! Episode 881 Steps: 1 Epsilon 0.2988
# Episode: 882
# Episode: 883
# SOLVED! Episode 883 Steps: 2 Epsilon 0.2988
# Episode: 884
# Episode: 885
# SOLVED! Episode 885 Steps: 2 Epsilon 0.2988
# Episode: 886
# Episode: 887
# Episode: 888
# Episode: 889
# Episode: 890
# Episode: 891
# Episode: 892
# Episode: 893
# SOLVED! Episode 893 Steps: 7 Epsilon 0.2988
# Episode: 894
# SOLVED! Episode 894 Steps: 3 Epsilon 0.2988
# Episode: 895
# Episode: 896
# SOLVED! Episode 896 Steps: 2 Epsilon 0.2988
# Episode: 897
# SOLVED! Episode 897 Steps: 1 Epsilon 0.2988
# Episode: 898
# Episode: 899
# SOLVED! Episode 899 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 61
# ==============================
# defaultdict(<class 'int'>, {3: 23, 1: 21, 7: 1, 6: 2, 2: 11, 5: 3})
# ******************************
# Episode: 900
# Episode: 901
# Episode: 902
# SOLVED! Episode 902 Steps: 3 Epsilon 0.2988
# Episode: 903
# SOLVED! Episode 903 Steps: 16 Epsilon 0.2988
# Episode: 904
# Episode: 905
# Episode: 906
# SOLVED! Episode 906 Steps: 2 Epsilon 0.2988
# Episode: 907
# Episode: 908
# Episode: 909
# SOLVED! Episode 909 Steps: 1 Epsilon 0.2988
# Episode: 910
# Episode: 911
# SOLVED! Episode 911 Steps: 2 Epsilon 0.2988
# Episode: 912
# Episode: 913
# Episode: 914
# Episode: 915
# Episode: 916
# Episode: 917
# Episode: 918
# Episode: 919
# Episode: 920
# SOLVED! Episode 920 Steps: 2 Epsilon 0.2988
# Episode: 921
# SOLVED! Episode 921 Steps: 3 Epsilon 0.2988
# Episode: 922
# SOLVED! Episode 922 Steps: 3 Epsilon 0.2988
# Episode: 923
# SOLVED! Episode 923 Steps: 1 Epsilon 0.2988
# Episode: 924
# Episode: 925
# Episode: 926
# SOLVED! Episode 926 Steps: 1 Epsilon 0.2988
# Episode: 927
# Episode: 928
# Episode: 929
# Episode: 930
# Episode: 931
# Episode: 932
# Episode: 933
# Episode: 934
# SOLVED! Episode 934 Steps: 2 Epsilon 0.2988
# Episode: 935
# Episode: 936
# SOLVED! Episode 936 Steps: 3 Epsilon 0.2988
# Episode: 937
# SOLVED! Episode 937 Steps: 2 Epsilon 0.2988
# Episode: 938
# SOLVED! Episode 938 Steps: 1 Epsilon 0.2988
# Episode: 939
# Episode: 940
# Episode: 941
# Episode: 942
# Episode: 943
# Episode: 944
# SOLVED! Episode 944 Steps: 3 Epsilon 0.2988
# Episode: 945
# SOLVED! Episode 945 Steps: 3 Epsilon 0.2988
# Episode: 946
# SOLVED! Episode 946 Steps: 3 Epsilon 0.2988
# Episode: 947
# SOLVED! Episode 947 Steps: 2 Epsilon 0.2988
# Episode: 948
# Episode: 949
# SOLVED! Episode 949 Steps: 2 Epsilon 0.2988
# Episode: 950
# Episode: 951
# Episode: 952
# SOLVED! Episode 952 Steps: 2 Epsilon 0.2988
# Episode: 953
# Episode: 954
# Episode: 955
# Episode: 956
# Episode: 957
# Episode: 958
# Episode: 959
# SOLVED! Episode 959 Steps: 3 Epsilon 0.2988
# Episode: 960
# Episode: 961
# Episode: 962
# Episode: 963
# SOLVED! Episode 963 Steps: 19 Epsilon 0.2988
# Episode: 964
# SOLVED! Episode 964 Steps: 2 Epsilon 0.2988
# Episode: 965
# Episode: 966
# Episode: 967
# Episode: 968
# Episode: 969
# Episode: 970
# Episode: 971
# Episode: 972
# Episode: 973
# SOLVED! Episode 973 Steps: 3 Epsilon 0.2988
# Episode: 974
# SOLVED! Episode 974 Steps: 3 Epsilon 0.2988
# Episode: 975
# Episode: 976
# SOLVED! Episode 976 Steps: 2 Epsilon 0.2988
# Episode: 977
# SOLVED! Episode 977 Steps: 3 Epsilon 0.2988
# Episode: 978
# SOLVED! Episode 978 Steps: 1 Epsilon 0.2988
# Episode: 979
# Episode: 980
# SOLVED! Episode 980 Steps: 2 Epsilon 0.2988
# Episode: 981
# Episode: 982
# SOLVED! Episode 982 Steps: 3 Epsilon 0.2988
# Episode: 983
# SOLVED! Episode 983 Steps: 2 Epsilon 0.2988
# Episode: 984
# Episode: 985
# SOLVED! Episode 985 Steps: 2 Epsilon 0.2988
# Episode: 986
# Episode: 987
# Episode: 988
# SOLVED! Episode 988 Steps: 3 Epsilon 0.2988
# Episode: 989
# SOLVED! Episode 989 Steps: 2 Epsilon 0.2988
# Episode: 990
# SOLVED! Episode 990 Steps: 1 Epsilon 0.2988
# Episode: 991
# SOLVED! Episode 991 Steps: 3 Epsilon 0.2988
# Episode: 992
# SOLVED! Episode 992 Steps: 1 Epsilon 0.2988
# Episode: 993
# SOLVED! Episode 993 Steps: 1 Epsilon 0.2988
# Episode: 994
# Episode: 995
# SOLVED! Episode 995 Steps: 1 Epsilon 0.2988
# Episode: 996
# Episode: 997
# SOLVED! Episode 997 Steps: 20 Epsilon 0.2988
# Episode: 998
# SOLVED! Episode 998 Steps: 3 Epsilon 0.2988
# Episode: 999
# SOLVED! Episode 999 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 57
# ==============================
# defaultdict(<class 'int'>, {3: 23, 1: 21, 2: 11, 5: 2})
# ******************************
# Episode: 1000
# SOLVED! Episode 1000 Steps: 3 Epsilon 0.2988
# Episode: 1001
# SOLVED! Episode 1001 Steps: 3 Epsilon 0.2988
# Episode: 1002
# Episode: 1003
# Episode: 1004
# Episode: 1005
# SOLVED! Episode 1005 Steps: 2 Epsilon 0.2988
# Episode: 1006
# Episode: 1007
# Episode: 1008
# Episode: 1009
# Episode: 1010
# SOLVED! Episode 1010 Steps: 2 Epsilon 0.2988
# Episode: 1011
# Episode: 1012
# SOLVED! Episode 1012 Steps: 4 Epsilon 0.2988
# Episode: 1013
# SOLVED! Episode 1013 Steps: 3 Epsilon 0.2988
# Episode: 1014
# SOLVED! Episode 1014 Steps: 1 Epsilon 0.2988
# Episode: 1015
# Episode: 1016
# SOLVED! Episode 1016 Steps: 3 Epsilon 0.2988
# Episode: 1017
# SOLVED! Episode 1017 Steps: 2 Epsilon 0.2988
# Episode: 1018
# Episode: 1019
# SOLVED! Episode 1019 Steps: 16 Epsilon 0.2988
# Episode: 1020
# Episode: 1021
# Episode: 1022
# Episode: 1023
# Episode: 1024
# SOLVED! Episode 1024 Steps: 1 Epsilon 0.2988
# Episode: 1025
# Episode: 1026
# Episode: 1027
# Episode: 1028
# SOLVED! Episode 1028 Steps: 2 Epsilon 0.2988
# Episode: 1029
# SOLVED! Episode 1029 Steps: 3 Epsilon 0.2988
# Episode: 1030
# Episode: 1031
# SOLVED! Episode 1031 Steps: 19 Epsilon 0.2988
# Episode: 1032
# Episode: 1033
# SOLVED! Episode 1033 Steps: 3 Epsilon 0.2988
# Episode: 1034
# Episode: 1035
# SOLVED! Episode 1035 Steps: 3 Epsilon 0.2988
# Episode: 1036
# SOLVED! Episode 1036 Steps: 2 Epsilon 0.2988
# Episode: 1037
# SOLVED! Episode 1037 Steps: 1 Epsilon 0.2988
# Episode: 1038
# Episode: 1039
# Episode: 1040
# SOLVED! Episode 1040 Steps: 2 Epsilon 0.2988
# Episode: 1041
# Episode: 1042
# Episode: 1043
# Episode: 1044
# SOLVED! Episode 1044 Steps: 1 Epsilon 0.2988
# Episode: 1045
# SOLVED! Episode 1045 Steps: 1 Epsilon 0.2988
# Episode: 1046
# Episode: 1047
# SOLVED! Episode 1047 Steps: 17 Epsilon 0.2988
# Episode: 1048
# Episode: 1049
# Episode: 1050
# Episode: 1051
# Episode: 1052
# SOLVED! Episode 1052 Steps: 3 Epsilon 0.2988
# Episode: 1053
# Episode: 1054
# Episode: 1055
# Episode: 1056
# SOLVED! Episode 1056 Steps: 1 Epsilon 0.2988
# Episode: 1057
# Episode: 1058
# SOLVED! Episode 1058 Steps: 2 Epsilon 0.2988
# Episode: 1059
# Episode: 1060
# Episode: 1061
# Episode: 1062
# SOLVED! Episode 1062 Steps: 17 Epsilon 0.2988
# Episode: 1063
# SOLVED! Episode 1063 Steps: 1 Epsilon 0.2988
# Episode: 1064
# SOLVED! Episode 1064 Steps: 1 Epsilon 0.2988
# Episode: 1065
# Episode: 1066
# Episode: 1067
# Episode: 1068
# Episode: 1069
# Episode: 1070
# SOLVED! Episode 1070 Steps: 3 Epsilon 0.2988
# Episode: 1071
# SOLVED! Episode 1071 Steps: 1 Epsilon 0.2988
# Episode: 1072
# SOLVED! Episode 1072 Steps: 3 Epsilon 0.2988
# Episode: 1073
# SOLVED! Episode 1073 Steps: 3 Epsilon 0.2988
# Episode: 1074
# Episode: 1075
# Episode: 1076
# Episode: 1077
# Episode: 1078
# SOLVED! Episode 1078 Steps: 2 Epsilon 0.2988
# Episode: 1079
# Episode: 1080
# Episode: 1081
# Episode: 1082
# SOLVED! Episode 1082 Steps: 2 Epsilon 0.2988
# Episode: 1083
# SOLVED! Episode 1083 Steps: 2 Epsilon 0.2988
# Episode: 1084
# SOLVED! Episode 1084 Steps: 3 Epsilon 0.2988
# Episode: 1085
# SOLVED! Episode 1085 Steps: 2 Epsilon 0.2988
# Episode: 1086
# SOLVED! Episode 1086 Steps: 2 Epsilon 0.2988
# Episode: 1087
# Episode: 1088
# Episode: 1089
# Episode: 1090
# Episode: 1091
# Episode: 1092
# Episode: 1093
# Episode: 1094
# SOLVED! Episode 1094 Steps: 1 Epsilon 0.2988
# Episode: 1095
# Episode: 1096
# SOLVED! Episode 1096 Steps: 3 Epsilon 0.2988
# Episode: 1097
# Episode: 1098
# SOLVED! Episode 1098 Steps: 2 Epsilon 0.2988
# Episode: 1099
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 56
# ==============================
# defaultdict(<class 'int'>, {3: 23, 1: 21, 2: 11, 7: 1})
# ******************************
# Episode: 1100
# Episode: 1101
# SOLVED! Episode 1101 Steps: 1 Epsilon 0.2988
# Episode: 1102
# Episode: 1103
# SOLVED! Episode 1103 Steps: 2 Epsilon 0.2988
# Episode: 1104
# Episode: 1105
# SOLVED! Episode 1105 Steps: 3 Epsilon 0.2988
# Episode: 1106
# SOLVED! Episode 1106 Steps: 2 Epsilon 0.2988
# Episode: 1107
# Episode: 1108
# SOLVED! Episode 1108 Steps: 3 Epsilon 0.2988
# Episode: 1109
# Episode: 1110
# Episode: 1111
# Episode: 1112
# SOLVED! Episode 1112 Steps: 3 Epsilon 0.2988
# Episode: 1113
# Episode: 1114
# Episode: 1115
# Episode: 1116
# SOLVED! Episode 1116 Steps: 1 Epsilon 0.2988
# Episode: 1117
# Episode: 1118
# SOLVED! Episode 1118 Steps: 1 Epsilon 0.2988
# Episode: 1119
# SOLVED! Episode 1119 Steps: 3 Epsilon 0.2988
# Episode: 1120
# SOLVED! Episode 1120 Steps: 1 Epsilon 0.2988
# Episode: 1121
# SOLVED! Episode 1121 Steps: 1 Epsilon 0.2988
# Episode: 1122
# Episode: 1123
# Episode: 1124
# Episode: 1125
# Episode: 1126
# SOLVED! Episode 1126 Steps: 2 Epsilon 0.2988
# Episode: 1127
# SOLVED! Episode 1127 Steps: 16 Epsilon 0.2988
# Episode: 1128
# Episode: 1129
# Episode: 1130
# Episode: 1131
# Episode: 1132
# SOLVED! Episode 1132 Steps: 1 Epsilon 0.2988
# Episode: 1133
# Episode: 1134
# Episode: 1135
# Episode: 1136
# SOLVED! Episode 1136 Steps: 2 Epsilon 0.2988
# Episode: 1137
# Episode: 1138
# SOLVED! Episode 1138 Steps: 1 Epsilon 0.2988
# Episode: 1139
# Episode: 1140
# SOLVED! Episode 1140 Steps: 3 Epsilon 0.2988
# Episode: 1141
# SOLVED! Episode 1141 Steps: 1 Epsilon 0.2988
# Episode: 1142
# Episode: 1143
# Episode: 1144
# Episode: 1145
# Episode: 1146
# Episode: 1147
# SOLVED! Episode 1147 Steps: 3 Epsilon 0.2988
# Episode: 1148
# Episode: 1149
# Episode: 1150
# SOLVED! Episode 1150 Steps: 1 Epsilon 0.2988
# Episode: 1151
# Episode: 1152
# SOLVED! Episode 1152 Steps: 3 Epsilon 0.2988
# Episode: 1153
# SOLVED! Episode 1153 Steps: 1 Epsilon 0.2988
# Episode: 1154
# Episode: 1155
# SOLVED! Episode 1155 Steps: 3 Epsilon 0.2988
# Episode: 1156
# SOLVED! Episode 1156 Steps: 2 Epsilon 0.2988
# Episode: 1157
# SOLVED! Episode 1157 Steps: 1 Epsilon 0.2988
# Episode: 1158
# SOLVED! Episode 1158 Steps: 1 Epsilon 0.2988
# Episode: 1159
# SOLVED! Episode 1159 Steps: 3 Epsilon 0.2988
# Episode: 1160
# Episode: 1161
# SOLVED! Episode 1161 Steps: 1 Epsilon 0.2988
# Episode: 1162
# Episode: 1163
# SOLVED! Episode 1163 Steps: 1 Epsilon 0.2988
# Episode: 1164
# SOLVED! Episode 1164 Steps: 3 Epsilon 0.2988
# Episode: 1165
# SOLVED! Episode 1165 Steps: 3 Epsilon 0.2988
# Episode: 1166
# Episode: 1167
# SOLVED! Episode 1167 Steps: 2 Epsilon 0.2988
# Episode: 1168
# SOLVED! Episode 1168 Steps: 1 Epsilon 0.2988
# Episode: 1169
# Episode: 1170
# Episode: 1171
# SOLVED! Episode 1171 Steps: 2 Epsilon 0.2988
# Episode: 1172
# SOLVED! Episode 1172 Steps: 3 Epsilon 0.2988
# Episode: 1173
# Episode: 1174
# Episode: 1175
# Episode: 1176
# SOLVED! Episode 1176 Steps: 3 Epsilon 0.2988
# Episode: 1177
# Episode: 1178
# Episode: 1179
# Episode: 1180
# Episode: 1181
# Episode: 1182
# Episode: 1183
# Episode: 1184
# SOLVED! Episode 1184 Steps: 1 Epsilon 0.2988
# Episode: 1185
# SOLVED! Episode 1185 Steps: 2 Epsilon 0.2988
# Episode: 1186
# Episode: 1187
# SOLVED! Episode 1187 Steps: 3 Epsilon 0.2988
# Episode: 1188
# SOLVED! Episode 1188 Steps: 3 Epsilon 0.2988
# Episode: 1189
# Episode: 1190
# SOLVED! Episode 1190 Steps: 6 Epsilon 0.2988
# Episode: 1191
# SOLVED! Episode 1191 Steps: 3 Epsilon 0.2988
# Episode: 1192
# Episode: 1193
# SOLVED! Episode 1193 Steps: 1 Epsilon 0.2988
# Episode: 1194
# SOLVED! Episode 1194 Steps: 1 Epsilon 0.2988
# Episode: 1195
# Episode: 1196
# Episode: 1197
# Episode: 1198
# Episode: 1199
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 55
# ==============================
# defaultdict(<class 'int'>, {3: 23, 1: 20, 2: 10, 5: 2})
# ******************************
# Episode: 1200
# Episode: 1201
# Episode: 1202
# Episode: 1203
# Episode: 1204
# Episode: 1205
# SOLVED! Episode 1205 Steps: 1 Epsilon 0.2988
# Episode: 1206
# SOLVED! Episode 1206 Steps: 3 Epsilon 0.2988
# Episode: 1207
# SOLVED! Episode 1207 Steps: 5 Epsilon 0.2988
# Episode: 1208
# Episode: 1209
# Episode: 1210
# SOLVED! Episode 1210 Steps: 3 Epsilon 0.2988
# Episode: 1211
# SOLVED! Episode 1211 Steps: 3 Epsilon 0.2988
# Episode: 1212
# SOLVED! Episode 1212 Steps: 1 Epsilon 0.2988
# Episode: 1213
# Episode: 1214
# Episode: 1215
# Episode: 1216
# Episode: 1217
# SOLVED! Episode 1217 Steps: 3 Epsilon 0.2988
# Episode: 1218
# SOLVED! Episode 1218 Steps: 1 Epsilon 0.2988
# Episode: 1219
# SOLVED! Episode 1219 Steps: 3 Epsilon 0.2988
# Episode: 1220
# Episode: 1221
# SOLVED! Episode 1221 Steps: 2 Epsilon 0.2988
# Episode: 1222
# SOLVED! Episode 1222 Steps: 3 Epsilon 0.2988
# Episode: 1223
# Episode: 1224
# Episode: 1225
# SOLVED! Episode 1225 Steps: 1 Epsilon 0.2988
# Episode: 1226
# Episode: 1227
# Episode: 1228
# SOLVED! Episode 1228 Steps: 1 Epsilon 0.2988
# Episode: 1229
# Episode: 1230
# SOLVED! Episode 1230 Steps: 2 Epsilon 0.2988
# Episode: 1231
# Episode: 1232
# Episode: 1233
# SOLVED! Episode 1233 Steps: 3 Epsilon 0.2988
# Episode: 1234
# Episode: 1235
# Episode: 1236
# Episode: 1237
# Episode: 1238
# SOLVED! Episode 1238 Steps: 3 Epsilon 0.2988
# Episode: 1239
# SOLVED! Episode 1239 Steps: 3 Epsilon 0.2988
# Episode: 1240
# Episode: 1241
# Episode: 1242
# Episode: 1243
# SOLVED! Episode 1243 Steps: 2 Epsilon 0.2988
# Episode: 1244
# SOLVED! Episode 1244 Steps: 3 Epsilon 0.2988
# Episode: 1245
# Episode: 1246
# SOLVED! Episode 1246 Steps: 1 Epsilon 0.2988
# Episode: 1247
# SOLVED! Episode 1247 Steps: 3 Epsilon 0.2988
# Episode: 1248
# Episode: 1249
# SOLVED! Episode 1249 Steps: 1 Epsilon 0.2988
# Episode: 1250
# SOLVED! Episode 1250 Steps: 3 Epsilon 0.2988
# Episode: 1251
# SOLVED! Episode 1251 Steps: 1 Epsilon 0.2988
# Episode: 1252
# SOLVED! Episode 1252 Steps: 3 Epsilon 0.2988
# Episode: 1253
# SOLVED! Episode 1253 Steps: 1 Epsilon 0.2988
# Episode: 1254
# Episode: 1255
# Episode: 1256
# SOLVED! Episode 1256 Steps: 2 Epsilon 0.2988
# Episode: 1257
# Episode: 1258
# Episode: 1259
# SOLVED! Episode 1259 Steps: 2 Epsilon 0.2988
# Episode: 1260
# SOLVED! Episode 1260 Steps: 2 Epsilon 0.2988
# Episode: 1261
# Episode: 1262
# SOLVED! Episode 1262 Steps: 2 Epsilon 0.2988
# Episode: 1263
# SOLVED! Episode 1263 Steps: 2 Epsilon 0.2988
# Episode: 1264
# Episode: 1265
# Episode: 1266
# SOLVED! Episode 1266 Steps: 3 Epsilon 0.2988
# Episode: 1267
# SOLVED! Episode 1267 Steps: 3 Epsilon 0.2988
# Episode: 1268
# Episode: 1269
# SOLVED! Episode 1269 Steps: 1 Epsilon 0.2988
# Episode: 1270
# Episode: 1271
# SOLVED! Episode 1271 Steps: 3 Epsilon 0.2988
# Episode: 1272
# SOLVED! Episode 1272 Steps: 1 Epsilon 0.2988
# Episode: 1273
# Episode: 1274
# Episode: 1275
# Episode: 1276
# Episode: 1277
# SOLVED! Episode 1277 Steps: 2 Epsilon 0.2988
# Episode: 1278
# SOLVED! Episode 1278 Steps: 3 Epsilon 0.2988
# Episode: 1279
# Episode: 1280
# Episode: 1281
# SOLVED! Episode 1281 Steps: 3 Epsilon 0.2988
# Episode: 1282
# SOLVED! Episode 1282 Steps: 2 Epsilon 0.2988
# Episode: 1283
# SOLVED! Episode 1283 Steps: 2 Epsilon 0.2988
# Episode: 1284
# Episode: 1285
# Episode: 1286
# Episode: 1287
# SOLVED! Episode 1287 Steps: 1 Epsilon 0.2988
# Episode: 1288
# Episode: 1289
# SOLVED! Episode 1289 Steps: 3 Epsilon 0.2988
# Episode: 1290
# Episode: 1291
# SOLVED! Episode 1291 Steps: 3 Epsilon 0.2988
# Episode: 1292
# SOLVED! Episode 1292 Steps: 1 Epsilon 0.2988
# Episode: 1293
# SOLVED! Episode 1293 Steps: 3 Epsilon 0.2988
# Episode: 1294
# SOLVED! Episode 1294 Steps: 2 Epsilon 0.2988
# Episode: 1295
# Episode: 1296
# Episode: 1297
# SOLVED! Episode 1297 Steps: 1 Epsilon 0.2988
# Episode: 1298
# Episode: 1299
# SOLVED! Episode 1299 Steps: 10 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 54
# ==============================
# defaultdict(<class 'int'>, {3: 24, 1: 20, 2: 10})
# ******************************
# Episode: 1300
# Episode: 1301
# Episode: 1302
# Episode: 1303
# Episode: 1304
# SOLVED! Episode 1304 Steps: 1 Epsilon 0.2988
# Episode: 1305
# Episode: 1306
# SOLVED! Episode 1306 Steps: 3 Epsilon 0.2988
# Episode: 1307
# SOLVED! Episode 1307 Steps: 16 Epsilon 0.2988
# Episode: 1308
# Episode: 1309
# Episode: 1310
# SOLVED! Episode 1310 Steps: 3 Epsilon 0.2988
# Episode: 1311
# Episode: 1312
# Episode: 1313
# SOLVED! Episode 1313 Steps: 1 Epsilon 0.2988
# Episode: 1314
# Episode: 1315
# Episode: 1316
# Episode: 1317
# Episode: 1318
# SOLVED! Episode 1318 Steps: 3 Epsilon 0.2988
# Episode: 1319
# SOLVED! Episode 1319 Steps: 2 Epsilon 0.2988
# Episode: 1320
# Episode: 1321
# Episode: 1322
# SOLVED! Episode 1322 Steps: 3 Epsilon 0.2988
# Episode: 1323
# Episode: 1324
# Episode: 1325
# SOLVED! Episode 1325 Steps: 2 Epsilon 0.2988
# Episode: 1326
# Episode: 1327
# SOLVED! Episode 1327 Steps: 3 Epsilon 0.2988
# Episode: 1328
# Episode: 1329
# Episode: 1330
# SOLVED! Episode 1330 Steps: 3 Epsilon 0.2988
# Episode: 1331
# Episode: 1332
# SOLVED! Episode 1332 Steps: 1 Epsilon 0.2988
# Episode: 1333
# SOLVED! Episode 1333 Steps: 1 Epsilon 0.2988
# Episode: 1334
# SOLVED! Episode 1334 Steps: 2 Epsilon 0.2988
# Episode: 1335
# Episode: 1336
# SOLVED! Episode 1336 Steps: 3 Epsilon 0.2988
# Episode: 1337
# SOLVED! Episode 1337 Steps: 1 Epsilon 0.2988
# Episode: 1338
# Episode: 1339
# Episode: 1340
# SOLVED! Episode 1340 Steps: 3 Epsilon 0.2988
# Episode: 1341
# SOLVED! Episode 1341 Steps: 3 Epsilon 0.2988
# Episode: 1342
# SOLVED! Episode 1342 Steps: 3 Epsilon 0.2988
# Episode: 1343
# SOLVED! Episode 1343 Steps: 6 Epsilon 0.2988
# Episode: 1344
# SOLVED! Episode 1344 Steps: 2 Epsilon 0.2988
# Episode: 1345
# SOLVED! Episode 1345 Steps: 3 Epsilon 0.2988
# Episode: 1346
# SOLVED! Episode 1346 Steps: 3 Epsilon 0.2988
# Episode: 1347
# Episode: 1348
# Episode: 1349
# SOLVED! Episode 1349 Steps: 3 Epsilon 0.2988
# Episode: 1350
# Episode: 1351
# SOLVED! Episode 1351 Steps: 3 Epsilon 0.2988
# Episode: 1352
# Episode: 1353
# Episode: 1354
# Episode: 1355
# Episode: 1356
# SOLVED! Episode 1356 Steps: 3 Epsilon 0.2988
# Episode: 1357
# Episode: 1358
# Episode: 1359
# Episode: 1360
# SOLVED! Episode 1360 Steps: 2 Epsilon 0.2988
# Episode: 1361
# Episode: 1362
# SOLVED! Episode 1362 Steps: 19 Epsilon 0.2988
# Episode: 1363
# Episode: 1364
# Episode: 1365
# SOLVED! Episode 1365 Steps: 3 Epsilon 0.2988
# Episode: 1366
# SOLVED! Episode 1366 Steps: 3 Epsilon 0.2988
# Episode: 1367
# Episode: 1368
# Episode: 1369
# Episode: 1370
# SOLVED! Episode 1370 Steps: 1 Epsilon 0.2988
# Episode: 1371
# Episode: 1372
# SOLVED! Episode 1372 Steps: 1 Epsilon 0.2988
# Episode: 1373
# SOLVED! Episode 1373 Steps: 3 Epsilon 0.2988
# Episode: 1374
# Episode: 1375
# SOLVED! Episode 1375 Steps: 1 Epsilon 0.2988
# Episode: 1376
# SOLVED! Episode 1376 Steps: 2 Epsilon 0.2988
# Episode: 1377
# Episode: 1378
# SOLVED! Episode 1378 Steps: 3 Epsilon 0.2988
# Episode: 1379
# Episode: 1380
# SOLVED! Episode 1380 Steps: 3 Epsilon 0.2988
# Episode: 1381
# Episode: 1382
# Episode: 1383
# SOLVED! Episode 1383 Steps: 2 Epsilon 0.2988
# Episode: 1384
# SOLVED! Episode 1384 Steps: 1 Epsilon 0.2988
# Episode: 1385
# Episode: 1386
# Episode: 1387
# SOLVED! Episode 1387 Steps: 2 Epsilon 0.2988
# Episode: 1388
# Episode: 1389
# SOLVED! Episode 1389 Steps: 18 Epsilon 0.2988
# Episode: 1390
# Episode: 1391
# SOLVED! Episode 1391 Steps: 1 Epsilon 0.2988
# Episode: 1392
# SOLVED! Episode 1392 Steps: 3 Epsilon 0.2988
# Episode: 1393
# SOLVED! Episode 1393 Steps: 1 Epsilon 0.2988
# Episode: 1394
# SOLVED! Episode 1394 Steps: 3 Epsilon 0.2988
# Episode: 1395
# Episode: 1396
# SOLVED! Episode 1396 Steps: 2 Epsilon 0.2988
# Episode: 1397
# Episode: 1398
# SOLVED! Episode 1398 Steps: 2 Epsilon 0.2988
# Episode: 1399
# SOLVED! Episode 1399 Steps: 1 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 57
# ==============================
# defaultdict(<class 'int'>, {3: 25, 1: 20, 2: 10, 5: 2})
# ******************************
# Episode: 1400
# SOLVED! Episode 1400 Steps: 1 Epsilon 0.2988
# Episode: 1401
# SOLVED! Episode 1401 Steps: 1 Epsilon 0.2988
# Episode: 1402
# SOLVED! Episode 1402 Steps: 3 Epsilon 0.2988
# Episode: 1403
# SOLVED! Episode 1403 Steps: 2 Epsilon 0.2988
# Episode: 1404
# Episode: 1405
# SOLVED! Episode 1405 Steps: 3 Epsilon 0.2988
# Episode: 1406
# Episode: 1407
# Episode: 1408
# Episode: 1409
# Episode: 1410
# Episode: 1411
# Episode: 1412
# SOLVED! Episode 1412 Steps: 1 Epsilon 0.2988
# Episode: 1413
# Episode: 1414
# SOLVED! Episode 1414 Steps: 2 Epsilon 0.2988
# Episode: 1415
# SOLVED! Episode 1415 Steps: 2 Epsilon 0.2988
# Episode: 1416
# Episode: 1417
# SOLVED! Episode 1417 Steps: 2 Epsilon 0.2988
# Episode: 1418
# Episode: 1419
# SOLVED! Episode 1419 Steps: 2 Epsilon 0.2988
# Episode: 1420
# SOLVED! Episode 1420 Steps: 5 Epsilon 0.2988
# Episode: 1421
# SOLVED! Episode 1421 Steps: 2 Epsilon 0.2988
# Episode: 1422
# SOLVED! Episode 1422 Steps: 3 Epsilon 0.2988
# Episode: 1423
# SOLVED! Episode 1423 Steps: 1 Epsilon 0.2988
# Episode: 1424
# Episode: 1425
# Episode: 1426
# Episode: 1427
# Episode: 1428
# Episode: 1429
# SOLVED! Episode 1429 Steps: 2 Epsilon 0.2988
# Episode: 1430
# Episode: 1431
# Episode: 1432
# Episode: 1433
# Episode: 1434
# Episode: 1435
# Episode: 1436
# SOLVED! Episode 1436 Steps: 1 Epsilon 0.2988
# Episode: 1437
# Episode: 1438
# Episode: 1439
# Episode: 1440
# SOLVED! Episode 1440 Steps: 3 Epsilon 0.2988
# Episode: 1441
# SOLVED! Episode 1441 Steps: 3 Epsilon 0.2988
# Episode: 1442
# Episode: 1443
# Episode: 1444
# Episode: 1445
# Episode: 1446
# SOLVED! Episode 1446 Steps: 2 Epsilon 0.2988
# Episode: 1447
# Episode: 1448
# Episode: 1449
# Episode: 1450
# SOLVED! Episode 1450 Steps: 3 Epsilon 0.2988
# Episode: 1451
# SOLVED! Episode 1451 Steps: 1 Epsilon 0.2988
# Episode: 1452
# Episode: 1453
# Episode: 1454
# Episode: 1455
# Episode: 1456
# Episode: 1457
# SOLVED! Episode 1457 Steps: 2 Epsilon 0.2988
# Episode: 1458
# Episode: 1459
# Episode: 1460
# Episode: 1461
# Episode: 1462
# Episode: 1463
# Episode: 1464
# Episode: 1465
# Episode: 1466
# Episode: 1467
# SOLVED! Episode 1467 Steps: 2 Epsilon 0.2988
# Episode: 1468
# Episode: 1469
# SOLVED! Episode 1469 Steps: 3 Epsilon 0.2988
# Episode: 1470
# SOLVED! Episode 1470 Steps: 2 Epsilon 0.2988
# Episode: 1471
# Episode: 1472
# SOLVED! Episode 1472 Steps: 3 Epsilon 0.2988
# Episode: 1473
# SOLVED! Episode 1473 Steps: 18 Epsilon 0.2988
# Episode: 1474
# Episode: 1475
# Episode: 1476
# Episode: 1477
# Episode: 1478
# Episode: 1479
# SOLVED! Episode 1479 Steps: 3 Epsilon 0.2988
# Episode: 1480
# SOLVED! Episode 1480 Steps: 2 Epsilon 0.2988
# Episode: 1481
# SOLVED! Episode 1481 Steps: 6 Epsilon 0.2988
# Episode: 1482
# SOLVED! Episode 1482 Steps: 1 Epsilon 0.2988
# Episode: 1483
# Episode: 1484
# Episode: 1485
# Episode: 1486
# SOLVED! Episode 1486 Steps: 3 Epsilon 0.2988
# Episode: 1487
# Episode: 1488
# Episode: 1489
# SOLVED! Episode 1489 Steps: 16 Epsilon 0.2988
# Episode: 1490
# Episode: 1491
# Episode: 1492
# SOLVED! Episode 1492 Steps: 3 Epsilon 0.2988
# Episode: 1493
# SOLVED! Episode 1493 Steps: 5 Epsilon 0.2988
# Episode: 1494
# Episode: 1495
# SOLVED! Episode 1495 Steps: 3 Epsilon 0.2988
# Episode: 1496
# Episode: 1497
# Episode: 1498
# Episode: 1499
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 59
# ==============================
# ...
# Episode: 1520
# SOLVED! Episode 1520 Steps: 3 Epsilon 0.2988
# Episode: 1521
# Episode: 1522
# Episode: 1523
# Episode: 1524
# SOLVED! Episode 1524 Steps: 1 Epsilon 0.2988
# Episode: 1525
# Episode: 1526
# SOLVED! Episode 1526 Steps: 2 Epsilon 0.2988
# Episode: 1527
# SOLVED! Episode 1527 Steps: 3 Epsilon 0.2988
# Episode: 1528
# Episode: 1529
# SOLVED! Episode 1529 Steps: 3 Epsilon 0.2988
# Episode: 1530
# SOLVED! Episode 1530 Steps: 2 Epsilon 0.2988
# Episode: 1531
# Episode: 1532
# SOLVED! Episode 1532 Steps: 3 Epsilon 0.2988
# Episode: 1533
# Episode: 1534
# Episode: 1535
# Episode: 1536
# Episode: 1537
# Episode: 1538
# SOLVED! Episode 1538 Steps: 1 Epsilon 0.2988
# Episode: 1539
# Episode: 1540
# Episode: 1541
# SOLVED! Episode 1541 Steps: 1 Epsilon 0.2988
# Episode: 1542
# SOLVED! Episode 1542 Steps: 3 Epsilon 0.2988
# Episode: 1543
# SOLVED! Episode 1543 Steps: 2 Epsilon 0.2988
# Episode: 1544
# SOLVED! Episode 1544 Steps: 1 Epsilon 0.2988
# Episode: 1545
# SOLVED! Episode 1545 Steps: 17 Epsilon 0.2988
# Episode: 1546
# Episode: 1547
# SOLVED! Episode 1547 Steps: 3 Epsilon 0.2988
# Episode: 1548
# Episode: 1549
# SOLVED! Episode 1549 Steps: 3 Epsilon 0.2988
# Episode: 1550
# Episode: 1551
# SOLVED! Episode 1551 Steps: 1 Epsilon 0.2988
# Episode: 1552
# Episode: 1553
# SOLVED! Episode 1553 Steps: 2 Epsilon 0.2988
# Episode: 1554
# SOLVED! Episode 1554 Steps: 3 Epsilon 0.2988
# Episode: 1555
# Episode: 1556
# Episode: 1557
# SOLVED! Episode 1557 Steps: 1 Epsilon 0.2988
# Episode: 1558
# SOLVED! Episode 1558 Steps: 3 Epsilon 0.2988
# Episode: 1559
# SOLVED! Episode 1559 Steps: 1 Epsilon 0.2988
# Episode: 1560
# Episode: 1561
# SOLVED! Episode 1561 Steps: 1 Epsilon 0.2988
# Episode: 1562
# Episode: 1563
# SOLVED! Episode 1563 Steps: 3 Epsilon 0.2988
# Episode: 1564
# Episode: 1565
# SOLVED! Episode 1565 Steps: 16 Epsilon 0.2988
# Episode: 1566
# SOLVED! Episode 1566 Steps: 3 Epsilon 0.2988
# Episode: 1567
# Episode: 1568
# Episode: 1569
# SOLVED! Episode 1569 Steps: 3 Epsilon 0.2988
# Episode: 1570
# SOLVED! Episode 1570 Steps: 1 Epsilon 0.2988
# Episode: 1571
# SOLVED! Episode 1571 Steps: 3 Epsilon 0.2988
# Episode: 1572
# SOLVED! Episode 1572 Steps: 2 Epsilon 0.2988
# Episode: 1573
# Episode: 1574
# Episode: 1575
# Episode: 1576
# Episode: 1577
# Episode: 1578
# Episode: 1579
# Episode: 1580
# SOLVED! Episode 1580 Steps: 2 Epsilon 0.2988
# Episode: 1581
# Episode: 1582
# Episode: 1583
# SOLVED! Episode 1583 Steps: 3 Epsilon 0.2988
# Episode: 1584
# Episode: 1585
# Episode: 1586
# SOLVED! Episode 1586 Steps: 3 Epsilon 0.2988
# Episode: 1587
# Episode: 1588
# Episode: 1589
# Episode: 1590
# SOLVED! Episode 1590 Steps: 3 Epsilon 0.2988
# Episode: 1591
# Episode: 1592
# Episode: 1593
# Episode: 1594
# SOLVED! Episode 1594 Steps: 3 Epsilon 0.2988
# Episode: 1595
# Episode: 1596
# Episode: 1597
# SOLVED! Episode 1597 Steps: 2 Epsilon 0.2988
# Episode: 1598
# SOLVED! Episode 1598 Steps: 3 Epsilon 0.2988
# Episode: 1599
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 61
# ==============================
# defaultdict(<class 'int'>, {3: 25, 1: 20, 6: 4, 2: 10, 5: 2})
# ******************************
# Episode: 1600
# SOLVED! Episode 1600 Steps: 2 Epsilon 0.2988
# Episode: 1601
# SOLVED! Episode 1601 Steps: 1 Epsilon 0.2988
# Episode: 1602
# SOLVED! Episode 1602 Steps: 3 Epsilon 0.2988
# Episode: 1603
# SOLVED! Episode 1603 Steps: 3 Epsilon 0.2988
# Episode: 1604
# Episode: 1605
# SOLVED! Episode 1605 Steps: 1 Epsilon 0.2988
# Episode: 1606
# Episode: 1607
# SOLVED! Episode 1607 Steps: 3 Epsilon 0.2988
# Episode: 1608
# Episode: 1609
# SOLVED! Episode 1609 Steps: 3 Epsilon 0.2988
# Episode: 1610
# Episode: 1611
# SOLVED! Episode 1611 Steps: 2 Epsilon 0.2988
# Episode: 1612
# SOLVED! Episode 1612 Steps: 1 Epsilon 0.2988
# Episode: 1613
# Episode: 1614
# SOLVED! Episode 1614 Steps: 3 Epsilon 0.2988
# Episode: 1615
# SOLVED! Episode 1615 Steps: 2 Epsilon 0.2988
# Episode: 1616
# Episode: 1617
# Episode: 1618
# SOLVED! Episode 1618 Steps: 3 Epsilon 0.2988
# Episode: 1619
# SOLVED! Episode 1619 Steps: 1 Epsilon 0.2988
# Episode: 1620
# Episode: 1621
# Episode: 1622
# SOLVED! Episode 1622 Steps: 1 Epsilon 0.2988
# Episode: 1623
# SOLVED! Episode 1623 Steps: 3 Epsilon 0.2988
# Episode: 1624
# Episode: 1625
# Episode: 1626
# Episode: 1627
# Episode: 1628
# Episode: 1629
# Episode: 1630
# Episode: 1631
# SOLVED! Episode 1631 Steps: 3 Epsilon 0.2988
# Episode: 1632
# Episode: 1633
# SOLVED! Episode 1633 Steps: 1 Epsilon 0.2988
# Episode: 1634
# SOLVED! Episode 1634 Steps: 6 Epsilon 0.2988
# Episode: 1635
# SOLVED! Episode 1635 Steps: 4 Epsilon 0.2988
# Episode: 1636
# Episode: 1637
# Episode: 1638
# Episode: 1639
# SOLVED! Episode 1639 Steps: 3 Epsilon 0.2988
# Episode: 1640
# SOLVED! Episode 1640 Steps: 2 Epsilon 0.2988
# Episode: 1641
# Episode: 1642
# SOLVED! Episode 1642 Steps: 9 Epsilon 0.2988
# Episode: 1643
# Episode: 1644
# SOLVED! Episode 1644 Steps: 1 Epsilon 0.2988
# Episode: 1645
# SOLVED! Episode 1645 Steps: 3 Epsilon 0.2988
# Episode: 1646
# SOLVED! Episode 1646 Steps: 1 Epsilon 0.2988
# Episode: 1647
# SOLVED! Episode 1647 Steps: 19 Epsilon 0.2988
# Episode: 1648
# Episode: 1649
# SOLVED! Episode 1649 Steps: 15 Epsilon 0.2988
# Episode: 1650
# SOLVED! Episode 1650 Steps: 20 Epsilon 0.2988
# Episode: 1651
# Episode: 1652
# Episode: 1653
# SOLVED! Episode 1653 Steps: 1 Epsilon 0.2988
# Episode: 1654
# Episode: 1655
# SOLVED! Episode 1655 Steps: 5 Epsilon 0.2988
# Episode: 1656
# Episode: 1657
# Episode: 1658
# Episode: 1659
# SOLVED! Episode 1659 Steps: 3 Epsilon 0.2988
# Episode: 1660
# Episode: 1661
# Episode: 1662
# Episode: 1663
# Episode: 1664
# SOLVED! Episode 1664 Steps: 1 Epsilon 0.2988
# Episode: 1665
# SOLVED! Episode 1665 Steps: 3 Epsilon 0.2988
# Episode: 1666
# Episode: 1667
# SOLVED! Episode 1667 Steps: 1 Epsilon 0.2988
# Episode: 1668
# Episode: 1669
# Episode: 1670
# SOLVED! Episode 1670 Steps: 3 Epsilon 0.2988
# Episode: 1671
# Episode: 1672
# Episode: 1673
# SOLVED! Episode 1673 Steps: 3 Epsilon 0.2988
# Episode: 1674
# Episode: 1675
# SOLVED! Episode 1675 Steps: 3 Epsilon 0.2988
# Episode: 1676
# SOLVED! Episode 1676 Steps: 3 Epsilon 0.2988
# Episode: 1677
# Episode: 1678
# Episode: 1679
# SOLVED! Episode 1679 Steps: 3 Epsilon 0.2988
# Episode: 1680
# Episode: 1681
# SOLVED! Episode 1681 Steps: 2 Epsilon 0.2988
# Episode: 1682
# Episode: 1683
# Episode: 1684
# SOLVED! Episode 1684 Steps: 1 Epsilon 0.2988
# Episode: 1685
# SOLVED! Episode 1685 Steps: 6 Epsilon 0.2988
# Episode: 1686
# Episode: 1687
# SOLVED! Episode 1687 Steps: 1 Epsilon 0.2988
# Episode: 1688
# SOLVED! Episode 1688 Steps: 17 Epsilon 0.2988
# Episode: 1689
# Episode: 1690
# SOLVED! Episode 1690 Steps: 3 Epsilon 0.2988
# Episode: 1691
# SOLVED! Episode 1691 Steps: 3 Epsilon 0.2988
# Episode: 1692
# Episode: 1693
# Episode: 1694
# SOLVED! Episode 1694 Steps: 2 Epsilon 0.2988
# Episode: 1695
# SOLVED! Episode 1695 Steps: 5 Epsilon 0.2988
# Episode: 1696
# Episode: 1697
# SOLVED! Episode 1697 Steps: 3 Epsilon 0.2988
# Episode: 1698
# SOLVED! Episode 1698 Steps: 1 Epsilon 0.2988
# Episode: 1699
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 60
# ==============================
# defaultdict(<class 'int'>, {3: 25, 1: 20, 6: 2, 2: 10, 5: 2, 7: 1})
# ******************************
# Episode: 1700
# SOLVED! Episode 1700 Steps: 2 Epsilon 0.2988
# Episode: 1701
# Episode: 1702
# Episode: 1703
# Episode: 1704
# SOLVED! Episode 1704 Steps: 1 Epsilon 0.2988
# Episode: 1705
# Episode: 1706
# SOLVED! Episode 1706 Steps: 1 Epsilon 0.2988
# Episode: 1707
# SOLVED! Episode 1707 Steps: 1 Epsilon 0.2988
# Episode: 1708
# Episode: 1709
# SOLVED! Episode 1709 Steps: 3 Epsilon 0.2988
# Episode: 1710
# Episode: 1711
# SOLVED! Episode 1711 Steps: 2 Epsilon 0.2988
# Episode: 1712
# Episode: 1713
# Episode: 1714
# SOLVED! Episode 1714 Steps: 2 Epsilon 0.2988
# Episode: 1715
# SOLVED! Episode 1715 Steps: 3 Epsilon 0.2988
# Episode: 1716
# SOLVED! Episode 1716 Steps: 3 Epsilon 0.2988
# Episode: 1717
# Episode: 1718
# SOLVED! Episode 1718 Steps: 2 Epsilon 0.2988
# Episode: 1719
# Episode: 1720
# SOLVED! Episode 1720 Steps: 2 Epsilon 0.2988
# Episode: 1721
# Episode: 1722
# SOLVED! Episode 1722 Steps: 3 Epsilon 0.2988
# Episode: 1723
# SOLVED! Episode 1723 Steps: 1 Epsilon 0.2988
# Episode: 1724
# SOLVED! Episode 1724 Steps: 3 Epsilon 0.2988
# Episode: 1725
# SOLVED! Episode 1725 Steps: 3 Epsilon 0.2988
# Episode: 1726
# Episode: 1727
# Episode: 1728
# Episode: 1729
# Episode: 1730
# Episode: 1731
# Episode: 1732
# Episode: 1733
# SOLVED! Episode 1733 Steps: 1 Epsilon 0.2988
# Episode: 1734
# Episode: 1735
# SOLVED! Episode 1735 Steps: 2 Epsilon 0.2988
# Episode: 1736
# SOLVED! Episode 1736 Steps: 3 Epsilon 0.2988
# Episode: 1737
# Episode: 1738
# Episode: 1739
# Episode: 1740
# Episode: 1741
# Episode: 1742
# Episode: 1743
# Episode: 1744
# SOLVED! Episode 1744 Steps: 6 Epsilon 0.2988
# Episode: 1745
# Episode: 1746
# Episode: 1747
# SOLVED! Episode 1747 Steps: 3 Epsilon 0.2988
# Episode: 1748
# SOLVED! Episode 1748 Steps: 1 Epsilon 0.2988
# Episode: 1749
# SOLVED! Episode 1749 Steps: 3 Epsilon 0.2988
# Episode: 1750
# Episode: 1751
# Episode: 1752
# Episode: 1753
# Episode: 1754
# Episode: 1755
# SOLVED! Episode 1755 Steps: 2 Epsilon 0.2988
# Episode: 1756
# SOLVED! Episode 1756 Steps: 1 Epsilon 0.2988
# Episode: 1757
# Episode: 1758
# Episode: 1759
# Episode: 1760
# SOLVED! Episode 1760 Steps: 3 Epsilon 0.2988
# Episode: 1761
# Episode: 1762
# Episode: 1763
# Episode: 1764
# SOLVED! Episode 1764 Steps: 3 Epsilon 0.2988
# Episode: 1765
# Episode: 1766
# Episode: 1767
# SOLVED! Episode 1767 Steps: 1 Epsilon 0.2988
# Episode: 1768
# SOLVED! Episode 1768 Steps: 1 Epsilon 0.2988
# Episode: 1769
# SOLVED! Episode 1769 Steps: 2 Epsilon 0.2988
# Episode: 1770
# Episode: 1771
# SOLVED! Episode 1771 Steps: 2 Epsilon 0.2988
# Episode: 1772
# SOLVED! Episode 1772 Steps: 2 Epsilon 0.2988
# Episode: 1773
# Episode: 1774
# Episode: 1775
# SOLVED! Episode 1775 Steps: 1 Epsilon 0.2988
# Episode: 1776
# Episode: 1777
# SOLVED! Episode 1777 Steps: 3 Epsilon 0.2988
# Episode: 1778
# Episode: 1779
# Episode: 1780
# SOLVED! Episode 1780 Steps: 1 Epsilon 0.2988
# Episode: 1781
# Episode: 1782
# Episode: 1783
# SOLVED! Episode 1783 Steps: 3 Epsilon 0.2988
# Episode: 1784
# Episode: 1785
# Episode: 1786
# SOLVED! Episode 1786 Steps: 3 Epsilon 0.2988
# Episode: 1787
# SOLVED! Episode 1787 Steps: 3 Epsilon 0.2988
# Episode: 1788
# Episode: 1789
# SOLVED! Episode 1789 Steps: 3 Epsilon 0.2988
# Episode: 1790
# SOLVED! Episode 1790 Steps: 2 Epsilon 0.2988
# Episode: 1791
# Episode: 1792
# SOLVED! Episode 1792 Steps: 5 Epsilon 0.2988
# Episode: 1793
# SOLVED! Episode 1793 Steps: 3 Epsilon 0.2988
# Episode: 1794
# Episode: 1795
# SOLVED! Episode 1795 Steps: 2 Epsilon 0.2988
# Episode: 1796
# Episode: 1797
# SOLVED! Episode 1797 Steps: 1 Epsilon 0.2988
# Episode: 1798
# SOLVED! Episode 1798 Steps: 2 Epsilon 0.2988
# Episode: 1799
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 58
# ==============================
# defaultdict(<class 'int'>, {3: 25, 1: 20, 6: 2, 2: 9, 5: 2})
# ******************************
# Episode: 1800
# SOLVED! Episode 1800 Steps: 1 Epsilon 0.2988
# Episode: 1801
# SOLVED! Episode 1801 Steps: 6 Epsilon 0.2988
# Episode: 1802
# Episode: 1803
# Episode: 1804
# Episode: 1805
# Episode: 1806
# Episode: 1807
# SOLVED! Episode 1807 Steps: 2 Epsilon 0.2988
# Episode: 1808
# SOLVED! Episode 1808 Steps: 3 Epsilon 0.2988
# Episode: 1809
# Episode: 1810
# Episode: 1811
# Episode: 1812
# SOLVED! Episode 1812 Steps: 2 Epsilon 0.2988
# Episode: 1813
# SOLVED! Episode 1813 Steps: 3 Epsilon 0.2988
# Episode: 1814
# SOLVED! Episode 1814 Steps: 3 Epsilon 0.2988
# Episode: 1815
# Episode: 1816
# SOLVED! Episode 1816 Steps: 1 Epsilon 0.2988
# Episode: 1817
# SOLVED! Episode 1817 Steps: 2 Epsilon 0.2988
# Episode: 1818
# Episode: 1819
# SOLVED! Episode 1819 Steps: 2 Epsilon 0.2988
# Episode: 1820
# SOLVED! Episode 1820 Steps: 3 Epsilon 0.2988
# Episode: 1821
# SOLVED! Episode 1821 Steps: 2 Epsilon 0.2988
# Episode: 1822
# Episode: 1823
# SOLVED! Episode 1823 Steps: 7 Epsilon 0.2988
# Episode: 1824
# Episode: 1825
# Episode: 1826
# Episode: 1827
# Episode: 1828
# Episode: 1829
# SOLVED! Episode 1829 Steps: 1 Epsilon 0.2988
# Episode: 1830
# SOLVED! Episode 1830 Steps: 3 Epsilon 0.2988
# Episode: 1831
# SOLVED! Episode 1831 Steps: 2 Epsilon 0.2988
# Episode: 1832
# SOLVED! Episode 1832 Steps: 5 Epsilon 0.2988
# Episode: 1833
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-b3ea89c6c240> in <module>
#      35
#      36         if (step+1) % agent.replay_rate == 0:
# ---> 37             agent.replay()
#      38
#      39         if done:
#
# <ipython-input-8-7a389dfa0e84> in replay(self)
#      88             ind += 1
#      89
# ---> 90         self.model.fit(states, targets, epochs=10, verbose=0)
#      91
#      92         self.update_target_model()
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1214                 _r=1):
#    1215               callbacks.on_train_batch_begin(step)
# -> 1216               tmp_logs = self.train_function(iterator)
#    1217               if data_handler.should_sync:
#    1218                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     908
#     909       with OptionalXlaContext(self._jit_compile):
# --> 910         result = self._call(*args, **kwds)
#     911
#     912       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     940       # In this case we have created variables on the first call, so we run the
#     941       # defunned version which is guaranteed to never create variables.
# --> 942       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     943     elif self._stateful_fn is not None:
#     944       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3128       (graph_function,
#    3129        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3130     return graph_function._call_flat(
#    3131         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3132
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1957         and executing_eagerly):
#    1958       # No tape is watching; skip to running the function.
# -> 1959       return self._build_call_outputs(self._inference_function.call(
#    1960           ctx, args, cancellation_manager=cancellation_manager))
#    1961     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     596       with _InterpolateFunctionError(self):
#     597         if cancellation_manager is None:
# --> 598           outputs = execute.execute(
#     599               str(self.signature.name),
#     600               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      56   try:
#      57     ctx.ensure_initialized()
# ---> 58     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      59                                         inputs, attrs, num_outputs)
#      60   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
