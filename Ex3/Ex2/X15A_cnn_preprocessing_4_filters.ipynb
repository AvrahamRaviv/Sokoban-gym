# %% [markdown]
# # Final Project - Reinforcements Learning
# Hello dear students,<br> this is the template notebook. Please click on the "File" tab and then on "Save a copy into drive".
#
# ---
# <br>
#
# ### Name and ID:
# Student 1: Avraham Raviv, 204355390
# <br>
# Student 2: Yevgeni Berkovitch, 317079234
# <br><br>
# <img src="https://play-lh.googleusercontent.com/e_oKlKPISbgdzut1H9opevS7-LTB8-8lsmpCdMkhlnqFenZhpjxbLmx7l158-xQQCIY">
#
# ### https://github.com/mpSchrader/gym-sokoban

# %% [markdown]
# # Installs

# %%
# %%capture
# !sudo apt-get update
# !sudo apt-get install -y xvfb ffmpeg freeglut3-dev
# !pip install 'imageio==2.4.0'
# !pip install gym
# !pip install pygame
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet
# !pip install gym
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install gym_sokoban

# !imageio_download_bin ffmpeg

# %% [markdown]
# # Imports

# %%
import random
import time

import numpy as np
import scipy as scp
import matplotlib.pyplot as plt

import base64
import imageio
from pyvirtualdisplay import Display
from IPython.display import HTML

import gym
from gym import error, spaces, utils
from soko_pap import *

from collections import deque
from queue import PriorityQueue

from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten

from tqdm.notebook import tqdm
from collections import defaultdict

# %%
# %matplotlib inline

# %%
imageio.plugins.ffmpeg.download()

# %%
from gym import logger as gymlogger
gymlogger.set_level(40) # error only

# %% [markdown]
# # Display utils
# The cell below contains the video display configuration. No need to make changes here.

# %%
def embed_mp4(filename):
    """Embeds an mp4 file in the notebook."""
    video = open(filename,'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())

    return HTML(tag)

# %% [markdown]
# # Utils

# %%
def get_distances(room_state):
    for i in range(room_state.shape[0]):
        for j in range(room_state.shape[1]):
            if room_state[i][j] == 2:
                target = (i, j)

    distances = np.zeros(shape=room_state.shape)
    visited_cells = set()
    cell_queue = deque()

    visited_cells.add(target)
    cell_queue.appendleft(target)

    while len(cell_queue) != 0:
        cell = cell_queue.pop()
        distance = distances[cell[0]][cell[1]]
        for x,y in ((1,0), (-1,-0), (0,1), (0,-1)):
            next_cell_x, next_cell_y = cell[0]+x, cell[1]+y
            if room_state[next_cell_x][next_cell_y] != 0 and not (next_cell_x, next_cell_y) in visited_cells:
                distances[next_cell_x][next_cell_y] = distance + 1
                visited_cells.add((next_cell_x, next_cell_y))
                cell_queue.appendleft((next_cell_x, next_cell_y))
                
    return distances   

def calc_distances(room_state, distances):
    box = None
    mover = None
    for i in range(room_state.shape[0]):
        for j in range(room_state.shape[1]):            
            if room_state[i][j] == 4:
                box = (i,j)
            
            if room_state[i][j] == 5:
                mover = (i,j)
    
    return mover, box, distances[box[0]][box[1]]   

def box2target_change_reward(room_state, next_room_state, distances):
    if np.array_equal(room_state, next_room_state):
        return -1.0
    
    mover, box, t2b = calc_distances(room_state, distances)
    n_mover, n_box, n_t2b = calc_distances(next_room_state, distances)
    
    change_reward = 0.0
    if n_t2b < t2b:
        change_reward += 5.0
    elif n_t2b > t2b:
        change_reward -= 5.0
        
    m2b = np.sqrt((mover[0]-box[0])**2 + (mover[1]-box[1])**2)
    n_m2b = np.sqrt((n_mover[0]-n_box[0])**2 + (n_mover[1]-n_box[1])**2)
    
    if n_m2b < m2b and m2b >= 2:
        change_reward += 1.0
    elif n_m2b > m2b and n_m2b >= 2:
        change_reward -= 1.0
        
    return change_reward

# %% [markdown]
# # Solution

# %%
class SOK_Agent:
    def __init__(self):
        # Construct DQN models
        self.state_size = (112,112,1) 
        self.action_size = 8
        self.model = self._build_model()
        self.target_model = self._build_model()
        self.target_model.set_weights(self.model.get_weights())
        self.batch_size = 8
        
        # Replay buffers
        self.replay_buffer = deque(maxlen=5000)
        self.prioritized_replay_buffer = deque(maxlen=500)
        
        # Hyperparameters
        self.gamma = 0.9
        self.epsilon = 1.0   
        self.epsilon_min = 0.3
        self.epsilon_decay = 0.995
        self.replay_rate = 10
        self.update_beta = 0.999

        self.verbosity = 100 

    def _build_model(self):
        model = Sequential()
        model.add(Conv2D(4, (16,16), strides=(16,16), input_shape=self.state_size, activation='relu'))
        model.add(Conv2D(64, (3,3), activation='relu'))
        model.add(Flatten())
        model.add(Dense(512, activation='relu'))       
        model.add(Dense(64, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer="adam")        
        return model

    def remember(self, state, action, reward, next_state, done):
        self.replay_buffer.append([state, action, reward, next_state, done])    
        
    def copy_to_prioritized_buffer(self, n):
        for i in range(n):
            self.prioritized_replay_buffer.append(self.replay_buffer[-1-i])  

    def act(self, state, stochastic=False):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        
        act_values = self.model.predict(state, verbose=0)[0]
        
        if stochastic:
            act_probs = np.exp(act_values)/np.exp(act_values).sum()
            return np.random.choice(np.arange(self.action_size), size=1, p=act_probs)[0]
              
        return np.argmax(act_values) 

    def replay(self): 
        if len(self.replay_buffer) < self.batch_size:
            return
        
        if len(self.prioritized_replay_buffer) < self.batch_size//2:
            minibatch = random.sample(self.replay_buffer, self.batch_size) 
        else:    
            minibatch = random.sample(self.replay_buffer, self.batch_size//2) 
            minibatch.extend(random.sample(self.prioritized_replay_buffer, self.batch_size//2))
        
        states = np.zeros((self.batch_size, self.state_size[0], self.state_size[1]))
        actions = np.zeros(self.batch_size, dtype=int)
        rewards = np.zeros(self.batch_size)
        next_states = np.zeros((self.batch_size, self.state_size[0], self.state_size[1]))
        statuses = np.zeros(self.batch_size)
        targets = np.zeros((self.batch_size, self.action_size)) 
        
        for i, (state, action, reward, next_state, done) in enumerate(minibatch): 
            states[i] = state.copy()
            actions[i] = action
            rewards[i] = reward
            next_states[i] = next_state.copy()
            statuses[i] = 1 if done else 0    
        
        targets = self.model.predict(states) 
        max_actions = np.argmax(self.model.predict(next_states), axis=1)
        next_rewards = self.target_model.predict(next_states)
        
        ind = 0
        for action, reward, next_reward, max_action, done in zip(actions, rewards, next_rewards, max_actions, statuses):  
            if not done:
                reward += self.gamma * next_reward[max_action]
            targets[ind][action] = reward
            ind += 1
        
        self.model.fit(states, targets, epochs=10, verbose=0) 
        
        self.update_target_model()        
    
        if self.epsilon > self.epsilon_min:
            self.epsilon = self.epsilon * self.epsilon_decay
        
    def update_target_model(self):
        model_w = self.model.get_weights()
        target_model_w = self.target_model.get_weights()
        updated_target_model_w = []
        for i in range(len(model_w)):
            updated_target_model_w.append(self.update_beta*target_model_w[i] + (1-self.update_beta)*model_w[i])
        self.target_model.set_weights(updated_target_model_w)    
            
    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

# %%
def process_frame(frame):
    f = frame.mean(axis=2)
    f = f / 255
    return np.expand_dims(f, axis=0)

# %% [markdown]
# ## Training

# %% [markdown]
# #### Test Suite

# %%
def test_agent(stochastic=False):
    current_epsilon = agent.epsilon
    agent.epsilon = 0.0
    num_solved = 0
    solved_in_steps = defaultdict(int)

    for t in tqdm(range(100)):    
        random.seed(t)
        sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
        sok.set_maxsteps(20)
        steps = 0

        state = sok.get_image('rgb_array')
        done = False
        while not done:
            steps += 1
            action = agent.act(process_frame(state), stochastic)
            if action < 4:
                action += 1
            else:
                action += 5
            state, reward, done, info = sok.step(action)

        if 3 in sok.room_state:            
            num_solved += 1
            solved_in_steps[steps] += 1
    
    agent.epsilon = current_epsilon
    print("*" * 30)
    print("Stochastic" if stochastic else "Deterministic")
    print("*" * 30)
    print("Solved: %d" % num_solved)
    print("=" * 30)
    print(solved_in_steps)
    print("*" * 30)

# %%
max_episodes = 50000
max_steps = 20

def init_sok(r):
    random.seed(r+100)
    sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
    sok.set_maxsteps(max_steps)
    return sok

# %%
agent = SOK_Agent()

steps_per_episode = []

for e in range(max_episodes):
    if e % 100 == 0 and e > 0:
        test_agent(stochastic=False)
        
    print("Episode: %d" % (e))
    
    sok = init_sok(e)
    random.seed(e)
    
    state = process_frame(sok.get_image('rgb_array'))
    room_state = sok.room_state.copy() 
    distances = get_distances(room_state)
    
    for step in range(sok.max_steps):
        action = agent.act(state)
        if action < 4:
            next_state, reward, done, _ = sok.step(action+1) 
        else:
            next_state, reward, done, _ = sok.step(action+5)         
        
        next_state = process_frame(next_state)        
        next_room_state = sok.room_state
        
        if not done:
            reward += box2target_change_reward(room_state, next_room_state, distances)
        
        agent.remember(state, action, reward, next_state, done)
        
        state = next_state.copy() 
        room_state = next_room_state.copy()                
        
        if (step+1) % agent.replay_rate == 0:
            agent.replay()            
        
        if done:   
            steps_per_episode.append(step+1)
            
            if 3 in sok.room_state:                
                print("SOLVED! Episode %d Steps: %d Epsilon %.4f" % (e, step+1, agent.epsilon)) 
                agent.copy_to_prioritized_buffer(step+1)
            
            #agent.save("exp1_episode%d.h5" % (e))            
            break
# Out:
# Episode: 0
# Episode: 1
# Episode: 2
# Episode: 3
# Episode: 4
# Episode: 5
# Episode: 6
# Episode: 7
# SOLVED! Episode 7 Steps: 6 Epsilon 0.9322
# Episode: 8
# Episode: 9
# Episode: 10
# Episode: 11
# Episode: 12
# Episode: 13
# SOLVED! Episode 13 Steps: 11 Epsilon 0.8822
# Episode: 14
# Episode: 15
# Episode: 16
# SOLVED! Episode 16 Steps: 19 Epsilon 0.8604
# Episode: 17
# Episode: 18
# Episode: 19
# Episode: 20
# Episode: 21
# Episode: 22
# Episode: 23
# Episode: 24
# Episode: 25
# Episode: 26
# Episode: 27
# Episode: 28
# Episode: 29
# SOLVED! Episode 29 Steps: 1 Epsilon 0.7629
# Episode: 30
# Episode: 31
# Episode: 32
# Episode: 33
# Episode: 34
# Episode: 35
# Episode: 36
# Episode: 37
# Episode: 38
# Episode: 39
# Episode: 40
# Episode: 41
# Episode: 42
# Episode: 43
# Episode: 44
# Episode: 45
# Episode: 46
# Episode: 47
# Episode: 48
# SOLVED! Episode 48 Steps: 1 Epsilon 0.6369
# Episode: 49
# Episode: 50
# Episode: 51
# Episode: 52
# Episode: 53
# Episode: 54
# Episode: 55
# Episode: 56
# SOLVED! Episode 56 Steps: 1 Epsilon 0.5937
# Episode: 57
# Episode: 58
# Episode: 59
# SOLVED! Episode 59 Steps: 10 Epsilon 0.5790
# Episode: 60
# Episode: 61
# SOLVED! Episode 61 Steps: 1 Epsilon 0.5733
# Episode: 62
# Episode: 63
# Episode: 64
# Episode: 65
# SOLVED! Episode 65 Steps: 1 Epsilon 0.5563
# Episode: 66
# Episode: 67
# Episode: 68
# Episode: 69
# Episode: 70
# SOLVED! Episode 70 Steps: 1 Epsilon 0.5344
# Episode: 71
# Episode: 72
# Episode: 73
# Episode: 74
# Episode: 75
# Episode: 76
# Episode: 77
# Episode: 78
# Episode: 79
# Episode: 80
# Episode: 81
# Episode: 82
# Episode: 83
# Episode: 84
# SOLVED! Episode 84 Steps: 1 Epsilon 0.4691
# Episode: 85
# SOLVED! Episode 85 Steps: 1 Epsilon 0.4691
# Episode: 86
# Episode: 87
# Episode: 88
# Episode: 89
# Episode: 90
# Episode: 91
# Episode: 92
# Episode: 93
# SOLVED! Episode 93 Steps: 14 Epsilon 0.4351
# Episode: 94
# SOLVED! Episode 94 Steps: 1 Epsilon 0.4351
# Episode: 95
# SOLVED! Episode 95 Steps: 1 Epsilon 0.4351
# Episode: 96
# Episode: 97
# Episode: 98
# Episode: 99
# SOLVED! Episode 99 Steps: 3 Epsilon 0.4223
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 27
# ==============================
# defaultdict(<class 'int'>, {3: 9, 1: 14, 2: 4})
# ******************************
# Episode: 100
# Episode: 101
# Episode: 102
# Episode: 103
# Episode: 104
# SOLVED! Episode 104 Steps: 3 Epsilon 0.4057
# Episode: 105
# Episode: 106
# Episode: 107
# SOLVED! Episode 107 Steps: 3 Epsilon 0.3976
# Episode: 108
# Episode: 109
# Episode: 110
# Episode: 111
# Episode: 112
# Episode: 113
# Episode: 114
# SOLVED! Episode 114 Steps: 1 Epsilon 0.3744
# Episode: 115
# Episode: 116
# Episode: 117
# Episode: 118
# SOLVED! Episode 118 Steps: 1 Epsilon 0.3633
# Episode: 119
# Episode: 120
# Episode: 121
# Episode: 122
# Episode: 123
# Episode: 124
# SOLVED! Episode 124 Steps: 3 Epsilon 0.3455
# Episode: 125
# SOLVED! Episode 125 Steps: 2 Epsilon 0.3455
# Episode: 126
# Episode: 127
# SOLVED! Episode 127 Steps: 2 Epsilon 0.3421
# Episode: 128
# SOLVED! Episode 128 Steps: 2 Epsilon 0.3421
# Episode: 129
# SOLVED! Episode 129 Steps: 1 Epsilon 0.3421
# Episode: 130
# Episode: 131
# Episode: 132
# Episode: 133
# SOLVED! Episode 133 Steps: 13 Epsilon 0.3303
# Episode: 134
# Episode: 135
# SOLVED! Episode 135 Steps: 3 Epsilon 0.3270
# Episode: 136
# SOLVED! Episode 136 Steps: 2 Epsilon 0.3270
# Episode: 137
# Episode: 138
# Episode: 139
# Episode: 140
# Episode: 141
# SOLVED! Episode 141 Steps: 11 Epsilon 0.3126
# Episode: 142
# SOLVED! Episode 142 Steps: 2 Epsilon 0.3126
# Episode: 143
# Episode: 144
# Episode: 145
# Episode: 146
# Episode: 147
# Episode: 148
# Episode: 149
# Episode: 150
# Episode: 151
# SOLVED! Episode 151 Steps: 1 Epsilon 0.2988
# Episode: 152
# SOLVED! Episode 152 Steps: 2 Epsilon 0.2988
# Episode: 153
# Episode: 154
# SOLVED! Episode 154 Steps: 3 Epsilon 0.2988
# Episode: 155
# Episode: 156
# Episode: 157
# Episode: 158
# Episode: 159
# Episode: 160
# Episode: 161
# SOLVED! Episode 161 Steps: 2 Epsilon 0.2988
# Episode: 162
# SOLVED! Episode 162 Steps: 3 Epsilon 0.2988
# Episode: 163
# SOLVED! Episode 163 Steps: 3 Epsilon 0.2988
# Episode: 164
# Episode: 165
# Episode: 166
# Episode: 167
# Episode: 168
# Episode: 169
# Episode: 170
# Episode: 171
# Episode: 172
# Episode: 173
# Episode: 174
# Episode: 175
# Episode: 176
# Episode: 177
# SOLVED! Episode 177 Steps: 12 Epsilon 0.2988
# Episode: 178
# SOLVED! Episode 178 Steps: 2 Epsilon 0.2988
# Episode: 179
# Episode: 180
# Episode: 181
# Episode: 182
# Episode: 183
# SOLVED! Episode 183 Steps: 6 Epsilon 0.2988
# Episode: 184
# Episode: 185
# Episode: 186
# SOLVED! Episode 186 Steps: 3 Epsilon 0.2988
# Episode: 187
# Episode: 188
# SOLVED! Episode 188 Steps: 3 Epsilon 0.2988
# Episode: 189
# SOLVED! Episode 189 Steps: 2 Epsilon 0.2988
# Episode: 190
# Episode: 191
# Episode: 192
# SOLVED! Episode 192 Steps: 3 Epsilon 0.2988
# Episode: 193
# Episode: 194
# Episode: 195
# Episode: 196
# Episode: 197
# Episode: 198
# Episode: 199
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 41
# ==============================
# defaultdict(<class 'int'>, {3: 17, 1: 17, 2: 7})
# ******************************
# Episode: 200
# Episode: 201
# Episode: 202
# Episode: 203
# Episode: 204
# Episode: 205
# Episode: 206
# Episode: 207
# Episode: 208
# Episode: 209
# SOLVED! Episode 209 Steps: 2 Epsilon 0.2988
# Episode: 210
# Episode: 211
# Episode: 212
# SOLVED! Episode 212 Steps: 3 Epsilon 0.2988
# Episode: 213
# Episode: 214
# SOLVED! Episode 214 Steps: 3 Epsilon 0.2988
# Episode: 215
# Episode: 216
# SOLVED! Episode 216 Steps: 3 Epsilon 0.2988
# Episode: 217
# SOLVED! Episode 217 Steps: 3 Epsilon 0.2988
# Episode: 218
# Episode: 219
# SOLVED! Episode 219 Steps: 2 Epsilon 0.2988
# Episode: 220
# SOLVED! Episode 220 Steps: 18 Epsilon 0.2988
# Episode: 221
# SOLVED! Episode 221 Steps: 6 Epsilon 0.2988
# Episode: 222
# Episode: 223
# SOLVED! Episode 223 Steps: 1 Epsilon 0.2988
# Episode: 224
# Episode: 225
# Episode: 226
# Episode: 227
# Episode: 228
# Episode: 229
# Episode: 230
# Episode: 231
# Episode: 232
# Episode: 233
# SOLVED! Episode 233 Steps: 1 Epsilon 0.2988
# Episode: 234
# SOLVED! Episode 234 Steps: 3 Epsilon 0.2988
# Episode: 235
# Episode: 236
# Episode: 237
# SOLVED! Episode 237 Steps: 2 Epsilon 0.2988
# Episode: 238
# SOLVED! Episode 238 Steps: 1 Epsilon 0.2988
# Episode: 239
# SOLVED! Episode 239 Steps: 7 Epsilon 0.2988
# Episode: 240
# Episode: 241
# Episode: 242
# SOLVED! Episode 242 Steps: 3 Epsilon 0.2988
# Episode: 243
# Episode: 244
# Episode: 245
# Episode: 246
# Episode: 247
# SOLVED! Episode 247 Steps: 13 Epsilon 0.2988
# Episode: 248
# Episode: 249
# SOLVED! Episode 249 Steps: 15 Epsilon 0.2988
# Episode: 250
# Episode: 251
# SOLVED! Episode 251 Steps: 3 Epsilon 0.2988
# Episode: 252
# Episode: 253
# Episode: 254
# Episode: 255
# Episode: 256
# SOLVED! Episode 256 Steps: 2 Epsilon 0.2988
# Episode: 257
# SOLVED! Episode 257 Steps: 3 Epsilon 0.2988
# Episode: 258
# Episode: 259
# Episode: 260
# Episode: 261
# Episode: 262
# Episode: 263
# Episode: 264
# Episode: 265
# Episode: 266
# Episode: 267
# Episode: 268
# SOLVED! Episode 268 Steps: 1 Epsilon 0.2988
# Episode: 269
# SOLVED! Episode 269 Steps: 3 Epsilon 0.2988
# Episode: 270
# Episode: 271
# Episode: 272
# SOLVED! Episode 272 Steps: 2 Epsilon 0.2988
# Episode: 273
# SOLVED! Episode 273 Steps: 12 Epsilon 0.2988
# Episode: 274
# Episode: 275
# Episode: 276
# Episode: 277
# Episode: 278
# Episode: 279
# Episode: 280
# Episode: 281
# Episode: 282
# Episode: 283
# Episode: 284
# Episode: 285
# Episode: 286
# Episode: 287
# Episode: 288
# Episode: 289
# Episode: 290
# Episode: 291
# Episode: 292
# SOLVED! Episode 292 Steps: 1 Epsilon 0.2988
# Episode: 293
# SOLVED! Episode 293 Steps: 3 Epsilon 0.2988
# Episode: 294
# Episode: 295
# Episode: 296
# Episode: 297
# Episode: 298
# Episode: 299
# SOLVED! Episode 299 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 45
# ==============================
# defaultdict(<class 'int'>, {3: 19, 1: 18, 2: 8})
# ******************************
# Episode: 300
# SOLVED! Episode 300 Steps: 1 Epsilon 0.2988
# Episode: 301
# Episode: 302
# Episode: 303
# Episode: 304
# Episode: 305
# Episode: 306
# Episode: 307
# SOLVED! Episode 307 Steps: 1 Epsilon 0.2988
# Episode: 308
# Episode: 309
# Episode: 310
# Episode: 311
# Episode: 312
# Episode: 313
# Episode: 314
# Episode: 315
# SOLVED! Episode 315 Steps: 3 Epsilon 0.2988
# Episode: 316
# Episode: 317
# Episode: 318
# SOLVED! Episode 318 Steps: 2 Epsilon 0.2988
# Episode: 319
# Episode: 320
# Episode: 321
# Episode: 322
# Episode: 323
# Episode: 324
# SOLVED! Episode 324 Steps: 1 Epsilon 0.2988
# Episode: 325
# Episode: 326
# Episode: 327
# SOLVED! Episode 327 Steps: 2 Epsilon 0.2988
# Episode: 328
# Episode: 329
# Episode: 330
# SOLVED! Episode 330 Steps: 2 Epsilon 0.2988
# Episode: 331
# Episode: 332
# Episode: 333
# Episode: 334
# SOLVED! Episode 334 Steps: 1 Epsilon 0.2988
# Episode: 335
# SOLVED! Episode 335 Steps: 1 Epsilon 0.2988
# Episode: 336
# SOLVED! Episode 336 Steps: 3 Epsilon 0.2988
# Episode: 337
# SOLVED! Episode 337 Steps: 2 Epsilon 0.2988
# Episode: 338
# Episode: 339
# Episode: 340
# Episode: 341
# SOLVED! Episode 341 Steps: 2 Epsilon 0.2988
# Episode: 342
# SOLVED! Episode 342 Steps: 2 Epsilon 0.2988
# Episode: 343
# SOLVED! Episode 343 Steps: 3 Epsilon 0.2988
# Episode: 344
# Episode: 345
# Episode: 346
# SOLVED! Episode 346 Steps: 3 Epsilon 0.2988
# Episode: 347
# Episode: 348
# Episode: 349
# Episode: 350
# Episode: 351
# Episode: 352
# Episode: 353
# Episode: 354
# Episode: 355
# Episode: 356
# SOLVED! Episode 356 Steps: 1 Epsilon 0.2988
# Episode: 357
# Episode: 358
# Episode: 359
# Episode: 360
# Episode: 361
# Episode: 362
# Episode: 363
# Episode: 364
# Episode: 365
# Episode: 366
# Episode: 367
# Episode: 368
# SOLVED! Episode 368 Steps: 3 Epsilon 0.2988
# Episode: 369
# Episode: 370
# SOLVED! Episode 370 Steps: 3 Epsilon 0.2988
# Episode: 371
# Episode: 372
# Episode: 373
# Episode: 374
# Episode: 375
# SOLVED! Episode 375 Steps: 5 Epsilon 0.2988
# Episode: 376
# SOLVED! Episode 376 Steps: 3 Epsilon 0.2988
# Episode: 377
# Episode: 378
# Episode: 379
# SOLVED! Episode 379 Steps: 3 Epsilon 0.2988
# Episode: 380
# Episode: 381
# Episode: 382
# Episode: 383
# Episode: 384
# Episode: 385
# Episode: 386
# Episode: 387
# Episode: 388
# Episode: 389
# Episode: 390
# Episode: 391
# SOLVED! Episode 391 Steps: 3 Epsilon 0.2988
# Episode: 392
# Episode: 393
# Episode: 394
# SOLVED! Episode 394 Steps: 1 Epsilon 0.2988
# Episode: 395
# Episode: 396
# SOLVED! Episode 396 Steps: 3 Epsilon 0.2988
# Episode: 397
# Episode: 398
# Episode: 399
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 52
# ==============================
# defaultdict(<class 'int'>, {3: 21, 1: 20, 2: 10, 5: 1})
# ******************************
# Episode: 400
# SOLVED! Episode 400 Steps: 2 Epsilon 0.2988
# Episode: 401
# Episode: 402
# Episode: 403
# SOLVED! Episode 403 Steps: 3 Epsilon 0.2988
# Episode: 404
# SOLVED! Episode 404 Steps: 3 Epsilon 0.2988
# Episode: 405
# SOLVED! Episode 405 Steps: 1 Epsilon 0.2988
# Episode: 406
# SOLVED! Episode 406 Steps: 1 Epsilon 0.2988
# Episode: 407
# Episode: 408
# Episode: 409
# Episode: 410
# SOLVED! Episode 410 Steps: 2 Epsilon 0.2988
# Episode: 411
# Episode: 412
# Episode: 413
# SOLVED! Episode 413 Steps: 3 Epsilon 0.2988
# Episode: 414
# Episode: 415
# Episode: 416
# SOLVED! Episode 416 Steps: 3 Epsilon 0.2988
# Episode: 417
# Episode: 418
# SOLVED! Episode 418 Steps: 3 Epsilon 0.2988
# Episode: 419
# Episode: 420
# Episode: 421
# SOLVED! Episode 421 Steps: 2 Epsilon 0.2988
# Episode: 422
# Episode: 423
# SOLVED! Episode 423 Steps: 1 Epsilon 0.2988
# Episode: 424
# Episode: 425
# Episode: 426
# Episode: 427
# Episode: 428
# SOLVED! Episode 428 Steps: 2 Epsilon 0.2988
# Episode: 429
# Episode: 430
# Episode: 431
# SOLVED! Episode 431 Steps: 12 Epsilon 0.2988
# Episode: 432
# Episode: 433
# Episode: 434
# Episode: 435
# SOLVED! Episode 435 Steps: 1 Epsilon 0.2988
# Episode: 436
# Episode: 437
# Episode: 438
# Episode: 439
# SOLVED! Episode 439 Steps: 3 Epsilon 0.2988
# Episode: 440
# Episode: 441
# SOLVED! Episode 441 Steps: 2 Epsilon 0.2988
# Episode: 442
# Episode: 443
# SOLVED! Episode 443 Steps: 2 Epsilon 0.2988
# Episode: 444
# Episode: 445
# Episode: 446
# Episode: 447
# Episode: 448
# SOLVED! Episode 448 Steps: 3 Epsilon 0.2988
# Episode: 449
# Episode: 450
# Episode: 451
# Episode: 452
# Episode: 453
# SOLVED! Episode 453 Steps: 3 Epsilon 0.2988
# Episode: 454
# Episode: 455
# SOLVED! Episode 455 Steps: 3 Epsilon 0.2988
# Episode: 456
# Episode: 457
# Episode: 458
# Episode: 459
# Episode: 460
# Episode: 461
# Episode: 462
# SOLVED! Episode 462 Steps: 2 Epsilon 0.2988
# Episode: 463
# Episode: 464
# Episode: 465
# SOLVED! Episode 465 Steps: 3 Epsilon 0.2988
# Episode: 466
# SOLVED! Episode 466 Steps: 7 Epsilon 0.2988
# Episode: 467
# Episode: 468
# Episode: 469
# Episode: 470
# Episode: 471
# Episode: 472
# SOLVED! Episode 472 Steps: 2 Epsilon 0.2988
# Episode: 473
# Episode: 474
# Episode: 475
# Episode: 476
# Episode: 477
# Episode: 478
# SOLVED! Episode 478 Steps: 3 Epsilon 0.2988
# Episode: 479
# SOLVED! Episode 479 Steps: 3 Epsilon 0.2988
# Episode: 480
# Episode: 481
# Episode: 482
# Episode: 483
# Episode: 484
# Episode: 485
# Episode: 486
# Episode: 487
# Episode: 488
# SOLVED! Episode 488 Steps: 2 Epsilon 0.2988
# Episode: 489
# Episode: 490
# SOLVED! Episode 490 Steps: 1 Epsilon 0.2988
# Episode: 491
# Episode: 492
# Episode: 493
# SOLVED! Episode 493 Steps: 1 Epsilon 0.2988
# Episode: 494
# SOLVED! Episode 494 Steps: 3 Epsilon 0.2988
# Episode: 495
# SOLVED! Episode 495 Steps: 1 Epsilon 0.2988
# Episode: 496
# Episode: 497
# Episode: 498
# Episode: 499
# SOLVED! Episode 499 Steps: 2 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 48
# ==============================
# defaultdict(<class 'int'>, {3: 20, 1: 20, 2: 8})
# ******************************
# Episode: 500
# SOLVED! Episode 500 Steps: 2 Epsilon 0.2988
# Episode: 501
# Episode: 502
# Episode: 503
# SOLVED! Episode 503 Steps: 3 Epsilon 0.2988
# Episode: 504
# Episode: 505
# SOLVED! Episode 505 Steps: 3 Epsilon 0.2988
# Episode: 506
# Episode: 507
# Episode: 508
# Episode: 509
# SOLVED! Episode 509 Steps: 12 Epsilon 0.2988
# Episode: 510
# SOLVED! Episode 510 Steps: 1 Epsilon 0.2988
# Episode: 511
# SOLVED! Episode 511 Steps: 2 Epsilon 0.2988
# Episode: 512
# SOLVED! Episode 512 Steps: 1 Epsilon 0.2988
# Episode: 513
# Episode: 514
# Episode: 515
# Episode: 516
# Episode: 517
# SOLVED! Episode 517 Steps: 1 Epsilon 0.2988
# Episode: 518
# Episode: 519
# SOLVED! Episode 519 Steps: 2 Epsilon 0.2988
# Episode: 520
# SOLVED! Episode 520 Steps: 1 Epsilon 0.2988
# Episode: 521
# Episode: 522
# SOLVED! Episode 522 Steps: 3 Epsilon 0.2988
# Episode: 523
# SOLVED! Episode 523 Steps: 3 Epsilon 0.2988
# Episode: 524
# SOLVED! Episode 524 Steps: 3 Epsilon 0.2988
# Episode: 525
# Episode: 526
# Episode: 527
# Episode: 528
# SOLVED! Episode 528 Steps: 1 Epsilon 0.2988
# Episode: 529
# SOLVED! Episode 529 Steps: 3 Epsilon 0.2988
# Episode: 530
# Episode: 531
# Episode: 532
# SOLVED! Episode 532 Steps: 2 Epsilon 0.2988
# Episode: 533
# Episode: 534
# Episode: 535
# Episode: 536
# SOLVED! Episode 536 Steps: 3 Epsilon 0.2988
# Episode: 537
# SOLVED! Episode 537 Steps: 2 Epsilon 0.2988
# Episode: 538
# Episode: 539
# Episode: 540
# Episode: 541
# SOLVED! Episode 541 Steps: 3 Epsilon 0.2988
# Episode: 542
# Episode: 543
# Episode: 544
# Episode: 545
# Episode: 546
# Episode: 547
# SOLVED! Episode 547 Steps: 2 Epsilon 0.2988
# Episode: 548
# SOLVED! Episode 548 Steps: 3 Epsilon 0.2988
# Episode: 549
# Episode: 550
# Episode: 551
# Episode: 552
# Episode: 553
# Episode: 554
# Episode: 555
# SOLVED! Episode 555 Steps: 1 Epsilon 0.2988
# Episode: 556
# Episode: 557
# Episode: 558
# SOLVED! Episode 558 Steps: 3 Epsilon 0.2988
# Episode: 559
# Episode: 560
# SOLVED! Episode 560 Steps: 3 Epsilon 0.2988
# Episode: 561
# Episode: 562
# SOLVED! Episode 562 Steps: 2 Epsilon 0.2988
# Episode: 563
# SOLVED! Episode 563 Steps: 1 Epsilon 0.2988
# Episode: 564
# SOLVED! Episode 564 Steps: 3 Epsilon 0.2988
# Episode: 565
# Episode: 566
# Episode: 567
# Episode: 568
# SOLVED! Episode 568 Steps: 2 Epsilon 0.2988
# Episode: 569
# Episode: 570
# Episode: 571
# Episode: 572
# Episode: 573
# Episode: 574
# Episode: 575
# Episode: 576
# SOLVED! Episode 576 Steps: 1 Epsilon 0.2988
# Episode: 577
# SOLVED! Episode 577 Steps: 3 Epsilon 0.2988
# Episode: 578
# Episode: 579
# Episode: 580
# SOLVED! Episode 580 Steps: 3 Epsilon 0.2988
# Episode: 581
# Episode: 582
# Episode: 583
# Episode: 584
# Episode: 585
# Episode: 586
# SOLVED! Episode 586 Steps: 3 Epsilon 0.2988
# Episode: 587
# SOLVED! Episode 587 Steps: 3 Epsilon 0.2988
# Episode: 588
# Episode: 589
# Episode: 590
# Episode: 591
# SOLVED! Episode 591 Steps: 3 Epsilon 0.2988
# Episode: 592
# Episode: 593
# Episode: 594
# Episode: 595
# Episode: 596
# Episode: 597
# Episode: 598
# Episode: 599
# SOLVED! Episode 599 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 50
# ==============================
# defaultdict(<class 'int'>, {3: 20, 1: 20, 2: 9, 5: 1})
# ******************************
# Episode: 600
# SOLVED! Episode 600 Steps: 3 Epsilon 0.2988
# Episode: 601
# Episode: 602
# SOLVED! Episode 602 Steps: 1 Epsilon 0.2988
# Episode: 603
# SOLVED! Episode 603 Steps: 2 Epsilon 0.2988
# Episode: 604
# Episode: 605
# Episode: 606
# Episode: 607
# SOLVED! Episode 607 Steps: 1 Epsilon 0.2988
# Episode: 608
# SOLVED! Episode 608 Steps: 1 Epsilon 0.2988
# Episode: 609
# Episode: 610
# Episode: 611
# SOLVED! Episode 611 Steps: 1 Epsilon 0.2988
# Episode: 612
# Episode: 613
# SOLVED! Episode 613 Steps: 1 Epsilon 0.2988
# Episode: 614
# Episode: 615
# SOLVED! Episode 615 Steps: 2 Epsilon 0.2988
# Episode: 616
# Episode: 617
# Episode: 618
# Episode: 619
# Episode: 620
# SOLVED! Episode 620 Steps: 3 Epsilon 0.2988
# Episode: 621
# Episode: 622
# Episode: 623
# SOLVED! Episode 623 Steps: 2 Epsilon 0.2988
# Episode: 624
# Episode: 625
# SOLVED! Episode 625 Steps: 2 Epsilon 0.2988
# Episode: 626
# Episode: 627
# Episode: 628
# SOLVED! Episode 628 Steps: 3 Epsilon 0.2988
# Episode: 629
# Episode: 630
# Episode: 631
# Episode: 632
# SOLVED! Episode 632 Steps: 3 Epsilon 0.2988
# Episode: 633
# SOLVED! Episode 633 Steps: 1 Epsilon 0.2988
# Episode: 634
# Episode: 635
# SOLVED! Episode 635 Steps: 3 Epsilon 0.2988
# Episode: 636
# Episode: 637
# SOLVED! Episode 637 Steps: 1 Epsilon 0.2988
# Episode: 638
# Episode: 639
# Episode: 640
# SOLVED! Episode 640 Steps: 2 Epsilon 0.2988
# Episode: 641
# Episode: 642
# Episode: 643
# Episode: 644
# Episode: 645
# SOLVED! Episode 645 Steps: 2 Epsilon 0.2988
# Episode: 646
# SOLVED! Episode 646 Steps: 1 Epsilon 0.2988
# Episode: 647
# Episode: 648
# SOLVED! Episode 648 Steps: 2 Epsilon 0.2988
# Episode: 649
# Episode: 650
# SOLVED! Episode 650 Steps: 3 Epsilon 0.2988
# Episode: 651
# SOLVED! Episode 651 Steps: 16 Epsilon 0.2988
# Episode: 652
# SOLVED! Episode 652 Steps: 1 Epsilon 0.2988
# Episode: 653
# Episode: 654
# Episode: 655
# SOLVED! Episode 655 Steps: 3 Epsilon 0.2988
# Episode: 656
# SOLVED! Episode 656 Steps: 3 Epsilon 0.2988
# Episode: 657
# SOLVED! Episode 657 Steps: 3 Epsilon 0.2988
# Episode: 658
# SOLVED! Episode 658 Steps: 1 Epsilon 0.2988
# Episode: 659
# SOLVED! Episode 659 Steps: 2 Epsilon 0.2988
# Episode: 660
# Episode: 661
# Episode: 662
# Episode: 663
# Episode: 664
# Episode: 665
# Episode: 666
# SOLVED! Episode 666 Steps: 2 Epsilon 0.2988
# Episode: 667
# Episode: 668
# Episode: 669
# SOLVED! Episode 669 Steps: 3 Epsilon 0.2988
# Episode: 670
# SOLVED! Episode 670 Steps: 2 Epsilon 0.2988
# Episode: 671
# SOLVED! Episode 671 Steps: 2 Epsilon 0.2988
# Episode: 672
# Episode: 673
# Episode: 674
# SOLVED! Episode 674 Steps: 3 Epsilon 0.2988
# Episode: 675
# SOLVED! Episode 675 Steps: 2 Epsilon 0.2988
# Episode: 676
# SOLVED! Episode 676 Steps: 3 Epsilon 0.2988
# Episode: 677
# Episode: 678
# Episode: 679
# SOLVED! Episode 679 Steps: 1 Epsilon 0.2988
# Episode: 680
# Episode: 681
# Episode: 682
# Episode: 683
# Episode: 684
# Episode: 685
# Episode: 686
# Episode: 687
# Episode: 688
# Episode: 689
# Episode: 690
# Episode: 691
# Episode: 692
# Episode: 693
# Episode: 694
# Episode: 695
# Episode: 696
# Episode: 697
# SOLVED! Episode 697 Steps: 3 Epsilon 0.2988
# Episode: 698
# SOLVED! Episode 698 Steps: 1 Epsilon 0.2988
# Episode: 699
# SOLVED! Episode 699 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 49
# ==============================
# defaultdict(<class 'int'>, {3: 20, 1: 20, 2: 9})
# ******************************
# Episode: 700
# Episode: 701
# Episode: 702
# SOLVED! Episode 702 Steps: 1 Epsilon 0.2988
# Episode: 703
# Episode: 704
# Episode: 705
# SOLVED! Episode 705 Steps: 1 Epsilon 0.2988
# Episode: 706
# Episode: 707
# Episode: 708
# Episode: 709
# Episode: 710
# SOLVED! Episode 710 Steps: 1 Epsilon 0.2988
# Episode: 711
# SOLVED! Episode 711 Steps: 3 Epsilon 0.2988
# Episode: 712
# Episode: 713
# Episode: 714
# Episode: 715
# Episode: 716
# Episode: 717
# Episode: 718
# SOLVED! Episode 718 Steps: 3 Epsilon 0.2988
# Episode: 719
# Episode: 720
# Episode: 721
# SOLVED! Episode 721 Steps: 2 Epsilon 0.2988
# Episode: 722
# Episode: 723
# Episode: 724
# Episode: 725
# SOLVED! Episode 725 Steps: 3 Epsilon 0.2988
# Episode: 726
# Episode: 727
# Episode: 728
# Episode: 729
# Episode: 730
# Episode: 731
# Episode: 732
# SOLVED! Episode 732 Steps: 3 Epsilon 0.2988
# Episode: 733
# SOLVED! Episode 733 Steps: 3 Epsilon 0.2988
# Episode: 734
# Episode: 735
# Episode: 736
# Episode: 737
# Episode: 738
# Episode: 739
# Episode: 740
# SOLVED! Episode 740 Steps: 6 Epsilon 0.2988
# Episode: 741
# Episode: 742
# SOLVED! Episode 742 Steps: 2 Epsilon 0.2988
# Episode: 743
# Episode: 744
# SOLVED! Episode 744 Steps: 1 Epsilon 0.2988
# Episode: 745
# Episode: 746
# Episode: 747
# Episode: 748
# Episode: 749
# Episode: 750
# Episode: 751
# SOLVED! Episode 751 Steps: 1 Epsilon 0.2988
# Episode: 752
# Episode: 753
# Episode: 754
# Episode: 755
# SOLVED! Episode 755 Steps: 1 Epsilon 0.2988
# Episode: 756
# SOLVED! Episode 756 Steps: 2 Epsilon 0.2988
# Episode: 757
# SOLVED! Episode 757 Steps: 1 Epsilon 0.2988
# Episode: 758
# SOLVED! Episode 758 Steps: 1 Epsilon 0.2988
# Episode: 759
# SOLVED! Episode 759 Steps: 2 Epsilon 0.2988
# Episode: 760
# Episode: 761
# SOLVED! Episode 761 Steps: 3 Epsilon 0.2988
# Episode: 762
# SOLVED! Episode 762 Steps: 3 Epsilon 0.2988
# Episode: 763
# Episode: 764
# SOLVED! Episode 764 Steps: 3 Epsilon 0.2988
# Episode: 765
# Episode: 766
# SOLVED! Episode 766 Steps: 3 Epsilon 0.2988
# Episode: 767
# SOLVED! Episode 767 Steps: 1 Epsilon 0.2988
# Episode: 768
# SOLVED! Episode 768 Steps: 3 Epsilon 0.2988
# Episode: 769
# Episode: 770
# SOLVED! Episode 770 Steps: 1 Epsilon 0.2988
# Episode: 771
# Episode: 772
# SOLVED! Episode 772 Steps: 3 Epsilon 0.2988
# Episode: 773
# SOLVED! Episode 773 Steps: 3 Epsilon 0.2988
# Episode: 774
# Episode: 775
# SOLVED! Episode 775 Steps: 1 Epsilon 0.2988
# Episode: 776
# Episode: 777
# SOLVED! Episode 777 Steps: 16 Epsilon 0.2988
# Episode: 778
# SOLVED! Episode 778 Steps: 3 Epsilon 0.2988
# Episode: 779
# Episode: 780
# Episode: 781
# SOLVED! Episode 781 Steps: 1 Epsilon 0.2988
# Episode: 782
# SOLVED! Episode 782 Steps: 2 Epsilon 0.2988
# Episode: 783
# Episode: 784
# Episode: 785
# Episode: 786
# SOLVED! Episode 786 Steps: 18 Epsilon 0.2988
# Episode: 787
# Episode: 788
# Episode: 789
# Episode: 790
# SOLVED! Episode 790 Steps: 1 Epsilon 0.2988
# Episode: 791
# Episode: 792
# SOLVED! Episode 792 Steps: 16 Epsilon 0.2988
# Episode: 793
# Episode: 794
# SOLVED! Episode 794 Steps: 1 Epsilon 0.2988
# Episode: 795
# Episode: 796
# Episode: 797
# SOLVED! Episode 797 Steps: 3 Epsilon 0.2988
# Episode: 798
# Episode: 799
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 48
# ==============================
# defaultdict(<class 'int'>, {3: 18, 1: 20, 2: 10})
# ******************************
# Episode: 800
# SOLVED! Episode 800 Steps: 2 Epsilon 0.2988
# Episode: 801
# Episode: 802
# Episode: 803
# Episode: 804
# Episode: 805
# Episode: 806
# SOLVED! Episode 806 Steps: 3 Epsilon 0.2988
# Episode: 807
# Episode: 808
# Episode: 809
# Episode: 810
# SOLVED! Episode 810 Steps: 3 Epsilon 0.2988
# Episode: 811
# SOLVED! Episode 811 Steps: 17 Epsilon 0.2988
# Episode: 812
# Episode: 813
# SOLVED! Episode 813 Steps: 1 Epsilon 0.2988
# Episode: 814
# Episode: 815
# Episode: 816
# Episode: 817
# Episode: 818
# Episode: 819
# Episode: 820
# Episode: 821
# Episode: 822
# Episode: 823
# SOLVED! Episode 823 Steps: 2 Epsilon 0.2988
# Episode: 824
# Episode: 825
# Episode: 826
# SOLVED! Episode 826 Steps: 1 Epsilon 0.2988
# Episode: 827
# SOLVED! Episode 827 Steps: 3 Epsilon 0.2988
# Episode: 828
# SOLVED! Episode 828 Steps: 2 Epsilon 0.2988
# Episode: 829
# Episode: 830
# Episode: 831
# Episode: 832
# SOLVED! Episode 832 Steps: 1 Epsilon 0.2988
# Episode: 833
# Episode: 834
# Episode: 835
# Episode: 836
# Episode: 837
# SOLVED! Episode 837 Steps: 2 Epsilon 0.2988
# Episode: 838
# Episode: 839
# Episode: 840
# SOLVED! Episode 840 Steps: 2 Epsilon 0.2988
# Episode: 841
# SOLVED! Episode 841 Steps: 1 Epsilon 0.2988
# Episode: 842
# Episode: 843
# SOLVED! Episode 843 Steps: 17 Epsilon 0.2988
# Episode: 844
# SOLVED! Episode 844 Steps: 3 Epsilon 0.2988
# Episode: 845
