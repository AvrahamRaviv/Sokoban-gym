# %% [markdown]
# # Final Project - Reinforcements Learning
# Hello dear students,<br> this is the template notebook. Please click on the "File" tab and then on "Save a copy into drive".
#
# ---
# <br>
#
# ### Name and ID:
# Student 1: Avraham Raviv, 204355390
# <br>
# Student 2: Yevgeni Berkovitch, 317079234
# <br><br>
# <img src="https://play-lh.googleusercontent.com/e_oKlKPISbgdzut1H9opevS7-LTB8-8lsmpCdMkhlnqFenZhpjxbLmx7l158-xQQCIY">
#
# ### https://github.com/mpSchrader/gym-sokoban

# %% [markdown]
# # Installs

# %%
# %%capture
# !sudo apt-get update
# !sudo apt-get install -y xvfb ffmpeg freeglut3-dev
# !pip install 'imageio==2.4.0'
# !pip install gym
# !pip install pygame
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet
# !pip install gym
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install gym_sokoban

# !imageio_download_bin ffmpeg

# %% [markdown]
# # Imports

# %%
import random
import time

import numpy as np
import scipy as scp
import matplotlib.pyplot as plt

import base64
import imageio
from pyvirtualdisplay import Display
from IPython.display import HTML

import gym
from gym import error, spaces, utils
from soko_pap import *

from collections import deque
from queue import PriorityQueue

from keras.models import Sequential
from keras.layers import Dense

from tqdm.notebook import tqdm
from collections import defaultdict

# %%
# %matplotlib inline

# %%
imageio.plugins.ffmpeg.download()

# %%
from gym import logger as gymlogger
gymlogger.set_level(40) # error only

# %% [markdown]
# # Display utils
# The cell below contains the video display configuration. No need to make changes here.

# %%
def embed_mp4(filename):
    """Embeds an mp4 file in the notebook."""
    video = open(filename,'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())

    return HTML(tag)

# %% [markdown]
# # Utils

# %%
def get_distances(room_state):
    for i in range(room_state.shape[0]):
        for j in range(room_state.shape[1]):
            if room_state[i][j] == 2:
                target = (i, j)

    distances = np.zeros(shape=room_state.shape)
    visited_cells = set()
    cell_queue = deque()

    visited_cells.add(target)
    cell_queue.appendleft(target)

    while len(cell_queue) != 0:
        cell = cell_queue.pop()
        distance = distances[cell[0]][cell[1]]
        for x,y in ((1,0), (-1,-0), (0,1), (0,-1)):
            next_cell_x, next_cell_y = cell[0]+x, cell[1]+y
            if room_state[next_cell_x][next_cell_y] != 0 and not (next_cell_x, next_cell_y) in visited_cells:
                distances[next_cell_x][next_cell_y] = distance + 1
                visited_cells.add((next_cell_x, next_cell_y))
                cell_queue.appendleft((next_cell_x, next_cell_y))
                
    return distances   

def calc_distances(room_state, distances):
    box = None
    mover = None
    for i in range(room_state.shape[0]):
        for j in range(room_state.shape[1]):            
            if room_state[i][j] == 4:
                box = (i,j)
            
            if room_state[i][j] == 5:
                mover = (i,j)
    
    return mover, box, distances[box[0]][box[1]]   

def box2target_change_reward(room_state, next_room_state, distances):
    if np.array_equal(room_state, next_room_state):
        return -1.0
    
    mover, box, t2b = calc_distances(room_state, distances)
    n_mover, n_box, n_t2b = calc_distances(next_room_state, distances)
    
    change_reward = 0.0
    if n_t2b < t2b:
        change_reward += 5.0
    elif n_t2b > t2b:
        change_reward -= 5.0
        
    m2b = np.sqrt((mover[0]-box[0])**2 + (mover[1]-box[1])**2)
    n_m2b = np.sqrt((n_mover[0]-n_box[0])**2 + (n_mover[1]-n_box[1])**2)
    
    if n_m2b < m2b and m2b >= 2:
        change_reward += 1.0
    elif n_m2b > m2b and n_m2b >= 2:
        change_reward -= 1.0
        
    return change_reward

# %% [markdown]
# # Solution

# %%
class SOK_Agent:
    def __init__(self):
        # Construct DQN models
        self.state_size = (25,) 
        self.action_size = 8
        self.model = self._build_model()
        self.target_model = self._build_model()
        self.target_model.set_weights(self.model.get_weights())
        self.batch_size = 8
        
        # Replay buffers
        self.replay_buffer = deque(maxlen=500)
        self.prioritized_replay_buffer = deque(maxlen=100_000)
        self.prioritized_replay_batch = 50        
        
        # Hyperparameters
        self.gamma = 0.9
        self.epsilon = 1.0   
        self.epsilon_min = 0.3
        self.epsilon_decay = 0.995
        self.replay_rate = 10
        self.update_beta = 0.999

        self.verbosity = 100 

    def _build_model(self):
        model = Sequential()
        model.add(Dense(25, input_shape=self.state_size, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer="adam")        
        return model

    def remember(self, state, action, reward, next_state, done):
        self.replay_buffer.append([state, action, reward, next_state, done])    
        
    def copy_to_prioritized_buffer(self, n):
        for i in range(n):
            self.prioritized_replay_buffer.append(self.replay_buffer[-1-i])  

    def act(self, state, stochastic=False):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        
        act_values = self.model.predict(state, verbose=0)[0]
        
        if stochastic:
            act_probs = np.exp(act_values)/np.exp(act_values).sum()
            return np.random.choice(np.arange(self.action_size), size=1, p=act_probs)[0]
              
        return np.argmax(act_values) 

    def replay(self): 
        if len(self.prioritized_replay_buffer) < self.batch_size:
            return
        
        minibatch = random.sample(self.prioritized_replay_buffer, self.batch_size)
        
        states = np.zeros((self.batch_size, self.state_size[0]))
        actions = np.zeros(self.batch_size, dtype=int)
        rewards = np.zeros(self.batch_size)
        next_states = np.zeros((self.batch_size, self.state_size[0]))
        statuses = np.zeros(self.batch_size)
        targets = np.zeros((self.batch_size, self.action_size)) 
        
        for i, (state, action, reward, next_state, done) in enumerate(minibatch): 
            states[i] = state.copy()
            actions[i] = action
            rewards[i] = reward
            next_states[i] = next_state.copy()
            statuses[i] = 1 if done else 0    
        
        targets = self.model.predict(states) 
        max_actions = np.argmax(self.model.predict(next_states), axis=1)
        next_rewards = self.target_model.predict(next_states)
        
        ind = 0
        for action, reward, next_reward, max_action, done in zip(actions, rewards, next_rewards, max_actions, statuses):  
            if not done:
                reward += self.gamma * next_reward[max_action]
            targets[ind][action] = reward
            ind += 1
        
        self.model.fit(states, targets, epochs=10, verbose=0) 
        
        self.update_target_model()        
    
        if self.epsilon > self.epsilon_min:
            self.epsilon = self.epsilon * self.epsilon_decay
        
    def update_target_model(self):
        model_w = self.model.get_weights()
        target_model_w = self.target_model.get_weights()
        updated_target_model_w = []
        for i in range(len(model_w)):
            updated_target_model_w.append(self.update_beta*target_model_w[i] + (1-self.update_beta)*model_w[i])
        self.target_model.set_weights(updated_target_model_w)    
            
    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

# %%
def process_frame(frame):
    f = frame[16:96, 16:96, 0]   
    f = f.reshape(5, 16, 5, 16).max(axis=(1, 3))
    f = f.flatten()
    f = f / 255
    return np.expand_dims(f, axis=0)

# %% [markdown]
# ## Training

# %% [markdown]
# #### Test Suite

# %%
def test_agent(stochastic=False):
    current_epsilon = agent.epsilon
    agent.epsilon = 0.0
    num_solved = 0
    solved_in_steps = defaultdict(int)

    for t in tqdm(range(100)):    
        random.seed(t)
        sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
        sok.set_maxsteps(20)
        steps = 0

        state = sok.get_image('rgb_array')
        done = False
        while not done:
            steps += 1
            action = agent.act(process_frame(state), stochastic)
            if action < 4:
                action += 1
            else:
                action += 5
            state, reward, done, info = sok.step(action)

        if 3 in sok.room_state:            
            num_solved += 1
            solved_in_steps[steps] += 1
    
    agent.epsilon = current_epsilon
    print("*" * 30)
    print("Stochastic" if stochastic else "Deterministic")
    print("*" * 30)
    print("Solved: %d" % num_solved)
    print("=" * 30)
    print(solved_in_steps)
    print("*" * 30)

# %%
max_episodes = 5000
max_steps = 100

def init_sok(r):
    random.seed(r+100)
    sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
    sok.set_maxsteps(max_steps)
    return sok

# %%
agent = SOK_Agent()

steps_per_episode = []

for e in range(max_episodes):
    if e % 100 == 0:
        test_agent(stochastic=False)
        test_agent(stochastic=True)
        
    print("Episode: %d" % (e))
    
    sok = init_sok(e)
    random.seed(e)
    
    state = process_frame(sok.get_image('rgb_array'))
    room_state = sok.room_state.copy() 
    distances = get_distances(room_state)
    
    for step in range(sok.max_steps):
        action = agent.act(state)
        if action < 4:
            next_state, reward, done, _ = sok.step(action+1) 
        else:
            next_state, reward, done, _ = sok.step(action+5)         
        
        next_state = process_frame(next_state)        
        next_room_state = sok.room_state
        
        if not done:
            reward += box2target_change_reward(room_state, next_room_state, distances)
        
        agent.remember(state, action, reward, next_state, done)
        
        state = next_state.copy() 
        room_state = next_room_state.copy()                
        
        if (step+1) % agent.replay_rate == 0:
            agent.replay()            
        
        if done:   
            steps_per_episode.append(step+1)
            
            if 3 in sok.room_state:                
                print("SOLVED! Episode %d Steps: %d Epsilon %.4f" % (e, step+1, agent.epsilon)) 
                agent.copy_to_prioritized_buffer(min(agent.prioritized_replay_batch, step+1))
            
            #agent.save("exp1_episode%d.h5" % (e))            
            break
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 1
# ==============================
# defaultdict(<class 'int'>, {1: 1})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 12
# ==============================
# defaultdict(<class 'int'>, {3: 5, 11: 1, 4: 1, 7: 2, 15: 1, 16: 2})
# ******************************
# Episode: 0
# Episode: 1
# SOLVED! Episode 1 Steps: 82 Epsilon 1.0000
# Episode: 2
# Episode: 3
# Episode: 4
# Episode: 5
# Episode: 6
# Episode: 7
# SOLVED! Episode 7 Steps: 9 Epsilon 0.7783
# Episode: 8
# Episode: 9
# Episode: 10
# Episode: 11
# Episode: 12
# Episode: 13
# Episode: 14
# SOLVED! Episode 14 Steps: 1 Epsilon 0.5762
# Episode: 15
# Episode: 16
# Episode: 17
# Episode: 18
# Episode: 19
# SOLVED! Episode 19 Steps: 52 Epsilon 0.4598
# Episode: 20
# Episode: 21
# Episode: 22
# SOLVED! Episode 22 Steps: 1 Epsilon 0.4159
# Episode: 23
# Episode: 24
# SOLVED! Episode 24 Steps: 23 Epsilon 0.3917
# Episode: 25
# Episode: 26
# Episode: 27
# Episode: 28
# SOLVED! Episode 28 Steps: 3 Epsilon 0.3370
# Episode: 29
# SOLVED! Episode 29 Steps: 1 Epsilon 0.3370
# Episode: 30
# Episode: 31
# SOLVED! Episode 31 Steps: 24 Epsilon 0.3173
# Episode: 32
# Episode: 33
# SOLVED! Episode 33 Steps: 98 Epsilon 0.2988
# Episode: 34
# Episode: 35
# Episode: 36
# Episode: 37
# SOLVED! Episode 37 Steps: 3 Epsilon 0.2988
# Episode: 38
# Episode: 39
# Episode: 40
# Episode: 41
# Episode: 42
# SOLVED! Episode 42 Steps: 100 Epsilon 0.2988
# Episode: 43
# Episode: 44
# Episode: 45
# Episode: 46
# Episode: 47
# Episode: 48
# SOLVED! Episode 48 Steps: 7 Epsilon 0.2988
# Episode: 49
# Episode: 50
# Episode: 51
# Episode: 52
# Episode: 53
# SOLVED! Episode 53 Steps: 3 Epsilon 0.2988
# Episode: 54
# Episode: 55
# Episode: 56
# Episode: 57
# Episode: 58
# Episode: 59
# Episode: 60
# Episode: 61
# Episode: 62
# SOLVED! Episode 62 Steps: 77 Epsilon 0.2988
# Episode: 63
# Episode: 64
# Episode: 65
# Episode: 66
# Episode: 67
# Episode: 68
# Episode: 69
# Episode: 70
# Episode: 71
# SOLVED! Episode 71 Steps: 50 Epsilon 0.2988
# Episode: 72
# Episode: 73
# Episode: 74
# SOLVED! Episode 74 Steps: 72 Epsilon 0.2988
# Episode: 75
# SOLVED! Episode 75 Steps: 43 Epsilon 0.2988
# Episode: 76
# Episode: 77
# Episode: 78
# Episode: 79
# Episode: 80
# SOLVED! Episode 80 Steps: 60 Epsilon 0.2988
# Episode: 81
# Episode: 82
# Episode: 83
# Episode: 84
# Episode: 85
# Episode: 86
# SOLVED! Episode 86 Steps: 79 Epsilon 0.2988
# Episode: 87
# Episode: 88
# SOLVED! Episode 88 Steps: 78 Epsilon 0.2988
# Episode: 89
# Episode: 90
# Episode: 91
# SOLVED! Episode 91 Steps: 1 Epsilon 0.2988
# Episode: 92
# Episode: 93
# Episode: 94
# SOLVED! Episode 94 Steps: 1 Epsilon 0.2988
# Episode: 95
# SOLVED! Episode 95 Steps: 1 Epsilon 0.2988
# Episode: 96
# Episode: 97
# Episode: 98
# Episode: 99
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 16
# ==============================
# defaultdict(<class 'int'>, {3: 7, 2: 4, 1: 5})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 21
# ==============================
# defaultdict(<class 'int'>, {7: 2, 3: 4, 4: 3, 2: 6, 13: 1, 5: 1, 1: 1, 9: 1, 6: 1, 8: 1})
# ******************************
# Episode: 100
# Episode: 101
# Episode: 102
# Episode: 103
# SOLVED! Episode 103 Steps: 81 Epsilon 0.2988
# Episode: 104
# Episode: 105
# Episode: 106
# SOLVED! Episode 106 Steps: 2 Epsilon 0.2988
# Episode: 107
# Episode: 108
# Episode: 109
# Episode: 110
# Episode: 111
# Episode: 112
# Episode: 113
# SOLVED! Episode 113 Steps: 82 Epsilon 0.2988
# Episode: 114
# Episode: 115
# Episode: 116
# SOLVED! Episode 116 Steps: 29 Epsilon 0.2988
# Episode: 117
# Episode: 118
# Episode: 119
# Episode: 120
# SOLVED! Episode 120 Steps: 3 Epsilon 0.2988
# Episode: 121
# Episode: 122
# Episode: 123
# Episode: 124
# Episode: 125
# SOLVED! Episode 125 Steps: 42 Epsilon 0.2988
# Episode: 126
# Episode: 127
# Episode: 128
# SOLVED! Episode 128 Steps: 2 Epsilon 0.2988
# Episode: 129
# SOLVED! Episode 129 Steps: 1 Epsilon 0.2988
# Episode: 130
# Episode: 131
# Episode: 132
# Episode: 133
# SOLVED! Episode 133 Steps: 17 Epsilon 0.2988
# Episode: 134
# Episode: 135
# Episode: 136
# Episode: 137
# Episode: 138
# Episode: 139
# Episode: 140
# Episode: 141
# SOLVED! Episode 141 Steps: 3 Epsilon 0.2988
# Episode: 142
# Episode: 143
# SOLVED! Episode 143 Steps: 3 Epsilon 0.2988
# Episode: 144
# Episode: 145
# Episode: 146
# Episode: 147
# Episode: 148
# Episode: 149
# Episode: 150
# SOLVED! Episode 150 Steps: 2 Epsilon 0.2988
# Episode: 151
# Episode: 152
# Episode: 153
# Episode: 154
# Episode: 155
# SOLVED! Episode 155 Steps: 1 Epsilon 0.2988
# Episode: 156
# Episode: 157
# Episode: 158
# Episode: 159
# SOLVED! Episode 159 Steps: 55 Epsilon 0.2988
# Episode: 160
# Episode: 161
# Episode: 162
# Episode: 163
# Episode: 164
# Episode: 165
# Episode: 166
# SOLVED! Episode 166 Steps: 2 Epsilon 0.2988
# Episode: 167
# Episode: 168
# SOLVED! Episode 168 Steps: 36 Epsilon 0.2988
# Episode: 169
# Episode: 170
# Episode: 171
# Episode: 172
# Episode: 173
# SOLVED! Episode 173 Steps: 3 Epsilon 0.2988
# Episode: 174
# Episode: 175
# Episode: 176
# Episode: 177
# SOLVED! Episode 177 Steps: 43 Epsilon 0.2988
# Episode: 178
# Episode: 179
# Episode: 180
# Episode: 181
# Episode: 182
# SOLVED! Episode 182 Steps: 3 Epsilon 0.2988
# Episode: 183
# SOLVED! Episode 183 Steps: 6 Epsilon 0.2988
# Episode: 184
# SOLVED! Episode 184 Steps: 3 Epsilon 0.2988
# Episode: 185
# SOLVED! Episode 185 Steps: 95 Epsilon 0.2988
# Episode: 186
# Episode: 187
# SOLVED! Episode 187 Steps: 2 Epsilon 0.2988
# Episode: 188
# Episode: 189
# Episode: 190
# Episode: 191
# SOLVED! Episode 191 Steps: 88 Epsilon 0.2988
# Episode: 192
# Episode: 193
# SOLVED! Episode 193 Steps: 42 Epsilon 0.2988
# Episode: 194
# Episode: 195
# Episode: 196
# Episode: 197
# Episode: 198
# Episode: 199
# SOLVED! Episode 199 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 16
# ==============================
# defaultdict(<class 'int'>, {3: 9, 1: 4, 2: 3})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 24
# ==============================
# defaultdict(<class 'int'>, {3: 8, 11: 1, 17: 1, 12: 2, 1: 4, 2: 4, 7: 1, 9: 2, 4: 1})
# ******************************
# Episode: 200
# SOLVED! Episode 200 Steps: 2 Epsilon 0.2988
# Episode: 201
# Episode: 202
# Episode: 203
# Episode: 204
# Episode: 205
# Episode: 206
# Episode: 207
# SOLVED! Episode 207 Steps: 3 Epsilon 0.2988
# Episode: 208
# Episode: 209
# SOLVED! Episode 209 Steps: 2 Epsilon 0.2988
# Episode: 210
# Episode: 211
# Episode: 212
# SOLVED! Episode 212 Steps: 71 Epsilon 0.2988
# Episode: 213
# SOLVED! Episode 213 Steps: 3 Epsilon 0.2988
# Episode: 214
# Episode: 215
# Episode: 216
# Episode: 217
# SOLVED! Episode 217 Steps: 3 Epsilon 0.2988
# Episode: 218
# Episode: 219
# SOLVED! Episode 219 Steps: 2 Epsilon 0.2988
# Episode: 220
# Episode: 221
# Episode: 222
# Episode: 223
# Episode: 224
# Episode: 225
# Episode: 226
# Episode: 227
# Episode: 228
# Episode: 229
# Episode: 230
# SOLVED! Episode 230 Steps: 15 Epsilon 0.2988
# Episode: 231
# SOLVED! Episode 231 Steps: 85 Epsilon 0.2988
# Episode: 232
# Episode: 233
# SOLVED! Episode 233 Steps: 1 Epsilon 0.2988
# Episode: 234
# SOLVED! Episode 234 Steps: 3 Epsilon 0.2988
# Episode: 235
# Episode: 236
# Episode: 237
# Episode: 238
# Episode: 239
# SOLVED! Episode 239 Steps: 7 Epsilon 0.2988
# Episode: 240
# Episode: 241
# Episode: 242
# SOLVED! Episode 242 Steps: 3 Epsilon 0.2988
# Episode: 243
# Episode: 244
# Episode: 245
# SOLVED! Episode 245 Steps: 2 Epsilon 0.2988
# Episode: 246
# Episode: 247
# SOLVED! Episode 247 Steps: 14 Epsilon 0.2988
# Episode: 248
# Episode: 249
# SOLVED! Episode 249 Steps: 3 Epsilon 0.2988
# Episode: 250
# SOLVED! Episode 250 Steps: 79 Epsilon 0.2988
# Episode: 251
# Episode: 252
# Episode: 253
# Episode: 254
# Episode: 255
# SOLVED! Episode 255 Steps: 56 Epsilon 0.2988
# Episode: 256
# SOLVED! Episode 256 Steps: 23 Epsilon 0.2988
# Episode: 257
# SOLVED! Episode 257 Steps: 3 Epsilon 0.2988
# Episode: 258
# SOLVED! Episode 258 Steps: 3 Epsilon 0.2988
# Episode: 259
# SOLVED! Episode 259 Steps: 3 Epsilon 0.2988
# Episode: 260
# Episode: 261
# Episode: 262
# Episode: 263
# Episode: 264
# Episode: 265
# Episode: 266
# SOLVED! Episode 266 Steps: 3 Epsilon 0.2988
# Episode: 267
# Episode: 268
# SOLVED! Episode 268 Steps: 7 Epsilon 0.2988
# Episode: 269
# Episode: 270
# SOLVED! Episode 270 Steps: 2 Epsilon 0.2988
# Episode: 271
# Episode: 272
# SOLVED! Episode 272 Steps: 67 Epsilon 0.2988
# Episode: 273
# Episode: 274
# Episode: 275
# Episode: 276
# Episode: 277
# Episode: 278
# Episode: 279
# Episode: 280
# Episode: 281
# Episode: 282
# Episode: 283
# Episode: 284
# Episode: 285
# SOLVED! Episode 285 Steps: 3 Epsilon 0.2988
# Episode: 286
# Episode: 287
# Episode: 288
# Episode: 289
# Episode: 290
# Episode: 291
# Episode: 292
# Episode: 293
# Episode: 294
# SOLVED! Episode 294 Steps: 1 Epsilon 0.2988
# Episode: 295
# Episode: 296
# Episode: 297
# Episode: 298
# Episode: 299
# SOLVED! Episode 299 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 18
# ==============================
# defaultdict(<class 'int'>, {3: 10, 1: 5, 2: 3})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 25
# ==============================
# defaultdict(<class 'int'>, {3: 10, 19: 1, 5: 1, 7: 2, 1: 3, 10: 1, 4: 2, 14: 1, 2: 3, 6: 1})
# ******************************
# Episode: 300
# SOLVED! Episode 300 Steps: 1 Epsilon 0.2988
# Episode: 301
# SOLVED! Episode 301 Steps: 74 Epsilon 0.2988
# Episode: 302
# SOLVED! Episode 302 Steps: 54 Epsilon 0.2988
# Episode: 303
# Episode: 304
# Episode: 305
# SOLVED! Episode 305 Steps: 2 Epsilon 0.2988
# Episode: 306
# Episode: 307
# SOLVED! Episode 307 Steps: 32 Epsilon 0.2988
# Episode: 308
# Episode: 309
# Episode: 310
# SOLVED! Episode 310 Steps: 37 Epsilon 0.2988
# Episode: 311
# Episode: 312
# Episode: 313
# SOLVED! Episode 313 Steps: 64 Epsilon 0.2988
# Episode: 314
# Episode: 315
# Episode: 316
# Episode: 317
# Episode: 318
# SOLVED! Episode 318 Steps: 2 Epsilon 0.2988
# Episode: 319
# SOLVED! Episode 319 Steps: 12 Epsilon 0.2988
# Episode: 320
# Episode: 321
# Episode: 322
# SOLVED! Episode 322 Steps: 46 Epsilon 0.2988
# Episode: 323
# SOLVED! Episode 323 Steps: 3 Epsilon 0.2988
# Episode: 324
# SOLVED! Episode 324 Steps: 1 Epsilon 0.2988
# Episode: 325
# Episode: 326
# Episode: 327
# Episode: 328
# Episode: 329
# Episode: 330
# SOLVED! Episode 330 Steps: 2 Epsilon 0.2988
# Episode: 331
# Episode: 332
# Episode: 333
# Episode: 334
# SOLVED! Episode 334 Steps: 6 Epsilon 0.2988
# Episode: 335
# Episode: 336
# SOLVED! Episode 336 Steps: 3 Epsilon 0.2988
# Episode: 337
# SOLVED! Episode 337 Steps: 19 Epsilon 0.2988
# Episode: 338
# Episode: 339
# Episode: 340
# Episode: 341
# Episode: 342
# Episode: 343
# Episode: 344
# Episode: 345
# Episode: 346
# SOLVED! Episode 346 Steps: 67 Epsilon 0.2988
# Episode: 347
# Episode: 348
# SOLVED! Episode 348 Steps: 1 Epsilon 0.2988
# Episode: 349
# Episode: 350
# Episode: 351
# SOLVED! Episode 351 Steps: 3 Epsilon 0.2988
# Episode: 352
# Episode: 353
# SOLVED! Episode 353 Steps: 3 Epsilon 0.2988
# Episode: 354
# Episode: 355
# Episode: 356
# Episode: 357
# Episode: 358
# Episode: 359
# Episode: 360
# Episode: 361
# SOLVED! Episode 361 Steps: 68 Epsilon 0.2988
# Episode: 362
# Episode: 363
# Episode: 364
# Episode: 365
# Episode: 366
# Episode: 367
# Episode: 368
# SOLVED! Episode 368 Steps: 3 Epsilon 0.2988
# Episode: 369
# Episode: 370
# Episode: 371
# Episode: 372
# Episode: 373
# Episode: 374
# Episode: 375
# Episode: 376
# Episode: 377
# Episode: 378
# Episode: 379
# SOLVED! Episode 379 Steps: 3 Epsilon 0.2988
# Episode: 380
# Episode: 381
# Episode: 382
# SOLVED! Episode 382 Steps: 2 Epsilon 0.2988
# Episode: 383
# Episode: 384
# Episode: 385
# Episode: 386
# Episode: 387
# Episode: 388
# Episode: 389
# SOLVED! Episode 389 Steps: 2 Epsilon 0.2988
# Episode: 390
# SOLVED! Episode 390 Steps: 1 Epsilon 0.2988
# Episode: 391
# SOLVED! Episode 391 Steps: 3 Epsilon 0.2988
# Episode: 392
# Episode: 393
# Episode: 394
# Episode: 395
# Episode: 396
# Episode: 397
# Episode: 398
# Episode: 399
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 20
# ==============================
# defaultdict(<class 'int'>, {3: 10, 2: 4, 1: 6})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 25
# ==============================
# defaultdict(<class 'int'>, {3: 10, 1: 6, 7: 2, 2: 4, 12: 1, 14: 1, 4: 1})
# ******************************
# Episode: 400
# SOLVED! Episode 400 Steps: 2 Epsilon 0.2988
# Episode: 401
# Episode: 402
# Episode: 403
# SOLVED! Episode 403 Steps: 3 Epsilon 0.2988
# Episode: 404
# Episode: 405
# SOLVED! Episode 405 Steps: 94 Epsilon 0.2988
# Episode: 406
# SOLVED! Episode 406 Steps: 1 Epsilon 0.2988
# Episode: 407
# Episode: 408
# Episode: 409
# Episode: 410
# Episode: 411
# Episode: 412
# Episode: 413
# SOLVED! Episode 413 Steps: 3 Epsilon 0.2988
# Episode: 414
# Episode: 415
# SOLVED! Episode 415 Steps: 47 Epsilon 0.2988
# Episode: 416
# SOLVED! Episode 416 Steps: 3 Epsilon 0.2988
# Episode: 417
# Episode: 418
# Episode: 419
# Episode: 420
# Episode: 421
# Episode: 422
# Episode: 423
# Episode: 424
# SOLVED! Episode 424 Steps: 42 Epsilon 0.2988
# Episode: 425
# Episode: 426
# Episode: 427
# SOLVED! Episode 427 Steps: 3 Epsilon 0.2988
# Episode: 428
# Episode: 429
# SOLVED! Episode 429 Steps: 1 Epsilon 0.2988
# Episode: 430
# SOLVED! Episode 430 Steps: 33 Epsilon 0.2988
# Episode: 431
# Episode: 432
# Episode: 433
# Episode: 434
# Episode: 435
# SOLVED! Episode 435 Steps: 1 Epsilon 0.2988
# Episode: 436
# Episode: 437
# Episode: 438
# SOLVED! Episode 438 Steps: 1 Epsilon 0.2988
# Episode: 439
# SOLVED! Episode 439 Steps: 3 Epsilon 0.2988
# Episode: 440
# Episode: 441
# Episode: 442
# Episode: 443
# Episode: 444
# Episode: 445
# Episode: 446
# Episode: 447
# Episode: 448
# SOLVED! Episode 448 Steps: 3 Epsilon 0.2988
# Episode: 449
# Episode: 450
# Episode: 451
# Episode: 452
# Episode: 453
# SOLVED! Episode 453 Steps: 3 Epsilon 0.2988
# Episode: 454
# Episode: 455
# SOLVED! Episode 455 Steps: 3 Epsilon 0.2988
# Episode: 456
# Episode: 457
# Episode: 458
# SOLVED! Episode 458 Steps: 3 Epsilon 0.2988
# Episode: 459
# Episode: 460
# Episode: 461
# Episode: 462
# SOLVED! Episode 462 Steps: 2 Epsilon 0.2988
# Episode: 463
# Episode: 464
# SOLVED! Episode 464 Steps: 26 Epsilon 0.2988
# Episode: 465
# SOLVED! Episode 465 Steps: 3 Epsilon 0.2988
# Episode: 466
# SOLVED! Episode 466 Steps: 7 Epsilon 0.2988
# Episode: 467
# SOLVED! Episode 467 Steps: 18 Epsilon 0.2988
# Episode: 468
# Episode: 469
# Episode: 470
# Episode: 471
# Episode: 472
# Episode: 473
# SOLVED! Episode 473 Steps: 51 Epsilon 0.2988
# Episode: 474
# Episode: 475
# Episode: 476
# Episode: 477
# Episode: 478
# Episode: 479
# SOLVED! Episode 479 Steps: 3 Epsilon 0.2988
# Episode: 480
# Episode: 481
# Episode: 482
# Episode: 483
# Episode: 484
# Episode: 485
# Episode: 486
# Episode: 487
# Episode: 488
# SOLVED! Episode 488 Steps: 2 Epsilon 0.2988
# Episode: 489
# Episode: 490
# SOLVED! Episode 490 Steps: 8 Epsilon 0.2988
# Episode: 491
# Episode: 492
# Episode: 493
# SOLVED! Episode 493 Steps: 1 Epsilon 0.2988
# Episode: 494
# SOLVED! Episode 494 Steps: 3 Epsilon 0.2988
# Episode: 495
# SOLVED! Episode 495 Steps: 8 Epsilon 0.2988
# Episode: 496
# Episode: 497
# Episode: 498
# SOLVED! Episode 498 Steps: 12 Epsilon 0.2988
# Episode: 499
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 20
# ==============================
# defaultdict(<class 'int'>, {3: 10, 2: 3, 1: 7})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 24
# ==============================
# defaultdict(<class 'int'>, {3: 8, 19: 1, 2: 2, 1: 5, 7: 1, 10: 1, 15: 1, 4: 2, 5: 1, 12: 1, 14: 1})
# ******************************
# Episode: 500
# SOLVED! Episode 500 Steps: 2 Epsilon 0.2988
# Episode: 501
# Episode: 502
# Episode: 503
# SOLVED! Episode 503 Steps: 3 Epsilon 0.2988
# Episode: 504
# Episode: 505
# Episode: 506
# Episode: 507
# Episode: 508
# Episode: 509
# SOLVED! Episode 509 Steps: 84 Epsilon 0.2988
# Episode: 510
# SOLVED! Episode 510 Steps: 1 Epsilon 0.2988
# Episode: 511
# SOLVED! Episode 511 Steps: 2 Epsilon 0.2988
# Episode: 512
# SOLVED! Episode 512 Steps: 1 Epsilon 0.2988
# Episode: 513
# Episode: 514
# Episode: 515
# Episode: 516
# Episode: 517
# SOLVED! Episode 517 Steps: 30 Epsilon 0.2988
# Episode: 518
# Episode: 519
# Episode: 520
# SOLVED! Episode 520 Steps: 1 Epsilon 0.2988
# Episode: 521
# Episode: 522
# Episode: 523
# Episode: 524
# Episode: 525
# Episode: 526
# Episode: 527
# Episode: 528
# SOLVED! Episode 528 Steps: 1 Epsilon 0.2988
# Episode: 529
# Episode: 530
# SOLVED! Episode 530 Steps: 1 Epsilon 0.2988
# Episode: 531
# SOLVED! Episode 531 Steps: 2 Epsilon 0.2988
# Episode: 532
# Episode: 533
# Episode: 534
# Episode: 535
# Episode: 536
# SOLVED! Episode 536 Steps: 3 Epsilon 0.2988
# Episode: 537
# SOLVED! Episode 537 Steps: 72 Epsilon 0.2988
# Episode: 538
# Episode: 539
# SOLVED! Episode 539 Steps: 23 Epsilon 0.2988
# Episode: 540
# Episode: 541
# Episode: 542
# SOLVED! Episode 542 Steps: 35 Epsilon 0.2988
# Episode: 543
# Episode: 544
# Episode: 545
# Episode: 546
# Episode: 547
# Episode: 548
# SOLVED! Episode 548 Steps: 3 Epsilon 0.2988
# Episode: 549
# Episode: 550
# Episode: 551
# Episode: 552
# SOLVED! Episode 552 Steps: 42 Epsilon 0.2988
# Episode: 553
# Episode: 554
# Episode: 555
# SOLVED! Episode 555 Steps: 1 Epsilon 0.2988
# Episode: 556
# Episode: 557
# SOLVED! Episode 557 Steps: 2 Epsilon 0.2988
# Episode: 558
# Episode: 559
# Episode: 560
# SOLVED! Episode 560 Steps: 3 Epsilon 0.2988
# Episode: 561
# Episode: 562
# SOLVED! Episode 562 Steps: 36 Epsilon 0.2988
# Episode: 563
# SOLVED! Episode 563 Steps: 1 Epsilon 0.2988
# Episode: 564
# SOLVED! Episode 564 Steps: 3 Epsilon 0.2988
# Episode: 565
# Episode: 566
# Episode: 567
# Episode: 568
# Episode: 569
# SOLVED! Episode 569 Steps: 28 Epsilon 0.2988
# Episode: 570
# Episode: 571
# SOLVED! Episode 571 Steps: 2 Epsilon 0.2988
# Episode: 572
# Episode: 573
# Episode: 574
# Episode: 575
# Episode: 576
# SOLVED! Episode 576 Steps: 1 Epsilon 0.2988
# Episode: 577
# SOLVED! Episode 577 Steps: 3 Epsilon 0.2988
# Episode: 578
# Episode: 579
# Episode: 580
# SOLVED! Episode 580 Steps: 32 Epsilon 0.2988
# Episode: 581
# Episode: 582
# Episode: 583
# SOLVED! Episode 583 Steps: 72 Epsilon 0.2988
# Episode: 584
# Episode: 585
# Episode: 586
# SOLVED! Episode 586 Steps: 3 Epsilon 0.2988
# Episode: 587
# Episode: 588
# Episode: 589
# Episode: 590
# Episode: 591
# Episode: 592
# SOLVED! Episode 592 Steps: 2 Epsilon 0.2988
# Episode: 593
# Episode: 594
# Episode: 595
# Episode: 596
# SOLVED! Episode 596 Steps: 16 Epsilon 0.2988
# Episode: 597
# Episode: 598
# Episode: 599
# SOLVED! Episode 599 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 14
# ==============================
# defaultdict(<class 'int'>, {3: 8, 1: 4, 2: 2})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 14
# ==============================
# defaultdict(<class 'int'>, {4: 5, 1: 3, 6: 1, 3: 1, 2: 3, 14: 1})
# ******************************
# Episode: 600
# Episode: 601
# Episode: 602
# SOLVED! Episode 602 Steps: 1 Epsilon 0.2988
# Episode: 603
# SOLVED! Episode 603 Steps: 2 Epsilon 0.2988
# Episode: 604
# Episode: 605
# Episode: 606
# Episode: 607
# Episode: 608
# SOLVED! Episode 608 Steps: 1 Epsilon 0.2988
# Episode: 609
# SOLVED! Episode 609 Steps: 42 Epsilon 0.2988
# Episode: 610
# Episode: 611
# SOLVED! Episode 611 Steps: 33 Epsilon 0.2988
# Episode: 612
# Episode: 613
# SOLVED! Episode 613 Steps: 1 Epsilon 0.2988
# Episode: 614
# Episode: 615
# SOLVED! Episode 615 Steps: 32 Epsilon 0.2988
# Episode: 616
# Episode: 617
# Episode: 618
# Episode: 619
# Episode: 620
# SOLVED! Episode 620 Steps: 3 Epsilon 0.2988
# Episode: 621
# Episode: 622
# Episode: 623
# Episode: 624
# Episode: 625
# Episode: 626
# Episode: 627
# Episode: 628
# SOLVED! Episode 628 Steps: 3 Epsilon 0.2988
# Episode: 629
# Episode: 630
# Episode: 631
# Episode: 632
# SOLVED! Episode 632 Steps: 3 Epsilon 0.2988
# Episode: 633
# SOLVED! Episode 633 Steps: 14 Epsilon 0.2988
# Episode: 634
# Episode: 635
# SOLVED! Episode 635 Steps: 3 Epsilon 0.2988
# Episode: 636
# Episode: 637
# SOLVED! Episode 637 Steps: 1 Epsilon 0.2988
# Episode: 638
# Episode: 639
# Episode: 640
# SOLVED! Episode 640 Steps: 2 Epsilon 0.2988
# Episode: 641
# Episode: 642
# Episode: 643
# SOLVED! Episode 643 Steps: 3 Epsilon 0.2988
# Episode: 644
# Episode: 645
# Episode: 646
# Episode: 647
# Episode: 648
# Episode: 649
# SOLVED! Episode 649 Steps: 3 Epsilon 0.2988
# Episode: 650
# SOLVED! Episode 650 Steps: 3 Epsilon 0.2988
# Episode: 651
# Episode: 652
# SOLVED! Episode 652 Steps: 1 Epsilon 0.2988
# Episode: 653
# Episode: 654
# Episode: 655
# SOLVED! Episode 655 Steps: 3 Epsilon 0.2988
# Episode: 656
# SOLVED! Episode 656 Steps: 3 Epsilon 0.2988
# Episode: 657
# SOLVED! Episode 657 Steps: 3 Epsilon 0.2988
# Episode: 658
# Episode: 659
# SOLVED! Episode 659 Steps: 2 Epsilon 0.2988
# Episode: 660
# Episode: 661
# Episode: 662
# Episode: 663
# SOLVED! Episode 663 Steps: 76 Epsilon 0.2988
# Episode: 664
# SOLVED! Episode 664 Steps: 2 Epsilon 0.2988
# Episode: 665
# Episode: 666
# Episode: 667
# Episode: 668
# Episode: 669
# SOLVED! Episode 669 Steps: 3 Epsilon 0.2988
# Episode: 670
# Episode: 671
# Episode: 672
# Episode: 673
# Episode: 674
# SOLVED! Episode 674 Steps: 3 Epsilon 0.2988
# Episode: 675
# SOLVED! Episode 675 Steps: 2 Epsilon 0.2988
# Episode: 676
# SOLVED! Episode 676 Steps: 3 Epsilon 0.2988
# Episode: 677
# SOLVED! Episode 677 Steps: 2 Epsilon 0.2988
# Episode: 678
# Episode: 679
# SOLVED! Episode 679 Steps: 1 Epsilon 0.2988
# Episode: 680
# Episode: 681
# Episode: 682
# Episode: 683
# Episode: 684
# Episode: 685
# Episode: 686
# Episode: 687
# SOLVED! Episode 687 Steps: 33 Epsilon 0.2988
# Episode: 688
# Episode: 689
# Episode: 690
# Episode: 691
# Episode: 692
# Episode: 693
# Episode: 694
# Episode: 695
# Episode: 696
# Episode: 697
# SOLVED! Episode 697 Steps: 3 Epsilon 0.2988
# Episode: 698
# SOLVED! Episode 698 Steps: 1 Epsilon 0.2988
# Episode: 699
# SOLVED! Episode 699 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 23
# ==============================
# defaultdict(<class 'int'>, {3: 12, 2: 5, 1: 6})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 28
# ==============================
# defaultdict(<class 'int'>, {4: 4, 5: 6, 2: 5, 1: 5, 7: 4, 3: 2, 14: 1, 8: 1})
# ******************************
# Episode: 700
# Episode: 701
# Episode: 702
# SOLVED! Episode 702 Steps: 6 Epsilon 0.2988
# Episode: 703
# Episode: 704
# Episode: 705
# SOLVED! Episode 705 Steps: 35 Epsilon 0.2988
# Episode: 706
# Episode: 707
# Episode: 708
# Episode: 709
# Episode: 710
# Episode: 711
# SOLVED! Episode 711 Steps: 3 Epsilon 0.2988
# Episode: 712
# Episode: 713
# Episode: 714
# Episode: 715
# Episode: 716
# Episode: 717
# Episode: 718
# Episode: 719
# Episode: 720
# Episode: 721
# SOLVED! Episode 721 Steps: 2 Epsilon 0.2988
# Episode: 722
# Episode: 723
# Episode: 724
# Episode: 725
# SOLVED! Episode 725 Steps: 3 Epsilon 0.2988
# Episode: 726
# Episode: 727
# Episode: 728
# Episode: 729
# Episode: 730
# Episode: 731
# Episode: 732
# SOLVED! Episode 732 Steps: 87 Epsilon 0.2988
# Episode: 733
# Episode: 734
# Episode: 735
# Episode: 736
# Episode: 737
# Episode: 738
# Episode: 739
# Episode: 740
# SOLVED! Episode 740 Steps: 2 Epsilon 0.2988
# Episode: 741
# SOLVED! Episode 741 Steps: 97 Epsilon 0.2988
# Episode: 742
# SOLVED! Episode 742 Steps: 71 Epsilon 0.2988
# Episode: 743
# Episode: 744
# SOLVED! Episode 744 Steps: 1 Epsilon 0.2988
# Episode: 745
# SOLVED! Episode 745 Steps: 59 Epsilon 0.2988
# Episode: 746
# Episode: 747
# SOLVED! Episode 747 Steps: 96 Epsilon 0.2988
# Episode: 748
# Episode: 749
# Episode: 750
# Episode: 751
# SOLVED! Episode 751 Steps: 1 Epsilon 0.2988
# Episode: 752
# Episode: 753
# Episode: 754
# Episode: 755
# SOLVED! Episode 755 Steps: 1 Epsilon 0.2988
# Episode: 756
# Episode: 757
# SOLVED! Episode 757 Steps: 42 Epsilon 0.2988
# Episode: 758
# SOLVED! Episode 758 Steps: 28 Epsilon 0.2988
# Episode: 759
# SOLVED! Episode 759 Steps: 2 Epsilon 0.2988
# Episode: 760
# Episode: 761
# SOLVED! Episode 761 Steps: 3 Epsilon 0.2988
# Episode: 762
# SOLVED! Episode 762 Steps: 3 Epsilon 0.2988
# Episode: 763
# Episode: 764
# Episode: 765
# Episode: 766
# SOLVED! Episode 766 Steps: 3 Epsilon 0.2988
# Episode: 767
# SOLVED! Episode 767 Steps: 35 Epsilon 0.2988
# Episode: 768
# Episode: 769
# Episode: 770
# SOLVED! Episode 770 Steps: 7 Epsilon 0.2988
# Episode: 771
# Episode: 772
# Episode: 773
# SOLVED! Episode 773 Steps: 3 Epsilon 0.2988
# Episode: 774
# Episode: 775
# SOLVED! Episode 775 Steps: 1 Epsilon 0.2988
# Episode: 776
# Episode: 777
# SOLVED! Episode 777 Steps: 68 Epsilon 0.2988
# Episode: 778
# SOLVED! Episode 778 Steps: 3 Epsilon 0.2988
# Episode: 779
# Episode: 780
# Episode: 781
# SOLVED! Episode 781 Steps: 1 Epsilon 0.2988
# Episode: 782
# Episode: 783
# SOLVED! Episode 783 Steps: 23 Epsilon 0.2988
# Episode: 784
# Episode: 785
# Episode: 786
# Episode: 787
# Episode: 788
# Episode: 789
# Episode: 790
# Episode: 791
# Episode: 792
# SOLVED! Episode 792 Steps: 1 Epsilon 0.2988
# Episode: 793
# Episode: 794
# SOLVED! Episode 794 Steps: 1 Epsilon 0.2988
# Episode: 795
# Episode: 796
# Episode: 797
# SOLVED! Episode 797 Steps: 3 Epsilon 0.2988
# Episode: 798
# Episode: 799
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 24
# ==============================
# defaultdict(<class 'int'>, {3: 11, 2: 4, 1: 9})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 23
# ==============================
# defaultdict(<class 'int'>, {4: 9, 2: 6, 5: 3, 11: 1, 20: 1, 9: 1, 3: 1, 7: 1})
# ******************************
# Episode: 800
# SOLVED! Episode 800 Steps: 16 Epsilon 0.2988
# Episode: 801
# SOLVED! Episode 801 Steps: 61 Epsilon 0.2988
# Episode: 802
# Episode: 803
# Episode: 804
# Episode: 805
# Episode: 806
# SOLVED! Episode 806 Steps: 3 Epsilon 0.2988
# Episode: 807
# Episode: 808
# Episode: 809
# Episode: 810
# SOLVED! Episode 810 Steps: 92 Epsilon 0.2988
# Episode: 811
# Episode: 812
# Episode: 813
# SOLVED! Episode 813 Steps: 1 Epsilon 0.2988
# Episode: 814
# Episode: 815
# Episode: 816
# Episode: 817
# Episode: 818
# Episode: 819
# Episode: 820
# Episode: 821
# SOLVED! Episode 821 Steps: 1 Epsilon 0.2988
# Episode: 822
# Episode: 823
# Episode: 824
# Episode: 825
# Episode: 826
# Episode: 827
# SOLVED! Episode 827 Steps: 13 Epsilon 0.2988
# Episode: 828
# Episode: 829
# Episode: 830
# Episode: 831
# Episode: 832
# SOLVED! Episode 832 Steps: 7 Epsilon 0.2988
# Episode: 833
# Episode: 834
# Episode: 835
# Episode: 836
# Episode: 837
# SOLVED! Episode 837 Steps: 47 Epsilon 0.2988
# Episode: 838
# Episode: 839
# Episode: 840
# Episode: 841
# SOLVED! Episode 841 Steps: 1 Epsilon 0.2988
# Episode: 842
# Episode: 843
# Episode: 844
# SOLVED! Episode 844 Steps: 3 Epsilon 0.2988
# Episode: 845
# Episode: 846
# Episode: 847
# Episode: 848
# Episode: 849
# Episode: 850
# SOLVED! Episode 850 Steps: 3 Epsilon 0.2988
# Episode: 851
# Episode: 852
# Episode: 853
# Episode: 854
# SOLVED! Episode 854 Steps: 3 Epsilon 0.2988
# Episode: 855
# Episode: 856
# Episode: 857
# Episode: 858
# Episode: 859
# SOLVED! Episode 859 Steps: 1 Epsilon 0.2988
# Episode: 860
# Episode: 861
# SOLVED! Episode 861 Steps: 3 Epsilon 0.2988
# Episode: 862
# Episode: 863
# Episode: 864
# Episode: 865
# SOLVED! Episode 865 Steps: 21 Epsilon 0.2988
# Episode: 866
# Episode: 867
# Episode: 868
# SOLVED! Episode 868 Steps: 89 Epsilon 0.2988
# Episode: 869
# Episode: 870
# Episode: 871
# SOLVED! Episode 871 Steps: 2 Epsilon 0.2988
# Episode: 872
# Episode: 873
# SOLVED! Episode 873 Steps: 2 Epsilon 0.2988
# Episode: 874
# Episode: 875
# Episode: 876
# Episode: 877
# Episode: 878
# Episode: 879
# Episode: 880
# SOLVED! Episode 880 Steps: 18 Epsilon 0.2988
# Episode: 881
# Episode: 882
# Episode: 883
# SOLVED! Episode 883 Steps: 32 Epsilon 0.2988
# Episode: 884
# Episode: 885
# SOLVED! Episode 885 Steps: 37 Epsilon 0.2988
# Episode: 886
# Episode: 887
# Episode: 888
# Episode: 889
# Episode: 890
# Episode: 891
# Episode: 892
# Episode: 893
# Episode: 894
# SOLVED! Episode 894 Steps: 3 Epsilon 0.2988
# Episode: 895
# Episode: 896
# SOLVED! Episode 896 Steps: 2 Epsilon 0.2988
# Episode: 897
# SOLVED! Episode 897 Steps: 1 Epsilon 0.2988
# Episode: 898
# Episode: 899
# SOLVED! Episode 899 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 21
# ==============================
# defaultdict(<class 'int'>, {3: 11, 1: 7, 2: 3})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 27
# ==============================
# defaultdict(<class 'int'>, {4: 8, 1: 3, 2: 5, 7: 4, 5: 1, 20: 1, 9: 1, 11: 1, 14: 2, 3: 1})
# ******************************
# Episode: 900
# Episode: 901
# Episode: 902
# SOLVED! Episode 902 Steps: 3 Epsilon 0.2988
# Episode: 903
# Episode: 904
# Episode: 905
# Episode: 906
# Episode: 907
# Episode: 908
# Episode: 909
# SOLVED! Episode 909 Steps: 36 Epsilon 0.2988
# Episode: 910
# Episode: 911
# SOLVED! Episode 911 Steps: 2 Epsilon 0.2988
# Episode: 912
# Episode: 913
# Episode: 914
# Episode: 915
# Episode: 916
# Episode: 917
# Episode: 918
# Episode: 919
# Episode: 920
# SOLVED! Episode 920 Steps: 2 Epsilon 0.2988
# Episode: 921
# Episode: 922
# Episode: 923
# Episode: 924
# Episode: 925
# Episode: 926
# SOLVED! Episode 926 Steps: 7 Epsilon 0.2988
# Episode: 927
# Episode: 928
# Episode: 929
# Episode: 930
# Episode: 931
# Episode: 932
# Episode: 933
# Episode: 934
# SOLVED! Episode 934 Steps: 2 Epsilon 0.2988
# Episode: 935
# Episode: 936
# SOLVED! Episode 936 Steps: 3 Epsilon 0.2988
# Episode: 937
# SOLVED! Episode 937 Steps: 2 Epsilon 0.2988
# Episode: 938
# SOLVED! Episode 938 Steps: 1 Epsilon 0.2988
# Episode: 939
# Episode: 940
# Episode: 941
# Episode: 942
# Episode: 943
# Episode: 944
# SOLVED! Episode 944 Steps: 3 Epsilon 0.2988
# Episode: 945
# SOLVED! Episode 945 Steps: 3 Epsilon 0.2988
# Episode: 946
# Episode: 947
# SOLVED! Episode 947 Steps: 26 Epsilon 0.2988
# Episode: 948
# Episode: 949
# SOLVED! Episode 949 Steps: 2 Epsilon 0.2988
# Episode: 950
# Episode: 951
# Episode: 952
# SOLVED! Episode 952 Steps: 85 Epsilon 0.2988
# Episode: 953
# Episode: 954
# Episode: 955
# Episode: 956
# Episode: 957
# Episode: 958
# Episode: 959
# SOLVED! Episode 959 Steps: 3 Epsilon 0.2988
# Episode: 960
# Episode: 961
# Episode: 962
# Episode: 963
# Episode: 964
# Episode: 965
# Episode: 966
# Episode: 967
# SOLVED! Episode 967 Steps: 1 Epsilon 0.2988
# Episode: 968
# Episode: 969
# SOLVED! Episode 969 Steps: 53 Epsilon 0.2988
# Episode: 970
# Episode: 971
# Episode: 972
# Episode: 973
# Episode: 974
# Episode: 975
# Episode: 976
# Episode: 977
# SOLVED! Episode 977 Steps: 3 Epsilon 0.2988
# Episode: 978
# SOLVED! Episode 978 Steps: 1 Epsilon 0.2988
# Episode: 979
# Episode: 980
# SOLVED! Episode 980 Steps: 2 Epsilon 0.2988
# Episode: 981
# Episode: 982
# SOLVED! Episode 982 Steps: 3 Epsilon 0.2988
# Episode: 983
# Episode: 984
# Episode: 985
# Episode: 986
# Episode: 987
# Episode: 988
# SOLVED! Episode 988 Steps: 3 Epsilon 0.2988
# Episode: 989
# Episode: 990
# Episode: 991
# Episode: 992
# SOLVED! Episode 992 Steps: 1 Epsilon 0.2988
# Episode: 993
# Episode: 994
# Episode: 995
# SOLVED! Episode 995 Steps: 1 Epsilon 0.2988
# Episode: 996
# Episode: 997
# SOLVED! Episode 997 Steps: 66 Epsilon 0.2988
# Episode: 998
# Episode: 999
# SOLVED! Episode 999 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 23
# ==============================
# defaultdict(<class 'int'>, {3: 8, 2: 5, 1: 10})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 27
# ==============================
# defaultdict(<class 'int'>, {4: 10, 2: 4, 3: 2, 20: 1, 7: 4, 12: 1, 1: 1, 8: 1, 14: 1, 9: 2})
# ******************************
# Episode: 1000
# SOLVED! Episode 1000 Steps: 3 Epsilon 0.2988
# Episode: 1001
# Episode: 1002
# SOLVED! Episode 1002 Steps: 42 Epsilon 0.2988
# Episode: 1003
# Episode: 1004
# Episode: 1005
# SOLVED! Episode 1005 Steps: 2 Epsilon 0.2988
# Episode: 1006
# Episode: 1007
# Episode: 1008
# Episode: 1009
# Episode: 1010
# Episode: 1011
# Episode: 1012
# Episode: 1013
# SOLVED! Episode 1013 Steps: 3 Epsilon 0.2988
# Episode: 1014
# Episode: 1015
# Episode: 1016
# Episode: 1017
# Episode: 1018
# SOLVED! Episode 1018 Steps: 36 Epsilon 0.2988
# Episode: 1019
# Episode: 1020
# Episode: 1021
# Episode: 1022
# Episode: 1023
# Episode: 1024
# Episode: 1025
# Episode: 1026
# Episode: 1027
# Episode: 1028
# SOLVED! Episode 1028 Steps: 2 Epsilon 0.2988
# Episode: 1029
# SOLVED! Episode 1029 Steps: 3 Epsilon 0.2988
# Episode: 1030
# Episode: 1031
# Episode: 1032
# Episode: 1033
# SOLVED! Episode 1033 Steps: 29 Epsilon 0.2988
# Episode: 1034
# SOLVED! Episode 1034 Steps: 62 Epsilon 0.2988
# Episode: 1035
# Episode: 1036
# SOLVED! Episode 1036 Steps: 2 Epsilon 0.2988
# Episode: 1037
# Episode: 1038
# Episode: 1039
# Episode: 1040
# Episode: 1041
# Episode: 1042
# Episode: 1043
# Episode: 1044
# SOLVED! Episode 1044 Steps: 1 Epsilon 0.2988
# Episode: 1045
# Episode: 1046
# Episode: 1047
# Episode: 1048
# Episode: 1049
# Episode: 1050
# Episode: 1051
# Episode: 1052
# SOLVED! Episode 1052 Steps: 3 Epsilon 0.2988
# Episode: 1053
# Episode: 1054
# Episode: 1055
# Episode: 1056
# Episode: 1057
# Episode: 1058
# Episode: 1059
# Episode: 1060
# Episode: 1061
# Episode: 1062
# Episode: 1063
# SOLVED! Episode 1063 Steps: 1 Epsilon 0.2988
# Episode: 1064
# SOLVED! Episode 1064 Steps: 7 Epsilon 0.2988
# Episode: 1065
# Episode: 1066
# Episode: 1067
# Episode: 1068
# Episode: 1069
# Episode: 1070
# Episode: 1071
# Episode: 1072
# Episode: 1073
# SOLVED! Episode 1073 Steps: 3 Epsilon 0.2988
# Episode: 1074
# Episode: 1075
# Episode: 1076
# Episode: 1077
# Episode: 1078
# SOLVED! Episode 1078 Steps: 2 Epsilon 0.2988
# Episode: 1079
# Episode: 1080
# SOLVED! Episode 1080 Steps: 18 Epsilon 0.2988
# Episode: 1081
# Episode: 1082
# SOLVED! Episode 1082 Steps: 2 Epsilon 0.2988
# Episode: 1083
# SOLVED! Episode 1083 Steps: 2 Epsilon 0.2988
# Episode: 1084
# SOLVED! Episode 1084 Steps: 3 Epsilon 0.2988
# Episode: 1085
# SOLVED! Episode 1085 Steps: 2 Epsilon 0.2988
# Episode: 1086
# SOLVED! Episode 1086 Steps: 2 Epsilon 0.2988
# Episode: 1087
# Episode: 1088
# Episode: 1089
# Episode: 1090
# Episode: 1091
# Episode: 1092
# Episode: 1093
# Episode: 1094
# Episode: 1095
# Episode: 1096
# SOLVED! Episode 1096 Steps: 20 Epsilon 0.2988
# Episode: 1097
# Episode: 1098
# Episode: 1099
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 26
# ==============================
# defaultdict(<class 'int'>, {3: 11, 2: 5, 1: 10})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 33
# ==============================
# defaultdict(<class 'int'>, {5: 5, 7: 3, 12: 1, 4: 5, 2: 7, 1: 6, 3: 5, 6: 1})
# ******************************
# Episode: 1100
# Episode: 1101
# SOLVED! Episode 1101 Steps: 1 Epsilon 0.2988
# Episode: 1102
# Episode: 1103
# SOLVED! Episode 1103 Steps: 2 Epsilon 0.2988
# Episode: 1104
# Episode: 1105
# Episode: 1106
# Episode: 1107
# Episode: 1108
# SOLVED! Episode 1108 Steps: 3 Epsilon 0.2988
# Episode: 1109
# Episode: 1110
# SOLVED! Episode 1110 Steps: 3 Epsilon 0.2988
# Episode: 1111
# Episode: 1112
# Episode: 1113
# Episode: 1114
# Episode: 1115
# Episode: 1116
# SOLVED! Episode 1116 Steps: 18 Epsilon 0.2988
# Episode: 1117
# Episode: 1118
# SOLVED! Episode 1118 Steps: 60 Epsilon 0.2988
# Episode: 1119
# Episode: 1120
# SOLVED! Episode 1120 Steps: 32 Epsilon 0.2988
# Episode: 1121
# SOLVED! Episode 1121 Steps: 1 Epsilon 0.2988
# Episode: 1122
# Episode: 1123
# Episode: 1124
# Episode: 1125
# Episode: 1126
# Episode: 1127
# Episode: 1128
# Episode: 1129
# Episode: 1130
# Episode: 1131
# Episode: 1132
# Episode: 1133
# Episode: 1134
# Episode: 1135
# Episode: 1136
# Episode: 1137
# Episode: 1138
# SOLVED! Episode 1138 Steps: 1 Epsilon 0.2988
# Episode: 1139
# Episode: 1140
# Episode: 1141
# Episode: 1142
# Episode: 1143
# Episode: 1144
# Episode: 1145
# Episode: 1146
# Episode: 1147
# SOLVED! Episode 1147 Steps: 3 Epsilon 0.2988
# Episode: 1148
# Episode: 1149
# Episode: 1150
# SOLVED! Episode 1150 Steps: 1 Epsilon 0.2988
# Episode: 1151
# Episode: 1152
# Episode: 1153
# Episode: 1154
# Episode: 1155
# SOLVED! Episode 1155 Steps: 95 Epsilon 0.2988
# Episode: 1156
# Episode: 1157
# SOLVED! Episode 1157 Steps: 1 Epsilon 0.2988
# Episode: 1158
# Episode: 1159
# SOLVED! Episode 1159 Steps: 3 Epsilon 0.2988
# Episode: 1160
# Episode: 1161
# SOLVED! Episode 1161 Steps: 1 Epsilon 0.2988
# Episode: 1162
# Episode: 1163
# SOLVED! Episode 1163 Steps: 1 Epsilon 0.2988
# Episode: 1164
# SOLVED! Episode 1164 Steps: 3 Epsilon 0.2988
# Episode: 1165
# Episode: 1166
# Episode: 1167
# Episode: 1168
# SOLVED! Episode 1168 Steps: 1 Epsilon 0.2988
# Episode: 1169
# Episode: 1170
# Episode: 1171
# SOLVED! Episode 1171 Steps: 2 Epsilon 0.2988
# Episode: 1172
# Episode: 1173
# Episode: 1174
# Episode: 1175
# Episode: 1176
# Episode: 1177
# Episode: 1178
# Episode: 1179
# Episode: 1180
# SOLVED! Episode 1180 Steps: 65 Epsilon 0.2988
# Episode: 1181
# Episode: 1182
# SOLVED! Episode 1182 Steps: 75 Epsilon 0.2988
# Episode: 1183
# Episode: 1184
# SOLVED! Episode 1184 Steps: 1 Epsilon 0.2988
# Episode: 1185
# SOLVED! Episode 1185 Steps: 2 Epsilon 0.2988
# Episode: 1186
# Episode: 1187
# Episode: 1188
# Episode: 1189
# Episode: 1190
# Episode: 1191
# SOLVED! Episode 1191 Steps: 3 Epsilon 0.2988
# Episode: 1192
# Episode: 1193
# SOLVED! Episode 1193 Steps: 1 Epsilon 0.2988
# Episode: 1194
# SOLVED! Episode 1194 Steps: 1 Epsilon 0.2988
# Episode: 1195
# Episode: 1196
# Episode: 1197
# Episode: 1198
# Episode: 1199
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 24
# ==============================
# defaultdict(<class 'int'>, {3: 10, 1: 8, 2: 6})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
