# %% [markdown]
# # Final Project - Reinforcements Learning
# Hello dear students,<br> this is the template notebook. Please click on the "File" tab and then on "Save a copy into drive".
#
# ---
# <br>
#
# ### Name and ID:
# Student 1: Avraham Raviv, 204355390
# <br>
# Student 2: Yevgeni Berkovitch, 317079234
# <br><br>
# <img src="https://play-lh.googleusercontent.com/e_oKlKPISbgdzut1H9opevS7-LTB8-8lsmpCdMkhlnqFenZhpjxbLmx7l158-xQQCIY">
#
# ### https://github.com/mpSchrader/gym-sokoban

# %% [markdown]
# # Installs

# %%
# %%capture
# !sudo apt-get update
# !sudo apt-get install -y xvfb ffmpeg freeglut3-dev
# !pip install 'imageio==2.4.0'
# !pip install gym
# !pip install pygame
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet
# !pip install gym
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install gym_sokoban

# !imageio_download_bin ffmpeg

# %% [markdown]
# # Imports

# %%
import random
import time

import numpy as np
import scipy as scp
import matplotlib.pyplot as plt

import base64
import imageio
from pyvirtualdisplay import Display
from IPython.display import HTML

import gym
from gym import error, spaces, utils
from soko_pap import *

from collections import deque
from queue import PriorityQueue

from keras.models import Sequential
from keras.layers import Dense

from tqdm.notebook import tqdm
from collections import defaultdict

# %%
# %matplotlib inline

# %%
imageio.plugins.ffmpeg.download()

# %%
from gym import logger as gymlogger
gymlogger.set_level(40) # error only

# %% [markdown]
# # Display utils
# The cell below contains the video display configuration. No need to make changes here.

# %%
def embed_mp4(filename):
    """Embeds an mp4 file in the notebook."""
    video = open(filename,'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())

    return HTML(tag)

# %% [markdown]
# # Utils

# %%
def get_distances(room_state):
    for i in range(room_state.shape[0]):
        for j in range(room_state.shape[1]):
            if room_state[i][j] == 2:
                target = (i, j)

    distances = np.zeros(shape=room_state.shape)
    visited_cells = set()
    cell_queue = deque()

    visited_cells.add(target)
    cell_queue.appendleft(target)

    while len(cell_queue) != 0:
        cell = cell_queue.pop()
        distance = distances[cell[0]][cell[1]]
        for x,y in ((1,0), (-1,-0), (0,1), (0,-1)):
            next_cell_x, next_cell_y = cell[0]+x, cell[1]+y
            if room_state[next_cell_x][next_cell_y] != 0 and not (next_cell_x, next_cell_y) in visited_cells:
                distances[next_cell_x][next_cell_y] = distance + 1
                visited_cells.add((next_cell_x, next_cell_y))
                cell_queue.appendleft((next_cell_x, next_cell_y))
                
    return distances   

def calc_distances(room_state, distances):
    box = None
    mover = None
    for i in range(room_state.shape[0]):
        for j in range(room_state.shape[1]):            
            if room_state[i][j] == 4:
                box = (i,j)
            
            if room_state[i][j] == 5:
                mover = (i,j)
    
    return mover, box, distances[box[0]][box[1]]   

def box2target_change_reward(room_state, next_room_state, distances):
    if np.array_equal(room_state, next_room_state):
        return -1.0
    
    mover, box, t2b = calc_distances(room_state, distances)
    n_mover, n_box, n_t2b = calc_distances(next_room_state, distances)
    
    change_reward = 0.0
    if n_t2b < t2b:
        change_reward += 5.0
    elif n_t2b > t2b:
        change_reward -= 5.0
        
    m2b = np.sqrt((mover[0]-box[0])**2 + (mover[1]-box[1])**2)
    n_m2b = np.sqrt((n_mover[0]-n_box[0])**2 + (n_mover[1]-n_box[1])**2)
    
    if n_m2b < m2b and m2b >= 2:
        change_reward += 1.0
    elif n_m2b > m2b and n_m2b >= 2:
        change_reward -= 1.0
        
    return change_reward

# %%
import numpy as np
x = np.array([[1,2],[3,4]])
tuple(x.flatten())
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# # Solution

# %%
class SOK_Agent:
    def __init__(self):
        # Construct DQN models
        self.state_size = (25,) 
        self.action_size = 8
        self.model = self._build_model()
        self.target_model = self._build_model()
        self.target_model.set_weights(self.model.get_weights())
        self.batch_size = 8
        
        # Replay buffers
        self.replay_buffer = deque(maxlen=5000)
        self.prioritized_replay_buffer = deque(maxlen=500)
        
        # Hyperparameters
        self.gamma = 0.9
        self.epsilon = 1.0   
        self.epsilon_min = 0.3
        self.epsilon_decay = 0.995
        self.replay_rate = 10
        self.update_beta = 0.999

        self.verbosity = 100 

    def _build_model(self):
        model = Sequential()
        model.add(Dense(25, input_shape=self.state_size, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer="adam")        
        return model

    def remember(self, state, action, reward, next_state, done):
        self.replay_buffer.append([state, action, reward, next_state, done])    
        
    def copy_to_prioritized_buffer(self, n):
        episode_memory = []
        states_counter = defaultdict(int)
                
        for i in range(n):
            state, action, reward, next_state, done = self.replay_buffer[-n+i]
            episode_memory.append((state, action, reward, next_state, done))
            states_counter[tuple(state.flatten())] += 1
        
        i = 0
        while i < len(episode_memory):
            state, action, reward, next_state, done = episode_memory[i]
            state_key = tuple(state.flatten())
            states_counter[state_key] -= 1
            i += 1
            
            if states_counter[state_key] > 0:                  
                while True:
                    state, action, reward, next_state, done = episode_memory[i]
                    if state_key == tuple(state.flatten()):
                        break
                        
                    states_counter[tuple(state.flatten())] -= 1
                    i += 1
            else:
                self.prioritized_replay_buffer.append((state, action, reward, next_state, done))  

    def act(self, state, stochastic=False):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        
        act_values = self.model.predict(state, verbose=0)[0]
        
        if stochastic:
            act_probs = np.exp(act_values)/np.exp(act_values).sum()
            return np.random.choice(np.arange(self.action_size), size=1, p=act_probs)[0]
              
        return np.argmax(act_values) 

    def replay(self): 
        if len(self.replay_buffer) < self.batch_size:
            return
        
        if len(self.prioritized_replay_buffer) < self.batch_size//2:
            minibatch = random.sample(self.replay_buffer, self.batch_size) 
        else:    
            minibatch = random.sample(self.replay_buffer, self.batch_size//2) 
            minibatch.extend(random.sample(self.prioritized_replay_buffer, self.batch_size//2))
        
        states = np.zeros((self.batch_size, self.state_size[0]))
        actions = np.zeros(self.batch_size, dtype=int)
        rewards = np.zeros(self.batch_size)
        next_states = np.zeros((self.batch_size, self.state_size[0]))
        statuses = np.zeros(self.batch_size)
        targets = np.zeros((self.batch_size, self.action_size)) 
        
        for i, (state, action, reward, next_state, done) in enumerate(minibatch): 
            states[i] = state.copy()
            actions[i] = action
            rewards[i] = reward
            next_states[i] = next_state.copy()
            statuses[i] = 1 if done else 0    
        
        targets = self.model.predict(states) 
        max_actions = np.argmax(self.model.predict(next_states), axis=1)
        next_rewards = self.target_model.predict(next_states)
        
        ind = 0
        for action, reward, next_reward, max_action, done in zip(actions, rewards, next_rewards, max_actions, statuses):  
            if not done:
                reward += self.gamma * next_reward[max_action]
            targets[ind][action] = reward
            ind += 1
        
        self.model.fit(states, targets, epochs=10, verbose=0) 
        
        self.update_target_model()        
    
        if self.epsilon > self.epsilon_min:
            self.epsilon = self.epsilon * self.epsilon_decay
        
    def update_target_model(self):
        model_w = self.model.get_weights()
        target_model_w = self.target_model.get_weights()
        updated_target_model_w = []
        for i in range(len(model_w)):
            updated_target_model_w.append(self.update_beta*target_model_w[i] + (1-self.update_beta)*model_w[i])
        self.target_model.set_weights(updated_target_model_w)    
            
    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

# %%
def process_frame(frame):
    f = frame[16:96, 16:96, 0]   
    f = f.reshape(5, 16, 5, 16).max(axis=(1, 3))
    f = f.flatten()
    f = f / 255
    return np.expand_dims(f, axis=0)

# %% [markdown]
# ## Training

# %% [markdown]
# #### Test Suite

# %%
def test_agent(stochastic=False):
    current_epsilon = agent.epsilon
    agent.epsilon = 0.0
    num_solved = 0
    solved_in_steps = defaultdict(int)

    for t in tqdm(range(100)):    
        random.seed(t)
        sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
        sok.set_maxsteps(20)
        steps = 0

        state = sok.get_image('rgb_array')
        done = False
        while not done:
            steps += 1
            action = agent.act(process_frame(state), stochastic)
            if action < 4:
                action += 1
            else:
                action += 5
            state, reward, done, info = sok.step(action)

        if 3 in sok.room_state:            
            num_solved += 1
            solved_in_steps[steps] += 1
    
    agent.epsilon = current_epsilon
    print("*" * 30)
    print("Stochastic" if stochastic else "Deterministic")
    print("*" * 30)
    print("Solved: %d" % num_solved)
    print("=" * 30)
    print(solved_in_steps)
    print("*" * 30)

# %%
max_episodes = 10000
max_steps = 50

def init_sok(r):
    random.seed(r+100)
    sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
    sok.set_maxsteps(max_steps)
    return sok

# %%
agent = SOK_Agent()

steps_per_episode = []

for e in range(max_episodes):
    if e % 100 == 0 and e > 0:
        test_agent(stochastic=False)
        
    print("Episode: %d" % (e+1))
    
    sok = init_sok(e)
    random.seed(e)
    
    state = process_frame(sok.get_image('rgb_array'))
    room_state = sok.room_state.copy() 
    distances = get_distances(room_state)
    
    for step in range(sok.max_steps):
        action = agent.act(state)
        if action < 4:
            next_state, reward, done, _ = sok.step(action+1) 
        else:
            next_state, reward, done, _ = sok.step(action+5)         
        
        next_state = process_frame(next_state)        
        next_room_state = sok.room_state
        
        if not done:
            reward += box2target_change_reward(room_state, next_room_state, distances)
        
        agent.remember(state, action, reward, next_state, done)
        
        state = next_state.copy() 
        room_state = next_room_state.copy()                
        
        if (step+1) % agent.replay_rate == 0:
            agent.replay()            
        
        if done:   
            steps_per_episode.append(step+1)
            
            if 3 in sok.room_state:                
                print("SOLVED! Episode %d Steps: %d Epsilon %.4f" % (e+1, step+1, agent.epsilon)) 
                agent.copy_to_prioritized_buffer(step+1)
            
            #agent.save("exp1_episode%d.h5" % (e))            
            break
# Out:
# Episode: 1
# Episode: 2
# Episode: 3
# Episode: 4
# Episode: 5
# Episode: 6
# SOLVED! Episode 6 Steps: 31 Epsilon 0.8691
# Episode: 7
# Episode: 8
# SOLVED! Episode 8 Steps: 7 Epsilon 0.8475
# Episode: 9
# Episode: 10
# Episode: 11
# Episode: 12
# SOLVED! Episode 12 Steps: 10 Epsilon 0.7822
# Episode: 13
# Episode: 14
# Episode: 15
# SOLVED! Episode 15 Steps: 1 Epsilon 0.7440
# Episode: 16
# Episode: 17
# Episode: 18
# Episode: 19
# Episode: 20
# Episode: 21
# Episode: 22
# Episode: 23
# Episode: 24
# Episode: 25
# Episode: 26
# SOLVED! Episode 26 Steps: 37 Epsilon 0.5704
# Episode: 27
# SOLVED! Episode 27 Steps: 5 Epsilon 0.5704
# Episode: 28
# Episode: 29
# Episode: 30
# Episode: 31
# Episode: 32
# Episode: 33
# Episode: 34
# Episode: 35
# Episode: 36
# Episode: 37
# Episode: 38
# Episode: 39
# Episode: 40
# Episode: 41
# Episode: 42
# Episode: 43
# Episode: 44
# Episode: 45
# Episode: 46
# Episode: 47
# Episode: 48
# SOLVED! Episode 48 Steps: 35 Epsilon 0.3404
# Episode: 49
# Episode: 50
# Episode: 51
# Episode: 52
# Episode: 53
# Episode: 54
# Episode: 55
# Episode: 56
# Episode: 57
# Episode: 58
# SOLVED! Episode 58 Steps: 50 Epsilon 0.2988
# Episode: 59
# Episode: 60
# SOLVED! Episode 60 Steps: 43 Epsilon 0.2988
# Episode: 61
# Episode: 62
# Episode: 63
# Episode: 64
# Episode: 65
# SOLVED! Episode 65 Steps: 3 Epsilon 0.2988
# Episode: 66
# Episode: 67
# Episode: 68
# Episode: 69
# SOLVED! Episode 69 Steps: 3 Epsilon 0.2988
# Episode: 70
# Episode: 71
# Episode: 72
# Episode: 73
# Episode: 74
# Episode: 75
# Episode: 76
# SOLVED! Episode 76 Steps: 2 Epsilon 0.2988
# Episode: 77
# Episode: 78
# Episode: 79
# Episode: 80
# SOLVED! Episode 80 Steps: 33 Epsilon 0.2988
# Episode: 81
# Episode: 82
# Episode: 83
# Episode: 84
# Episode: 85
# Episode: 86
# Episode: 87
# Episode: 88
# Episode: 89
# SOLVED! Episode 89 Steps: 2 Epsilon 0.2988
# Episode: 90
# Episode: 91
# Episode: 92
# SOLVED! Episode 92 Steps: 1 Epsilon 0.2988
# Episode: 93
# Episode: 94
# Episode: 95
# SOLVED! Episode 95 Steps: 1 Epsilon 0.2988
# Episode: 96
# SOLVED! Episode 96 Steps: 8 Epsilon 0.2988
# Episode: 97
# Episode: 98
# Episode: 99
# Episode: 100
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 18
# ==============================
# defaultdict(<class 'int'>, {3: 9, 1: 5, 2: 4})
# ******************************
# Episode: 101
# Episode: 102
# Episode: 103
# SOLVED! Episode 103 Steps: 33 Epsilon 0.2988
# Episode: 104
# Episode: 105
# Episode: 106
# Episode: 107
# Episode: 108
# Episode: 109
# Episode: 110
# SOLVED! Episode 110 Steps: 7 Epsilon 0.2988
# Episode: 111
# Episode: 112
# Episode: 113
# Episode: 114
# Episode: 115
# SOLVED! Episode 115 Steps: 36 Epsilon 0.2988
# Episode: 116
# Episode: 117
# Episode: 118
# Episode: 119
# Episode: 120
# Episode: 121
# SOLVED! Episode 121 Steps: 3 Epsilon 0.2988
# Episode: 122
# Episode: 123
# Episode: 124
# SOLVED! Episode 124 Steps: 3 Epsilon 0.2988
# Episode: 125
# Episode: 126
# Episode: 127
# Episode: 128
# SOLVED! Episode 128 Steps: 2 Epsilon 0.2988
# Episode: 129
# SOLVED! Episode 129 Steps: 2 Epsilon 0.2988
# Episode: 130
# SOLVED! Episode 130 Steps: 1 Epsilon 0.2988
# Episode: 131
# Episode: 132
# Episode: 133
# Episode: 134
# SOLVED! Episode 134 Steps: 3 Epsilon 0.2988
# Episode: 135
# Episode: 136
# Episode: 137
# Episode: 138
# Episode: 139
# Episode: 140
# Episode: 141
# Episode: 142
# SOLVED! Episode 142 Steps: 3 Epsilon 0.2988
# Episode: 143
# Episode: 144
# SOLVED! Episode 144 Steps: 3 Epsilon 0.2988
# Episode: 145
# Episode: 146
# Episode: 147
# Episode: 148
# Episode: 149
# Episode: 150
# Episode: 151
# SOLVED! Episode 151 Steps: 2 Epsilon 0.2988
# Episode: 152
# Episode: 153
# Episode: 154
# Episode: 155
# Episode: 156
# Episode: 157
# Episode: 158
# SOLVED! Episode 158 Steps: 18 Epsilon 0.2988
# Episode: 159
# Episode: 160
# Episode: 161
# SOLVED! Episode 161 Steps: 32 Epsilon 0.2988
# Episode: 162
# SOLVED! Episode 162 Steps: 2 Epsilon 0.2988
# Episode: 163
# Episode: 164
# Episode: 165
# Episode: 166
# Episode: 167
# SOLVED! Episode 167 Steps: 2 Epsilon 0.2988
# Episode: 168
# Episode: 169
# SOLVED! Episode 169 Steps: 11 Epsilon 0.2988
# Episode: 170
# Episode: 171
# Episode: 172
# Episode: 173
# Episode: 174
# SOLVED! Episode 174 Steps: 3 Epsilon 0.2988
# Episode: 175
# Episode: 176
# Episode: 177
# Episode: 178
# Episode: 179
# SOLVED! Episode 179 Steps: 2 Epsilon 0.2988
# Episode: 180
# Episode: 181
# Episode: 182
# Episode: 183
# Episode: 184
# SOLVED! Episode 184 Steps: 6 Epsilon 0.2988
# Episode: 185
# Episode: 186
# Episode: 187
# Episode: 188
# SOLVED! Episode 188 Steps: 2 Epsilon 0.2988
# Episode: 189
# SOLVED! Episode 189 Steps: 3 Epsilon 0.2988
# Episode: 190
# Episode: 191
# Episode: 192
# SOLVED! Episode 192 Steps: 31 Epsilon 0.2988
# Episode: 193
# SOLVED! Episode 193 Steps: 3 Epsilon 0.2988
# Episode: 194
# Episode: 195
# Episode: 196
# Episode: 197
# Episode: 198
# Episode: 199
# Episode: 200
# SOLVED! Episode 200 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 21
# ==============================
# defaultdict(<class 'int'>, {3: 8, 1: 7, 2: 6})
# ******************************
# Episode: 201
# SOLVED! Episode 201 Steps: 2 Epsilon 0.2988
# Episode: 202
# Episode: 203
# Episode: 204
# Episode: 205
# Episode: 206
# Episode: 207
# Episode: 208
# Episode: 209
# Episode: 210
# SOLVED! Episode 210 Steps: 33 Epsilon 0.2988
# Episode: 211
# Episode: 212
# Episode: 213
# Episode: 214
# Episode: 215
# SOLVED! Episode 215 Steps: 3 Epsilon 0.2988
# Episode: 216
# Episode: 217
# Episode: 218
# SOLVED! Episode 218 Steps: 3 Epsilon 0.2988
# Episode: 219
# Episode: 220
# SOLVED! Episode 220 Steps: 2 Epsilon 0.2988
# Episode: 221
# Episode: 222
# Episode: 223
# Episode: 224
# Episode: 225
# Episode: 226
# Episode: 227
# Episode: 228
# SOLVED! Episode 228 Steps: 2 Epsilon 0.2988
# Episode: 229
# Episode: 230
# Episode: 231
# Episode: 232
# SOLVED! Episode 232 Steps: 26 Epsilon 0.2988
# Episode: 233
# Episode: 234
# SOLVED! Episode 234 Steps: 1 Epsilon 0.2988
# Episode: 235
# SOLVED! Episode 235 Steps: 3 Epsilon 0.2988
# Episode: 236
# Episode: 237
# Episode: 238
# Episode: 239
# Episode: 240
# SOLVED! Episode 240 Steps: 1 Epsilon 0.2988
# Episode: 241
# Episode: 242
# Episode: 243
# Episode: 244
# Episode: 245
# Episode: 246
# SOLVED! Episode 246 Steps: 2 Epsilon 0.2988
# Episode: 247
# Episode: 248
# Episode: 249
# SOLVED! Episode 249 Steps: 36 Epsilon 0.2988
# Episode: 250
# Episode: 251
# Episode: 252
# Episode: 253
# Episode: 254
# Episode: 255
# Episode: 256
# Episode: 257
# Episode: 258
# SOLVED! Episode 258 Steps: 3 Epsilon 0.2988
# Episode: 259
# Episode: 260
# SOLVED! Episode 260 Steps: 3 Epsilon 0.2988
# Episode: 261
# Episode: 262
# Episode: 263
# Episode: 264
# Episode: 265
# Episode: 266
# Episode: 267
# SOLVED! Episode 267 Steps: 3 Epsilon 0.2988
# Episode: 268
# Episode: 269
# SOLVED! Episode 269 Steps: 1 Epsilon 0.2988
# Episode: 270
# Episode: 271
# Episode: 272
# Episode: 273
# SOLVED! Episode 273 Steps: 2 Epsilon 0.2988
# Episode: 274
# Episode: 275
# Episode: 276
# Episode: 277
# Episode: 278
# Episode: 279
# Episode: 280
# Episode: 281
# SOLVED! Episode 281 Steps: 2 Epsilon 0.2988
# Episode: 282
# Episode: 283
# Episode: 284
# Episode: 285
# Episode: 286
# SOLVED! Episode 286 Steps: 3 Epsilon 0.2988
# Episode: 287
# Episode: 288
# Episode: 289
# Episode: 290
# Episode: 291
# Episode: 292
# Episode: 293
# SOLVED! Episode 293 Steps: 1 Epsilon 0.2988
# Episode: 294
# Episode: 295
# SOLVED! Episode 295 Steps: 1 Epsilon 0.2988
# Episode: 296
# Episode: 297
# Episode: 298
# Episode: 299
# Episode: 300
# SOLVED! Episode 300 Steps: 3 Epsilon 0.2988
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 19
# ==============================
# defaultdict(<class 'int'>, {3: 7, 1: 7, 2: 5})
# ******************************
# Episode: 301
# SOLVED! Episode 301 Steps: 1 Epsilon 0.2988
# Episode: 302
# Episode: 303
# SOLVED! Episode 303 Steps: 2 Epsilon 0.2988
# Episode: 304
# Episode: 305
# Episode: 306
# Episode: 307
# Episode: 308
# Episode: 309
# Episode: 310
# Episode: 311
# Episode: 312
# Episode: 313
# Episode: 314
# Episode: 315
# Episode: 316
# Episode: 317
# Episode: 318
# Episode: 319
# Episode: 320
# Episode: 321
# Episode: 322
# Episode: 323
# SOLVED! Episode 323 Steps: 14 Epsilon 0.2988
# Episode: 324
# Episode: 325
# SOLVED! Episode 325 Steps: 1 Epsilon 0.2988
# Episode: 326
# Episode: 327
# Episode: 328
# SOLVED! Episode 328 Steps: 2 Epsilon 0.2988
# Episode: 329
# Episode: 330
# Episode: 331
# Episode: 332
# Episode: 333
# Episode: 334
# Episode: 335
# SOLVED! Episode 335 Steps: 1 Epsilon 0.2988
# Episode: 336
# SOLVED! Episode 336 Steps: 1 Epsilon 0.2988
# Episode: 337
# SOLVED! Episode 337 Steps: 3 Epsilon 0.2988
# Episode: 338
# SOLVED! Episode 338 Steps: 2 Epsilon 0.2988
# Episode: 339
# Episode: 340
# Episode: 341
# Episode: 342
# SOLVED! Episode 342 Steps: 2 Epsilon 0.2988
# Episode: 343
# SOLVED! Episode 343 Steps: 2 Epsilon 0.2988
# Episode: 344
# SOLVED! Episode 344 Steps: 3 Epsilon 0.2988
# Episode: 345
# Episode: 346
# Episode: 347
# SOLVED! Episode 347 Steps: 3 Epsilon 0.2988
# Episode: 348
# Episode: 349
# SOLVED! Episode 349 Steps: 1 Epsilon 0.2988
# Episode: 350
# Episode: 351
# Episode: 352
# SOLVED! Episode 352 Steps: 3 Epsilon 0.2988
# Episode: 353
# Episode: 354
# SOLVED! Episode 354 Steps: 3 Epsilon 0.2988
# Episode: 355
# Episode: 356
# Episode: 357
# Episode: 358
# Episode: 359
# Episode: 360
# Episode: 361
# Episode: 362
# Episode: 363
# Episode: 364
# Episode: 365
# Episode: 366
# Episode: 367
# Episode: 368
# Episode: 369
# SOLVED! Episode 369 Steps: 3 Epsilon 0.2988
# Episode: 370
# Episode: 371
# Episode: 372
# Episode: 373
# Episode: 374
# Episode: 375
# Episode: 376
# Episode: 377
# Episode: 378
# Episode: 379
# Episode: 380
# SOLVED! Episode 380 Steps: 3 Epsilon 0.2988
# Episode: 381
# Episode: 382
# Episode: 383
# SOLVED! Episode 383 Steps: 2 Epsilon 0.2988
# Episode: 384
# Episode: 385
# Episode: 386
# Episode: 387
# Episode: 388
# Episode: 389
# Episode: 390
# SOLVED! Episode 390 Steps: 2 Epsilon 0.2988
# Episode: 391
# SOLVED! Episode 391 Steps: 1 Epsilon 0.2988
# Episode: 392
# SOLVED! Episode 392 Steps: 3 Epsilon 0.2988
# Episode: 393
# Episode: 394
# Episode: 395
# SOLVED! Episode 395 Steps: 1 Epsilon 0.2988
# Episode: 396
# Episode: 397
# Episode: 398
# Episode: 399
# Episode: 400
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 22
# ==============================
# defaultdict(<class 'int'>, {3: 10, 1: 8, 2: 4})
# ******************************
# Episode: 401
# SOLVED! Episode 401 Steps: 2 Epsilon 0.2988
# Episode: 402
# Episode: 403
# Episode: 404
# SOLVED! Episode 404 Steps: 3 Epsilon 0.2988
# Episode: 405
# Episode: 406
# SOLVED! Episode 406 Steps: 1 Epsilon 0.2988
# Episode: 407
# Episode: 408
# Episode: 409
# Episode: 410
# Episode: 411
# SOLVED! Episode 411 Steps: 2 Epsilon 0.2988
# Episode: 412
# Episode: 413
# Episode: 414
# SOLVED! Episode 414 Steps: 3 Epsilon 0.2988
# Episode: 415
# Episode: 416
# SOLVED! Episode 416 Steps: 2 Epsilon 0.2988
# Episode: 417
# SOLVED! Episode 417 Steps: 3 Epsilon 0.2988
# Episode: 418
# Episode: 419
# Episode: 420
# Episode: 421
# Episode: 422
# Episode: 423
# Episode: 424
# SOLVED! Episode 424 Steps: 7 Epsilon 0.2988
# Episode: 425
# Episode: 426
# Episode: 427
# Episode: 428
# SOLVED! Episode 428 Steps: 3 Epsilon 0.2988
# Episode: 429
