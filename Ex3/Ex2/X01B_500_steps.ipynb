# %% [markdown]
# # Final Project - Reinforcements Learning
# Hello dear students,<br> this is the template notebook. Please click on the "File" tab and then on "Save a copy into drive".
#
# ---
# <br>
#
# ### Name and ID:
# Student 1: Avraham Raviv, 204355390
# <br>
# Student 2: Yevgeni Berkovitch, 317079234
# <br><br>
# <img src="https://play-lh.googleusercontent.com/e_oKlKPISbgdzut1H9opevS7-LTB8-8lsmpCdMkhlnqFenZhpjxbLmx7l158-xQQCIY">
#
# ### https://github.com/mpSchrader/gym-sokoban

# %% [markdown]
# # Installs

# %%
# %%capture
# !sudo apt-get update
# !sudo apt-get install -y xvfb ffmpeg freeglut3-dev
# !pip install 'imageio==2.4.0'
# !pip install gym
# !pip install pygame
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet
# !pip install gym
# !apt-get install python-opengl -y
# !apt install xvfb -y
# !pip install gym_sokoban

# !imageio_download_bin ffmpeg

# %% [markdown]
# # Imports

# %%
import random
import time

import numpy as np
import scipy as scp
import matplotlib.pyplot as plt

import base64
import imageio
from pyvirtualdisplay import Display
from IPython.display import HTML

import gym
from gym import error, spaces, utils
from soko_pap import *

from collections import deque
from queue import PriorityQueue

from keras.models import Sequential
from keras.layers import Dense

from tqdm.notebook import tqdm
from collections import defaultdict

# %%
# %matplotlib inline

# %%
imageio.plugins.ffmpeg.download()

# %%
from gym import logger as gymlogger
gymlogger.set_level(40) # error only

# %% [markdown]
# # Display utils
# The cell below contains the video display configuration. No need to make changes here.

# %%
def embed_mp4(filename):
    """Embeds an mp4 file in the notebook."""
    video = open(filename,'rb').read()
    b64 = base64.b64encode(video)
    tag = '''
    <video width="640" height="480" controls>
    <source src="data:video/mp4;base64,{0}" type="video/mp4">
    Your browser does not support the video tag.
    </video>'''.format(b64.decode())

    return HTML(tag)

# %% [markdown]
# # Utils

# %%
def get_distances(room_state):
    for i in range(room_state.shape[0]):
        for j in range(room_state.shape[1]):
            if room_state[i][j] == 2:
                target = (i, j)

    distances = np.zeros(shape=room_state.shape)
    visited_cells = set()
    cell_queue = deque()

    visited_cells.add(target)
    cell_queue.appendleft(target)

    while len(cell_queue) != 0:
        cell = cell_queue.pop()
        distance = distances[cell[0]][cell[1]]
        for x,y in ((1,0), (-1,-0), (0,1), (0,-1)):
            next_cell_x, next_cell_y = cell[0]+x, cell[1]+y
            if room_state[next_cell_x][next_cell_y] != 0 and not (next_cell_x, next_cell_y) in visited_cells:
                distances[next_cell_x][next_cell_y] = distance + 1
                visited_cells.add((next_cell_x, next_cell_y))
                cell_queue.appendleft((next_cell_x, next_cell_y))
                
    return distances   

def calc_distances(room_state, distances):
    box = None
    mover = None
    for i in range(room_state.shape[0]):
        for j in range(room_state.shape[1]):            
            if room_state[i][j] == 4:
                box = (i,j)
            
            if room_state[i][j] == 5:
                mover = (i,j)
    
    return mover, box, distances[box[0]][box[1]]   

def box2target_change_reward(room_state, next_room_state, distances):
    if np.array_equal(room_state, next_room_state):
        return -1.0
    
    mover, box, t2b = calc_distances(room_state, distances)
    n_mover, n_box, n_t2b = calc_distances(next_room_state, distances)
    
    change_reward = 0.0
    if n_t2b < t2b:
        change_reward += 5.0
    elif n_t2b > t2b:
        change_reward -= 5.0
        
    m2b = np.sqrt((mover[0]-box[0])**2 + (mover[1]-box[1])**2)
    n_m2b = np.sqrt((n_mover[0]-n_box[0])**2 + (n_mover[1]-n_box[1])**2)
    
    if n_m2b < m2b and m2b >= 2:
        change_reward += 1.0
    elif n_m2b > m2b and n_m2b >= 2:
        change_reward -= 1.0
        
    return change_reward

# %% [markdown]
# # Solution

# %%
class SOK_Agent:
    def __init__(self):
        # Construct DQN models
        self.state_size = (25,) 
        self.action_size = 8
        self.model = self._build_model()
        self.target_model = self._build_model()
        self.target_model.set_weights(self.model.get_weights())
        self.batch_size = 8
        
        # Replay buffers
        self.replay_buffer = deque(maxlen=5000)
        self.prioritized_replay_buffer = deque(maxlen=500)
        self.prioritized_replay_batch = 50        
        
        # Hyperparameters
        self.gamma = 0.9
        self.epsilon = 1.0   
        self.epsilon_min = 0.3
        self.epsilon_decay = 0.995
        self.replay_rate = 10
        self.update_beta = 0.999

        self.verbosity = 100 

    def _build_model(self):
        model = Sequential()
        model.add(Dense(512, input_shape=self.state_size, activation='relu'))
        model.add(Dense(self.action_size, activation='linear'))
        model.compile(loss='mse', optimizer="adam")        
        return model

    def remember(self, state, action, reward, next_state, done):
        self.replay_buffer.append([state, action, reward, next_state, done])    
        
    def copy_to_prioritized_buffer(self, n):
        for i in range(n):
            self.prioritized_replay_buffer.append(self.replay_buffer[-1-i])  

    def act(self, state, stochastic=False):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        
        act_values = self.model.predict(state, verbose=0)[0]
        
        if stochastic:
            act_probs = np.exp(act_values)/np.exp(act_values).sum()
            return np.random.choice(np.arange(self.action_size), size=1, p=act_probs)[0]
              
        return np.argmax(act_values) 

    def replay(self): 
        if len(self.replay_buffer) < self.batch_size:
            return
        
        if len(self.replay_buffer) < self.batch_size:
            return
        
        if len(self.prioritized_replay_buffer) < self.batch_size//2:
            minibatch = random.sample(self.replay_buffer, self.batch_size) 
        else:    
            minibatch = random.sample(self.replay_buffer, self.batch_size//2) 
            minibatch.extend(random.sample(self.prioritized_replay_buffer, self.batch_size//2))
        
        states = np.zeros((self.batch_size, self.state_size[0]))
        actions = np.zeros(self.batch_size, dtype=int)
        rewards = np.zeros(self.batch_size)
        next_states = np.zeros((self.batch_size, self.state_size[0]))
        statuses = np.zeros(self.batch_size)
        targets = np.zeros((self.batch_size, self.action_size)) 
        
        for i, (state, action, reward, next_state, done) in enumerate(minibatch): 
            states[i] = state.copy()
            actions[i] = action
            rewards[i] = reward
            next_states[i] = next_state.copy()
            statuses[i] = 1 if done else 0    
        
        targets = self.model.predict(states) 
        max_actions = np.argmax(self.model.predict(next_states), axis=1)
        next_rewards = self.target_model.predict(next_states)
        
        ind = 0
        for action, reward, next_reward, max_action, done in zip(actions, rewards, next_rewards, max_actions, statuses):  
            if not done:
                reward += self.gamma * next_reward[max_action]
            targets[ind][action] = reward
            ind += 1
        
        self.model.fit(states, targets, epochs=10, verbose=0) 
        
        self.update_target_model()        
    
        if self.epsilon > self.epsilon_min:
            self.epsilon = self.epsilon * self.epsilon_decay
        
    def update_target_model(self):
        model_w = self.model.get_weights()
        target_model_w = self.target_model.get_weights()
        updated_target_model_w = []
        for i in range(len(model_w)):
            updated_target_model_w.append(self.update_beta*target_model_w[i] + (1-self.update_beta)*model_w[i])
        self.target_model.set_weights(updated_target_model_w)    
            
    def load(self, name):
        self.model.load_weights(name)

    def save(self, name):
        self.model.save_weights(name)

# %%
def process_frame(frame):
    f = frame[16:96, 16:96, 0]   
    f = f.reshape(5, 16, 5, 16).max(axis=(1, 3))
    f = f.flatten()
    f = f / 255
    return np.expand_dims(f, axis=0)

# %% [markdown]
# ## Training

# %% [markdown]
# #### Test Suite

# %%
def test_agent(stochastic=False):
    current_epsilon = agent.epsilon
    agent.epsilon = 0.0
    num_solved = 0
    solved_in_steps = defaultdict(int)

    for t in tqdm(range(100)):    
        random.seed(t)
        sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
        sok.set_maxsteps(20)
        steps = 0

        state = sok.get_image('rgb_array')
        done = False
        while not done:
            steps += 1
            action = agent.act(process_frame(state), stochastic)
            if action < 4:
                action += 1
            else:
                action += 5
            state, reward, done, info = sok.step(action)

        if 3 in sok.room_state:            
            num_solved += 1
            solved_in_steps[steps] += 1
    
    agent.epsilon = current_epsilon
    print("*" * 30)
    print("Stochastic" if stochastic else "Deterministic")
    print("*" * 30)
    print("Solved: %d" % num_solved)
    print("=" * 30)
    print(solved_in_steps)
    print("*" * 30)

# %%
max_episodes = 1000
max_steps = 500

def init_sok(r):
    random.seed(r+100)
    sok = PushAndPullSokobanEnv(dim_room=(7, 7), num_boxes=1)
    sok.set_maxsteps(max_steps)
    return sok

# %%
agent = SOK_Agent()

steps_per_episode = []

for e in range(max_episodes):
    if (e+1) % 100 == 0:
        test_agent(stochastic=False)
        test_agent(stochastic=True)
        
    print("Episode: %d" % (e))
    
    sok = init_sok(e)
    random.seed(e)
    
    state = process_frame(sok.get_image('rgb_array'))
    room_state = sok.room_state.copy() 
    distances = get_distances(room_state)
    
    for step in range(sok.max_steps):
        action = agent.act(state)
        if action < 4:
            next_state, reward, done, _ = sok.step(action+1) 
        else:
            next_state, reward, done, _ = sok.step(action+5)         
        
        next_state = process_frame(next_state)        
        next_room_state = sok.room_state
        
        if not done:
            reward += box2target_change_reward(room_state, next_room_state, distances)
        
        agent.remember(state, action, reward, next_state, done)
        
        state = next_state.copy() 
        room_state = next_room_state.copy()                
        
        if (step+1) % agent.replay_rate == 0:
            agent.replay()            
        
        if done:   
            steps_per_episode.append(step+1)
            
            if 3 in sok.room_state:                
                print("SOLVED! Episode %d Steps: %d Epsilon %.4f" % (e, step+1, agent.epsilon)) 
                agent.copy_to_prioritized_buffer(min(agent.prioritized_replay_batch, step+1))
            
            #agent.save("exp1_episode%d.h5" % (e))            
            break
# Out:
# Episode: 0
# SOLVED! Episode 0 Steps: 359 Epsilon 0.8391
# Episode: 1
# Episode: 2
# SOLVED! Episode 2 Steps: 362 Epsilon 0.5452
# Episode: 3
# Episode: 4
# SOLVED! Episode 4 Steps: 319 Epsilon 0.3633
# Episode: 5
# Episode: 6
# SOLVED! Episode 6 Steps: 3 Epsilon 0.2988
# Episode: 7
# SOLVED! Episode 7 Steps: 386 Epsilon 0.2988
# Episode: 8
# Episode: 9
# SOLVED! Episode 9 Steps: 297 Epsilon 0.2988
# Episode: 10
# Episode: 11
# Episode: 12
# Episode: 13
# SOLVED! Episode 13 Steps: 29 Epsilon 0.2988
# Episode: 14
# SOLVED! Episode 14 Steps: 1 Epsilon 0.2988
# Episode: 15
# Episode: 16
# Episode: 17
# SOLVED! Episode 17 Steps: 328 Epsilon 0.2988
# Episode: 18
# SOLVED! Episode 18 Steps: 321 Epsilon 0.2988
# Episode: 19
# SOLVED! Episode 19 Steps: 112 Epsilon 0.2988
# Episode: 20
# SOLVED! Episode 20 Steps: 140 Epsilon 0.2988
# Episode: 21
# SOLVED! Episode 21 Steps: 432 Epsilon 0.2988
# Episode: 22
# SOLVED! Episode 22 Steps: 21 Epsilon 0.2988
# Episode: 23
# Episode: 24
# SOLVED! Episode 24 Steps: 128 Epsilon 0.2988
# Episode: 25
# Episode: 26
# Episode: 27
# Episode: 28
# SOLVED! Episode 28 Steps: 305 Epsilon 0.2988
# Episode: 29
# Episode: 30
# Episode: 31
# SOLVED! Episode 31 Steps: 24 Epsilon 0.2988
# Episode: 32
# Episode: 33
# Episode: 34
# Episode: 35
# Episode: 36
# Episode: 37
# SOLVED! Episode 37 Steps: 193 Epsilon 0.2988
# Episode: 38
# SOLVED! Episode 38 Steps: 453 Epsilon 0.2988
# Episode: 39
# SOLVED! Episode 39 Steps: 2 Epsilon 0.2988
# Episode: 40
# Episode: 41
# SOLVED! Episode 41 Steps: 3 Epsilon 0.2988
# Episode: 42
# Episode: 43
# SOLVED! Episode 43 Steps: 82 Epsilon 0.2988
# Episode: 44
# SOLVED! Episode 44 Steps: 401 Epsilon 0.2988
# Episode: 45
# Episode: 46
# SOLVED! Episode 46 Steps: 3 Epsilon 0.2988
# Episode: 47
# Episode: 48
# SOLVED! Episode 48 Steps: 1 Epsilon 0.2988
# Episode: 49
# Episode: 50
# SOLVED! Episode 50 Steps: 111 Epsilon 0.2988
# Episode: 51
# SOLVED! Episode 51 Steps: 152 Epsilon 0.2988
# Episode: 52
# Episode: 53
# Episode: 54
# SOLVED! Episode 54 Steps: 375 Epsilon 0.2988
# Episode: 55
# Episode: 56
# SOLVED! Episode 56 Steps: 90 Epsilon 0.2988
# Episode: 57
# SOLVED! Episode 57 Steps: 74 Epsilon 0.2988
# Episode: 58
# Episode: 59
# SOLVED! Episode 59 Steps: 2 Epsilon 0.2988
# Episode: 60
# Episode: 61
# Episode: 62
# Episode: 63
# Episode: 64
# SOLVED! Episode 64 Steps: 72 Epsilon 0.2988
# Episode: 65
# SOLVED! Episode 65 Steps: 1 Epsilon 0.2988
# Episode: 66
# Episode: 67
# Episode: 68
# SOLVED! Episode 68 Steps: 3 Epsilon 0.2988
# Episode: 69
# SOLVED! Episode 69 Steps: 2 Epsilon 0.2988
# Episode: 70
# Episode: 71
# SOLVED! Episode 71 Steps: 102 Epsilon 0.2988
# Episode: 72
# SOLVED! Episode 72 Steps: 162 Epsilon 0.2988
# Episode: 73
# Episode: 74
# Episode: 75
# SOLVED! Episode 75 Steps: 66 Epsilon 0.2988
# Episode: 76
# SOLVED! Episode 76 Steps: 192 Epsilon 0.2988
# Episode: 77
# Episode: 78
# Episode: 79
# Episode: 80
# Episode: 81
# Episode: 82
# SOLVED! Episode 82 Steps: 3 Epsilon 0.2988
# Episode: 83
# Episode: 84
# SOLVED! Episode 84 Steps: 1 Epsilon 0.2988
# Episode: 85
# SOLVED! Episode 85 Steps: 1 Epsilon 0.2988
# Episode: 86
# Episode: 87
# Episode: 88
# SOLVED! Episode 88 Steps: 60 Epsilon 0.2988
# Episode: 89
# Episode: 90
# SOLVED! Episode 90 Steps: 230 Epsilon 0.2988
# Episode: 91
# SOLVED! Episode 91 Steps: 1 Epsilon 0.2988
# Episode: 92
# Episode: 93
# SOLVED! Episode 93 Steps: 1 Epsilon 0.2988
# Episode: 94
# SOLVED! Episode 94 Steps: 1 Epsilon 0.2988
# Episode: 95
# SOLVED! Episode 95 Steps: 8 Epsilon 0.2988
# Episode: 96
# Episode: 97
# Episode: 98
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 21
# ==============================
# defaultdict(<class 'int'>, {3: 10, 2: 4, 1: 7})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 26
# ==============================
# defaultdict(<class 'int'>, {5: 2, 2: 4, 1: 8, 3: 4, 4: 2, 20: 1, 6: 2, 12: 1, 14: 1, 7: 1})
# ******************************
# Episode: 99
# Episode: 100
# Episode: 101
# Episode: 102
# SOLVED! Episode 102 Steps: 3 Epsilon 0.2988
# Episode: 103
# Episode: 104
# Episode: 105
# Episode: 106
# SOLVED! Episode 106 Steps: 12 Epsilon 0.2988
# Episode: 107
# Episode: 108
# Episode: 109
# Episode: 110
# Episode: 111
# Episode: 112
# Episode: 113
# SOLVED! Episode 113 Steps: 18 Epsilon 0.2988
# Episode: 114
# SOLVED! Episode 114 Steps: 1 Epsilon 0.2988
# Episode: 115
# Episode: 116
# SOLVED! Episode 116 Steps: 3 Epsilon 0.2988
# Episode: 117
# Episode: 118
# SOLVED! Episode 118 Steps: 30 Epsilon 0.2988
# Episode: 119
# Episode: 120
# SOLVED! Episode 120 Steps: 3 Epsilon 0.2988
# Episode: 121
# Episode: 122
# Episode: 123
# SOLVED! Episode 123 Steps: 3 Epsilon 0.2988
# Episode: 124
# SOLVED! Episode 124 Steps: 195 Epsilon 0.2988
# Episode: 125
# SOLVED! Episode 125 Steps: 147 Epsilon 0.2988
# Episode: 126
# Episode: 127
# SOLVED! Episode 127 Steps: 183 Epsilon 0.2988
# Episode: 128
# SOLVED! Episode 128 Steps: 2 Epsilon 0.2988
# Episode: 129
# SOLVED! Episode 129 Steps: 1 Epsilon 0.2988
# Episode: 130
# Episode: 131
# Episode: 132
# Episode: 133
# SOLVED! Episode 133 Steps: 3 Epsilon 0.2988
# Episode: 134
# Episode: 135
# Episode: 136
# SOLVED! Episode 136 Steps: 35 Epsilon 0.2988
# Episode: 137
# Episode: 138
# Episode: 139
# Episode: 140
# Episode: 141
# SOLVED! Episode 141 Steps: 3 Epsilon 0.2988
# Episode: 142
# Episode: 143
# SOLVED! Episode 143 Steps: 3 Epsilon 0.2988
# Episode: 144
# Episode: 145
# Episode: 146
# Episode: 147
# Episode: 148
# Episode: 149
# Episode: 150
# SOLVED! Episode 150 Steps: 2 Epsilon 0.2988
# Episode: 151
# SOLVED! Episode 151 Steps: 1 Epsilon 0.2988
# Episode: 152
# SOLVED! Episode 152 Steps: 2 Epsilon 0.2988
# Episode: 153
# Episode: 154
# SOLVED! Episode 154 Steps: 3 Epsilon 0.2988
# Episode: 155
# SOLVED! Episode 155 Steps: 19 Epsilon 0.2988
# Episode: 156
# Episode: 157
# Episode: 158
# Episode: 159
# SOLVED! Episode 159 Steps: 205 Epsilon 0.2988
# Episode: 160
# SOLVED! Episode 160 Steps: 72 Epsilon 0.2988
# Episode: 161
# SOLVED! Episode 161 Steps: 2 Epsilon 0.2988
# Episode: 162
# SOLVED! Episode 162 Steps: 3 Epsilon 0.2988
# Episode: 163
# SOLVED! Episode 163 Steps: 3 Epsilon 0.2988
# Episode: 164
# Episode: 165
# Episode: 166
# Episode: 167
# Episode: 168
# SOLVED! Episode 168 Steps: 88 Epsilon 0.2988
# Episode: 169
# Episode: 170
# SOLVED! Episode 170 Steps: 150 Epsilon 0.2988
# Episode: 171
# Episode: 172
# SOLVED! Episode 172 Steps: 452 Epsilon 0.2988
# Episode: 173
# SOLVED! Episode 173 Steps: 3 Epsilon 0.2988
# Episode: 174
# Episode: 175
# SOLVED! Episode 175 Steps: 46 Epsilon 0.2988
# Episode: 176
# Episode: 177
# SOLVED! Episode 177 Steps: 48 Epsilon 0.2988
# Episode: 178
# SOLVED! Episode 178 Steps: 18 Epsilon 0.2988
# Episode: 179
# Episode: 180
# Episode: 181
# Episode: 182
# SOLVED! Episode 182 Steps: 73 Epsilon 0.2988
# Episode: 183
# SOLVED! Episode 183 Steps: 6 Epsilon 0.2988
# Episode: 184
# Episode: 185
# Episode: 186
# SOLVED! Episode 186 Steps: 3 Epsilon 0.2988
# Episode: 187
# Episode: 188
# SOLVED! Episode 188 Steps: 3 Epsilon 0.2988
# Episode: 189
# SOLVED! Episode 189 Steps: 33 Epsilon 0.2988
# Episode: 190
# SOLVED! Episode 190 Steps: 59 Epsilon 0.2988
# Episode: 191
# SOLVED! Episode 191 Steps: 132 Epsilon 0.2988
# Episode: 192
# SOLVED! Episode 192 Steps: 3 Epsilon 0.2988
# Episode: 193
# SOLVED! Episode 193 Steps: 68 Epsilon 0.2988
# Episode: 194
# SOLVED! Episode 194 Steps: 309 Epsilon 0.2988
# Episode: 195
# Episode: 196
# Episode: 197
# Episode: 198
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 25
# ==============================
# defaultdict(<class 'int'>, {3: 10, 1: 10, 2: 5})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 32
# ==============================
# defaultdict(<class 'int'>, {4: 2, 20: 1, 3: 12, 2: 4, 1: 9, 6: 1, 7: 1, 9: 1, 14: 1})
# ******************************
# Episode: 199
# Episode: 200
# SOLVED! Episode 200 Steps: 125 Epsilon 0.2988
# Episode: 201
# SOLVED! Episode 201 Steps: 285 Epsilon 0.2988
# Episode: 202
# Episode: 203
# Episode: 204
# Episode: 205
# Episode: 206
# Episode: 207
# SOLVED! Episode 207 Steps: 426 Epsilon 0.2988
# Episode: 208
# Episode: 209
# SOLVED! Episode 209 Steps: 35 Epsilon 0.2988
# Episode: 210
# Episode: 211
# Episode: 212
# SOLVED! Episode 212 Steps: 173 Epsilon 0.2988
# Episode: 213
# SOLVED! Episode 213 Steps: 83 Epsilon 0.2988
# Episode: 214
# SOLVED! Episode 214 Steps: 20 Epsilon 0.2988
# Episode: 215
# Episode: 216
# SOLVED! Episode 216 Steps: 3 Epsilon 0.2988
# Episode: 217
# SOLVED! Episode 217 Steps: 265 Epsilon 0.2988
# Episode: 218
# SOLVED! Episode 218 Steps: 192 Epsilon 0.2988
# Episode: 219
# SOLVED! Episode 219 Steps: 158 Epsilon 0.2988
# Episode: 220
# SOLVED! Episode 220 Steps: 6 Epsilon 0.2988
# Episode: 221
# SOLVED! Episode 221 Steps: 6 Epsilon 0.2988
# Episode: 222
# Episode: 223
# Episode: 224
# Episode: 225
# Episode: 226
# Episode: 227
# Episode: 228
# Episode: 229
# Episode: 230
# SOLVED! Episode 230 Steps: 1 Epsilon 0.2988
# Episode: 231
# SOLVED! Episode 231 Steps: 391 Epsilon 0.2988
# Episode: 232
# Episode: 233
# SOLVED! Episode 233 Steps: 1 Epsilon 0.2988
# Episode: 234
# SOLVED! Episode 234 Steps: 60 Epsilon 0.2988
# Episode: 235
# Episode: 236
# Episode: 237
# SOLVED! Episode 237 Steps: 175 Epsilon 0.2988
# Episode: 238
# SOLVED! Episode 238 Steps: 1 Epsilon 0.2988
# Episode: 239
# SOLVED! Episode 239 Steps: 1 Epsilon 0.2988
# Episode: 240
# SOLVED! Episode 240 Steps: 446 Epsilon 0.2988
# Episode: 241
# Episode: 242
# SOLVED! Episode 242 Steps: 174 Epsilon 0.2988
# Episode: 243
# Episode: 244
# SOLVED! Episode 244 Steps: 1 Epsilon 0.2988
# Episode: 245
# Episode: 246
# Episode: 247
# SOLVED! Episode 247 Steps: 13 Epsilon 0.2988
# Episode: 248
# Episode: 249
# Episode: 250
# Episode: 251
# SOLVED! Episode 251 Steps: 212 Epsilon 0.2988
# Episode: 252
# Episode: 253
# Episode: 254
# SOLVED! Episode 254 Steps: 57 Epsilon 0.2988
# Episode: 255
# SOLVED! Episode 255 Steps: 59 Epsilon 0.2988
# Episode: 256
# SOLVED! Episode 256 Steps: 2 Epsilon 0.2988
# Episode: 257
# SOLVED! Episode 257 Steps: 3 Epsilon 0.2988
# Episode: 258
# SOLVED! Episode 258 Steps: 87 Epsilon 0.2988
# Episode: 259
# SOLVED! Episode 259 Steps: 3 Epsilon 0.2988
# Episode: 260
# Episode: 261
# Episode: 262
# Episode: 263
# Episode: 264
# Episode: 265
# Episode: 266
# SOLVED! Episode 266 Steps: 3 Epsilon 0.2988
# Episode: 267
# Episode: 268
# SOLVED! Episode 268 Steps: 1 Epsilon 0.2988
# Episode: 269
# Episode: 270
# Episode: 271
# Episode: 272
# Episode: 273
# Episode: 274
# SOLVED! Episode 274 Steps: 372 Epsilon 0.2988
# Episode: 275
# Episode: 276
# Episode: 277
# Episode: 278
# SOLVED! Episode 278 Steps: 353 Epsilon 0.2988
# Episode: 279
# Episode: 280
# SOLVED! Episode 280 Steps: 2 Epsilon 0.2988
# Episode: 281
# Episode: 282
# SOLVED! Episode 282 Steps: 251 Epsilon 0.2988
# Episode: 283
# Episode: 284
# Episode: 285
# SOLVED! Episode 285 Steps: 3 Epsilon 0.2988
# Episode: 286
# Episode: 287
# Episode: 288
# Episode: 289
# SOLVED! Episode 289 Steps: 32 Epsilon 0.2988
# Episode: 290
# Episode: 291
# SOLVED! Episode 291 Steps: 171 Epsilon 0.2988
# Episode: 292
# SOLVED! Episode 292 Steps: 450 Epsilon 0.2988
# Episode: 293
# SOLVED! Episode 293 Steps: 3 Epsilon 0.2988
# Episode: 294
# SOLVED! Episode 294 Steps: 237 Epsilon 0.2988
# Episode: 295
# Episode: 296
# Episode: 297
# SOLVED! Episode 297 Steps: 147 Epsilon 0.2988
# Episode: 298
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 21
# ==============================
# defaultdict(<class 'int'>, {3: 11, 2: 4, 1: 6})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 29
# ==============================
# defaultdict(<class 'int'>, {3: 11, 7: 3, 10: 2, 1: 6, 2: 2, 4: 2, 9: 1, 18: 1, 6: 1})
# ******************************
# Episode: 299
# SOLVED! Episode 299 Steps: 3 Epsilon 0.2988
# Episode: 300
# SOLVED! Episode 300 Steps: 1 Epsilon 0.2988
# Episode: 301
# Episode: 302
# Episode: 303
# Episode: 304
# Episode: 305
# SOLVED! Episode 305 Steps: 48 Epsilon 0.2988
# Episode: 306
# Episode: 307
# SOLVED! Episode 307 Steps: 32 Epsilon 0.2988
# Episode: 308
# Episode: 309
# Episode: 310
# SOLVED! Episode 310 Steps: 3 Epsilon 0.2988
# Episode: 311
# Episode: 312
# Episode: 313
# SOLVED! Episode 313 Steps: 407 Epsilon 0.2988
# Episode: 314
# SOLVED! Episode 314 Steps: 261 Epsilon 0.2988
# Episode: 315
# SOLVED! Episode 315 Steps: 3 Epsilon 0.2988
# Episode: 316
# Episode: 317
# Episode: 318
# SOLVED! Episode 318 Steps: 101 Epsilon 0.2988
# Episode: 319
# Episode: 320
# Episode: 321
# SOLVED! Episode 321 Steps: 452 Epsilon 0.2988
# Episode: 322
# SOLVED! Episode 322 Steps: 14 Epsilon 0.2988
# Episode: 323
# SOLVED! Episode 323 Steps: 3 Epsilon 0.2988
# Episode: 324
# SOLVED! Episode 324 Steps: 1 Epsilon 0.2988
# Episode: 325
# Episode: 326
# SOLVED! Episode 326 Steps: 50 Epsilon 0.2988
# Episode: 327
# SOLVED! Episode 327 Steps: 403 Epsilon 0.2988
# Episode: 328
# Episode: 329
# Episode: 330
# SOLVED! Episode 330 Steps: 336 Epsilon 0.2988
# Episode: 331
# Episode: 332
# Episode: 333
# Episode: 334
# SOLVED! Episode 334 Steps: 1 Epsilon 0.2988
# Episode: 335
# SOLVED! Episode 335 Steps: 292 Epsilon 0.2988
# Episode: 336
# SOLVED! Episode 336 Steps: 3 Epsilon 0.2988
# Episode: 337
# SOLVED! Episode 337 Steps: 359 Epsilon 0.2988
# Episode: 338
# SOLVED! Episode 338 Steps: 465 Epsilon 0.2988
# Episode: 339
# Episode: 340
# Episode: 341
# SOLVED! Episode 341 Steps: 2 Epsilon 0.2988
# Episode: 342
# SOLVED! Episode 342 Steps: 7 Epsilon 0.2988
# Episode: 343
# SOLVED! Episode 343 Steps: 11 Epsilon 0.2988
# Episode: 344
# Episode: 345
# Episode: 346
# SOLVED! Episode 346 Steps: 3 Epsilon 0.2988
# Episode: 347
# Episode: 348
# SOLVED! Episode 348 Steps: 30 Epsilon 0.2988
# Episode: 349
# Episode: 350
# Episode: 351
# Episode: 352
# Episode: 353
# Episode: 354
# SOLVED! Episode 354 Steps: 417 Epsilon 0.2988
# Episode: 355
# Episode: 356
# Episode: 357
# Episode: 358
# Episode: 359
# Episode: 360
# Episode: 361
# Episode: 362
# Episode: 363
# Episode: 364
# Episode: 365
# SOLVED! Episode 365 Steps: 273 Epsilon 0.2988
# Episode: 366
# SOLVED! Episode 366 Steps: 168 Epsilon 0.2988
# Episode: 367
# Episode: 368
# SOLVED! Episode 368 Steps: 3 Epsilon 0.2988
# Episode: 369
# Episode: 370
# SOLVED! Episode 370 Steps: 3 Epsilon 0.2988
# Episode: 371
# Episode: 372
# Episode: 373
# Episode: 374
# SOLVED! Episode 374 Steps: 363 Epsilon 0.2988
# Episode: 375
# Episode: 376
# SOLVED! Episode 376 Steps: 3 Epsilon 0.2988
# Episode: 377
# Episode: 378
# Episode: 379
# Episode: 380
# Episode: 381
# Episode: 382
# SOLVED! Episode 382 Steps: 239 Epsilon 0.2988
# Episode: 383
# Episode: 384
# Episode: 385
# Episode: 386
# Episode: 387
# Episode: 388
# Episode: 389
# SOLVED! Episode 389 Steps: 251 Epsilon 0.2988
# Episode: 390
# Episode: 391
# Episode: 392
# Episode: 393
# SOLVED! Episode 393 Steps: 423 Epsilon 0.2988
# Episode: 394
# SOLVED! Episode 394 Steps: 1 Epsilon 0.2988
# Episode: 395
# Episode: 396
# SOLVED! Episode 396 Steps: 3 Epsilon 0.2988
# Episode: 397
# Episode: 398
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Deterministic
# ******************************
# Solved: 13
# ==============================
# defaultdict(<class 'int'>, {3: 7, 2: 3, 1: 3})
# ******************************
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# ******************************
# Stochastic
# ******************************
# Solved: 16
# ==============================
# defaultdict(<class 'int'>, {3: 9, 6: 1, 4: 1, 2: 4, 14: 1})
# ******************************
# Episode: 399
# Episode: 400
# SOLVED! Episode 400 Steps: 23 Epsilon 0.2988
# Episode: 401
# Episode: 402
# Episode: 403
# SOLVED! Episode 403 Steps: 355 Epsilon 0.2988
# Episode: 404
# SOLVED! Episode 404 Steps: 216 Epsilon 0.2988
# Episode: 405
# SOLVED! Episode 405 Steps: 1 Epsilon 0.2988
# Episode: 406
# Episode: 407
# Episode: 408
# Episode: 409
# Episode: 410
# SOLVED! Episode 410 Steps: 341 Epsilon 0.2988
# Episode: 411
# Episode: 412
# Episode: 413
# SOLVED! Episode 413 Steps: 3 Epsilon 0.2988
# Episode: 414
# SOLVED! Episode 414 Steps: 387 Epsilon 0.2988
# Episode: 415
# Episode: 416
# SOLVED! Episode 416 Steps: 3 Epsilon 0.2988
# Episode: 417
# Episode: 418
# SOLVED! Episode 418 Steps: 3 Epsilon 0.2988
# Episode: 419
# Episode: 420
# Episode: 421
# Episode: 422
# Episode: 423
# SOLVED! Episode 423 Steps: 1 Epsilon 0.2988
# Episode: 424
# Episode: 425
# Episode: 426
# Episode: 427
# SOLVED! Episode 427 Steps: 3 Epsilon 0.2988
# Episode: 428
# SOLVED! Episode 428 Steps: 2 Epsilon 0.2988
# Episode: 429
# SOLVED! Episode 429 Steps: 237 Epsilon 0.2988
# Episode: 430
# SOLVED! Episode 430 Steps: 45 Epsilon 0.2988
# Episode: 431
# Episode: 432
# Episode: 433
# Episode: 434
# Episode: 435
# SOLVED! Episode 435 Steps: 329 Epsilon 0.2988
# Episode: 436
# Episode: 437
# SOLVED! Episode 437 Steps: 293 Epsilon 0.2988
# Episode: 438
# SOLVED! Episode 438 Steps: 7 Epsilon 0.2988
# Episode: 439
# Episode: 440
# Episode: 441
# SOLVED! Episode 441 Steps: 2 Epsilon 0.2988
# Episode: 442
# Episode: 443
# SOLVED! Episode 443 Steps: 2 Epsilon 0.2988
# Episode: 444
# SOLVED! Episode 444 Steps: 495 Epsilon 0.2988
# Episode: 445
# Episode: 446
# Episode: 447
# Episode: 448
# SOLVED! Episode 448 Steps: 3 Epsilon 0.2988
# Episode: 449
# Episode: 450
# SOLVED! Episode 450 Steps: 139 Epsilon 0.2988
# Episode: 451
# Episode: 452
# SOLVED! Episode 452 Steps: 197 Epsilon 0.2988
# Episode: 453
# SOLVED! Episode 453 Steps: 45 Epsilon 0.2988
# Episode: 454
